# %%
import pandas as pd

pois = r"error_predictions.parquet"

# Load the POI layer
pois = pd.read_parquet(pois)

print(f"Loaded {len(pois)} POIs")
# Out:
# Loaded 4809 POIs

# %%
pois.head()
# Out:
#     gml_id   volume_m3                            label_en osm_building_type  \
# 72    1043   24.137969               residential buildings              None
# 73    1064   74.749769  Buildings for business or commerce              None
# 74    1065  145.850833  Buildings for business or commerce              None
# 75    1066   90.041737  Buildings for business or commerce              None
# 148   1742  113.700224  Buildings for business or commerce              None
#
#     osm_landuse_class osm_landuse_name gfk_class    ALKIS_Landuse_info  \
# 72        residential             None   Gebäude             residence
# 73         allotments             None   Gebäude             residence
# 74        residential             None   Gebäude  residence;commercial
# 75        residential             None   Gebäude             residence
# 148       residential             None   Gebäude             residence
#
#     osm_names        alkis_address  ...  shop tourism information tags_search  \
# 72       None  Braunschweig, Stadt  ...  None    None        None        None
# 73       None  Braunschweig, Stadt  ...  None    None        None        None
# 74       None  Braunschweig, Stadt  ...  None    None        None        None
# 75       None  Braunschweig, Stadt  ...  None    None        None        None
# 148      None  Braunschweig, Stadt  ...  None    None        None        None
#
#     additional_information website  \
# 72                    None    None
# 73                    None    None
# 74                    None    None
# 75                    None    None
# 148                   None    None
#
#                                               sentence interpreted_type  \
# 72   This row describes one building. Building iden...            error
# 73   This row describes one building. Building iden...            error
# 74   This row describes one building. Building iden...            error
# 75   This row describes one building. Building iden...            error
# 148  This row describes one building. Building iden...            error
#
#     mid_labels bosserhof_class
# 72          []            None
# 73          []            None
# 74          []            None
# 75          []            None
# 148         []            None
#
# [5 rows x 23 columns]

# %%
pois.columns
# Out:
# Index(['gml_id', 'volume_m3', 'label_en', 'osm_building_type',
#        'osm_landuse_class', 'osm_landuse_name', 'gfk_class',
#        'ALKIS_Landuse_info', 'osm_names', 'alkis_address', 'email', 'amenity',
#        'building', 'shop', 'tourism', 'information', 'tags_search',
#        'additional_information', 'website', 'sentence', 'interpreted_type',
#        'mid_labels', 'bosserhof_class'],
#       dtype='object')

# %%
pois = pois.drop(columns=["interpreted_type", "mid_labels", "bosserhof_class"],axis=1)
pois.columns
# Out:
# Index(['gml_id', 'volume_m3', 'label_en', 'osm_building_type',
#        'osm_landuse_class', 'osm_landuse_name', 'gfk_class',
#        'ALKIS_Landuse_info', 'osm_names', 'alkis_address', 'email', 'amenity',
#        'building', 'shop', 'tourism', 'information', 'tags_search',
#        'additional_information', 'website', 'sentence'],
#       dtype='object')

# %%
pois.head()
# Out:
#     gml_id   volume_m3                            label_en osm_building_type  \
# 72    1043   24.137969               residential buildings              None
# 73    1064   74.749769  Buildings for business or commerce              None
# 74    1065  145.850833  Buildings for business or commerce              None
# 75    1066   90.041737  Buildings for business or commerce              None
# 148   1742  113.700224  Buildings for business or commerce              None
#
#     osm_landuse_class osm_landuse_name gfk_class    ALKIS_Landuse_info  \
# 72        residential             None   Gebäude             residence
# 73         allotments             None   Gebäude             residence
# 74        residential             None   Gebäude  residence;commercial
# 75        residential             None   Gebäude             residence
# 148       residential             None   Gebäude             residence
#
#     osm_names        alkis_address email amenity building  shop tourism  \
# 72       None  Braunschweig, Stadt  None    None     None  None    None
# 73       None  Braunschweig, Stadt  None    None     None  None    None
# 74       None  Braunschweig, Stadt  None    None     None  None    None
# 75       None  Braunschweig, Stadt  None    None     None  None    None
# 148      None  Braunschweig, Stadt  None    None     None  None    None
#
#     information tags_search additional_information website  \
# 72         None        None                   None    None
# 73         None        None                   None    None
# 74         None        None                   None    None
# 75         None        None                   None    None
# 148        None        None                   None    None
#
#                                               sentence
# 72   This row describes one building. Building iden...
# 73   This row describes one building. Building iden...
# 74   This row describes one building. Building iden...
# 75   This row describes one building. Building iden...
# 148  This row describes one building. Building iden...

# %%
import json
import time
import re
import requests
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

ENV_PATH = Path(".env")
load_dotenv(dotenv_path=ENV_PATH)

TU_TOKEN = os.getenv("TU_KI_TOOLBOX_TOKEN")

if not TU_TOKEN:
    raise RuntimeError(
        "Missing TU_KI_TOOLBOX_TOKEN."
        "Check Areas-of-interest-POIs/.env"
    )

API_URL = "https://ki-toolbox.tu-braunschweig.de/api/v1/chat/send"
# MODEL = "gpt-5.4-2026-03-05" # chatgpt-5.2
MODEL = "gpt-oss-120b" # open source chatgpt-oss-120b

# %%
SYSTEM_PROMPT = """

Reasoning: high

You are a building activity interpreter and classifier.

Your job is to infer what a place most likely is from a text snippet
and classify it in TWO WAYS:
1) Activity labels (visitor intent / building use based on the label set)
2) A Bosserhof-based building-use class for capacity / volume estimation

IMPORTANT SCOPE RESTRICTION (CRITICAL)
This task is about CLASSIFYING BUILDINGS OR BUILDING-LIKE PLACES ONLY.

- If the described place is NOT a building or not a place people enter/use as a destination,
  you MUST return:
    - "mid_labels": []
    - "bosserhof_class": null
- Do NOT assign any class to pure outdoor objects, infrastructure, or non-living POIs.

INPUT
You will receive ONE text describing a place. It may contain:
- Name, address, city
- OSM tags: amenity=*, shop=*, office=*, leisure=*, tourism=*, building=*, landuse=*
- Free-form keywords (German/English): “Gymnasium”, “Kita”, “Praxis”, “Rathaus”, “Universität”, etc.

────────────────────────────────────
PART A — ACTIVITY LABELS (VISITOR INTENT)
────────────────────────────────────

ALLOWED ACTIVITY LABELS
- work
- university
- school
- childcare
- retail_daily
- retail_non_daily
- leisure
- sports
- errands
- meetup
- lessons
- business

CORE PRINCIPLE
Classify by VISITOR INTENT to a BUILDING:
What do people primarily go there FOR?

MULTI-LABEL RULE (CRITICAL)
A building may support MULTIPLE activities.
Assign ALL labels that clearly apply to the building’s typical use.
Do not force labels that are only weakly implied.

────────────────────────────────────
LABEL DEFINITIONS
────────────────────────────────────

- work

Represents on-site labor, operational activity, or institutional functioning carried out by people inside the building.
Assign this label whenever the building’s normal use depends on people being physically present
to carry out tasks, responsibilities, operations, supervision, coordination, production,
maintenance, administration, instruction, care, or service provision.
The focus of this label is not why visitors come, but whether the building functions as a place
where human work is performed as part of its regular purpose.
A building should receive "work" whenever people are not merely present incidentally,
but are there in an active functional role that helps the building fulfill its purpose.
This includes cases where the same building also serves customers, students, patients, clients,
guests, or other visitors. In such cases, "work" must be added in parallel with the visitor-oriented label(s),
because the activity of workers is part of the building’s core function.
Do not require explicit evidence of employment words or job titles.
Infer "work" from the meaning of the building, the type of activity taking place there,
and the fact that its function normally depends on people performing organized tasks on-site.
Do NOT assign "work" when human presence is only private, incidental, passive, or non-functional,
such as merely being at home, visiting socially, resting, or informally occupying the space
without contributing to the building’s operation or organized purpose.
Core idea: "People are here not only to use the building, but also to make it function."

- university

Represents tertiary/higher-level education activity.
Covers structured learning, teaching, and research at the higher education level
Involves academic instruction, research, and study environments
Distinct from general learning by its institutional and advanced nature
Core idea: “Advanced academic education and research happen here.”

- school

Represents formal compulsory or pre-tertiary education activity.
Covers structured education for children and adolescents
Includes general and vocational schooling
Defined by curriculum-based learning under institutional supervision
Core idea: “Children or teenagers receive structured education here.”

- childcare

Represents supervision and early development care for young children.
Focuses on care, supervision, and early-stage development
Not primarily academic or curriculum-driven (unlike school)
Strong emphasis on custodial and developmental support
Core idea: “Young children are cared for and supervised here.”

- retail_daily

Represents frequent, necessity-driven consumption activity.
Covers acquisition of essential, regularly needed goods
Characterized by high frequency and routine visits
Typically tied to basic living needs
Core idea: “People come here regularly to fulfill essential daily needs.”

- retail_non_daily

Represents infrequent, discretionary consumption activity.
Covers acquisition of non-essential or durable goods
Visits are planned, occasional, or need-based
Often involves comparison, browsing, or larger purchases
Core idea: “People come here occasionally to buy non-essential or long-term goods.”

- leisure

Represents hedonic, relaxation, or enjoyment-oriented activity.
Focuses on free-time use driven by pleasure, comfort, or experience
Includes passive or active enjoyment, but not primarily goal-oriented tasks
Distinguished by non-obligatory participation. People choose to go here for enjoyment, not out of necessity or obligation.
Core idea: “People come here to relax, enjoy, or spend free time.”

- sports

Represents physical activity, exercise, or bodily training.
Focuses on intentional physical exertion or fitness improvement
Can be recreational or structured, but always movement-centered
Distinguished from leisure by physical intensity and purpose
Core idea: “People come here to be physically active or train their body.”

- errands

Represents task-oriented, functional activities needed for daily life management.
Covers practical obligations or maintenance tasks
Typically short, goal-driven visits with a clear outcome
Often involves services, administration, or personal maintenance
Core idea: “People come here to complete necessary tasks or obligations.”

- meetup

Represents social interaction and gathering activity.
Focuses on interpersonal connection and shared presence
Can be informal or organized, but the primary purpose is social exchange
Not necessarily tied to consumption or formal structure
Core idea: “People come here to meet and interact with others.”

- lessons

Represents structured instruction or skill acquisition activity.
Focuses on learning guided by an instructor
Can occur at any level (formal or informal), but always organized and instructional
Distinguished from general education by activity type (learning session), not institution
Core idea: “People come here to learn something through instruction.”

- business

Represents professional or organizational interaction activity (non-routine workplace).
Covers goal-oriented professional interactions, often external-facing
Includes meetings, consulting, administrative dealings, or formal exchanges
Distinct from "work" because it reflects the visitor’s purpose, not employment
Core idea: “People come here for professional or organizational matters.”

IMPORTANT
- Multiple labels are allowed and encouraged when clearly supported
- Prefer precision over over-labeling
- If there is no clear building-related visitor activity, return "mid_labels": []

────────────────────────────────────
PART B — BOSSERHOF BUILDING-USE CLASS
────────────────────────────────────

GOAL
Assign EXACTLY ONE Bosserhof label that matches the categories/subcategories.

This label is for capacity / floor-area / employee-intensity estimation,
so it MUST reflect the dominant FUNCTIONAL USE OF THE BUILDING.

STEP 1 — Subcategory FIRST (preferred)
If you can confidently map the building to ONE of the Bosserhof SUBCATEGORIES listed below,
output that subcategory label (exact string match).

STEP 2 — Headline category fallback (MANDATORY WHEN SUBCATEGORY IS UNCERTAIN)
If the exact subcategory is uncertain but the dominant functional sector is inferable,
you MUST output the corresponding HEADLINE category.
Do not return null when a headline category can reasonably represent the building's dominant use.

STEP 3 — No assignment
If the building does not fit reliably in any headline category OR is not an enterable building,
output bosserhof_class = null.

────────────────────────────────────
ALLOWED BOSSERHOF HEADLINE CATEGORIES AND SUBCATEGORIES
────────────────────────────────────

NEAREST-VALID-CLASS RULE (MANDATORY)

If the building is clearly enterable and supports a recognizable human activity,
you MUST assign the closest Bosserhof class, even if the fit is imperfect.

1) Transport
- no fixed subcategories given; use headline when transport building with staff is clear
Notes: Transport-related buildings with operational staff (depots, terminals)
Exclude: stops/platforms/tracks

2) Yards, depots, storage areas, construction yards
- no fixed subcategories given; use headline when storage/yard with staff is clear
Notes: Storage or operational yards with staff
Exclude: pure storage without staff, open yards without buildings

3) Industrial operations / Production
Subcategories:
- highly productive industries / machine / material or space intensive
- others

4) Crafts and trades
Subcategories:
- craft businesses
- craft courtyards

5) Services
Subcategories:
- normal office
- open-plan office
- business-oriented services
- customer-oriented services
- hotels
- hotels with conference areas
- restaurants / gastronomy
- suppliers for car dealerships
- vehicle / electrical repair
- customer service
- car dealerships

6) Retail
Subcategories:
- wholesale
- retail (small-scale)
- discount stores
- DIY stores
- furniture stores
- hypermarkets / superstores
- shopping centers
- self-service department stores
- department stores
- factory outlet centers

7) Public facilities
Subcategories:
- schools
- universities
- research institutes
- kindergartens
- hospitals
- nursing homes

8) Facilities for culture, leisure and sports
Subcategories:
- entertainment, culture
- large cinemas
- musical theatres
- large discos, fun / leisure pools
- arenas, large events
- theme parks
- fitness / wellness

────────────────────────────────────
OUTPUT FORMAT (STRICT JSON ONLY)
────────────────────────────────────

{
  "interpreted_type": "<plain-English description of what the place most likely is>",
  "mid_labels": ["<zero or more activity labels from the allowed list>"],
  "bosserhof_class": "<one Bosserhof class or null>",
  "reason": "<max 200 words. Explain both classifications, referencing OSM tags, keywords, and any verification used. Explicitly justify the Bosserhof choice or why it is null.>"
}
""".strip()

# %%
# -----------------------------
# MiD labels (STRICT)
# -----------------------------

TARGET_MID_LABELS = {
    "work",
    "university",
    "school",
    "childcare",
    "retail_daily",
    "retail_non_daily",
    "leisure",
    "sports",
    "errands",
    "meetup",
    "lessons",
    "business"
}

# -----------------------------
# JSON extraction
# -----------------------------
def extract_first_json_object(text: str) -> dict:
    """
    Extract the first JSON object from model output.
    """
    m = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found in output.")
    return json.loads(m.group(0))


# -----------------------------
# Validation (PROMPT-ALIGNED)
# -----------------------------
def validate(obj: dict):
    # ---- Required keys ----
    if "interpreted_type" not in obj or not isinstance(obj["interpreted_type"], str):
        raise ValueError("Missing or invalid interpreted_type")

    if "mid_labels" not in obj or not isinstance(obj["mid_labels"], list):
        raise ValueError("mid_labels must be a list")

    if "bosserhof_class" not in obj:
        raise ValueError("Missing bosserhof_class")

    if "reason" not in obj or not isinstance(obj["reason"], str):
        raise ValueError("Missing or invalid reason")

    # ---- Validate MiD labels ----
    for lab in obj["mid_labels"]:
        if lab not in TARGET_MID_LABELS:
            raise ValueError(f"Invalid MiD label: {lab}")

    # ---- Validate Bosserhof class ----
    bc = obj["bosserhof_class"]

    # Allowed: no assignment
    if bc is None or bc == []:
        pass

    # Allowed: any non-empty string (granular OR fallback)
    elif isinstance(bc, str) and bc.strip():
        pass

    else:
        raise ValueError("bosserhof_class must be a non-empty string, [] or None")

    # ---- Consistency rule ----
    # If there is no building-related visitor activity,
    # there must not be a Bosserhof assignment
    if len(obj["mid_labels"]) == 0 and bc not in (None, []):
        raise ValueError(
            "bosserhof_class assigned but mid_labels is empty — inconsistent"
        )

# %%
def call_tu_llm(
    user_input: str = None,
    batch_inputs: list = None,
    max_retries=3,
    backoff_sec=2.0,
    debug=False,
) -> str:

    headers = {
        "Authorization": f"Bearer {TU_TOKEN}",
        "Accept": "application/json",
        "Content-Type": "application/json",
    }

    # -----------------------------
    # Build prompt
    # -----------------------------
    if batch_inputs is not None:
        items = []
        for i, row in enumerate(batch_inputs, start=1):
            gml_id = str(row["gml_id"])
            sentence = "" if row.get("sentence") is None else str(row.get("sentence"))
            items.append(
                f"ITEM {i}\n"
                f"gml_id: {gml_id}\n"
                f"sentence: {sentence}"
            )
        prompt_text = "\n\n".join(items)
    else:
        prompt_text = "" if user_input is None else str(user_input)

    payload = {
        "thread": None,
        "prompt": prompt_text,
        "model": MODEL,
        "customInstructions": SYSTEM_PROMPT,
        "hideCustomInstructions": True,
    }

    last_err = None

    for attempt in range(1, max_retries + 1):
        try:
            r = requests.post(
                API_URL,
                headers=headers,
                json=payload,
                stream=True,
                timeout=120,
            )

            if debug:
                print("STATUS:", r.status_code)
                try:
                    print("REQUEST PAYLOAD:", json.dumps(payload, indent=2)[:4000])
                except Exception:
                    pass

            r.raise_for_status()

            full_text = ""

            for line in r.iter_lines(decode_unicode=True):
                if not line:
                    continue
                try:
                    event = json.loads(line)
                except json.JSONDecodeError:
                    continue

                if event.get("type") == "chunk":
                    full_text += event.get("content", "")
                elif event.get("type") == "done":
                    if "response" in event:
                        full_text = event["response"]
                    break

            return full_text

        except Exception as e:
            last_err = e
            if debug:
                print(f"Attempt {attempt} failed: {e}")
            time.sleep(backoff_sec * attempt)

    raise RuntimeError(f"TU LLM call failed: {last_err}")

# %%
def predict_from_sentence(gml_id=None, sentence=None, batch_rows=None, debug=False):
    # -------------------------------------------------
    # BATCH MODE
    # -------------------------------------------------
    if batch_rows is not None:
        try:
            raw = call_tu_llm(batch_inputs=batch_rows, debug=debug)
            objs = extract_first_json_array(raw)

            if not isinstance(objs, list):
                raise ValueError("Batch output is not a list.")

            if len(objs) != len(batch_rows):
                raise ValueError(
                    f"Batch size mismatch: got {len(objs)} outputs for {len(batch_rows)} inputs."
                )

            results = []
            for row, obj in zip(batch_rows, objs):
                row_gml_id = row["gml_id"]

                try:
                    validate(obj)
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": obj["interpreted_type"],
                        "mid_labels": obj["mid_labels"],
                        "bosserhof_class": obj["bosserhof_class"],
                    })
                except Exception:
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": "error",
                        "mid_labels": [],
                        "bosserhof_class": None,
                    })

            return results

        except Exception:
            return [
                {
                    "gml_id": row["gml_id"],
                    "interpreted_type": "error",
                    "mid_labels": [],
                    "bosserhof_class": None,
                }
                for row in batch_rows
            ]

    # -------------------------------------------------
    # SINGLE MODE
    # -------------------------------------------------
    gml_id = gml_id.item() if hasattr(gml_id, "item") else gml_id
    sentence = "" if sentence is None else str(sentence)

    try:
        raw = call_tu_llm(user_input=sentence, debug=debug)
        obj = extract_first_json_object(raw)
        validate(obj)

        return {
            "gml_id": gml_id,
            "interpreted_type": obj["interpreted_type"],
            "mid_labels": obj["mid_labels"],
            "bosserhof_class": obj["bosserhof_class"],
        }

    except Exception:
        return {
            "gml_id": gml_id,
            "interpreted_type": "error",
            "mid_labels": [],
            "bosserhof_class": None,
        }
    
def extract_first_json_array(text: str):
    import json
    import re

    match = re.search(r"\[\s*{.*}\s*\]", text, flags=re.DOTALL)
    if not match:
        raise ValueError("No JSON array found in model response.")
    return json.loads(match.group(0))

# %%
import time
import math
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd


# ---------------------------------------------------------
# Helper: split list into chunks
# ---------------------------------------------------------
def chunk_list(items, batch_size):
    for i in range(0, len(items), batch_size):
        yield items[i:i + batch_size]


# ---------------------------------------------------------
# RETRY WRAPPER FOR A WHOLE BATCH
# ---------------------------------------------------------
def predict_batch_with_retry(batch_rows, debug=False, max_retries=3, wait_sec=5):
    last_err = None
    batch_ids = [str(r["gml_id"]) for r in batch_rows]

    for attempt in range(1, max_retries + 1):
        try:
            return predict_batch_from_sentences(
                batch_rows=batch_rows,
                debug=debug,
            )
        except Exception as e:
            last_err = e
            print(f"[batch {batch_ids[:3]}... size={len(batch_rows)}] attempt {attempt}/{max_retries} failed: {e}")
            time.sleep(wait_sec)

    raise last_err


# ---------------------------------------------------------
# THIS IS THE MAIN PLACE TO IMPLEMENT REAL API BATCHING
# ---------------------------------------------------------
def predict_batch_from_sentences(batch_rows, debug=False):
    results = []

    prompts = []
    for row in batch_rows:
        gml_id = str(row["gml_id"])
        sentence = row.get("sentence", "")
        prompts.append({
            "gml_id": gml_id,
            "sentence": sentence,
        })

    res = predict_from_sentence(
        batch_rows=prompts,
        debug=debug,
    )

    if not isinstance(res, list):
        raise ValueError("Batch prediction must return a list.")

    if len(res) != len(batch_rows):
        raise ValueError(
            f"Batch output length mismatch: got {len(res)} results for {len(batch_rows)} rows."
        )

    for item in res:
        if isinstance(item, dict):
            results.append(item)
        else:
            results.append({"prediction": item})

    return results


# ---------------------------------------------------------
# APPEND TO PARQUET
# ---------------------------------------------------------
def append_parquet(path, new_rows, deduplicate_on=None):
    if not new_rows:
        return

    new_df = pd.DataFrame(new_rows)

    if path.exists():
        old_df = pd.read_parquet(path)
        merged = pd.concat([old_df, new_df], ignore_index=True)
    else:
        merged = new_df.copy()

    if deduplicate_on is not None:
        merged = merged.drop_duplicates(subset=[deduplicate_on], keep="last")

    merged.to_parquet(path, index=False)


# ---------------------------------------------------------
# MAIN FUNCTION: PARALLEL + BATCHED
# ---------------------------------------------------------
def classify_resume_parallel_batched(
    pois_df: pd.DataFrame,
    checkpoint_path="predictions_checkpoint.parquet",
    error_path="prediction_errors.parquet",
    save_every=200,
    max_workers=5,
    batch_size=10,
    debug=False,
    max_retries=3,
    retry_wait_sec=5,
):
    checkpoint_path = Path(checkpoint_path)
    error_path = Path(error_path)

    df = pois_df.copy().reset_index(drop=True)

    if "gml_id" not in df.columns:
        raise ValueError("pois_df must contain a 'gml_id' column.")

    if "sentence" not in df.columns:
        raise ValueError("pois_df must contain a 'sentence' column.")

    df["gml_id"] = df["gml_id"].astype(str)

    # do not checkpoint geometry
    cols_to_save = [c for c in df.columns if c != "geometry"]

    # ---------------------------
    # Load checkpoint
    # ---------------------------
    if checkpoint_path.exists():
        checkpoint_df = pd.read_parquet(checkpoint_path)
        checkpoint_df["gml_id"] = checkpoint_df["gml_id"].astype(str)
        done_ids = set(checkpoint_df["gml_id"])
        print(f"Loaded checkpoint with {len(done_ids)} completed rows")
    else:
        done_ids = set()
        print("No checkpoint found. Starting from scratch.")

    remaining_df = df[~df["gml_id"].isin(done_ids)].copy()
    print(f"Remaining rows to process: {len(remaining_df)} / {len(df)}")

    records = remaining_df.to_dict("records")
    batches = list(chunk_list(records, batch_size))

    print(f"Total batches to process: {len(batches)} | batch_size={batch_size} | max_workers={max_workers}")

    def batch_worker(batch_rows):
        batch_results = predict_batch_with_retry(
            batch_rows=batch_rows,
            debug=debug,
            max_retries=max_retries,
            wait_sec=retry_wait_sec,
        )

        if not isinstance(batch_results, list):
            raise ValueError("predict_batch_from_sentences() must return a list.")

        if len(batch_results) != len(batch_rows):
            raise ValueError(
                f"Batch output length mismatch: got {len(batch_results)} results for {len(batch_rows)} rows."
            )

        out_rows = []
        for row_dict, res in zip(batch_rows, batch_results):
            out_row = {k: v for k, v in row_dict.items() if k in cols_to_save}

            if isinstance(res, dict):
                out_row.update(res)
            else:
                out_row["prediction"] = res

            out_rows.append(out_row)

        return out_rows

    buffer = []
    error_buffer = []
    processed_now = 0
    completed_batches = 0

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_batch = {
            executor.submit(batch_worker, batch_rows): batch_rows
            for batch_rows in batches
        }

        for future in as_completed(future_to_batch):
            batch_rows = future_to_batch[future]
            batch_ids = [str(r["gml_id"]) for r in batch_rows]

            try:
                out_rows = future.result()
                buffer.extend(out_rows)

                processed_now += len(out_rows)
                completed_batches += 1

                print(
                    f"Processed {processed_now}/{len(remaining_df)} new rows "
                    f"| completed batches {completed_batches}/{len(batches)} "
                    f"| last batch size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]}"
                )

            except Exception as e:
                for row in batch_rows:
                    error_buffer.append({
                        "gml_id": str(row["gml_id"]),
                        "error": str(e),
                    })

                completed_batches += 1
                print(
                    f"Failed batch {completed_batches}/{len(batches)} "
                    f"| size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]} "
                    f"| error={e}"
                )

            # Save regularly from main thread only
            if len(buffer) >= save_every:
                append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
                print(f"Checkpoint saved with {len(buffer)} new rows")
                buffer = []

            if len(error_buffer) >= save_every:
                append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
                print(f"Error log saved with {len(error_buffer)} rows")
                error_buffer = []

    # final flush
    if buffer:
        append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
        print("Final checkpoint saved.")

    if error_buffer:
        append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
        print("Final error log saved.")

    final_df = pd.read_parquet(checkpoint_path)
    final_df["gml_id"] = final_df["gml_id"].astype(str)

    return final_df

# %%
final_df = classify_resume_parallel_batched(
    pois_df=pois,
    checkpoint_path="predictions_checkpoint(error-rows)-1.parquet",
    error_path="prediction_errors(error-rows)-1.parquet",
    save_every=100,
    max_workers=2,
    batch_size=4,
    debug=False,
    max_retries=2,
    retry_wait_sec=3,
)
# Out:
# No checkpoint found. Starting from scratch.
# Remaining rows to process: 4809 / 4809
# Total batches to process: 1203 | batch_size=4 | max_workers=2
# Processed 4/4809 new rows | completed batches 1/1203 | last batch size=4 | gml_id range=1742 -> 1781
# Processed 8/4809 new rows | completed batches 2/1203 | last batch size=4 | gml_id range=1043 -> 1066
# Processed 12/4809 new rows | completed batches 3/1203 | last batch size=4 | gml_id range=1846 -> 1953
# Processed 16/4809 new rows | completed batches 4/1203 | last batch size=4 | gml_id range=2105 -> 2688
# Processed 20/4809 new rows | completed batches 5/1203 | last batch size=4 | gml_id range=2689 -> 2987
# Processed 24/4809 new rows | completed batches 6/1203 | last batch size=4 | gml_id range=3046 -> 3126
# Processed 28/4809 new rows | completed batches 7/1203 | last batch size=4 | gml_id range=3127 -> 4982
# Processed 32/4809 new rows | completed batches 8/1203 | last batch size=4 | gml_id range=4983 -> 5082
# Processed 36/4809 new rows | completed batches 9/1203 | last batch size=4 | gml_id range=5083 -> 5596
# Processed 40/4809 new rows | completed batches 10/1203 | last batch size=4 | gml_id range=5597 -> 6264
# Processed 44/4809 new rows | completed batches 11/1203 | last batch size=4 | gml_id range=6265 -> 6324
# Processed 48/4809 new rows | completed batches 12/1203 | last batch size=4 | gml_id range=6741 -> 6752
# Processed 52/4809 new rows | completed batches 13/1203 | last batch size=4 | gml_id range=6325 -> 6740
# Processed 56/4809 new rows | completed batches 14/1203 | last batch size=4 | gml_id range=8585 -> 9523
# Processed 60/4809 new rows | completed batches 15/1203 | last batch size=4 | gml_id range=6753 -> 8584
# Processed 64/4809 new rows | completed batches 16/1203 | last batch size=4 | gml_id range=9556 -> 10525
# Processed 68/4809 new rows | completed batches 17/1203 | last batch size=4 | gml_id range=10526 -> 10529
# Processed 72/4809 new rows | completed batches 18/1203 | last batch size=4 | gml_id range=11875 -> 11974
# Processed 76/4809 new rows | completed batches 19/1203 | last batch size=4 | gml_id range=10530 -> 11874
# Processed 80/4809 new rows | completed batches 20/1203 | last batch size=4 | gml_id range=13420 -> 13423
# Processed 84/4809 new rows | completed batches 21/1203 | last batch size=4 | gml_id range=11975 -> 13411
# Processed 88/4809 new rows | completed batches 22/1203 | last batch size=4 | gml_id range=13476 -> 13713
# Processed 92/4809 new rows | completed batches 23/1203 | last batch size=4 | gml_id range=14364 -> 14367
# Processed 96/4809 new rows | completed batches 24/1203 | last batch size=4 | gml_id range=14599 -> 14848
# Processed 100/4809 new rows | completed batches 25/1203 | last batch size=4 | gml_id range=14548 -> 14551
# Checkpoint saved with 100 new rows
# Processed 104/4809 new rows | completed batches 26/1203 | last batch size=4 | gml_id range=14849 -> 15263
# Processed 108/4809 new rows | completed batches 27/1203 | last batch size=4 | gml_id range=15296 -> 15475
# Processed 112/4809 new rows | completed batches 28/1203 | last batch size=4 | gml_id range=15924 -> 16558
# Processed 116/4809 new rows | completed batches 29/1203 | last batch size=4 | gml_id range=15692 -> 15919
# Processed 120/4809 new rows | completed batches 30/1203 | last batch size=4 | gml_id range=16559 -> 17189
# Processed 124/4809 new rows | completed batches 31/1203 | last batch size=4 | gml_id range=17190 -> 19043
# Processed 128/4809 new rows | completed batches 32/1203 | last batch size=4 | gml_id range=19084 -> 19087
# Processed 132/4809 new rows | completed batches 33/1203 | last batch size=4 | gml_id range=19108 -> 19194
# Processed 136/4809 new rows | completed batches 34/1203 | last batch size=4 | gml_id range=19195 -> 19614
# Processed 140/4809 new rows | completed batches 35/1203 | last batch size=4 | gml_id range=19958 -> 20472
# Processed 144/4809 new rows | completed batches 36/1203 | last batch size=4 | gml_id range=19615 -> 19957
# Processed 148/4809 new rows | completed batches 37/1203 | last batch size=4 | gml_id range=20473 -> 20400
# Processed 152/4809 new rows | completed batches 38/1203 | last batch size=4 | gml_id range=20732 -> 20735
# Processed 156/4809 new rows | completed batches 39/1203 | last batch size=4 | gml_id range=21156 -> 21767
# Processed 160/4809 new rows | completed batches 40/1203 | last batch size=4 | gml_id range=21768 -> 21811
# Processed 164/4809 new rows | completed batches 41/1203 | last batch size=4 | gml_id range=21904 -> 22295
# Processed 168/4809 new rows | completed batches 42/1203 | last batch size=4 | gml_id range=22408 -> 22411
# Processed 172/4809 new rows | completed batches 43/1203 | last batch size=4 | gml_id range=22424 -> 22455
# Processed 176/4809 new rows | completed batches 44/1203 | last batch size=4 | gml_id range=23329 -> 23336
# Processed 180/4809 new rows | completed batches 45/1203 | last batch size=4 | gml_id range=22528 -> 23328
# Processed 184/4809 new rows | completed batches 46/1203 | last batch size=4 | gml_id range=23337 -> 23587
# Processed 188/4809 new rows | completed batches 47/1203 | last batch size=4 | gml_id range=23604 -> 24520
# Processed 192/4809 new rows | completed batches 48/1203 | last batch size=4 | gml_id range=25750 -> 26054
# Processed 196/4809 new rows | completed batches 49/1203 | last batch size=4 | gml_id range=24521 -> 25749
# Processed 200/4809 new rows | completed batches 50/1203 | last batch size=4 | gml_id range=26055 -> 26190
# Checkpoint saved with 100 new rows
# Processed 204/4809 new rows | completed batches 51/1203 | last batch size=4 | gml_id range=26322 -> 27691
# Processed 208/4809 new rows | completed batches 52/1203 | last batch size=4 | gml_id range=26191 -> 26321
# Processed 212/4809 new rows | completed batches 53/1203 | last batch size=4 | gml_id range=27868 -> 28153
# Processed 216/4809 new rows | completed batches 54/1203 | last batch size=4 | gml_id range=28154 -> 28097
# Processed 220/4809 new rows | completed batches 55/1203 | last batch size=4 | gml_id range=28098 -> 29104
# Processed 224/4809 new rows | completed batches 56/1203 | last batch size=4 | gml_id range=29105 -> 29325
# Processed 228/4809 new rows | completed batches 57/1203 | last batch size=4 | gml_id range=29326 -> 30060
# Processed 232/4809 new rows | completed batches 58/1203 | last batch size=4 | gml_id range=30061 -> 30158
# Processed 236/4809 new rows | completed batches 59/1203 | last batch size=4 | gml_id range=30250 -> 30642
# Processed 240/4809 new rows | completed batches 60/1203 | last batch size=4 | gml_id range=30159 -> 30249
# Processed 244/4809 new rows | completed batches 61/1203 | last batch size=4 | gml_id range=30645 -> 31412
# Processed 248/4809 new rows | completed batches 62/1203 | last batch size=4 | gml_id range=31413 -> 31512
# Processed 252/4809 new rows | completed batches 63/1203 | last batch size=4 | gml_id range=31513 -> 31956
# Processed 256/4809 new rows | completed batches 64/1203 | last batch size=4 | gml_id range=31957 -> 32353
# Processed 260/4809 new rows | completed batches 65/1203 | last batch size=4 | gml_id range=32354 -> 32397
# Processed 264/4809 new rows | completed batches 66/1203 | last batch size=4 | gml_id range=32497 -> 35268
# Processed 268/4809 new rows | completed batches 67/1203 | last batch size=4 | gml_id range=32398 -> 32496
# Processed 272/4809 new rows | completed batches 68/1203 | last batch size=4 | gml_id range=35467 -> 35478
# Processed 276/4809 new rows | completed batches 69/1203 | last batch size=4 | gml_id range=35436 -> 35557
# Processed 280/4809 new rows | completed batches 70/1203 | last batch size=4 | gml_id range=35558 -> 35601
# Processed 284/4809 new rows | completed batches 71/1203 | last batch size=4 | gml_id range=35602 -> 35629
# Processed 288/4809 new rows | completed batches 72/1203 | last batch size=4 | gml_id range=35630 -> 35909
# Processed 292/4809 new rows | completed batches 73/1203 | last batch size=4 | gml_id range=35910 -> 36329
# Processed 296/4809 new rows | completed batches 74/1203 | last batch size=4 | gml_id range=36330 -> 37106
# Processed 300/4809 new rows | completed batches 75/1203 | last batch size=4 | gml_id range=37107 -> 37642
# Checkpoint saved with 100 new rows
# Processed 304/4809 new rows | completed batches 76/1203 | last batch size=4 | gml_id range=38947 -> 40006
# Processed 308/4809 new rows | completed batches 77/1203 | last batch size=4 | gml_id range=37643 -> 38620
# Processed 312/4809 new rows | completed batches 78/1203 | last batch size=4 | gml_id range=40031 -> 41720
# Processed 316/4809 new rows | completed batches 79/1203 | last batch size=4 | gml_id range=40007 -> 40030
# Processed 320/4809 new rows | completed batches 80/1203 | last batch size=4 | gml_id range=41721 -> 42987
# Processed 324/4809 new rows | completed batches 81/1203 | last batch size=4 | gml_id range=43092 -> 44128
# Processed 328/4809 new rows | completed batches 82/1203 | last batch size=4 | gml_id range=44129 -> 44649
# Processed 332/4809 new rows | completed batches 83/1203 | last batch size=4 | gml_id range=44650 -> 44937
# Processed 336/4809 new rows | completed batches 84/1203 | last batch size=4 | gml_id range=44938 -> 45049
# Processed 340/4809 new rows | completed batches 85/1203 | last batch size=4 | gml_id range=45050 -> 45105
# Processed 344/4809 new rows | completed batches 86/1203 | last batch size=4 | gml_id range=45818 -> 45821
# Processed 348/4809 new rows | completed batches 87/1203 | last batch size=4 | gml_id range=45106 -> 45817
# Processed 352/4809 new rows | completed batches 88/1203 | last batch size=4 | gml_id range=46149 -> 46334
# Processed 356/4809 new rows | completed batches 89/1203 | last batch size=4 | gml_id range=46335 -> 47081
# Processed 360/4809 new rows | completed batches 90/1203 | last batch size=4 | gml_id range=47082 -> 47706
# Processed 364/4809 new rows | completed batches 91/1203 | last batch size=4 | gml_id range=47707 -> 48202
# Processed 368/4809 new rows | completed batches 92/1203 | last batch size=4 | gml_id range=48203 -> 48330
# Processed 372/4809 new rows | completed batches 93/1203 | last batch size=4 | gml_id range=48331 -> 49535
# Processed 376/4809 new rows | completed batches 94/1203 | last batch size=4 | gml_id range=49580 -> 49787
# Processed 380/4809 new rows | completed batches 95/1203 | last batch size=4 | gml_id range=49812 -> 50733
# Processed 384/4809 new rows | completed batches 96/1203 | last batch size=4 | gml_id range=50734 -> 51193
# Processed 388/4809 new rows | completed batches 97/1203 | last batch size=4 | gml_id range=51306 -> 51403
# Processed 392/4809 new rows | completed batches 98/1203 | last batch size=4 | gml_id range=51194 -> 51305
# Processed 396/4809 new rows | completed batches 99/1203 | last batch size=4 | gml_id range=51628 -> 51646
# Processed 400/4809 new rows | completed batches 100/1203 | last batch size=4 | gml_id range=51420 -> 51603
# Checkpoint saved with 100 new rows
# Processed 404/4809 new rows | completed batches 101/1203 | last batch size=4 | gml_id range=51647 -> 51631
# Processed 408/4809 new rows | completed batches 102/1203 | last batch size=4 | gml_id range=51643 -> 51998
# Processed 412/4809 new rows | completed batches 103/1203 | last batch size=4 | gml_id range=51999 -> 52354
# Processed 416/4809 new rows | completed batches 104/1203 | last batch size=4 | gml_id range=52355 -> 52478
# Processed 420/4809 new rows | completed batches 105/1203 | last batch size=4 | gml_id range=52479 -> 52784
# Processed 424/4809 new rows | completed batches 106/1203 | last batch size=4 | gml_id range=52785 -> 53064
# Processed 428/4809 new rows | completed batches 107/1203 | last batch size=4 | gml_id range=53065 -> 53264
# Processed 432/4809 new rows | completed batches 108/1203 | last batch size=4 | gml_id range=53265 -> 53682
# Processed 436/4809 new rows | completed batches 109/1203 | last batch size=4 | gml_id range=53683 -> 56133
