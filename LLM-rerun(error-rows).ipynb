# %%
import pandas as pd

pois = r"error_predictions-4.parquet"

# Load the POI layer
pois = pd.read_parquet(pois)

print(f"Loaded {len(pois)} POIs")

# import geopandas as gpd
# from pathlib import Path

# pois_path = Path("final_predictions_with_geometry_rerun-single-prediction-row_filtered.gpkg")   # change filename if needed

# # Load GPKG layer
# pois = gpd.read_file(pois_path)

# print(f"Loaded {len(pois)} rows")
# Out:
# Loaded 2949 POIs

# %%
pois.head()
# Out:
#     index gml_id   volume_m3                            label_en  \
# 16   70.0   1202   46.739183  Buildings for business or commerce
# 17   71.0   1203  267.323392  Buildings for business or commerce
# 18   72.0   1204   92.083069  Buildings for business or commerce
# 19   73.0   1205   90.124355  Buildings for business or commerce
# 40  341.0   4841   43.316556  Buildings for business or commerce
#
#    osm_building_type osm_landuse_class osm_landuse_name gfk_class  \
# 16              None       residential             None   Gebäude
# 17              None       residential             None   Gebäude
# 18              None       residential             None   Gebäude
# 19              None       residential             None   Gebäude
# 40              None       residential             None   Gebäude
#
#    ALKIS_Landuse_info osm_names  ...  shop tourism information tags_search  \
# 16          residence      None  ...  None    None        None        None
# 17          residence      None  ...  None    None        None        None
# 18          residence      None  ...  None    None        None        None
# 19          residence      None  ...  None    None        None        None
# 40          residence      None  ...  None    None        None        None
#
#    additional_information website  \
# 16                   None    None
# 17                   None    None
# 18                   None    None
# 19                   None    None
# 40                   None    None
#
#                                              sentence interpreted_type  \
# 16  general_building_context: building_label=Build...            error
# 17  general_building_context: building_label=Build...            error
# 18  general_building_context: building_label=Build...            error
# 19  general_building_context: building_label=Build...            error
# 40  general_building_context: building_label=Build...            error
#
#    mid_labels bosserhof_class
# 16         []            None
# 17         []            None
# 18         []            None
# 19         []            None
# 40         []            None
#
# [5 rows x 24 columns]

# %%
pois.columns
# Out:
# Index(['index', 'gml_id', 'volume_m3', 'label_en', 'osm_building_type',
#        'osm_landuse_class', 'osm_landuse_name', 'gfk_class',
#        'ALKIS_Landuse_info', 'osm_names', 'alkis_address', 'email', 'amenity',
#        'building', 'shop', 'tourism', 'information', 'tags_search',
#        'additional_information', 'website', 'sentence', 'interpreted_type',
#        'mid_labels', 'bosserhof_class'],
#       dtype='object')

# %%
pois = pois.drop(columns=["interpreted_type", "mid_labels", "bosserhof_class"],axis=1)
pois.columns

# pois = pois.drop(columns=["geometry"],axis=1)
# pois.columns
# Out:
# Index(['index', 'gml_id', 'volume_m3', 'label_en', 'osm_building_type',
#        'osm_landuse_class', 'osm_landuse_name', 'gfk_class',
#        'ALKIS_Landuse_info', 'osm_names', 'alkis_address', 'email', 'amenity',
#        'building', 'shop', 'tourism', 'information', 'tags_search',
#        'additional_information', 'website', 'sentence'],
#       dtype='object')

# %%
pois.head()
# Out:
#     index gml_id   volume_m3                            label_en  \
# 16   70.0   1202   46.739183  Buildings for business or commerce
# 17   71.0   1203  267.323392  Buildings for business or commerce
# 18   72.0   1204   92.083069  Buildings for business or commerce
# 19   73.0   1205   90.124355  Buildings for business or commerce
# 40  341.0   4841   43.316556  Buildings for business or commerce
#
#    osm_building_type osm_landuse_class osm_landuse_name gfk_class  \
# 16              None       residential             None   Gebäude
# 17              None       residential             None   Gebäude
# 18              None       residential             None   Gebäude
# 19              None       residential             None   Gebäude
# 40              None       residential             None   Gebäude
#
#    ALKIS_Landuse_info osm_names  ... email amenity building  shop tourism  \
# 16          residence      None  ...  None    None     None  None    None
# 17          residence      None  ...  None    None     None  None    None
# 18          residence      None  ...  None    None     None  None    None
# 19          residence      None  ...  None    None     None  None    None
# 40          residence      None  ...  None    None     None  None    None
#
#    information tags_search additional_information website  \
# 16        None        None                   None    None
# 17        None        None                   None    None
# 18        None        None                   None    None
# 19        None        None                   None    None
# 40        None        None                   None    None
#
#                                              sentence
# 16  general_building_context: building_label=Build...
# 17  general_building_context: building_label=Build...
# 18  general_building_context: building_label=Build...
# 19  general_building_context: building_label=Build...
# 40  general_building_context: building_label=Build...
#
# [5 rows x 21 columns]

# %%
import json
import time
import re
import requests
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

ENV_PATH = Path(".env")
load_dotenv(dotenv_path=ENV_PATH)

TU_TOKEN = os.getenv("TU_KI_TOOLBOX_TOKEN")

if not TU_TOKEN:
    raise RuntimeError(
        "Missing TU_KI_TOOLBOX_TOKEN."
        "Check Areas-of-interest-POIs/.env"
    )

API_URL = "https://ki-toolbox.tu-braunschweig.de/api/v1/chat/send"
# MODEL = "gpt-5.4-2026-03-05" # chatgpt-5.2
MODEL = "gpt-oss-120b" # open source chatgpt-oss-120b

# %%
SYSTEM_PROMPT = """
You are a building activity interpreter and classifier.

Your task is to classify BUILDINGS using structured input divided into TWO PARTS:

1) precise_known_info → high-confidence OSM-derived signals such as names, amenity, shop, office, tourism, healthcare, leisure, etc.
2) general_building_context → broader contextual signals such as ALKIS landuse, OSM building type, OSM landuse, auxiliary tags, and other building-context information.

You must produce TWO outputs:
1) Activity labels (mid_labels) → what activities take place inside the building
2) Bosserhof class → the dominant functional building-use class for capacity / volume estimation

────────────────────────────────────
CRITICAL SCOPE RULE
────────────────────────────────────

Only classify ENTERABLE BUILDINGS or building-like places people actually use as destinations.

If the described place is not a building, not enterable, or only an outdoor / infrastructure / passive object:
- "mid_labels": []
- "bosserhof_class": null

────────────────────────────────────
INPUT STRUCTURE AND EVIDENCE PRIORITY
────────────────────────────────────

precise_known_info:
- Primary source for mid_labels
- Usually contains reliable OSM-derived evidence
- May contain several names, shops, amenities, offices, healthcare uses, leisure uses, tourism uses, or other POI functions
- Treat multiple entries as possible multiple activities inside the same building

general_building_context:
- Primary source for Bosserhof classification
- Broader but less precise
- May include ALKIS building/land-use information, OSM building type, tags (General Information About pois), or auxiliary contextual fields
- Use it as fallback for mid_labels only when precise_known_info is weak, empty, or incomplete

────────────────────────────────────
PART A — ACTIVITY LABELS (VISITOR INTENT)
────────────────────────────────────

ALLOWED ACTIVITY LABELS
- work
- university
- school
- childcare
- retail_daily
- retail_non_daily
- leisure
- sports
- errands
- meetup
- lessons
- business

GOAL:
Identify ALL clearly supported activities taking place INSIDE the building.

MANDATORY PROCEDURE:
1) First extract every distinct function from precise_known_info.
   Each name, amenity, shop, office, healthcare, leisure, tourism, craft, service, or other POI-like entry can represent a separate function.
2) Map each extracted function independently to one or more activity labels.
3) Aggregate labels across all functions.
4) Remove duplicates.
5) Do not stop after the first detected function.

If precise_known_info is missing or very weak, use general_building_context to infer likely building activity, but be more conservative.

MULTI-ACTIVITY RULE (VERY IMPORTANT):
- A building may contain MANY activities (e.g., mall, mixed-use building)
- You MUST extract ALL clearly supported activities
- Do NOT collapse multiple activities into one
- Do NOT stop at the first match

Think of the building as a container of activities:
→ Identify EACH distinct function mentioned
→ Map EACH to a label

────────────────────────────────────
LABEL DEFINITIONS
────────────────────────────────────

- work

Represents on-site labor, operational activity, or institutional functioning carried out by people inside the building.
Assign this label whenever the building’s normal use depends on people being physically present
to carry out tasks, responsibilities, operations, supervision, coordination, production,
maintenance, administration, instruction, care, or service provision.
The focus of this label is not why visitors come, but whether the building functions as a place
where human work is performed as part of its regular purpose.
A building should receive "work" whenever people are not merely present incidentally,
but are there in an active functional role that helps the building fulfill its purpose.
This includes cases where the same building also serves customers, students, patients, clients,
guests, or other visitors. In such cases, "work" must be added in parallel with the visitor-oriented label(s),
because the activity of workers is part of the building’s core function.
Core idea: "People are here not only to use the building, but also to make it function."

- university

Represents tertiary/higher-level education activity.
Covers structured learning, teaching, and research at the higher education level
Involves academic instruction, research, and study environments
Distinct from general learning by its institutional and advanced nature
Core idea: “Advanced academic education and research happen here.”

- school

Represents formal compulsory or pre-tertiary education activity.
Covers structured education for children and adolescents
Includes general and vocational schooling
Defined by curriculum-based learning under institutional supervision
Core idea: “Children or teenagers receive structured education here.”

- childcare

Represents supervision and early development care for young children.
Focuses on care, supervision, and early-stage development
Not primarily academic or curriculum-driven (unlike school)
Strong emphasis on custodial and developmental support
Core idea: “Young children are cared for and supervised here.”

- retail_daily

Represents frequent, necessity-driven consumption activity.
Covers acquisition of essential, regularly needed goods
Characterized by high frequency and routine visits
Typically tied to basic living needs
Core idea: “People come here regularly to fulfill essential daily needs.”

- retail_non_daily

Represents infrequent, discretionary consumption activity.
Covers acquisition of non-essential or durable goods
Visits are planned, occasional, or need-based
Often involves comparison, browsing, or larger purchases
Core idea: “People come here occasionally to buy non-essential or long-term goods.”

- leisure

Represents hedonic, relaxation, or enjoyment-oriented activity.
Focuses on free-time use driven by pleasure, comfort, or experience
Includes passive or active enjoyment, but not primarily goal-oriented tasks
Distinguished by non-obligatory participation. People choose to go here for enjoyment, not out of necessity or obligation.
Core idea: “People come here to relax, enjoy, or spend free time.”

- sports

Represents physical activity, exercise, or bodily training.
Focuses on intentional physical exertion or fitness improvement
Can be recreational or structured, but always movement-centered
Distinguished from leisure by physical intensity and purpose
Core idea: “People come here to be physically active or train their body.”

- errands

Represents task-oriented, functional activities needed for daily life management.
Covers practical obligations or maintenance tasks
Typically short, goal-driven visits with a clear outcome
Often involves services, administration, or personal maintenance
Core idea: “People come here to complete necessary tasks or obligations.”

- meetup

Represents social interaction and gathering activity.
Focuses on interpersonal connection and shared presence
Can be informal or organized, but the primary purpose is social exchange
Not necessarily tied to consumption or formal structure
Core idea: “People come here to meet and interact with others.”

- lessons

Represents structured instruction or skill acquisition activity.
Focuses on learning guided by an instructor
Can occur at any level (formal or informal), but always organized and instructional
Distinguished from general education by activity type (learning session), not institution
Core idea: “People come here to learn something through instruction.”

- business

Represents professional or organizational interaction activity (non-routine workplace).
Covers goal-oriented professional interactions, often external-facing
Includes meetings, consulting, administrative dealings, or formal exchanges
Distinct from "work" because it reflects the visitor’s purpose, not employment
Core idea: “People come here for professional or organizational matters.”

────────────────────────────────────
PART B — BOSSERHOF BUILDING-USE CLASS
────────────────────────────────────

GOAL
Assign EXACTLY ONE Bosserhof label that matches the categories/subcategories.

KEY PRINCIPLE:
Bosserhof is NOT about activities — it is about the BUILDING TYPE.

SOURCE PRIORITY FOR BOSSERHOF:
1) general_building_context is the primary source
2) precise_known_info supports or refines the choice
3) mid_labels can help interpret use, but must not override stronger building-type evidence

DOMINANCE HEURISTIC:
Choose the dominant function using:
1) explicit building type or ALKIS function
2) landuse / area context
3) scale indicators such as mall, shopping centre, school complex, office building, industrial hall, hospital, hotel
4) repeated / majority functions among multiple entries
5) if still unclear, choose the closest headline class rather than null

MULTI-TENANT BUILDINGS:
- Extract ALL activities (mid_labels)
- Assign ONE dominant Bosserhof class

STEP 1 — Subcategory FIRST (preferred)
If you can confidently map the building to ONE of the Bosserhof SUBCATEGORIES listed below,
output that subcategory label (exact string match).

STEP 2 — Headline category fallback (MANDATORY WHEN SUBCATEGORY IS UNCERTAIN)
If the exact subcategory is uncertain but the dominant functional sector is inferable,
you MUST output the corresponding HEADLINE category.
Do not return null when a headline category can reasonably represent the building's dominant use.

STEP 3 — No assignment
If the building does not fit reliably in any headline category OR is not an enterable building,
output bosserhof_class = null.

────────────────────────────────────
ALLOWED BOSSERHOF HEADLINE CATEGORIES AND SUBCATEGORIES
────────────────────────────────────

NEAREST-VALID-CLASS RULE (MANDATORY)

If the building is clearly enterable and supports a recognizable human activity,
you MUST assign the closest Bosserhof class, even if the fit is imperfect.

1) Transport
- no fixed subcategories given; use headline when transport building with staff is clear
Notes: Transport-related buildings with operational staff (depots, terminals)
Exclude: stops/platforms/tracks

2) Yards, depots, storage areas, construction yards
- no fixed subcategories given; use headline when storage/yard with staff is clear
Notes: Storage or operational yards with staff
Exclude: pure storage without staff, open yards without buildings

3) Industrial operations / Production
Subcategories:
- highly productive industries / machine / material or space intensive
- others

4) Crafts and trades
Subcategories:
- craft businesses
- craft courtyards

5) Services
Subcategories:
- normal office
- open-plan office
- business-oriented services
- customer-oriented services
- hotels
- hotels with conference areas
- restaurants / gastronomy
- suppliers for car dealerships
- vehicle / electrical repair
- customer service
- car dealerships

6) Retail
Subcategories:
- wholesale
- retail (small-scale)
- discount stores
- DIY stores
- furniture stores
- hypermarkets / superstores
- shopping centers
- self-service department stores
- department stores
- factory outlet centers

7) Public facilities
Subcategories:
- schools
- universities
- research institutes
- kindergartens
- hospitals
- nursing homes

8) Facilities for culture, leisure and sports
Subcategories:
- entertainment, culture
- large cinemas
- musical theatres
- large discos, fun / leisure pools
- arenas, large events
- theme parks
- fitness / wellness

────────────────────────────────────
OUTPUT FORMAT (STRICT JSON ONLY)
────────────────────────────────────

{
  "interpreted_type": "<plain-English description of what the place most likely is>",
  "mid_labels": ["<zero or more activity labels from the allowed list>"],
  "bosserhof_class": "<one Bosserhof class or null>"}
""".strip()

# %%
# -----------------------------
# MiD labels (STRICT)
# -----------------------------

TARGET_MID_LABELS = {
    "work",
    "university",
    "school",
    "childcare",
    "retail_daily",
    "retail_non_daily",
    "leisure",
    "sports",
    "errands",
    "meetup",
    "lessons",
    "business"
}

# -----------------------------
# JSON extraction
# -----------------------------
def extract_first_json_object(text: str) -> dict:
    """
    Extract the first JSON object from model output.
    """
    m = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found in output.")
    return json.loads(m.group(0))


# -----------------------------
# Validation (PROMPT-ALIGNED)
# -----------------------------
def validate(obj: dict):
    if "interpreted_type" not in obj or not isinstance(obj["interpreted_type"], str):
        raise ValueError("Missing or invalid interpreted_type")

    if "mid_labels" not in obj or not isinstance(obj["mid_labels"], list):
        raise ValueError("mid_labels must be a list")

    if "bosserhof_class" not in obj:
        raise ValueError("Missing bosserhof_class")

    for lab in obj["mid_labels"]:
        if lab not in TARGET_MID_LABELS:
            raise ValueError(f"Invalid MiD label: {lab}")

    bc = obj["bosserhof_class"]

    # null is valid
    if bc is None:
        return

    # string class is valid
    if isinstance(bc, str) and bc.strip():
        return

    raise ValueError("bosserhof_class must be a non-empty string or None")

# %%
def call_tu_llm(
    user_input: str = None,
    batch_inputs: list = None,
    max_retries=3,
    backoff_sec=2.0,
    debug=False,
) -> str:

    headers = {
        "Authorization": f"Bearer {TU_TOKEN}",
        "Accept": "application/json",
        "Content-Type": "application/json",
    }

    # -----------------------------
    # Build prompt
    # -----------------------------
    if batch_inputs is not None:
        items = []
        for i, row in enumerate(batch_inputs, start=1):
            gml_id = str(row["gml_id"])
            sentence = "" if row.get("sentence") is None else str(row.get("sentence"))
            items.append(
                f"ITEM {i}\n"
                f"gml_id: {gml_id}\n"
                f"sentence: {sentence}"
            )
        prompt_text = "\n\n".join(items)
    else:
        prompt_text = "" if user_input is None else str(user_input)

    payload = {
        "thread": None,
        "prompt": prompt_text,
        "model": MODEL,
        "customInstructions": SYSTEM_PROMPT,
        "hideCustomInstructions": True,
    }

    last_err = None

    for attempt in range(1, max_retries + 1):
        try:
            r = requests.post(
                API_URL,
                headers=headers,
                json=payload,
                stream=True,
                timeout=120,
            )

            if debug:
                print("STATUS:", r.status_code)
                try:
                    print("REQUEST PAYLOAD:", json.dumps(payload, indent=2)[:4000])
                except Exception:
                    pass

            r.raise_for_status()

            full_text = ""

            for line in r.iter_lines(decode_unicode=True):
                if not line:
                    continue
                try:
                    event = json.loads(line)
                except json.JSONDecodeError:
                    continue

                if event.get("type") == "chunk":
                    full_text += event.get("content", "")
                elif event.get("type") == "done":
                    if "response" in event:
                        full_text = event["response"]
                    break

            return full_text

        except Exception as e:
            last_err = e
            if debug:
                print(f"Attempt {attempt} failed: {e}")
            time.sleep(backoff_sec * attempt)

    raise RuntimeError(f"TU LLM call failed: {last_err}")

# %%
def predict_from_sentence(gml_id=None, sentence=None, batch_rows=None, debug=False):
    # -------------------------------------------------
    # BATCH MODE
    # -------------------------------------------------
    if batch_rows is not None:
        try:
            raw = call_tu_llm(batch_inputs=batch_rows, debug=debug)
            objs = extract_first_json_array(raw)

            if not isinstance(objs, list):
                raise ValueError("Batch output is not a list.")

            if len(objs) != len(batch_rows):
                raise ValueError(
                    f"Batch size mismatch: got {len(objs)} outputs for {len(batch_rows)} inputs."
                )

            results = []
            for row, obj in zip(batch_rows, objs):
                row_gml_id = row["gml_id"]

                try:
                    validate(obj)
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": obj["interpreted_type"],
                        "mid_labels": obj["mid_labels"],
                        "bosserhof_class": obj["bosserhof_class"],
                    })
                except Exception:
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": "error",
                        "mid_labels": [],
                        "bosserhof_class": None,
                    })

            return results

        except Exception:
            return [
                {
                    "gml_id": row["gml_id"],
                    "interpreted_type": "error",
                    "mid_labels": [],
                    "bosserhof_class": None,
                }
                for row in batch_rows
            ]

    # -------------------------------------------------
    # SINGLE MODE
    # -------------------------------------------------
    gml_id = gml_id.item() if hasattr(gml_id, "item") else gml_id
    sentence = "" if sentence is None else str(sentence)

    try:
        raw = call_tu_llm(user_input=sentence, debug=debug)
        obj = extract_first_json_object(raw)
        validate(obj)

        return {
            "gml_id": gml_id,
            "interpreted_type": obj["interpreted_type"],
            "mid_labels": obj["mid_labels"],
            "bosserhof_class": obj["bosserhof_class"],
        }

    except Exception:
        return {
            "gml_id": gml_id,
            "interpreted_type": "error",
            "mid_labels": [],
            "bosserhof_class": None,
        }
    
def extract_first_json_array(text: str):
    import json
    import re

    match = re.search(r"\[\s*{.*}\s*\]", text, flags=re.DOTALL)
    if not match:
        raise ValueError("No JSON array found in model response.")
    return json.loads(match.group(0))

# %%
import time
import math
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd


# ---------------------------------------------------------
# Helper: split list into chunks
# ---------------------------------------------------------
def chunk_list(items, batch_size):
    for i in range(0, len(items), batch_size):
        yield items[i:i + batch_size]


# ---------------------------------------------------------
# RETRY WRAPPER FOR A WHOLE BATCH
# ---------------------------------------------------------
def predict_batch_with_retry(batch_rows, debug=False, max_retries=3, wait_sec=5):
    last_err = None
    batch_ids = [str(r["gml_id"]) for r in batch_rows]

    for attempt in range(1, max_retries + 1):
        try:
            return predict_batch_from_sentences(
                batch_rows=batch_rows,
                debug=debug,
            )
        except Exception as e:
            last_err = e
            print(f"[batch {batch_ids[:3]}... size={len(batch_rows)}] attempt {attempt}/{max_retries} failed: {e}")
            time.sleep(wait_sec)

    raise last_err


# ---------------------------------------------------------
# THIS IS THE MAIN PLACE TO IMPLEMENT REAL API BATCHING
# ---------------------------------------------------------
def predict_batch_from_sentences(batch_rows, debug=False):
    results = []

    prompts = []
    for row in batch_rows:
        gml_id = str(row["gml_id"])
        sentence = row.get("sentence", "")
        prompts.append({
            "gml_id": gml_id,
            "sentence": sentence,
        })

    res = predict_from_sentence(
        batch_rows=prompts,
        debug=debug,
    )

    if not isinstance(res, list):
        raise ValueError("Batch prediction must return a list.")

    if len(res) != len(batch_rows):
        raise ValueError(
            f"Batch output length mismatch: got {len(res)} results for {len(batch_rows)} rows."
        )

    for item in res:
        if isinstance(item, dict):
            results.append(item)
        else:
            results.append({"prediction": item})

    return results


# ---------------------------------------------------------
# APPEND TO PARQUET
# ---------------------------------------------------------
def append_parquet(path, new_rows, deduplicate_on=None):
    if not new_rows:
        return

    new_df = pd.DataFrame(new_rows)

    if path.exists():
        old_df = pd.read_parquet(path)
        merged = pd.concat([old_df, new_df], ignore_index=True)
    else:
        merged = new_df.copy()

    if deduplicate_on is not None:
        merged = merged.drop_duplicates(subset=[deduplicate_on], keep="last")

    merged.to_parquet(path, index=False)


# ---------------------------------------------------------
# MAIN FUNCTION: PARALLEL + BATCHED
# ---------------------------------------------------------
def classify_resume_parallel_batched(
    pois_df: pd.DataFrame,
    checkpoint_path="predictions_checkpoint.parquet",
    error_path="prediction_errors.parquet",
    save_every=200,
    max_workers=5,
    batch_size=10,
    debug=False,
    max_retries=3,
    retry_wait_sec=5,
):
    checkpoint_path = Path(checkpoint_path)
    error_path = Path(error_path)

    df = pois_df.copy().reset_index(drop=True)

    if "gml_id" not in df.columns:
        raise ValueError("pois_df must contain a 'gml_id' column.")

    if "sentence" not in df.columns:
        raise ValueError("pois_df must contain a 'sentence' column.")

    df["gml_id"] = df["gml_id"].astype(str)

    # do not checkpoint geometry
    cols_to_save = [c for c in df.columns if c != "geometry"]

    # ---------------------------
    # Load checkpoint
    # ---------------------------
    if checkpoint_path.exists():
        checkpoint_df = pd.read_parquet(checkpoint_path)
        checkpoint_df["gml_id"] = checkpoint_df["gml_id"].astype(str)
        done_ids = set(checkpoint_df["gml_id"])
        print(f"Loaded checkpoint with {len(done_ids)} completed rows")
    else:
        done_ids = set()
        print("No checkpoint found. Starting from scratch.")

    remaining_df = df[~df["gml_id"].isin(done_ids)].copy()
    print(f"Remaining rows to process: {len(remaining_df)} / {len(df)}")

    records = remaining_df.to_dict("records")
    batches = list(chunk_list(records, batch_size))

    print(f"Total batches to process: {len(batches)} | batch_size={batch_size} | max_workers={max_workers}")

    def batch_worker(batch_rows):
        batch_results = predict_batch_with_retry(
            batch_rows=batch_rows,
            debug=debug,
            max_retries=max_retries,
            wait_sec=retry_wait_sec,
        )

        if not isinstance(batch_results, list):
            raise ValueError("predict_batch_from_sentences() must return a list.")

        if len(batch_results) != len(batch_rows):
            raise ValueError(
                f"Batch output length mismatch: got {len(batch_results)} results for {len(batch_rows)} rows."
            )

        out_rows = []
        for row_dict, res in zip(batch_rows, batch_results):
            out_row = {k: v for k, v in row_dict.items() if k in cols_to_save}

            if isinstance(res, dict):
                out_row.update(res)
            else:
                out_row["prediction"] = res

            out_rows.append(out_row)

        return out_rows

    buffer = []
    error_buffer = []
    processed_now = 0
    completed_batches = 0

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_batch = {
            executor.submit(batch_worker, batch_rows): batch_rows
            for batch_rows in batches
        }

        for future in as_completed(future_to_batch):
            batch_rows = future_to_batch[future]
            batch_ids = [str(r["gml_id"]) for r in batch_rows]

            try:
                out_rows = future.result()
                buffer.extend(out_rows)

                processed_now += len(out_rows)
                completed_batches += 1

                print(
                    f"Processed {processed_now}/{len(remaining_df)} new rows "
                    f"| completed batches {completed_batches}/{len(batches)} "
                    f"| last batch size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]}"
                )

            except Exception as e:
                for row in batch_rows:
                    error_buffer.append({
                        "gml_id": str(row["gml_id"]),
                        "error": str(e),
                    })

                completed_batches += 1
                print(
                    f"Failed batch {completed_batches}/{len(batches)} "
                    f"| size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]} "
                    f"| error={e}"
                )

            # Save regularly from main thread only
            if len(buffer) >= save_every:
                append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
                print(f"Checkpoint saved with {len(buffer)} new rows")
                buffer = []

            if len(error_buffer) >= save_every:
                append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
                print(f"Error log saved with {len(error_buffer)} rows")
                error_buffer = []

    # final flush
    if buffer:
        append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
        print("Final checkpoint saved.")

    if error_buffer:
        append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
        print("Final error log saved.")

    final_df = pd.read_parquet(checkpoint_path)
    final_df["gml_id"] = final_df["gml_id"].astype(str)

    return final_df

# %%
final_df = classify_resume_parallel_batched(
    pois_df=pois,
    checkpoint_path="predictions_checkpoint(error-rows)-4.parquet",
    error_path="prediction_errors(error-rows)-4.parquet",
    save_every=50,
    max_workers=3,
    batch_size=4,
    debug=False,
    max_retries=2,
    retry_wait_sec=3,
)
# Out:
# No checkpoint found. Starting from scratch.
# Remaining rows to process: 2949 / 2949
# Total batches to process: 738 | batch_size=4 | max_workers=3
# Processed 4/2949 new rows | completed batches 1/738 | last batch size=4 | gml_id range=4841 -> 5796
# Processed 8/2949 new rows | completed batches 2/738 | last batch size=4 | gml_id range=1202 -> 1205
# Processed 12/2949 new rows | completed batches 3/738 | last batch size=4 | gml_id range=5798 -> 6288
# Processed 16/2949 new rows | completed batches 4/738 | last batch size=4 | gml_id range=9038 -> 9050
# Processed 20/2949 new rows | completed batches 5/738 | last batch size=4 | gml_id range=9440 -> 9461
# Processed 24/2949 new rows | completed batches 6/738 | last batch size=4 | gml_id range=6289 -> 6274
# Processed 28/2949 new rows | completed batches 7/738 | last batch size=4 | gml_id range=13879 -> 14210
# Processed 32/2949 new rows | completed batches 8/738 | last batch size=4 | gml_id range=17073 -> 17147
# Processed 36/2949 new rows | completed batches 9/738 | last batch size=4 | gml_id range=17654 -> 17727
# Processed 40/2949 new rows | completed batches 10/738 | last batch size=4 | gml_id range=17983 -> 17944
# Processed 44/2949 new rows | completed batches 11/738 | last batch size=4 | gml_id range=18833 -> 19086
# Processed 48/2949 new rows | completed batches 12/738 | last batch size=4 | gml_id range=19997 -> 20000
# Processed 52/2949 new rows | completed batches 13/738 | last batch size=4 | gml_id range=20456 -> 20503
# Checkpoint saved with 52 new rows
# Processed 56/2949 new rows | completed batches 14/738 | last batch size=4 | gml_id range=21842 -> 22003
# Processed 60/2949 new rows | completed batches 15/738 | last batch size=4 | gml_id range=22495 -> 22491
# Processed 64/2949 new rows | completed batches 16/738 | last batch size=4 | gml_id range=22492 -> 22563
# Processed 68/2949 new rows | completed batches 17/738 | last batch size=4 | gml_id range=23396 -> 23450
# Processed 72/2949 new rows | completed batches 18/738 | last batch size=4 | gml_id range=23451 -> 23703
# Processed 76/2949 new rows | completed batches 19/738 | last batch size=4 | gml_id range=27557 -> 27562
# Processed 80/2949 new rows | completed batches 20/738 | last batch size=4 | gml_id range=28692 -> 28755
# Processed 84/2949 new rows | completed batches 21/738 | last batch size=4 | gml_id range=28806 -> 28829
# Processed 88/2949 new rows | completed batches 22/738 | last batch size=4 | gml_id range=32117 -> 32885
# Processed 92/2949 new rows | completed batches 23/738 | last batch size=4 | gml_id range=31609 -> 31989
# Processed 96/2949 new rows | completed batches 24/738 | last batch size=4 | gml_id range=33762 -> 34141
# Processed 100/2949 new rows | completed batches 25/738 | last batch size=4 | gml_id range=36861 -> 36877
# Processed 104/2949 new rows | completed batches 26/738 | last batch size=4 | gml_id range=34312 -> 34536
# Checkpoint saved with 52 new rows
# Processed 108/2949 new rows | completed batches 27/738 | last batch size=4 | gml_id range=36318 -> 36421
# Processed 112/2949 new rows | completed batches 28/738 | last batch size=4 | gml_id range=37075 -> 37101
# Processed 116/2949 new rows | completed batches 29/738 | last batch size=4 | gml_id range=36949 -> 37027
# Processed 120/2949 new rows | completed batches 30/738 | last batch size=4 | gml_id range=37028 -> 37074
# Processed 124/2949 new rows | completed batches 31/738 | last batch size=4 | gml_id range=37569 -> 37530
# Processed 128/2949 new rows | completed batches 32/738 | last batch size=4 | gml_id range=37893 -> 37896
# Processed 132/2949 new rows | completed batches 33/738 | last batch size=4 | gml_id range=38031 -> 38049
# Processed 136/2949 new rows | completed batches 34/738 | last batch size=4 | gml_id range=38592 -> 38608
# Processed 140/2949 new rows | completed batches 35/738 | last batch size=4 | gml_id range=38886 -> 39278
# Processed 144/2949 new rows | completed batches 36/738 | last batch size=4 | gml_id range=39287 -> 39659
# Processed 148/2949 new rows | completed batches 37/738 | last batch size=4 | gml_id range=39877 -> 40044
# Processed 152/2949 new rows | completed batches 38/738 | last batch size=4 | gml_id range=39661 -> 39851
# Processed 156/2949 new rows | completed batches 39/738 | last batch size=4 | gml_id range=43419 -> 43423
# Checkpoint saved with 52 new rows
# Processed 160/2949 new rows | completed batches 40/738 | last batch size=4 | gml_id range=43524 -> 44203
# Processed 164/2949 new rows | completed batches 41/738 | last batch size=4 | gml_id range=46503 -> 46610
# Processed 168/2949 new rows | completed batches 42/738 | last batch size=4 | gml_id range=48375 -> 48696
# Processed 172/2949 new rows | completed batches 43/738 | last batch size=4 | gml_id range=45956 -> 46501
# Processed 176/2949 new rows | completed batches 44/738 | last batch size=4 | gml_id range=51589 -> 51714
# Processed 180/2949 new rows | completed batches 45/738 | last batch size=4 | gml_id range=49162 -> 49196
# Processed 184/2949 new rows | completed batches 46/738 | last batch size=4 | gml_id range=53191 -> 53263
# Processed 188/2949 new rows | completed batches 47/738 | last batch size=4 | gml_id range=58841 -> 58856
# Processed 192/2949 new rows | completed batches 48/738 | last batch size=4 | gml_id range=57594 -> 57658
# Processed 196/2949 new rows | completed batches 49/738 | last batch size=4 | gml_id range=60384 -> 60586
# Processed 200/2949 new rows | completed batches 50/738 | last batch size=4 | gml_id range=64146 -> 64420
# Processed 204/2949 new rows | completed batches 51/738 | last batch size=4 | gml_id range=65452 -> 65756
# Processed 208/2949 new rows | completed batches 52/738 | last batch size=4 | gml_id range=67495 -> 67498
# Checkpoint saved with 52 new rows
# Processed 212/2949 new rows | completed batches 53/738 | last batch size=4 | gml_id range=68503 -> 68736
# Processed 216/2949 new rows | completed batches 54/738 | last batch size=4 | gml_id range=71917 -> 71920
# Processed 220/2949 new rows | completed batches 55/738 | last batch size=4 | gml_id range=74368 -> 74528
# Processed 224/2949 new rows | completed batches 56/738 | last batch size=4 | gml_id range=72571 -> 72605
# Processed 228/2949 new rows | completed batches 57/738 | last batch size=4 | gml_id range=73702 -> 73706
# Processed 232/2949 new rows | completed batches 58/738 | last batch size=4 | gml_id range=78288 -> 78650
# Processed 236/2949 new rows | completed batches 59/738 | last batch size=4 | gml_id range=74850 -> 74862
# Processed 240/2949 new rows | completed batches 60/738 | last batch size=4 | gml_id range=78651 -> 78836
# Processed 244/2949 new rows | completed batches 61/738 | last batch size=4 | gml_id range=79866 -> 79915
# Processed 248/2949 new rows | completed batches 62/738 | last batch size=4 | gml_id range=78911 -> 79738
# Processed 252/2949 new rows | completed batches 63/738 | last batch size=4 | gml_id range=81889 -> 82324
# Processed 256/2949 new rows | completed batches 64/738 | last batch size=4 | gml_id range=82350 -> 83929
# Processed 260/2949 new rows | completed batches 65/738 | last batch size=4 | gml_id range=84447 -> 84545
# Checkpoint saved with 52 new rows
# Processed 264/2949 new rows | completed batches 66/738 | last batch size=4 | gml_id range=88782 -> 88786
# Processed 268/2949 new rows | completed batches 67/738 | last batch size=4 | gml_id range=85249 -> 85693
# Processed 272/2949 new rows | completed batches 68/738 | last batch size=4 | gml_id range=91338 -> 91359
# Processed 276/2949 new rows | completed batches 69/738 | last batch size=4 | gml_id range=91096 -> 91117
# Processed 280/2949 new rows | completed batches 70/738 | last batch size=4 | gml_id range=92206 -> 93528
# Processed 284/2949 new rows | completed batches 71/738 | last batch size=4 | gml_id range=99421 -> 99580
# Processed 288/2949 new rows | completed batches 72/738 | last batch size=4 | gml_id range=100348 -> 100370
# Processed 292/2949 new rows | completed batches 73/738 | last batch size=4 | gml_id range=103234 -> 104188
# Processed 296/2949 new rows | completed batches 74/738 | last batch size=4 | gml_id range=100719 -> 101437
# Processed 300/2949 new rows | completed batches 75/738 | last batch size=4 | gml_id range=101754 -> 101761
# Processed 304/2949 new rows | completed batches 76/738 | last batch size=4 | gml_id range=109743 -> 109773
# Processed 308/2949 new rows | completed batches 77/738 | last batch size=4 | gml_id range=111973 -> 112052
# Processed 312/2949 new rows | completed batches 78/738 | last batch size=4 | gml_id range=112658 -> 112675
# Checkpoint saved with 52 new rows
# Processed 316/2949 new rows | completed batches 79/738 | last batch size=4 | gml_id range=115837 -> 115850
# Processed 320/2949 new rows | completed batches 80/738 | last batch size=4 | gml_id range=107222 -> 108400
# Processed 324/2949 new rows | completed batches 81/738 | last batch size=4 | gml_id range=114758 -> 114840
# Processed 328/2949 new rows | completed batches 82/738 | last batch size=4 | gml_id range=117442 -> 117854
# Processed 332/2949 new rows | completed batches 83/738 | last batch size=4 | gml_id range=118009 -> 118012
# Processed 336/2949 new rows | completed batches 84/738 | last batch size=4 | gml_id range=117883 -> 117897
# Processed 340/2949 new rows | completed batches 85/738 | last batch size=4 | gml_id range=118086 -> 118956
# Processed 344/2949 new rows | completed batches 86/738 | last batch size=4 | gml_id range=124809 -> 125587
# Processed 348/2949 new rows | completed batches 87/738 | last batch size=4 | gml_id range=123384 -> 123606
# Processed 352/2949 new rows | completed batches 88/738 | last batch size=4 | gml_id range=119841 -> 119892
# Processed 356/2949 new rows | completed batches 89/738 | last batch size=4 | gml_id range=126440 -> 126787
# Processed 360/2949 new rows | completed batches 90/738 | last batch size=4 | gml_id range=129095 -> 129160
# Processed 364/2949 new rows | completed batches 91/738 | last batch size=4 | gml_id range=124416 -> 124808
# Checkpoint saved with 52 new rows
# Processed 368/2949 new rows | completed batches 92/738 | last batch size=4 | gml_id range=128523 -> 128459
# Processed 372/2949 new rows | completed batches 93/738 | last batch size=4 | gml_id range=137623 -> 137822
# Processed 376/2949 new rows | completed batches 94/738 | last batch size=4 | gml_id range=140656 -> 140760
# Processed 380/2949 new rows | completed batches 95/738 | last batch size=4 | gml_id range=138625 -> 139233
# Processed 384/2949 new rows | completed batches 96/738 | last batch size=4 | gml_id range=143537 -> 143565
# Processed 388/2949 new rows | completed batches 97/738 | last batch size=4 | gml_id range=144004 -> 144136
# Processed 392/2949 new rows | completed batches 98/738 | last batch size=4 | gml_id range=144927 -> 145497
# Processed 396/2949 new rows | completed batches 99/738 | last batch size=4 | gml_id range=141115 -> 141370
# Processed 400/2949 new rows | completed batches 100/738 | last batch size=4 | gml_id range=147101 -> 147397
# Processed 404/2949 new rows | completed batches 101/738 | last batch size=4 | gml_id range=146851 -> 147099
# Processed 408/2949 new rows | completed batches 102/738 | last batch size=4 | gml_id range=151368 -> 151407
# Processed 412/2949 new rows | completed batches 103/738 | last batch size=4 | gml_id range=159830 -> 160048
# Processed 416/2949 new rows | completed batches 104/738 | last batch size=4 | gml_id range=154267 -> 154522
# Checkpoint saved with 52 new rows
# Processed 420/2949 new rows | completed batches 105/738 | last batch size=4 | gml_id range=162172 -> 162177
# Processed 424/2949 new rows | completed batches 106/738 | last batch size=4 | gml_id range=154791 -> 154896
# Processed 428/2949 new rows | completed batches 107/738 | last batch size=4 | gml_id range=161581 -> 161573
# Processed 432/2949 new rows | completed batches 108/738 | last batch size=4 | gml_id range=168612 -> 168685
# Processed 436/2949 new rows | completed batches 109/738 | last batch size=4 | gml_id range=162810 -> 163185
# Processed 440/2949 new rows | completed batches 110/738 | last batch size=4 | gml_id range=168765 -> 169032
# Processed 444/2949 new rows | completed batches 111/738 | last batch size=4 | gml_id range=169136 -> 169516
# Processed 448/2949 new rows | completed batches 112/738 | last batch size=4 | gml_id range=178016 -> 178030
# Processed 452/2949 new rows | completed batches 113/738 | last batch size=4 | gml_id range=171846 -> 172098
# Processed 456/2949 new rows | completed batches 114/738 | last batch size=4 | gml_id range=175104 -> 175286
# Processed 460/2949 new rows | completed batches 115/738 | last batch size=4 | gml_id range=179427 -> 179787
# Processed 464/2949 new rows | completed batches 116/738 | last batch size=4 | gml_id range=181547 -> 181714
# Processed 468/2949 new rows | completed batches 117/738 | last batch size=4 | gml_id range=184226 -> 184229
# Checkpoint saved with 52 new rows
# Processed 472/2949 new rows | completed batches 118/738 | last batch size=4 | gml_id range=181231 -> 181519
# Processed 476/2949 new rows | completed batches 119/738 | last batch size=4 | gml_id range=188336 -> 188909
# Processed 480/2949 new rows | completed batches 120/738 | last batch size=4 | gml_id range=185514 -> 185854
# Processed 484/2949 new rows | completed batches 121/738 | last batch size=4 | gml_id range=191835 -> 192733
# Processed 488/2949 new rows | completed batches 122/738 | last batch size=4 | gml_id range=192734 -> 192708
# Processed 492/2949 new rows | completed batches 123/738 | last batch size=4 | gml_id range=195673 -> 195832
# Processed 496/2949 new rows | completed batches 124/738 | last batch size=4 | gml_id range=197616 -> 198205
# Processed 500/2949 new rows | completed batches 125/738 | last batch size=4 | gml_id range=198239 -> 198251
# Processed 504/2949 new rows | completed batches 126/738 | last batch size=4 | gml_id range=198708 -> 198756
# Processed 508/2949 new rows | completed batches 127/738 | last batch size=4 | gml_id range=206249 -> 206656
# Processed 512/2949 new rows | completed batches 128/738 | last batch size=4 | gml_id range=204833 -> 205275
# Processed 516/2949 new rows | completed batches 129/738 | last batch size=4 | gml_id range=222681 -> 223534
# Processed 520/2949 new rows | completed batches 130/738 | last batch size=4 | gml_id range=226571 -> 226960
# Checkpoint saved with 52 new rows
# Processed 524/2949 new rows | completed batches 131/738 | last batch size=4 | gml_id range=227762 -> 227907
# Processed 528/2949 new rows | completed batches 132/738 | last batch size=4 | gml_id range=232801 -> 233289
# Processed 532/2949 new rows | completed batches 133/738 | last batch size=4 | gml_id range=233292 -> 234166
# Processed 536/2949 new rows | completed batches 134/738 | last batch size=4 | gml_id range=235771 -> 238741
# Processed 540/2949 new rows | completed batches 135/738 | last batch size=4 | gml_id range=239216 -> 239248
# Processed 544/2949 new rows | completed batches 136/738 | last batch size=4 | gml_id range=242975 -> 243902
# Processed 548/2949 new rows | completed batches 137/738 | last batch size=4 | gml_id range=242555 -> 242974
# Processed 552/2949 new rows | completed batches 138/738 | last batch size=4 | gml_id range=250675 -> 250982
# Processed 556/2949 new rows | completed batches 139/738 | last batch size=4 | gml_id range=251132 -> 251177
# Processed 560/2949 new rows | completed batches 140/738 | last batch size=4 | gml_id range=252864 -> 254307
# Processed 564/2949 new rows | completed batches 141/738 | last batch size=4 | gml_id range=261212 -> 261273
# Processed 568/2949 new rows | completed batches 142/738 | last batch size=4 | gml_id range=260119 -> 260710
# Processed 572/2949 new rows | completed batches 143/738 | last batch size=4 | gml_id range=270317 -> 270538
# Checkpoint saved with 52 new rows
# Processed 576/2949 new rows | completed batches 144/738 | last batch size=4 | gml_id range=276041 -> 276636
# Processed 580/2949 new rows | completed batches 145/738 | last batch size=4 | gml_id range=274442 -> 275556
# Processed 584/2949 new rows | completed batches 146/738 | last batch size=4 | gml_id range=285806 -> 286226
# Processed 588/2949 new rows | completed batches 147/738 | last batch size=4 | gml_id range=289087 -> 289562
# Processed 592/2949 new rows | completed batches 148/738 | last batch size=4 | gml_id range=290791 -> 290836
# Processed 596/2949 new rows | completed batches 149/738 | last batch size=4 | gml_id range=301550 -> 302091
# Processed 600/2949 new rows | completed batches 150/738 | last batch size=4 | gml_id range=312634 -> 312676
# Processed 604/2949 new rows | completed batches 151/738 | last batch size=4 | gml_id range=316688 -> 317083
# Processed 608/2949 new rows | completed batches 152/738 | last batch size=4 | gml_id range=317106 -> 317939
# Processed 612/2949 new rows | completed batches 153/738 | last batch size=4 | gml_id range=324868 -> 324942
# Processed 616/2949 new rows | completed batches 154/738 | last batch size=4 | gml_id range=323694 -> 324867
# Processed 620/2949 new rows | completed batches 155/738 | last batch size=4 | gml_id range=325291 -> 325115
# Processed 624/2949 new rows | completed batches 156/738 | last batch size=4 | gml_id range=324730 -> 325224
# Checkpoint saved with 52 new rows
# Processed 628/2949 new rows | completed batches 157/738 | last batch size=4 | gml_id range=329740 -> 329778
# Processed 632/2949 new rows | completed batches 158/738 | last batch size=4 | gml_id range=329214 -> 329307
# Processed 636/2949 new rows | completed batches 159/738 | last batch size=4 | gml_id range=330284 -> 330662
# Processed 640/2949 new rows | completed batches 160/738 | last batch size=4 | gml_id range=331837 -> 332090
# Processed 644/2949 new rows | completed batches 161/738 | last batch size=4 | gml_id range=333197 -> 333682
# Processed 648/2949 new rows | completed batches 162/738 | last batch size=4 | gml_id range=332612 -> 333130
# Processed 652/2949 new rows | completed batches 163/738 | last batch size=4 | gml_id range=335389 -> 335394
# Processed 656/2949 new rows | completed batches 164/738 | last batch size=4 | gml_id range=333835 -> 333543
# Processed 660/2949 new rows | completed batches 165/738 | last batch size=4 | gml_id range=349145 -> 349195
# Processed 664/2949 new rows | completed batches 166/738 | last batch size=4 | gml_id range=349503 -> 349758
# Processed 668/2949 new rows | completed batches 167/738 | last batch size=4 | gml_id range=346471 -> 346507
# Processed 672/2949 new rows | completed batches 168/738 | last batch size=4 | gml_id range=351171 -> 352652
# Processed 676/2949 new rows | completed batches 169/738 | last batch size=4 | gml_id range=352840 -> 353177
# Checkpoint saved with 52 new rows
# Processed 680/2949 new rows | completed batches 170/738 | last batch size=4 | gml_id range=360099 -> 360474
# Processed 684/2949 new rows | completed batches 171/738 | last batch size=4 | gml_id range=351096 -> 351170
# Processed 688/2949 new rows | completed batches 172/738 | last batch size=4 | gml_id range=365983 -> 366085
# Processed 692/2949 new rows | completed batches 173/738 | last batch size=4 | gml_id range=378961 -> 379170
# Processed 696/2949 new rows | completed batches 174/738 | last batch size=4 | gml_id range=373288 -> 374343
# Processed 700/2949 new rows | completed batches 175/738 | last batch size=4 | gml_id range=376079 -> 376207
# Processed 704/2949 new rows | completed batches 176/738 | last batch size=4 | gml_id range=388216 -> 388553
# Processed 708/2949 new rows | completed batches 177/738 | last batch size=4 | gml_id range=391645 -> 391654
# Processed 712/2949 new rows | completed batches 178/738 | last batch size=4 | gml_id range=379276 -> 379872
# Processed 716/2949 new rows | completed batches 179/738 | last batch size=4 | gml_id range=395382 -> 395398
# Processed 720/2949 new rows | completed batches 180/738 | last batch size=4 | gml_id range=392020 -> 392336
# Processed 724/2949 new rows | completed batches 181/738 | last batch size=4 | gml_id range=394461 -> 394992
# Processed 728/2949 new rows | completed batches 182/738 | last batch size=4 | gml_id range=396537 -> 396635
# Checkpoint saved with 52 new rows
# Processed 732/2949 new rows | completed batches 183/738 | last batch size=4 | gml_id range=404650 -> 405261
# Processed 736/2949 new rows | completed batches 184/738 | last batch size=4 | gml_id range=408438 -> 408552
# Processed 740/2949 new rows | completed batches 185/738 | last batch size=4 | gml_id range=408589 -> 408729
# Processed 744/2949 new rows | completed batches 186/738 | last batch size=4 | gml_id range=408536 -> 408437
# Processed 748/2949 new rows | completed batches 187/738 | last batch size=4 | gml_id range=408730 -> 409061
# Processed 752/2949 new rows | completed batches 188/738 | last batch size=4 | gml_id range=411845 -> 412038
# Processed 756/2949 new rows | completed batches 189/738 | last batch size=4 | gml_id range=409158 -> 409408
# Processed 760/2949 new rows | completed batches 190/738 | last batch size=4 | gml_id range=424554 -> 425005
# Processed 764/2949 new rows | completed batches 191/738 | last batch size=4 | gml_id range=422790 -> 422784
# Processed 768/2949 new rows | completed batches 192/738 | last batch size=4 | gml_id range=426209 -> 426501
# Processed 772/2949 new rows | completed batches 193/738 | last batch size=4 | gml_id range=427556 -> 427585
# Processed 776/2949 new rows | completed batches 194/738 | last batch size=4 | gml_id range=428622 -> 428639
# Processed 780/2949 new rows | completed batches 195/738 | last batch size=4 | gml_id range=429241 -> 429383
# Checkpoint saved with 52 new rows
# Processed 784/2949 new rows | completed batches 196/738 | last batch size=4 | gml_id range=433210 -> 433425
# Processed 788/2949 new rows | completed batches 197/738 | last batch size=4 | gml_id range=433442 -> 433621
# Processed 792/2949 new rows | completed batches 198/738 | last batch size=4 | gml_id range=431291 -> 431324
# Processed 796/2949 new rows | completed batches 199/738 | last batch size=4 | gml_id range=436956 -> 438183
# Processed 800/2949 new rows | completed batches 200/738 | last batch size=4 | gml_id range=438445 -> 438706
# Processed 804/2949 new rows | completed batches 201/738 | last batch size=4 | gml_id range=435487 -> 435522
# Processed 808/2949 new rows | completed batches 202/738 | last batch size=4 | gml_id range=441705 -> 442074
# Processed 812/2949 new rows | completed batches 203/738 | last batch size=4 | gml_id range=443906 -> 444188
# Processed 816/2949 new rows | completed batches 204/738 | last batch size=4 | gml_id range=440434 -> 440503
# Processed 820/2949 new rows | completed batches 205/738 | last batch size=4 | gml_id range=444189 -> 444549
# Processed 824/2949 new rows | completed batches 206/738 | last batch size=4 | gml_id range=444372 -> 444571
# Processed 828/2949 new rows | completed batches 207/738 | last batch size=4 | gml_id range=447387 -> 447425
# Processed 832/2949 new rows | completed batches 208/738 | last batch size=4 | gml_id range=447272 -> 447386
# Checkpoint saved with 52 new rows
# Processed 836/2949 new rows | completed batches 209/738 | last batch size=4 | gml_id range=451360 -> 451395
# Processed 840/2949 new rows | completed batches 210/738 | last batch size=4 | gml_id range=452323 -> 452706
# Processed 844/2949 new rows | completed batches 211/738 | last batch size=4 | gml_id range=450758 -> 451091
# Processed 848/2949 new rows | completed batches 212/738 | last batch size=4 | gml_id range=456402 -> 456966
# Processed 852/2949 new rows | completed batches 213/738 | last batch size=4 | gml_id range=460499 -> 460535
# Processed 856/2949 new rows | completed batches 214/738 | last batch size=4 | gml_id range=460536 -> 460521
# Processed 860/2949 new rows | completed batches 215/738 | last batch size=4 | gml_id range=463963 -> 463986
# Processed 864/2949 new rows | completed batches 216/738 | last batch size=4 | gml_id range=461802 -> 462081
# Processed 868/2949 new rows | completed batches 217/738 | last batch size=4 | gml_id range=465528 -> 465668
# Processed 872/2949 new rows | completed batches 218/738 | last batch size=4 | gml_id range=465981 -> 466001
# Processed 876/2949 new rows | completed batches 219/738 | last batch size=4 | gml_id range=464294 -> 464335
# Processed 880/2949 new rows | completed batches 220/738 | last batch size=4 | gml_id range=467373 -> 467430
# Processed 884/2949 new rows | completed batches 221/738 | last batch size=4 | gml_id range=467061 -> 467268
# Checkpoint saved with 52 new rows
# Processed 888/2949 new rows | completed batches 222/738 | last batch size=4 | gml_id range=470527 -> 470481
# Processed 892/2949 new rows | completed batches 223/738 | last batch size=4 | gml_id range=474836 -> 475840
# Processed 896/2949 new rows | completed batches 224/738 | last batch size=4 | gml_id range=478476 -> 478978
# Processed 900/2949 new rows | completed batches 225/738 | last batch size=4 | gml_id range=470482 -> 471021
# Processed 904/2949 new rows | completed batches 226/738 | last batch size=4 | gml_id range=477568 -> 478497
# Processed 908/2949 new rows | completed batches 227/738 | last batch size=4 | gml_id range=478997 -> 479280
# Processed 912/2949 new rows | completed batches 228/738 | last batch size=4 | gml_id range=480942 -> 481040
# Processed 916/2949 new rows | completed batches 229/738 | last batch size=4 | gml_id range=481349 -> 481827
# Processed 920/2949 new rows | completed batches 230/738 | last batch size=4 | gml_id range=484690 -> 484976
# Processed 924/2949 new rows | completed batches 231/738 | last batch size=4 | gml_id range=484206 -> 484689
# Processed 928/2949 new rows | completed batches 232/738 | last batch size=4 | gml_id range=486246 -> 486632
# Processed 932/2949 new rows | completed batches 233/738 | last batch size=4 | gml_id range=488951 -> 488894
# Processed 936/2949 new rows | completed batches 234/738 | last batch size=4 | gml_id range=489045 -> 489275
# Checkpoint saved with 52 new rows
# Processed 940/2949 new rows | completed batches 235/738 | last batch size=4 | gml_id range=491351 -> 491417
# Processed 944/2949 new rows | completed batches 236/738 | last batch size=4 | gml_id range=491538 -> 491628
# Processed 948/2949 new rows | completed batches 237/738 | last batch size=4 | gml_id range=496590 -> 496613
# Processed 952/2949 new rows | completed batches 238/738 | last batch size=4 | gml_id range=494166 -> 494367
# Processed 956/2949 new rows | completed batches 239/738 | last batch size=4 | gml_id range=499853 -> 500059
# Processed 960/2949 new rows | completed batches 240/738 | last batch size=4 | gml_id range=501746 -> 502034
# Processed 964/2949 new rows | completed batches 241/738 | last batch size=4 | gml_id range=503297 -> 505169
# Processed 968/2949 new rows | completed batches 242/738 | last batch size=4 | gml_id range=505170 -> 505761
# Processed 972/2949 new rows | completed batches 243/738 | last batch size=4 | gml_id range=509503 -> 509779
# Processed 976/2949 new rows | completed batches 244/738 | last batch size=4 | gml_id range=510917 -> 510943
# Processed 980/2949 new rows | completed batches 245/738 | last batch size=4 | gml_id range=507195 -> 507395
# Processed 984/2949 new rows | completed batches 246/738 | last batch size=4 | gml_id range=511143 -> 511146
# Processed 988/2949 new rows | completed batches 247/738 | last batch size=4 | gml_id range=511958 -> 511961
# Checkpoint saved with 52 new rows
# Processed 992/2949 new rows | completed batches 248/738 | last batch size=4 | gml_id range=512957 -> 512907
# Processed 996/2949 new rows | completed batches 249/738 | last batch size=4 | gml_id range=512767 -> 512954
# Processed 1000/2949 new rows | completed batches 250/738 | last batch size=4 | gml_id range=514442 -> 514507
# Processed 1004/2949 new rows | completed batches 251/738 | last batch size=4 | gml_id range=513664 -> 513747
# Processed 1008/2949 new rows | completed batches 252/738 | last batch size=4 | gml_id range=514667 -> 514683
# Processed 1012/2949 new rows | completed batches 253/738 | last batch size=4 | gml_id range=514941 -> 515415
# Processed 1016/2949 new rows | completed batches 254/738 | last batch size=4 | gml_id range=515895 -> 517183
# Processed 1020/2949 new rows | completed batches 255/738 | last batch size=4 | gml_id range=515416 -> 515894
# Processed 1024/2949 new rows | completed batches 256/738 | last batch size=4 | gml_id range=517185 -> 517429
# Processed 1028/2949 new rows | completed batches 257/738 | last batch size=4 | gml_id range=519195 -> 519201
# Processed 1032/2949 new rows | completed batches 258/738 | last batch size=4 | gml_id range=518638 -> 519160
# Processed 1036/2949 new rows | completed batches 259/738 | last batch size=4 | gml_id range=519247 -> 520493
# Processed 1040/2949 new rows | completed batches 260/738 | last batch size=4 | gml_id range=522930 -> 523941
# Checkpoint saved with 52 new rows
# Processed 1044/2949 new rows | completed batches 261/738 | last batch size=4 | gml_id range=520732 -> 520859
# Processed 1048/2949 new rows | completed batches 262/738 | last batch size=4 | gml_id range=529322 -> 529812
# Processed 1052/2949 new rows | completed batches 263/738 | last batch size=4 | gml_id range=528966 -> 529291
# Processed 1056/2949 new rows | completed batches 264/738 | last batch size=4 | gml_id range=530090 -> 530636
# Processed 1060/2949 new rows | completed batches 265/738 | last batch size=4 | gml_id range=530637 -> 530657
# Processed 1064/2949 new rows | completed batches 266/738 | last batch size=4 | gml_id range=531478 -> 532084
# Processed 1068/2949 new rows | completed batches 267/738 | last batch size=4 | gml_id range=534715 -> 534766
# Processed 1072/2949 new rows | completed batches 268/738 | last batch size=4 | gml_id range=535359 -> 535375
# Processed 1076/2949 new rows | completed batches 269/738 | last batch size=4 | gml_id range=540319 -> 540364
# Processed 1080/2949 new rows | completed batches 270/738 | last batch size=4 | gml_id range=537114 -> 537750
# Processed 1084/2949 new rows | completed batches 271/738 | last batch size=4 | gml_id range=542525 -> 542539
# Processed 1088/2949 new rows | completed batches 272/738 | last batch size=4 | gml_id range=540378 -> 540598
# Processed 1092/2949 new rows | completed batches 273/738 | last batch size=4 | gml_id range=545300 -> 545363
# Checkpoint saved with 52 new rows
# Processed 1096/2949 new rows | completed batches 274/738 | last batch size=4 | gml_id range=547120 -> 547167
# Processed 1100/2949 new rows | completed batches 275/738 | last batch size=4 | gml_id range=545962 -> 546441
# Processed 1104/2949 new rows | completed batches 276/738 | last batch size=4 | gml_id range=547849 -> 548973
# Processed 1108/2949 new rows | completed batches 277/738 | last batch size=4 | gml_id range=549505 -> 549638
# Processed 1112/2949 new rows | completed batches 278/738 | last batch size=4 | gml_id range=548974 -> 549023
# Processed 1116/2949 new rows | completed batches 279/738 | last batch size=4 | gml_id range=552098 -> 552157
# Processed 1120/2949 new rows | completed batches 280/738 | last batch size=4 | gml_id range=561213 -> 562085
# Processed 1124/2949 new rows | completed batches 281/738 | last batch size=4 | gml_id range=565866 -> 565906
# Processed 1128/2949 new rows | completed batches 282/738 | last batch size=4 | gml_id range=558491 -> 559177
# Processed 1132/2949 new rows | completed batches 283/738 | last batch size=4 | gml_id range=570116 -> 571027
# Processed 1136/2949 new rows | completed batches 284/738 | last batch size=4 | gml_id range=571028 -> 571038
# Processed 1140/2949 new rows | completed batches 285/738 | last batch size=4 | gml_id range=571470 -> 571783
# Processed 1144/2949 new rows | completed batches 286/738 | last batch size=4 | gml_id range=586784 -> 588384
# Checkpoint saved with 52 new rows
# Processed 1148/2949 new rows | completed batches 287/738 | last batch size=4 | gml_id range=583583 -> 583310
# Processed 1152/2949 new rows | completed batches 288/738 | last batch size=4 | gml_id range=591153 -> 591453
# Processed 1156/2949 new rows | completed batches 289/738 | last batch size=4 | gml_id range=589180 -> 590019
# Processed 1160/2949 new rows | completed batches 290/738 | last batch size=4 | gml_id range=594872 -> 595089
# Processed 1164/2949 new rows | completed batches 291/738 | last batch size=4 | gml_id range=593482 -> 594207
# Processed 1168/2949 new rows | completed batches 292/738 | last batch size=4 | gml_id range=596115 -> 596131
# Processed 1172/2949 new rows | completed batches 293/738 | last batch size=4 | gml_id range=601319 -> 601476
# Processed 1176/2949 new rows | completed batches 294/738 | last batch size=4 | gml_id range=601461 -> 601570
# Processed 1180/2949 new rows | completed batches 295/738 | last batch size=4 | gml_id range=601571 -> 601616
# Processed 1184/2949 new rows | completed batches 296/738 | last batch size=4 | gml_id range=602385 -> 602964
# Processed 1188/2949 new rows | completed batches 297/738 | last batch size=4 | gml_id range=607463 -> 607387
# Processed 1192/2949 new rows | completed batches 298/738 | last batch size=4 | gml_id range=610029 -> 611559
# Processed 1196/2949 new rows | completed batches 299/738 | last batch size=4 | gml_id range=608527 -> 608773
# Checkpoint saved with 52 new rows
# Processed 1200/2949 new rows | completed batches 300/738 | last batch size=4 | gml_id range=611572 -> 611610
# Processed 1204/2949 new rows | completed batches 301/738 | last batch size=4 | gml_id range=2487 -> 2503
# Processed 1208/2949 new rows | completed batches 302/738 | last batch size=4 | gml_id range=611618 -> 611631
# Processed 1212/2949 new rows | completed batches 303/738 | last batch size=4 | gml_id range=64 -> 68
# Processed 1216/2949 new rows | completed batches 304/738 | last batch size=4 | gml_id range=3374 -> 3399
# Processed 1220/2949 new rows | completed batches 305/738 | last batch size=4 | gml_id range=5097 -> 5113
# Processed 1224/2949 new rows | completed batches 306/738 | last batch size=4 | gml_id range=4716 -> 4773
# Processed 1228/2949 new rows | completed batches 307/738 | last batch size=4 | gml_id range=7427 -> 7444
# Processed 1232/2949 new rows | completed batches 308/738 | last batch size=4 | gml_id range=9524 -> 9579
# Processed 1236/2949 new rows | completed batches 309/738 | last batch size=4 | gml_id range=9326 -> 9352
# Processed 1240/2949 new rows | completed batches 310/738 | last batch size=4 | gml_id range=10433 -> 10447
# Processed 1244/2949 new rows | completed batches 311/738 | last batch size=4 | gml_id range=15413 -> 15444
# Processed 1248/2949 new rows | completed batches 312/738 | last batch size=4 | gml_id range=16335 -> 16334
# Checkpoint saved with 52 new rows
# Processed 1252/2949 new rows | completed batches 313/738 | last batch size=4 | gml_id range=14254 -> 14258
# Processed 1256/2949 new rows | completed batches 314/738 | last batch size=4 | gml_id range=17036 -> 17059
# Processed 1260/2949 new rows | completed batches 315/738 | last batch size=4 | gml_id range=18111 -> 18202
# Processed 1264/2949 new rows | completed batches 316/738 | last batch size=4 | gml_id range=19146 -> 19164
# Processed 1268/2949 new rows | completed batches 317/738 | last batch size=4 | gml_id range=19851 -> 19950
# Processed 1272/2949 new rows | completed batches 318/738 | last batch size=4 | gml_id range=21223 -> 21226
# Processed 1276/2949 new rows | completed batches 319/738 | last batch size=4 | gml_id range=22594 -> 22629
# Processed 1280/2949 new rows | completed batches 320/738 | last batch size=4 | gml_id range=23792 -> 23805
# Processed 1284/2949 new rows | completed batches 321/738 | last batch size=4 | gml_id range=23773 -> 23783
# Processed 1288/2949 new rows | completed batches 322/738 | last batch size=4 | gml_id range=24031 -> 24036
# Processed 1292/2949 new rows | completed batches 323/738 | last batch size=4 | gml_id range=24433 -> 24444
# Processed 1296/2949 new rows | completed batches 324/738 | last batch size=4 | gml_id range=24219 -> 24308
# Processed 1300/2949 new rows | completed batches 325/738 | last batch size=4 | gml_id range=31927 -> 31935
# Checkpoint saved with 52 new rows
# Processed 1304/2949 new rows | completed batches 326/738 | last batch size=4 | gml_id range=30026 -> 30052
# Processed 1308/2949 new rows | completed batches 327/738 | last batch size=4 | gml_id range=36179 -> 36251
# Processed 1312/2949 new rows | completed batches 328/738 | last batch size=4 | gml_id range=37314 -> 37317
# Processed 1316/2949 new rows | completed batches 329/738 | last batch size=4 | gml_id range=38109 -> 38103
# Processed 1320/2949 new rows | completed batches 330/738 | last batch size=4 | gml_id range=37988 -> 37991
# Processed 1324/2949 new rows | completed batches 331/738 | last batch size=4 | gml_id range=38361 -> 38344
# Processed 1328/2949 new rows | completed batches 332/738 | last batch size=4 | gml_id range=38386 -> 38377
# Processed 1332/2949 new rows | completed batches 333/738 | last batch size=4 | gml_id range=38715 -> 38778
# Processed 1336/2949 new rows | completed batches 334/738 | last batch size=4 | gml_id range=39439 -> 39553
# Processed 1340/2949 new rows | completed batches 335/738 | last batch size=4 | gml_id range=38501 -> 38505
# Processed 1344/2949 new rows | completed batches 336/738 | last batch size=4 | gml_id range=40264 -> 40295
# Processed 1348/2949 new rows | completed batches 337/738 | last batch size=4 | gml_id range=40429 -> 40433
# Processed 1352/2949 new rows | completed batches 338/738 | last batch size=4 | gml_id range=44047 -> 44110
# Checkpoint saved with 52 new rows
# Processed 1356/2949 new rows | completed batches 339/738 | last batch size=4 | gml_id range=43060 -> 43144
# Processed 1360/2949 new rows | completed batches 340/738 | last batch size=4 | gml_id range=44111 -> 44200
# Processed 1364/2949 new rows | completed batches 341/738 | last batch size=4 | gml_id range=45090 -> 45131
# Processed 1368/2949 new rows | completed batches 342/738 | last batch size=4 | gml_id range=46010 -> 46069
# Processed 1372/2949 new rows | completed batches 343/738 | last batch size=4 | gml_id range=46641 -> 46705
# Processed 1376/2949 new rows | completed batches 344/738 | last batch size=4 | gml_id range=47746 -> 49297
# Processed 1380/2949 new rows | completed batches 345/738 | last batch size=4 | gml_id range=45942 -> 45955
# Processed 1384/2949 new rows | completed batches 346/738 | last batch size=4 | gml_id range=47861 -> 47871
# Processed 1388/2949 new rows | completed batches 347/738 | last batch size=4 | gml_id range=49298 -> 48993
# Processed 1392/2949 new rows | completed batches 348/738 | last batch size=4 | gml_id range=49016 -> 50383
# Processed 1396/2949 new rows | completed batches 349/738 | last batch size=4 | gml_id range=50394 -> 53250
# Processed 1400/2949 new rows | completed batches 350/738 | last batch size=4 | gml_id range=51678 -> 58952
# Processed 1404/2949 new rows | completed batches 351/738 | last batch size=4 | gml_id range=53251 -> 51676
# Checkpoint saved with 52 new rows
# Processed 1408/2949 new rows | completed batches 352/738 | last batch size=4 | gml_id range=58954 -> 59112
# Processed 1412/2949 new rows | completed batches 353/738 | last batch size=4 | gml_id range=59377 -> 59594
# Processed 1416/2949 new rows | completed batches 354/738 | last batch size=4 | gml_id range=59114 -> 59558
# Processed 1420/2949 new rows | completed batches 355/738 | last batch size=4 | gml_id range=59591 -> 59376
# Processed 1424/2949 new rows | completed batches 356/738 | last batch size=4 | gml_id range=59603 -> 61266
# Processed 1428/2949 new rows | completed batches 357/738 | last batch size=4 | gml_id range=61340 -> 62390
# Processed 1432/2949 new rows | completed batches 358/738 | last batch size=4 | gml_id range=63786 -> 64380
# Processed 1436/2949 new rows | completed batches 359/738 | last batch size=4 | gml_id range=62395 -> 63785
# Processed 1440/2949 new rows | completed batches 360/738 | last batch size=4 | gml_id range=64394 -> 65549
# Processed 1444/2949 new rows | completed batches 361/738 | last batch size=4 | gml_id range=66258 -> 67719
# Processed 1448/2949 new rows | completed batches 362/738 | last batch size=4 | gml_id range=65550 -> 66236
# Processed 1452/2949 new rows | completed batches 363/738 | last batch size=4 | gml_id range=67787 -> 67916
# Processed 1456/2949 new rows | completed batches 364/738 | last batch size=4 | gml_id range=67917 -> 69454
# Checkpoint saved with 52 new rows
# Processed 1460/2949 new rows | completed batches 365/738 | last batch size=4 | gml_id range=69439 -> 70599
# Processed 1464/2949 new rows | completed batches 366/738 | last batch size=4 | gml_id range=70600 -> 72102
# Processed 1468/2949 new rows | completed batches 367/738 | last batch size=4 | gml_id range=72103 -> 71531
# Processed 1472/2949 new rows | completed batches 368/738 | last batch size=4 | gml_id range=71547 -> 75819
# Processed 1476/2949 new rows | completed batches 369/738 | last batch size=4 | gml_id range=75847 -> 76521
# Processed 1480/2949 new rows | completed batches 370/738 | last batch size=4 | gml_id range=77306 -> 76844
# Processed 1484/2949 new rows | completed batches 371/738 | last batch size=4 | gml_id range=76523 -> 77304
# Processed 1488/2949 new rows | completed batches 372/738 | last batch size=4 | gml_id range=78199 -> 78350
# Processed 1492/2949 new rows | completed batches 373/738 | last batch size=4 | gml_id range=76890 -> 78197
# Processed 1496/2949 new rows | completed batches 374/738 | last batch size=4 | gml_id range=78437 -> 78811
# Processed 1500/2949 new rows | completed batches 375/738 | last batch size=4 | gml_id range=78812 -> 79093
# Processed 1504/2949 new rows | completed batches 376/738 | last batch size=4 | gml_id range=79094 -> 79534
# Processed 1508/2949 new rows | completed batches 377/738 | last batch size=4 | gml_id range=79577 -> 79922
# Checkpoint saved with 52 new rows
# Processed 1512/2949 new rows | completed batches 378/738 | last batch size=4 | gml_id range=79918 -> 80312
# Processed 1516/2949 new rows | completed batches 379/738 | last batch size=4 | gml_id range=80313 -> 81417
# Processed 1520/2949 new rows | completed batches 380/738 | last batch size=4 | gml_id range=83324 -> 83485
# Processed 1524/2949 new rows | completed batches 381/738 | last batch size=4 | gml_id range=81418 -> 83323
# Processed 1528/2949 new rows | completed batches 382/738 | last batch size=4 | gml_id range=84585 -> 85340
# Processed 1532/2949 new rows | completed batches 383/738 | last batch size=4 | gml_id range=83506 -> 84552
# Processed 1536/2949 new rows | completed batches 384/738 | last batch size=4 | gml_id range=85341 -> 85444
# Processed 1540/2949 new rows | completed batches 385/738 | last batch size=4 | gml_id range=85492 -> 86802
# Processed 1544/2949 new rows | completed batches 386/738 | last batch size=4 | gml_id range=86803 -> 88270
# Processed 1548/2949 new rows | completed batches 387/738 | last batch size=4 | gml_id range=89402 -> 89616
# Processed 1552/2949 new rows | completed batches 388/738 | last batch size=4 | gml_id range=88272 -> 89400
# Processed 1556/2949 new rows | completed batches 389/738 | last batch size=4 | gml_id range=89618 -> 90733
# Processed 1560/2949 new rows | completed batches 390/738 | last batch size=4 | gml_id range=90734 -> 90092
# Checkpoint saved with 52 new rows
# Processed 1564/2949 new rows | completed batches 391/738 | last batch size=4 | gml_id range=91753 -> 91760
# Processed 1568/2949 new rows | completed batches 392/738 | last batch size=4 | gml_id range=90093 -> 91740
# Processed 1572/2949 new rows | completed batches 393/738 | last batch size=4 | gml_id range=93365 -> 93678
# Processed 1576/2949 new rows | completed batches 394/738 | last batch size=4 | gml_id range=91774 -> 92246
# Processed 1580/2949 new rows | completed batches 395/738 | last batch size=4 | gml_id range=92248 -> 93363
# Processed 1584/2949 new rows | completed batches 396/738 | last batch size=4 | gml_id range=93563 -> 94544
# Processed 1588/2949 new rows | completed batches 397/738 | last batch size=4 | gml_id range=93679 -> 93557
# Processed 1592/2949 new rows | completed batches 398/738 | last batch size=4 | gml_id range=94545 -> 96488
# Processed 1596/2949 new rows | completed batches 399/738 | last batch size=4 | gml_id range=96489 -> 97391
# Processed 1600/2949 new rows | completed batches 400/738 | last batch size=4 | gml_id range=97392 -> 100604
# Processed 1604/2949 new rows | completed batches 401/738 | last batch size=4 | gml_id range=101554 -> 102015
# Processed 1608/2949 new rows | completed batches 402/738 | last batch size=4 | gml_id range=100606 -> 101527
# Processed 1612/2949 new rows | completed batches 403/738 | last batch size=4 | gml_id range=103871 -> 103959
# Checkpoint saved with 52 new rows
# Processed 1616/2949 new rows | completed batches 404/738 | last batch size=4 | gml_id range=102016 -> 103357
# Processed 1620/2949 new rows | completed batches 405/738 | last batch size=4 | gml_id range=103349 -> 103868
# Processed 1624/2949 new rows | completed batches 406/738 | last batch size=4 | gml_id range=105203 -> 105517
# Processed 1628/2949 new rows | completed batches 407/738 | last batch size=4 | gml_id range=103962 -> 105202
# Processed 1632/2949 new rows | completed batches 408/738 | last batch size=4 | gml_id range=105518 -> 106402
# Processed 1636/2949 new rows | completed batches 409/738 | last batch size=4 | gml_id range=106419 -> 107168
# Processed 1640/2949 new rows | completed batches 410/738 | last batch size=4 | gml_id range=108637 -> 109975
# Processed 1644/2949 new rows | completed batches 411/738 | last batch size=4 | gml_id range=107169 -> 108646
# Processed 1648/2949 new rows | completed batches 412/738 | last batch size=4 | gml_id range=109978 -> 110094
# Processed 1652/2949 new rows | completed batches 413/738 | last batch size=4 | gml_id range=110096 -> 111157
# Processed 1656/2949 new rows | completed batches 414/738 | last batch size=4 | gml_id range=111158 -> 110445
# Processed 1660/2949 new rows | completed batches 415/738 | last batch size=4 | gml_id range=110446 -> 112854
# Processed 1664/2949 new rows | completed batches 416/738 | last batch size=4 | gml_id range=112881 -> 112956
# Checkpoint saved with 52 new rows
# Processed 1668/2949 new rows | completed batches 417/738 | last batch size=4 | gml_id range=112957 -> 112987
# Processed 1672/2949 new rows | completed batches 418/738 | last batch size=4 | gml_id range=112988 -> 113979
# Processed 1676/2949 new rows | completed batches 419/738 | last batch size=4 | gml_id range=113980 -> 114728
# Processed 1680/2949 new rows | completed batches 420/738 | last batch size=4 | gml_id range=114729 -> 116137
# Processed 1684/2949 new rows | completed batches 421/738 | last batch size=4 | gml_id range=116138 -> 117404
# Processed 1688/2949 new rows | completed batches 422/738 | last batch size=4 | gml_id range=117392 -> 117652
# Processed 1692/2949 new rows | completed batches 423/738 | last batch size=4 | gml_id range=117653 -> 118287
# Processed 1696/2949 new rows | completed batches 424/738 | last batch size=4 | gml_id range=118290 -> 118507
# Processed 1700/2949 new rows | completed batches 425/738 | last batch size=4 | gml_id range=118508 -> 121163
# Processed 1704/2949 new rows | completed batches 426/738 | last batch size=4 | gml_id range=121164 -> 120168
# Processed 1708/2949 new rows | completed batches 427/738 | last batch size=4 | gml_id range=120169 -> 123407
# Processed 1712/2949 new rows | completed batches 428/738 | last batch size=4 | gml_id range=123408 -> 124274
# Processed 1716/2949 new rows | completed batches 429/738 | last batch size=4 | gml_id range=124298 -> 124753
# Checkpoint saved with 52 new rows
# Processed 1720/2949 new rows | completed batches 430/738 | last batch size=4 | gml_id range=124754 -> 125900
# Processed 1724/2949 new rows | completed batches 431/738 | last batch size=4 | gml_id range=125902 -> 128996
# Processed 1728/2949 new rows | completed batches 432/738 | last batch size=4 | gml_id range=129003 -> 130600
# Processed 1732/2949 new rows | completed batches 433/738 | last batch size=4 | gml_id range=132229 -> 135730
# Processed 1736/2949 new rows | completed batches 434/738 | last batch size=4 | gml_id range=135732 -> 134813
# Processed 1740/2949 new rows | completed batches 435/738 | last batch size=4 | gml_id range=130601 -> 132228
# ...
# Processed 2384/2949 new rows | completed batches 596/738 | last batch size=4 | gml_id range=425313 -> 426767
# Processed 2388/2949 new rows | completed batches 597/738 | last batch size=4 | gml_id range=419959 -> 425312
# Processed 2392/2949 new rows | completed batches 598/738 | last batch size=4 | gml_id range=429410 -> 429874
# Checkpoint saved with 52 new rows
# Processed 2396/2949 new rows | completed batches 599/738 | last batch size=4 | gml_id range=429877 -> 431203
# Processed 2400/2949 new rows | completed batches 600/738 | last batch size=4 | gml_id range=429875 -> 429876
# Processed 2404/2949 new rows | completed batches 601/738 | last batch size=4 | gml_id range=431204 -> 433131
# Processed 2408/2949 new rows | completed batches 602/738 | last batch size=4 | gml_id range=433158 -> 433376
# Processed 2412/2949 new rows | completed batches 603/738 | last batch size=4 | gml_id range=433377 -> 435088
# Processed 2416/2949 new rows | completed batches 604/738 | last batch size=4 | gml_id range=435117 -> 437913
# Processed 2420/2949 new rows | completed batches 605/738 | last batch size=4 | gml_id range=437964 -> 438975
# Processed 2424/2949 new rows | completed batches 606/738 | last batch size=4 | gml_id range=439088 -> 439747
# Processed 2428/2949 new rows | completed batches 607/738 | last batch size=4 | gml_id range=439757 -> 440048
# Processed 2432/2949 new rows | completed batches 608/738 | last batch size=4 | gml_id range=440049 -> 442663
# Processed 2436/2949 new rows | completed batches 609/738 | last batch size=4 | gml_id range=442664 -> 442720
# Processed 2440/2949 new rows | completed batches 610/738 | last batch size=4 | gml_id range=442721 -> 443647
# Processed 2444/2949 new rows | completed batches 611/738 | last batch size=4 | gml_id range=443672 -> 444784
# Checkpoint saved with 52 new rows
# Processed 2448/2949 new rows | completed batches 612/738 | last batch size=4 | gml_id range=446719 -> 447005
# Processed 2452/2949 new rows | completed batches 613/738 | last batch size=4 | gml_id range=447085 -> 448086
# Processed 2456/2949 new rows | completed batches 614/738 | last batch size=4 | gml_id range=448087 -> 448531
# Processed 2460/2949 new rows | completed batches 615/738 | last batch size=4 | gml_id range=444785 -> 446686
# Processed 2464/2949 new rows | completed batches 616/738 | last batch size=4 | gml_id range=448182 -> 448557
# Processed 2468/2949 new rows | completed batches 617/738 | last batch size=4 | gml_id range=448546 -> 448180
# Processed 2472/2949 new rows | completed batches 618/738 | last batch size=4 | gml_id range=448567 -> 450481
# Processed 2476/2949 new rows | completed batches 619/738 | last batch size=4 | gml_id range=450482 -> 450862
# Processed 2480/2949 new rows | completed batches 620/738 | last batch size=4 | gml_id range=454136 -> 457235
# Processed 2484/2949 new rows | completed batches 621/738 | last batch size=4 | gml_id range=450904 -> 454134
# Processed 2488/2949 new rows | completed batches 622/738 | last batch size=4 | gml_id range=457236 -> 459526
# Processed 2492/2949 new rows | completed batches 623/738 | last batch size=4 | gml_id range=459532 -> 461316
# Processed 2496/2949 new rows | completed batches 624/738 | last batch size=4 | gml_id range=461318 -> 463180
# Checkpoint saved with 52 new rows
# Processed 2500/2949 new rows | completed batches 625/738 | last batch size=4 | gml_id range=463181 -> 463217
# Processed 2504/2949 new rows | completed batches 626/738 | last batch size=4 | gml_id range=465125 -> 465164
# Processed 2508/2949 new rows | completed batches 627/738 | last batch size=4 | gml_id range=465165 -> 466302
# Processed 2512/2949 new rows | completed batches 628/738 | last batch size=4 | gml_id range=463220 -> 465118
# Processed 2516/2949 new rows | completed batches 629/738 | last batch size=4 | gml_id range=466371 -> 465823
# Processed 2520/2949 new rows | completed batches 630/738 | last batch size=4 | gml_id range=465824 -> 467227
# Processed 2524/2949 new rows | completed batches 631/738 | last batch size=4 | gml_id range=467244 -> 467519
# Processed 2528/2949 new rows | completed batches 632/738 | last batch size=4 | gml_id range=468003 -> 468221
# Processed 2532/2949 new rows | completed batches 633/738 | last batch size=4 | gml_id range=467671 -> 467946
# Processed 2536/2949 new rows | completed batches 634/738 | last batch size=4 | gml_id range=468512 -> 469249
# Processed 2540/2949 new rows | completed batches 635/738 | last batch size=4 | gml_id range=468254 -> 468511
# Processed 2544/2949 new rows | completed batches 636/738 | last batch size=4 | gml_id range=469284 -> 470090
# Processed 2548/2949 new rows | completed batches 637/738 | last batch size=4 | gml_id range=470094 -> 470769
# Checkpoint saved with 52 new rows
# Processed 2552/2949 new rows | completed batches 638/738 | last batch size=4 | gml_id range=470770 -> 472512
# Processed 2556/2949 new rows | completed batches 639/738 | last batch size=4 | gml_id range=472513 -> 472622
# Processed 2560/2949 new rows | completed batches 640/738 | last batch size=4 | gml_id range=472623 -> 473109
# Processed 2564/2949 new rows | completed batches 641/738 | last batch size=4 | gml_id range=473110 -> 474959
# Processed 2568/2949 new rows | completed batches 642/738 | last batch size=4 | gml_id range=476667 -> 477499
# Processed 2572/2949 new rows | completed batches 643/738 | last batch size=4 | gml_id range=474960 -> 476652
# Processed 2576/2949 new rows | completed batches 644/738 | last batch size=4 | gml_id range=477520 -> 478039
# Processed 2580/2949 new rows | completed batches 645/738 | last batch size=4 | gml_id range=478284 -> 479417
# Processed 2584/2949 new rows | completed batches 646/738 | last batch size=4 | gml_id range=479418 -> 485265
# Processed 2588/2949 new rows | completed batches 647/738 | last batch size=4 | gml_id range=478064 -> 478247
# Processed 2592/2949 new rows | completed batches 648/738 | last batch size=4 | gml_id range=486517 -> 486554
# Processed 2596/2949 new rows | completed batches 649/738 | last batch size=4 | gml_id range=485287 -> 486516
# Processed 2600/2949 new rows | completed batches 650/738 | last batch size=4 | gml_id range=486555 -> 486610
# Checkpoint saved with 52 new rows
# Processed 2604/2949 new rows | completed batches 651/738 | last batch size=4 | gml_id range=486611 -> 486781
# Processed 2608/2949 new rows | completed batches 652/738 | last batch size=4 | gml_id range=486782 -> 487735
# Processed 2612/2949 new rows | completed batches 653/738 | last batch size=4 | gml_id range=487736 -> 489915
# Processed 2616/2949 new rows | completed batches 654/738 | last batch size=4 | gml_id range=489922 -> 490449
# Processed 2620/2949 new rows | completed batches 655/738 | last batch size=4 | gml_id range=490465 -> 492426
# Processed 2624/2949 new rows | completed batches 656/738 | last batch size=4 | gml_id range=492427 -> 492465
# Processed 2628/2949 new rows | completed batches 657/738 | last batch size=4 | gml_id range=492466 -> 493798
# Processed 2632/2949 new rows | completed batches 658/738 | last batch size=4 | gml_id range=493799 -> 495279
# Processed 2636/2949 new rows | completed batches 659/738 | last batch size=4 | gml_id range=495319 -> 495535
# Processed 2640/2949 new rows | completed batches 660/738 | last batch size=4 | gml_id range=495537 -> 495872
# Processed 2644/2949 new rows | completed batches 661/738 | last batch size=4 | gml_id range=495873 -> 497408
# Processed 2648/2949 new rows | completed batches 662/738 | last batch size=4 | gml_id range=497506 -> 499011
# Processed 2652/2949 new rows | completed batches 663/738 | last batch size=4 | gml_id range=497409 -> 497464
# Checkpoint saved with 52 new rows
# Processed 2656/2949 new rows | completed batches 664/738 | last batch size=4 | gml_id range=499014 -> 499724
# Processed 2660/2949 new rows | completed batches 665/738 | last batch size=4 | gml_id range=501907 -> 504842
# Processed 2664/2949 new rows | completed batches 666/738 | last batch size=4 | gml_id range=499725 -> 501905
# Processed 2668/2949 new rows | completed batches 667/738 | last batch size=4 | gml_id range=504843 -> 506564
# Processed 2672/2949 new rows | completed batches 668/738 | last batch size=4 | gml_id range=506702 -> 507262
# Processed 2676/2949 new rows | completed batches 669/738 | last batch size=4 | gml_id range=507270 -> 508280
# Processed 2680/2949 new rows | completed batches 670/738 | last batch size=4 | gml_id range=508316 -> 509388
# Processed 2684/2949 new rows | completed batches 671/738 | last batch size=4 | gml_id range=509390 -> 510974
# Processed 2688/2949 new rows | completed batches 672/738 | last batch size=4 | gml_id range=511456 -> 511556
# Processed 2692/2949 new rows | completed batches 673/738 | last batch size=4 | gml_id range=510975 -> 511455
# Processed 2696/2949 new rows | completed batches 674/738 | last batch size=4 | gml_id range=512637 -> 513582
# Processed 2700/2949 new rows | completed batches 675/738 | last batch size=4 | gml_id range=511557 -> 512634
# Processed 2704/2949 new rows | completed batches 676/738 | last batch size=4 | gml_id range=513583 -> 513640
# Checkpoint saved with 52 new rows
# Processed 2708/2949 new rows | completed batches 677/738 | last batch size=4 | gml_id range=513641 -> 513977
# Processed 2712/2949 new rows | completed batches 678/738 | last batch size=4 | gml_id range=514510 -> 515104
# Processed 2716/2949 new rows | completed batches 679/738 | last batch size=4 | gml_id range=513978 -> 514509
# Processed 2720/2949 new rows | completed batches 680/738 | last batch size=4 | gml_id range=515105 -> 515213
# Processed 2724/2949 new rows | completed batches 681/738 | last batch size=4 | gml_id range=515214 -> 515688
# Processed 2728/2949 new rows | completed batches 682/738 | last batch size=4 | gml_id range=515689 -> 515813
# Processed 2732/2949 new rows | completed batches 683/738 | last batch size=4 | gml_id range=515814 -> 516584
# Processed 2736/2949 new rows | completed batches 684/738 | last batch size=4 | gml_id range=516615 -> 518181
# Processed 2740/2949 new rows | completed batches 685/738 | last batch size=4 | gml_id range=518182 -> 518670
# Processed 2744/2949 new rows | completed batches 686/738 | last batch size=4 | gml_id range=518721 -> 519737
# Processed 2748/2949 new rows | completed batches 687/738 | last batch size=4 | gml_id range=519738 -> 520426
# Processed 2752/2949 new rows | completed batches 688/738 | last batch size=4 | gml_id range=520427 -> 521152
# Processed 2756/2949 new rows | completed batches 689/738 | last batch size=4 | gml_id range=521153 -> 522769
# Checkpoint saved with 52 new rows
# Processed 2760/2949 new rows | completed batches 690/738 | last batch size=4 | gml_id range=522794 -> 522426
# Processed 2764/2949 new rows | completed batches 691/738 | last batch size=4 | gml_id range=523670 -> 523347
# Processed 2768/2949 new rows | completed batches 692/738 | last batch size=4 | gml_id range=522427 -> 523645
# Processed 2772/2949 new rows | completed batches 693/738 | last batch size=4 | gml_id range=523424 -> 523739
# Processed 2776/2949 new rows | completed batches 694/738 | last batch size=4 | gml_id range=528880 -> 529021
# Processed 2780/2949 new rows | completed batches 695/738 | last batch size=4 | gml_id range=523740 -> 528851
# Processed 2784/2949 new rows | completed batches 696/738 | last batch size=4 | gml_id range=529056 -> 529804
# Processed 2788/2949 new rows | completed batches 697/738 | last batch size=4 | gml_id range=529805 -> 529876
# Processed 2792/2949 new rows | completed batches 698/738 | last batch size=4 | gml_id range=529906 -> 530138
# Processed 2796/2949 new rows | completed batches 699/738 | last batch size=4 | gml_id range=530141 -> 530402
# Processed 2800/2949 new rows | completed batches 700/738 | last batch size=4 | gml_id range=530405 -> 530651
# Processed 2804/2949 new rows | completed batches 701/738 | last batch size=4 | gml_id range=530652 -> 531445
# Processed 2808/2949 new rows | completed batches 702/738 | last batch size=4 | gml_id range=531446 -> 532333
# Checkpoint saved with 52 new rows
# Processed 2812/2949 new rows | completed batches 703/738 | last batch size=4 | gml_id range=532335 -> 532382
# Processed 2816/2949 new rows | completed batches 704/738 | last batch size=4 | gml_id range=533076 -> 533950
# Processed 2820/2949 new rows | completed batches 705/738 | last batch size=4 | gml_id range=532383 -> 533075
# Processed 2824/2949 new rows | completed batches 706/738 | last batch size=4 | gml_id range=533952 -> 535277
# Processed 2828/2949 new rows | completed batches 707/738 | last batch size=4 | gml_id range=535278 -> 534795
# Processed 2832/2949 new rows | completed batches 708/738 | last batch size=4 | gml_id range=534796 -> 537230
# Processed 2836/2949 new rows | completed batches 709/738 | last batch size=4 | gml_id range=538280 -> 538238
# Processed 2840/2949 new rows | completed batches 710/738 | last batch size=4 | gml_id range=537232 -> 538279
# Processed 2844/2949 new rows | completed batches 711/738 | last batch size=4 | gml_id range=538239 -> 538665
# Processed 2848/2949 new rows | completed batches 712/738 | last batch size=4 | gml_id range=538666 -> 538708
# Processed 2852/2949 new rows | completed batches 713/738 | last batch size=4 | gml_id range=538725 -> 539209
# Processed 2856/2949 new rows | completed batches 714/738 | last batch size=4 | gml_id range=539211 -> 540098
# Processed 2860/2949 new rows | completed batches 715/738 | last batch size=4 | gml_id range=540100 -> 540093
# Checkpoint saved with 52 new rows
# Processed 2864/2949 new rows | completed batches 716/738 | last batch size=4 | gml_id range=540094 -> 541157
# Processed 2868/2949 new rows | completed batches 717/738 | last batch size=4 | gml_id range=541159 -> 543087
# Processed 2872/2949 new rows | completed batches 718/738 | last batch size=4 | gml_id range=543088 -> 543375
# Processed 2876/2949 new rows | completed batches 719/738 | last batch size=4 | gml_id range=543376 -> 544222
# Processed 2880/2949 new rows | completed batches 720/738 | last batch size=4 | gml_id range=544223 -> 544549
# Processed 2884/2949 new rows | completed batches 721/738 | last batch size=4 | gml_id range=544550 -> 545488
# Processed 2888/2949 new rows | completed batches 722/738 | last batch size=4 | gml_id range=545489 -> 545724
# Processed 2892/2949 new rows | completed batches 723/738 | last batch size=4 | gml_id range=545804 -> 546420
# Processed 2896/2949 new rows | completed batches 724/738 | last batch size=4 | gml_id range=546438 -> 547389
# Processed 2900/2949 new rows | completed batches 725/738 | last batch size=4 | gml_id range=547419 -> 550452
# Processed 2904/2949 new rows | completed batches 726/738 | last batch size=4 | gml_id range=555873 -> 565189
# Processed 2908/2949 new rows | completed batches 727/738 | last batch size=4 | gml_id range=551954 -> 555858
# Processed 2912/2949 new rows | completed batches 728/738 | last batch size=4 | gml_id range=550453 -> 551952
# Checkpoint saved with 52 new rows
# Processed 2916/2949 new rows | completed batches 729/738 | last batch size=4 | gml_id range=569595 -> 571301
# Processed 2920/2949 new rows | completed batches 730/738 | last batch size=4 | gml_id range=565182 -> 566780
# Processed 2924/2949 new rows | completed batches 731/738 | last batch size=4 | gml_id range=566795 -> 569582
# Processed 2928/2949 new rows | completed batches 732/738 | last batch size=4 | gml_id range=571364 -> 572928
# Processed 2932/2949 new rows | completed batches 733/738 | last batch size=4 | gml_id range=576374 -> 589545
# Processed 2936/2949 new rows | completed batches 734/738 | last batch size=4 | gml_id range=589581 -> 594153
# Processed 2940/2949 new rows | completed batches 735/738 | last batch size=4 | gml_id range=573118 -> 576357
# Processed 2944/2949 new rows | completed batches 736/738 | last batch size=4 | gml_id range=594156 -> 596686
# Processed 2948/2949 new rows | completed batches 737/738 | last batch size=4 | gml_id range=596722 -> 609012
# Processed 2949/2949 new rows | completed batches 738/738 | last batch size=1 | gml_id range=609008 -> 609008
# Final checkpoint saved.
