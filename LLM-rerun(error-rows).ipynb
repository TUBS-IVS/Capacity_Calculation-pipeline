# %%
import pandas as pd

pois = r"error_predictions.parquet"

# Load the POI layer
pois = pd.read_parquet(pois)

print(f"Loaded {len(pois)} POIs")

# import geopandas as gpd
# from pathlib import Path

# pois_path = Path("final_predictions_with_geometry_rerun-single-prediction-row_filtered.gpkg")   # change filename if needed

# # Load GPKG layer
# pois = gpd.read_file(pois_path)

# print(f"Loaded {len(pois)} rows")
# Out:
# Loaded 16742 POIs

# %%
pois.head()
# Out:
#      gml_id    volume_m3                            label_en  \
# 0        17   163.316463  Buildings for business or commerce
# 1        18  5501.119241               residential buildings
# 2        19  1624.116199               residential buildings
# 3        20  2482.074274               residential buildings
# 1996   2111    84.735173  Buildings for business or commerce
#
#      osm_building_type osm_landuse_class osm_landuse_name gfk_class  \
# 0                 None       residential             None   Gebäude
# 1                 None       residential             None   Gebäude
# 2                 None       residential             None   Gebäude
# 3                 None       residential             None   Gebäude
# 1996              None       residential             None   Gebäude
#
#         ALKIS_Landuse_info osm_names                           alkis_address  \
# 0                residence      None                     Braunschweig, Stadt
# 1                residence      None  Danziger Straße 26 Braunschweig, Stadt
# 2     residence;industrial      None      Fasanenkamp 10 Braunschweig, Stadt
# 3                residence      None    Margeritenweg 37 Braunschweig, Stadt
# 1996             residence      None                     Braunschweig, Stadt
#
#       ... tourism information tags_search additional_information website  \
# 0     ...    None        None        None                   None    None
# 1     ...    None        None        None                   None    None
# 2     ...    None        None        None                   None    None
# 3     ...    None        None        None                   None    None
# 1996  ...    None        None        None                   None    None
#
#                                                sentence interpreted_type  \
# 0     general_building_context: building_label=Build...            error
# 1     general_building_context: building_label=resid...            error
# 2     general_building_context: building_label=resid...            error
# 3     general_building_context: building_label=resid...            error
# 1996  general_building_context: building_label=Build...            error
#
#      mid_labels bosserhof_class  \
# 0            []            None
# 1            []            None
# 2            []            None
# 3            []            None
# 1996         []            None
#
#                                                   error
# 0     TU LLM call failed: 429 Client Error: 429 for ...
# 1     TU LLM call failed: 429 Client Error: 429 for ...
# 2     TU LLM call failed: 429 Client Error: 429 for ...
# 3     TU LLM call failed: 429 Client Error: 429 for ...
# 1996  TU LLM call failed: 429 Client Error: 429 for ...
#
# [5 rows x 24 columns]

# %%
pois.columns
# Out:
# Index(['gml_id', 'volume_m3', 'label_en', 'osm_building_type',
#        'osm_landuse_class', 'osm_landuse_name', 'gfk_class',
#        'ALKIS_Landuse_info', 'osm_names', 'alkis_address', 'email', 'amenity',
#        'building', 'shop', 'tourism', 'information', 'tags_search',
#        'additional_information', 'website', 'sentence', 'interpreted_type',
#        'mid_labels', 'bosserhof_class', 'error'],
#       dtype='object')

# %%
pois = pois.drop(columns=["interpreted_type", "mid_labels", "bosserhof_class", "error"],axis=1)
pois.columns

# pois = pois.drop(columns=["geometry"],axis=1)
# pois.columns
# Out:
# Index(['gml_id', 'volume_m3', 'label_en', 'osm_building_type',
#        'osm_landuse_class', 'osm_landuse_name', 'gfk_class',
#        'ALKIS_Landuse_info', 'osm_names', 'alkis_address', 'email', 'amenity',
#        'building', 'shop', 'tourism', 'information', 'tags_search',
#        'additional_information', 'website', 'sentence'],
#       dtype='object')

# %%
pois.head()
# Out:
#      gml_id    volume_m3                            label_en  \
# 0        17   163.316463  Buildings for business or commerce
# 1        18  5501.119241               residential buildings
# 2        19  1624.116199               residential buildings
# 3        20  2482.074274               residential buildings
# 1996   2111    84.735173  Buildings for business or commerce
#
#      osm_building_type osm_landuse_class osm_landuse_name gfk_class  \
# 0                 None       residential             None   Gebäude
# 1                 None       residential             None   Gebäude
# 2                 None       residential             None   Gebäude
# 3                 None       residential             None   Gebäude
# 1996              None       residential             None   Gebäude
#
#         ALKIS_Landuse_info osm_names                           alkis_address  \
# 0                residence      None                     Braunschweig, Stadt
# 1                residence      None  Danziger Straße 26 Braunschweig, Stadt
# 2     residence;industrial      None      Fasanenkamp 10 Braunschweig, Stadt
# 3                residence      None    Margeritenweg 37 Braunschweig, Stadt
# 1996             residence      None                     Braunschweig, Stadt
#
#      email amenity building  shop tourism information tags_search  \
# 0     None    None     None  None    None        None        None
# 1     None    None     None  None    None        None        None
# 2     None    None     None  None    None        None        None
# 3     None    None     None  None    None        None        None
# 1996  None    None     None  None    None        None        None
#
#      additional_information website  \
# 0                      None    None
# 1                      None    None
# 2                      None    None
# 3                      None    None
# 1996                   None    None
#
#                                                sentence
# 0     general_building_context: building_label=Build...
# 1     general_building_context: building_label=resid...
# 2     general_building_context: building_label=resid...
# 3     general_building_context: building_label=resid...
# 1996  general_building_context: building_label=Build...

# %%
import json
import time
import re
import requests
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

ENV_PATH = Path(".env")
load_dotenv(dotenv_path=ENV_PATH)

TU_TOKEN = os.getenv("TU_KI_TOOLBOX_TOKEN")

if not TU_TOKEN:
    raise RuntimeError(
        "Missing TU_KI_TOOLBOX_TOKEN."
        "Check Areas-of-interest-POIs/.env"
    )

API_URL = "https://ki-toolbox.tu-braunschweig.de/api/v1/chat/send"
# MODEL = "gpt-5.4-2026-03-05" # chatgpt-5.2
MODEL = "gpt-oss-120b" # open source chatgpt-oss-120b

# %%
SYSTEM_PROMPT = """
You are a building activity interpreter and classifier.

Your task is to classify BUILDINGS using structured input divided into TWO PARTS:

1) precise_known_info → high-confidence OSM-derived signals such as names, amenity, shop, office, tourism, healthcare, leisure, etc.
2) general_building_context → broader contextual signals such as ALKIS landuse, OSM building type, OSM landuse, auxiliary tags, and other building-context information.

You must produce TWO outputs:
1) Activity labels (mid_labels) → what activities take place inside the building
2) Bosserhof class → the dominant functional building-use class for capacity / volume estimation

────────────────────────────────────
CRITICAL SCOPE RULE
────────────────────────────────────

Only classify ENTERABLE BUILDINGS or building-like places people actually use as destinations.

If the described place is not a building, not enterable, or only an outdoor / infrastructure / passive object:
- "mid_labels": []
- "bosserhof_class": null

────────────────────────────────────
INPUT STRUCTURE AND EVIDENCE PRIORITY
────────────────────────────────────

precise_known_info:
- Primary source for mid_labels
- Usually contains reliable OSM-derived evidence
- May contain several names, shops, amenities, offices, healthcare uses, leisure uses, tourism uses, or other POI functions
- Treat multiple entries as possible multiple activities inside the same building

general_building_context:
- Primary source for Bosserhof classification
- Broader but less precise
- May include ALKIS building/land-use information, OSM building type, tags (General Information About pois), or auxiliary contextual fields
- Use it as fallback for mid_labels only when precise_known_info is weak, empty, or incomplete

────────────────────────────────────
PART A — ACTIVITY LABELS (VISITOR INTENT)
────────────────────────────────────

ALLOWED ACTIVITY LABELS
- work
- university
- school
- childcare
- retail_daily
- retail_non_daily
- leisure
- sports
- errands
- meetup
- lessons
- business

GOAL:
Identify ALL clearly supported activities taking place INSIDE the building.

MANDATORY PROCEDURE:
1) First extract every distinct function from precise_known_info.
   Each name, amenity, shop, office, healthcare, leisure, tourism, craft, service, or other POI-like entry can represent a separate function.
2) Map each extracted function independently to one or more activity labels.
3) Aggregate labels across all functions.
4) Remove duplicates.
5) Do not stop after the first detected function.

If precise_known_info is missing or very weak, use general_building_context to infer likely building activity, but be more conservative.

MULTI-ACTIVITY RULE (VERY IMPORTANT):
- A building may contain MANY activities (e.g., mall, mixed-use building)
- You MUST extract ALL clearly supported activities
- Do NOT collapse multiple activities into one
- Do NOT stop at the first match

Think of the building as a container of activities:
→ Identify EACH distinct function mentioned
→ Map EACH to a label

────────────────────────────────────
LABEL DEFINITIONS
────────────────────────────────────

- work

Represents on-site labor, operational activity, or institutional functioning carried out by people inside the building.
Assign this label whenever the building’s normal use depends on people being physically present
to carry out tasks, responsibilities, operations, supervision, coordination, production,
maintenance, administration, instruction, care, or service provision.
The focus of this label is not why visitors come, but whether the building functions as a place
where human work is performed as part of its regular purpose.
A building should receive "work" whenever people are not merely present incidentally,
but are there in an active functional role that helps the building fulfill its purpose.
This includes cases where the same building also serves customers, students, patients, clients,
guests, or other visitors. In such cases, "work" must be added in parallel with the visitor-oriented label(s),
because the activity of workers is part of the building’s core function.
Core idea: "People are here not only to use the building, but also to make it function."

- university

Represents tertiary/higher-level education activity.
Covers structured learning, teaching, and research at the higher education level
Involves academic instruction, research, and study environments
Distinct from general learning by its institutional and advanced nature
Core idea: “Advanced academic education and research happen here.”

- school

Represents formal compulsory or pre-tertiary education activity.
Covers structured education for children and adolescents
Includes general and vocational schooling
Defined by curriculum-based learning under institutional supervision
Core idea: “Children or teenagers receive structured education here.”

- childcare

Represents supervision and early development care for young children.
Focuses on care, supervision, and early-stage development
Not primarily academic or curriculum-driven (unlike school)
Strong emphasis on custodial and developmental support
Core idea: “Young children are cared for and supervised here.”

- retail_daily

Represents frequent, necessity-driven consumption activity.
Covers acquisition of essential, regularly needed goods
Characterized by high frequency and routine visits
Typically tied to basic living needs
Core idea: “People come here regularly to fulfill essential daily needs.”

- retail_non_daily

Represents infrequent, discretionary consumption activity.
Covers acquisition of non-essential or durable goods
Visits are planned, occasional, or need-based
Often involves comparison, browsing, or larger purchases
Core idea: “People come here occasionally to buy non-essential or long-term goods.”

- leisure

Represents hedonic, relaxation, or enjoyment-oriented activity.
Focuses on free-time use driven by pleasure, comfort, or experience
Includes passive or active enjoyment, but not primarily goal-oriented tasks
Distinguished by non-obligatory participation. People choose to go here for enjoyment, not out of necessity or obligation.
Core idea: “People come here to relax, enjoy, or spend free time.”

- sports

Represents physical activity, exercise, or bodily training.
Focuses on intentional physical exertion or fitness improvement
Can be recreational or structured, but always movement-centered
Distinguished from leisure by physical intensity and purpose
Core idea: “People come here to be physically active or train their body.”

- errands

Represents task-oriented, functional activities needed for daily life management.
Covers practical obligations or maintenance tasks
Typically short, goal-driven visits with a clear outcome
Often involves services, administration, or personal maintenance
Core idea: “People come here to complete necessary tasks or obligations.”

- meetup

Represents social interaction and gathering activity.
Focuses on interpersonal connection and shared presence
Can be informal or organized, but the primary purpose is social exchange
Not necessarily tied to consumption or formal structure
Core idea: “People come here to meet and interact with others.”

- lessons

Represents structured instruction or skill acquisition activity.
Focuses on learning guided by an instructor
Can occur at any level (formal or informal), but always organized and instructional
Distinguished from general education by activity type (learning session), not institution
Core idea: “People come here to learn something through instruction.”

- business

Represents professional or organizational interaction activity (non-routine workplace).
Covers goal-oriented professional interactions, often external-facing
Includes meetings, consulting, administrative dealings, or formal exchanges
Distinct from "work" because it reflects the visitor’s purpose, not employment
Core idea: “People come here for professional or organizational matters.”

────────────────────────────────────
PART B — BOSSERHOF BUILDING-USE CLASS
────────────────────────────────────

GOAL
Assign EXACTLY ONE Bosserhof label that matches the categories/subcategories.

KEY PRINCIPLE:
Bosserhof is NOT about activities — it is about the BUILDING TYPE.

SOURCE PRIORITY FOR BOSSERHOF:
1) general_building_context is the primary source
2) precise_known_info supports or refines the choice
3) mid_labels can help interpret use, but must not override stronger building-type evidence

DOMINANCE HEURISTIC:
Choose the dominant function using:
1) explicit building type or ALKIS function
2) landuse / area context
3) scale indicators such as mall, shopping centre, school complex, office building, industrial hall, hospital, hotel
4) repeated / majority functions among multiple entries
5) if still unclear, choose the closest headline class rather than null

MULTI-TENANT BUILDINGS:
- Extract ALL activities (mid_labels)
- Assign ONE dominant Bosserhof class

STEP 1 — Subcategory FIRST (preferred)
If you can confidently map the building to ONE of the Bosserhof SUBCATEGORIES listed below,
output that subcategory label (exact string match).

STEP 2 — Headline category fallback (MANDATORY WHEN SUBCATEGORY IS UNCERTAIN)
If the exact subcategory is uncertain but the dominant functional sector is inferable,
you MUST output the corresponding HEADLINE category.
Do not return null when a headline category can reasonably represent the building's dominant use.

STEP 3 — No assignment
If the building does not fit reliably in any headline category OR is not an enterable building,
output bosserhof_class = null.

────────────────────────────────────
ALLOWED BOSSERHOF HEADLINE CATEGORIES AND SUBCATEGORIES
────────────────────────────────────

NEAREST-VALID-CLASS RULE (MANDATORY)

If the building is clearly enterable and supports a recognizable human activity,
you MUST assign the closest Bosserhof class, even if the fit is imperfect.

1) Transport
- no fixed subcategories given; use headline when transport building with staff is clear
Notes: Transport-related buildings with operational staff (depots, terminals)
Exclude: stops/platforms/tracks

2) Yards, depots, storage areas, construction yards
- no fixed subcategories given; use headline when storage/yard with staff is clear
Notes: Storage or operational yards with staff
Exclude: pure storage without staff, open yards without buildings

3) Industrial operations / Production
Subcategories:
- highly productive industries / machine / material or space intensive
- others

4) Crafts and trades
Subcategories:
- craft businesses
- craft courtyards

5) Services
Subcategories:
- normal office
- open-plan office
- business-oriented services
- customer-oriented services
- hotels
- hotels with conference areas
- restaurants / gastronomy
- suppliers for car dealerships
- vehicle / electrical repair
- customer service
- car dealerships

6) Retail
Subcategories:
- wholesale
- retail (small-scale)
- discount stores
- DIY stores
- furniture stores
- hypermarkets / superstores
- shopping centers
- self-service department stores
- department stores
- factory outlet centers

7) Public facilities
Subcategories:
- schools
- universities
- research institutes
- kindergartens
- hospitals
- nursing homes

8) Facilities for culture, leisure and sports
Subcategories:
- entertainment, culture
- large cinemas
- musical theatres
- large discos, fun / leisure pools
- arenas, large events
- theme parks
- fitness / wellness

────────────────────────────────────
OUTPUT FORMAT (STRICT JSON ONLY)
────────────────────────────────────

{
  "interpreted_type": "<plain-English description of what the place most likely is>",
  "mid_labels": ["<zero or more activity labels from the allowed list>"],
  "bosserhof_class": "<one Bosserhof class or null>"}
""".strip()

# %%
# -----------------------------
# MiD labels (STRICT)
# -----------------------------

TARGET_MID_LABELS = {
    "work",
    "university",
    "school",
    "childcare",
    "retail_daily",
    "retail_non_daily",
    "leisure",
    "sports",
    "errands",
    "meetup",
    "lessons",
    "business"
}

# -----------------------------
# JSON extraction
# -----------------------------
def extract_first_json_object(text: str) -> dict:
    """
    Extract the first JSON object from model output.
    """
    m = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found in output.")
    return json.loads(m.group(0))


# -----------------------------
# Validation (PROMPT-ALIGNED)
# -----------------------------
def validate(obj: dict):
    if "interpreted_type" not in obj or not isinstance(obj["interpreted_type"], str):
        raise ValueError("Missing or invalid interpreted_type")

    if "mid_labels" not in obj or not isinstance(obj["mid_labels"], list):
        raise ValueError("mid_labels must be a list")

    if "bosserhof_class" not in obj:
        raise ValueError("Missing bosserhof_class")

    for lab in obj["mid_labels"]:
        if lab not in TARGET_MID_LABELS:
            raise ValueError(f"Invalid MiD label: {lab}")

    bc = obj["bosserhof_class"]

    # null is valid
    if bc is None:
        return

    # string class is valid
    if isinstance(bc, str) and bc.strip():
        return

    raise ValueError("bosserhof_class must be a non-empty string or None")

# %%
def call_tu_llm(
    user_input: str = None,
    batch_inputs: list = None,
    max_retries=3,
    backoff_sec=2.0,
    debug=False,
) -> str:

    headers = {
        "Authorization": f"Bearer {TU_TOKEN}",
        "Accept": "application/json",
        "Content-Type": "application/json",
    }

    # -----------------------------
    # Build prompt
    # -----------------------------
    if batch_inputs is not None:
        items = []
        for i, row in enumerate(batch_inputs, start=1):
            gml_id = str(row["gml_id"])
            sentence = "" if row.get("sentence") is None else str(row.get("sentence"))
            items.append(
                f"ITEM {i}\n"
                f"gml_id: {gml_id}\n"
                f"sentence: {sentence}"
            )
        prompt_text = "\n\n".join(items)
    else:
        prompt_text = "" if user_input is None else str(user_input)

    payload = {
        "thread": None,
        "prompt": prompt_text,
        "model": MODEL,
        "customInstructions": SYSTEM_PROMPT,
        "hideCustomInstructions": True,
    }

    last_err = None

    for attempt in range(1, max_retries + 1):
        try:
            r = requests.post(
                API_URL,
                headers=headers,
                json=payload,
                stream=True,
                timeout=120,
            )

            if debug:
                print("STATUS:", r.status_code)
                try:
                    print("REQUEST PAYLOAD:", json.dumps(payload, indent=2)[:4000])
                except Exception:
                    pass

            r.raise_for_status()

            full_text = ""

            for line in r.iter_lines(decode_unicode=True):
                if not line:
                    continue
                try:
                    event = json.loads(line)
                except json.JSONDecodeError:
                    continue

                if event.get("type") == "chunk":
                    full_text += event.get("content", "")
                elif event.get("type") == "done":
                    if "response" in event:
                        full_text = event["response"]
                    break

            return full_text

        except Exception as e:
            last_err = e
            if debug:
                print(f"Attempt {attempt} failed: {e}")
            time.sleep(backoff_sec * attempt)

    raise RuntimeError(f"TU LLM call failed: {last_err}")

# %%
def predict_from_sentence(gml_id=None, sentence=None, batch_rows=None, debug=False):
    # -------------------------------------------------
    # BATCH MODE
    # -------------------------------------------------
    if batch_rows is not None:
        try:
            raw = call_tu_llm(batch_inputs=batch_rows, debug=debug)
            objs = extract_first_json_array(raw)

            if not isinstance(objs, list):
                raise ValueError("Batch output is not a list.")

            if len(objs) != len(batch_rows):
                raise ValueError(
                    f"Batch size mismatch: got {len(objs)} outputs for {len(batch_rows)} inputs."
                )

            results = []
            for row, obj in zip(batch_rows, objs):
                row_gml_id = row["gml_id"]

                try:
                    validate(obj)
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": obj["interpreted_type"],
                        "mid_labels": obj["mid_labels"],
                        "bosserhof_class": obj["bosserhof_class"],
                    })
                except Exception:
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": "error",
                        "mid_labels": [],
                        "bosserhof_class": None,
                    })

            return results

        except Exception:
            return [
                {
                    "gml_id": row["gml_id"],
                    "interpreted_type": "error",
                    "mid_labels": [],
                    "bosserhof_class": None,
                }
                for row in batch_rows
            ]

    # -------------------------------------------------
    # SINGLE MODE
    # -------------------------------------------------
    gml_id = gml_id.item() if hasattr(gml_id, "item") else gml_id
    sentence = "" if sentence is None else str(sentence)

    try:
        raw = call_tu_llm(user_input=sentence, debug=debug)
        obj = extract_first_json_object(raw)
        validate(obj)

        return {
            "gml_id": gml_id,
            "interpreted_type": obj["interpreted_type"],
            "mid_labels": obj["mid_labels"],
            "bosserhof_class": obj["bosserhof_class"],
        }

    except Exception:
        return {
            "gml_id": gml_id,
            "interpreted_type": "error",
            "mid_labels": [],
            "bosserhof_class": None,
        }
    
def extract_first_json_array(text: str):
    import json
    import re

    match = re.search(r"\[\s*{.*}\s*\]", text, flags=re.DOTALL)
    if not match:
        raise ValueError("No JSON array found in model response.")
    return json.loads(match.group(0))

# %%
import time
import math
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd


# ---------------------------------------------------------
# Helper: split list into chunks
# ---------------------------------------------------------
def chunk_list(items, batch_size):
    for i in range(0, len(items), batch_size):
        yield items[i:i + batch_size]


# ---------------------------------------------------------
# RETRY WRAPPER FOR A WHOLE BATCH
# ---------------------------------------------------------
def predict_batch_with_retry(batch_rows, debug=False, max_retries=3, wait_sec=5):
    last_err = None
    batch_ids = [str(r["gml_id"]) for r in batch_rows]

    for attempt in range(1, max_retries + 1):
        try:
            return predict_batch_from_sentences(
                batch_rows=batch_rows,
                debug=debug,
            )
        except Exception as e:
            last_err = e
            print(f"[batch {batch_ids[:3]}... size={len(batch_rows)}] attempt {attempt}/{max_retries} failed: {e}")
            time.sleep(wait_sec)

    raise last_err


# ---------------------------------------------------------
# THIS IS THE MAIN PLACE TO IMPLEMENT REAL API BATCHING
# ---------------------------------------------------------
def predict_batch_from_sentences(batch_rows, debug=False):
    results = []

    prompts = []
    for row in batch_rows:
        gml_id = str(row["gml_id"])
        sentence = row.get("sentence", "")
        prompts.append({
            "gml_id": gml_id,
            "sentence": sentence,
        })

    res = predict_from_sentence(
        batch_rows=prompts,
        debug=debug,
    )

    if not isinstance(res, list):
        raise ValueError("Batch prediction must return a list.")

    if len(res) != len(batch_rows):
        raise ValueError(
            f"Batch output length mismatch: got {len(res)} results for {len(batch_rows)} rows."
        )

    for item in res:
        if isinstance(item, dict):
            results.append(item)
        else:
            results.append({"prediction": item})

    return results


# ---------------------------------------------------------
# APPEND TO PARQUET
# ---------------------------------------------------------
def append_parquet(path, new_rows, deduplicate_on=None):
    if not new_rows:
        return

    new_df = pd.DataFrame(new_rows)

    if path.exists():
        old_df = pd.read_parquet(path)
        merged = pd.concat([old_df, new_df], ignore_index=True)
    else:
        merged = new_df.copy()

    if deduplicate_on is not None:
        merged = merged.drop_duplicates(subset=[deduplicate_on], keep="last")

    merged.to_parquet(path, index=False)


# ---------------------------------------------------------
# MAIN FUNCTION: PARALLEL + BATCHED
# ---------------------------------------------------------
def classify_resume_parallel_batched(
    pois_df: pd.DataFrame,
    checkpoint_path="predictions_checkpoint.parquet",
    error_path="prediction_errors.parquet",
    save_every=200,
    max_workers=5,
    batch_size=10,
    debug=False,
    max_retries=3,
    retry_wait_sec=5,
):
    checkpoint_path = Path(checkpoint_path)
    error_path = Path(error_path)

    df = pois_df.copy().reset_index(drop=True)

    if "gml_id" not in df.columns:
        raise ValueError("pois_df must contain a 'gml_id' column.")

    if "sentence" not in df.columns:
        raise ValueError("pois_df must contain a 'sentence' column.")

    df["gml_id"] = df["gml_id"].astype(str)

    # do not checkpoint geometry
    cols_to_save = [c for c in df.columns if c != "geometry"]

    # ---------------------------
    # Load checkpoint
    # ---------------------------
    if checkpoint_path.exists():
        checkpoint_df = pd.read_parquet(checkpoint_path)
        checkpoint_df["gml_id"] = checkpoint_df["gml_id"].astype(str)
        done_ids = set(checkpoint_df["gml_id"])
        print(f"Loaded checkpoint with {len(done_ids)} completed rows")
    else:
        done_ids = set()
        print("No checkpoint found. Starting from scratch.")

    remaining_df = df[~df["gml_id"].isin(done_ids)].copy()
    print(f"Remaining rows to process: {len(remaining_df)} / {len(df)}")

    records = remaining_df.to_dict("records")
    batches = list(chunk_list(records, batch_size))

    print(f"Total batches to process: {len(batches)} | batch_size={batch_size} | max_workers={max_workers}")

    def batch_worker(batch_rows):
        batch_results = predict_batch_with_retry(
            batch_rows=batch_rows,
            debug=debug,
            max_retries=max_retries,
            wait_sec=retry_wait_sec,
        )

        if not isinstance(batch_results, list):
            raise ValueError("predict_batch_from_sentences() must return a list.")

        if len(batch_results) != len(batch_rows):
            raise ValueError(
                f"Batch output length mismatch: got {len(batch_results)} results for {len(batch_rows)} rows."
            )

        out_rows = []
        for row_dict, res in zip(batch_rows, batch_results):
            out_row = {k: v for k, v in row_dict.items() if k in cols_to_save}

            if isinstance(res, dict):
                out_row.update(res)
            else:
                out_row["prediction"] = res

            out_rows.append(out_row)

        return out_rows

    buffer = []
    error_buffer = []
    processed_now = 0
    completed_batches = 0

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_batch = {
            executor.submit(batch_worker, batch_rows): batch_rows
            for batch_rows in batches
        }

        for future in as_completed(future_to_batch):
            batch_rows = future_to_batch[future]
            batch_ids = [str(r["gml_id"]) for r in batch_rows]

            try:
                out_rows = future.result()
                buffer.extend(out_rows)

                processed_now += len(out_rows)
                completed_batches += 1

                print(
                    f"Processed {processed_now}/{len(remaining_df)} new rows "
                    f"| completed batches {completed_batches}/{len(batches)} "
                    f"| last batch size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]}"
                )

            except Exception as e:
                for row in batch_rows:
                    error_buffer.append({
                        "gml_id": str(row["gml_id"]),
                        "error": str(e),
                    })

                completed_batches += 1
                print(
                    f"Failed batch {completed_batches}/{len(batches)} "
                    f"| size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]} "
                    f"| error={e}"
                )

            # Save regularly from main thread only
            if len(buffer) >= save_every:
                append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
                print(f"Checkpoint saved with {len(buffer)} new rows")
                buffer = []

            if len(error_buffer) >= save_every:
                append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
                print(f"Error log saved with {len(error_buffer)} rows")
                error_buffer = []

    # final flush
    if buffer:
        append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
        print("Final checkpoint saved.")

    if error_buffer:
        append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
        print("Final error log saved.")

    final_df = pd.read_parquet(checkpoint_path)
    final_df["gml_id"] = final_df["gml_id"].astype(str)

    return final_df

# %%
final_df = classify_resume_parallel_batched(
    pois_df=pois,
    checkpoint_path="predictions_checkpoint(error-rows)-1.parquet",
    error_path="prediction_errors(error-rows).parquet",
    save_every=50,
    max_workers=3,
    batch_size=4,
    debug=False,
    max_retries=2,
    retry_wait_sec=3,
)
# Out:
# No checkpoint found. Starting from scratch.
# Remaining rows to process: 16742 / 16742
# Total batches to process: 4186 | batch_size=4 | max_workers=3
# Processed 4/16742 new rows | completed batches 1/4186 | last batch size=4 | gml_id range=2874 -> 2877
# Processed 8/16742 new rows | completed batches 2/4186 | last batch size=4 | gml_id range=17 -> 20
# Processed 12/16742 new rows | completed batches 3/4186 | last batch size=4 | gml_id range=2111 -> 2114
# Processed 16/16742 new rows | completed batches 4/4186 | last batch size=4 | gml_id range=4582 -> 4586
# Processed 20/16742 new rows | completed batches 5/4186 | last batch size=4 | gml_id range=3984 -> 3988
# Processed 24/16742 new rows | completed batches 6/4186 | last batch size=4 | gml_id range=5315 -> 5319
# Processed 28/16742 new rows | completed batches 7/4186 | last batch size=4 | gml_id range=6200 -> 6205
# Processed 32/16742 new rows | completed batches 8/4186 | last batch size=4 | gml_id range=7716 -> 7719
# Processed 36/16742 new rows | completed batches 9/4186 | last batch size=4 | gml_id range=9255 -> 9258
# Processed 40/16742 new rows | completed batches 10/4186 | last batch size=4 | gml_id range=10477 -> 10480
# Processed 44/16742 new rows | completed batches 11/4186 | last batch size=4 | gml_id range=18523 -> 18526
# Processed 48/16742 new rows | completed batches 12/4186 | last batch size=4 | gml_id range=15164 -> 15167
# Processed 52/16742 new rows | completed batches 13/4186 | last batch size=4 | gml_id range=23208 -> 23211
# Checkpoint saved with 52 new rows
# Processed 56/16742 new rows | completed batches 14/4186 | last batch size=4 | gml_id range=23893 -> 23897
# Processed 60/16742 new rows | completed batches 15/4186 | last batch size=4 | gml_id range=25034 -> 25037
# Processed 64/16742 new rows | completed batches 16/4186 | last batch size=4 | gml_id range=25173 -> 25178
# Processed 68/16742 new rows | completed batches 17/4186 | last batch size=4 | gml_id range=25928 -> 25931
# Processed 72/16742 new rows | completed batches 18/4186 | last batch size=4 | gml_id range=18788 -> 18791
# Processed 76/16742 new rows | completed batches 19/4186 | last batch size=4 | gml_id range=30921 -> 30924
# Processed 80/16742 new rows | completed batches 20/4186 | last batch size=4 | gml_id range=30266 -> 30269
# Processed 84/16742 new rows | completed batches 21/4186 | last batch size=4 | gml_id range=36734 -> 36737
# Processed 88/16742 new rows | completed batches 22/4186 | last batch size=4 | gml_id range=39997 -> 40000
# Processed 92/16742 new rows | completed batches 23/4186 | last batch size=4 | gml_id range=38945 -> 38949
# Processed 96/16742 new rows | completed batches 24/4186 | last batch size=4 | gml_id range=41585 -> 41588
# Processed 100/16742 new rows | completed batches 25/4186 | last batch size=4 | gml_id range=42643 -> 42646
# Processed 104/16742 new rows | completed batches 26/4186 | last batch size=4 | gml_id range=42655 -> 42658
# Checkpoint saved with 52 new rows
# Processed 108/16742 new rows | completed batches 27/4186 | last batch size=4 | gml_id range=42318 -> 42321
# Processed 112/16742 new rows | completed batches 28/4186 | last batch size=4 | gml_id range=44637 -> 44641
# Processed 116/16742 new rows | completed batches 29/4186 | last batch size=4 | gml_id range=46852 -> 46855
# Processed 120/16742 new rows | completed batches 30/4186 | last batch size=4 | gml_id range=46873 -> 46876
# Processed 124/16742 new rows | completed batches 31/4186 | last batch size=4 | gml_id range=50809 -> 50812
# Processed 128/16742 new rows | completed batches 32/4186 | last batch size=4 | gml_id range=50699 -> 50702
# Processed 132/16742 new rows | completed batches 33/4186 | last batch size=4 | gml_id range=52700 -> 52703
# Processed 136/16742 new rows | completed batches 34/4186 | last batch size=4 | gml_id range=55993 -> 55996
# Processed 140/16742 new rows | completed batches 35/4186 | last batch size=4 | gml_id range=56650 -> 56653
# Processed 144/16742 new rows | completed batches 36/4186 | last batch size=4 | gml_id range=56750 -> 56753
# Processed 148/16742 new rows | completed batches 37/4186 | last batch size=4 | gml_id range=59777 -> 59780
# Processed 152/16742 new rows | completed batches 38/4186 | last batch size=4 | gml_id range=60215 -> 60218
# Processed 156/16742 new rows | completed batches 39/4186 | last batch size=4 | gml_id range=62413 -> 62416
# Checkpoint saved with 52 new rows
# Processed 160/16742 new rows | completed batches 40/4186 | last batch size=4 | gml_id range=61608 -> 61611
# Processed 164/16742 new rows | completed batches 41/4186 | last batch size=4 | gml_id range=62530 -> 62533
# Processed 168/16742 new rows | completed batches 42/4186 | last batch size=4 | gml_id range=63937 -> 63940
# Processed 172/16742 new rows | completed batches 43/4186 | last batch size=4 | gml_id range=63035 -> 63038
# Processed 176/16742 new rows | completed batches 44/4186 | last batch size=4 | gml_id range=65797 -> 65800
# Processed 180/16742 new rows | completed batches 45/4186 | last batch size=4 | gml_id range=67645 -> 67648
# Processed 184/16742 new rows | completed batches 46/4186 | last batch size=4 | gml_id range=67313 -> 67317
# Processed 188/16742 new rows | completed batches 47/4186 | last batch size=4 | gml_id range=68596 -> 68599
# Processed 192/16742 new rows | completed batches 48/4186 | last batch size=4 | gml_id range=67838 -> 67841
# Processed 196/16742 new rows | completed batches 49/4186 | last batch size=4 | gml_id range=67928 -> 67933
# Processed 200/16742 new rows | completed batches 50/4186 | last batch size=4 | gml_id range=70352 -> 70355
# Processed 204/16742 new rows | completed batches 51/4186 | last batch size=4 | gml_id range=71038 -> 71041
# Processed 208/16742 new rows | completed batches 52/4186 | last batch size=4 | gml_id range=70430 -> 70433
# Checkpoint saved with 52 new rows
# Processed 212/16742 new rows | completed batches 53/4186 | last batch size=4 | gml_id range=71446 -> 71449
# Processed 216/16742 new rows | completed batches 54/4186 | last batch size=4 | gml_id range=72752 -> 72755
# Processed 220/16742 new rows | completed batches 55/4186 | last batch size=4 | gml_id range=72894 -> 72898
# Processed 224/16742 new rows | completed batches 56/4186 | last batch size=4 | gml_id range=73220 -> 73223
# Processed 228/16742 new rows | completed batches 57/4186 | last batch size=4 | gml_id range=77229 -> 77232
# Processed 232/16742 new rows | completed batches 58/4186 | last batch size=4 | gml_id range=77865 -> 77868
# Processed 236/16742 new rows | completed batches 59/4186 | last batch size=4 | gml_id range=79181 -> 79186
# Processed 240/16742 new rows | completed batches 60/4186 | last batch size=4 | gml_id range=80241 -> 80244
# Processed 244/16742 new rows | completed batches 61/4186 | last batch size=4 | gml_id range=82799 -> 82802
# Processed 248/16742 new rows | completed batches 62/4186 | last batch size=4 | gml_id range=84774 -> 84777
# Processed 252/16742 new rows | completed batches 63/4186 | last batch size=4 | gml_id range=87497 -> 87500
# Processed 256/16742 new rows | completed batches 64/4186 | last batch size=4 | gml_id range=84843 -> 84846
# Processed 260/16742 new rows | completed batches 65/4186 | last batch size=4 | gml_id range=89416 -> 89419
# Checkpoint saved with 52 new rows
# Processed 264/16742 new rows | completed batches 66/4186 | last batch size=4 | gml_id range=91406 -> 91409
# Processed 268/16742 new rows | completed batches 67/4186 | last batch size=4 | gml_id range=92021 -> 92024
# Processed 272/16742 new rows | completed batches 68/4186 | last batch size=4 | gml_id range=92224 -> 92227
# Processed 276/16742 new rows | completed batches 69/4186 | last batch size=4 | gml_id range=92228 -> 92231
# Processed 280/16742 new rows | completed batches 70/4186 | last batch size=4 | gml_id range=94653 -> 94656
# Processed 284/16742 new rows | completed batches 71/4186 | last batch size=4 | gml_id range=95034 -> 95037
# Processed 288/16742 new rows | completed batches 72/4186 | last batch size=4 | gml_id range=95920 -> 95923
# Processed 292/16742 new rows | completed batches 73/4186 | last batch size=4 | gml_id range=96414 -> 96417
# Processed 296/16742 new rows | completed batches 74/4186 | last batch size=4 | gml_id range=96532 -> 96535
# Processed 300/16742 new rows | completed batches 75/4186 | last batch size=4 | gml_id range=97050 -> 97053
# Processed 304/16742 new rows | completed batches 76/4186 | last batch size=4 | gml_id range=98095 -> 98099
# Processed 308/16742 new rows | completed batches 77/4186 | last batch size=4 | gml_id range=97698 -> 97701
# Processed 312/16742 new rows | completed batches 78/4186 | last batch size=4 | gml_id range=97858 -> 97861
# Checkpoint saved with 52 new rows
# Processed 316/16742 new rows | completed batches 79/4186 | last batch size=4 | gml_id range=99813 -> 99816
# Processed 320/16742 new rows | completed batches 80/4186 | last batch size=4 | gml_id range=98424 -> 98428
# Processed 324/16742 new rows | completed batches 81/4186 | last batch size=4 | gml_id range=100062 -> 100065
# Processed 328/16742 new rows | completed batches 82/4186 | last batch size=4 | gml_id range=100253 -> 100256
# Processed 332/16742 new rows | completed batches 83/4186 | last batch size=4 | gml_id range=101617 -> 101621
# Processed 336/16742 new rows | completed batches 84/4186 | last batch size=4 | gml_id range=101746 -> 101750
# Processed 340/16742 new rows | completed batches 85/4186 | last batch size=4 | gml_id range=102078 -> 102083
# Processed 344/16742 new rows | completed batches 86/4186 | last batch size=4 | gml_id range=102791 -> 102795
# Processed 348/16742 new rows | completed batches 87/4186 | last batch size=4 | gml_id range=104752 -> 104755
# Processed 352/16742 new rows | completed batches 88/4186 | last batch size=4 | gml_id range=105329 -> 105332
# Processed 356/16742 new rows | completed batches 89/4186 | last batch size=4 | gml_id range=103799 -> 103803
# Processed 360/16742 new rows | completed batches 90/4186 | last batch size=4 | gml_id range=110855 -> 110858
# Processed 364/16742 new rows | completed batches 91/4186 | last batch size=4 | gml_id range=110786 -> 110789
# Checkpoint saved with 52 new rows
# Processed 368/16742 new rows | completed batches 92/4186 | last batch size=4 | gml_id range=105693 -> 105696
# Processed 372/16742 new rows | completed batches 93/4186 | last batch size=4 | gml_id range=111469 -> 111472
# Processed 376/16742 new rows | completed batches 94/4186 | last batch size=4 | gml_id range=110987 -> 110990
# Processed 380/16742 new rows | completed batches 95/4186 | last batch size=4 | gml_id range=113655 -> 113658
# Processed 384/16742 new rows | completed batches 96/4186 | last batch size=4 | gml_id range=115853 -> 115856
# Processed 388/16742 new rows | completed batches 97/4186 | last batch size=4 | gml_id range=116710 -> 116714
# Processed 392/16742 new rows | completed batches 98/4186 | last batch size=4 | gml_id range=116706 -> 116709
# Processed 396/16742 new rows | completed batches 99/4186 | last batch size=4 | gml_id range=116715 -> 116719
# Processed 400/16742 new rows | completed batches 100/4186 | last batch size=4 | gml_id range=116724 -> 116728
# Processed 404/16742 new rows | completed batches 101/4186 | last batch size=4 | gml_id range=116747 -> 116751
# Processed 408/16742 new rows | completed batches 102/4186 | last batch size=4 | gml_id range=116720 -> 116723
# Processed 412/16742 new rows | completed batches 103/4186 | last batch size=4 | gml_id range=116741 -> 116746
# Processed 416/16742 new rows | completed batches 104/4186 | last batch size=4 | gml_id range=116729 -> 116732
# Checkpoint saved with 52 new rows
# Processed 420/16742 new rows | completed batches 105/4186 | last batch size=4 | gml_id range=116737 -> 116740
# Processed 424/16742 new rows | completed batches 106/4186 | last batch size=4 | gml_id range=116733 -> 116736
# Processed 428/16742 new rows | completed batches 107/4186 | last batch size=4 | gml_id range=116757 -> 116760
# Processed 432/16742 new rows | completed batches 108/4186 | last batch size=4 | gml_id range=116752 -> 116756
# Processed 436/16742 new rows | completed batches 109/4186 | last batch size=4 | gml_id range=116769 -> 116772
# Processed 440/16742 new rows | completed batches 110/4186 | last batch size=4 | gml_id range=116765 -> 116768
# Processed 444/16742 new rows | completed batches 111/4186 | last batch size=4 | gml_id range=116761 -> 116764
# Processed 448/16742 new rows | completed batches 112/4186 | last batch size=4 | gml_id range=116777 -> 116782
# Processed 452/16742 new rows | completed batches 113/4186 | last batch size=4 | gml_id range=116773 -> 116776
# Processed 456/16742 new rows | completed batches 114/4186 | last batch size=4 | gml_id range=116783 -> 116786
# Processed 460/16742 new rows | completed batches 115/4186 | last batch size=4 | gml_id range=116787 -> 116790
# Processed 464/16742 new rows | completed batches 116/4186 | last batch size=4 | gml_id range=116791 -> 116794
# Processed 468/16742 new rows | completed batches 117/4186 | last batch size=4 | gml_id range=116799 -> 116802
# Checkpoint saved with 52 new rows
# Processed 472/16742 new rows | completed batches 118/4186 | last batch size=4 | gml_id range=116946 -> 116949
# Processed 476/16742 new rows | completed batches 119/4186 | last batch size=4 | gml_id range=116936 -> 116939
# Processed 480/16742 new rows | completed batches 120/4186 | last batch size=4 | gml_id range=116950 -> 116953
# Processed 484/16742 new rows | completed batches 121/4186 | last batch size=4 | gml_id range=116942 -> 116945
# Processed 488/16742 new rows | completed batches 122/4186 | last batch size=4 | gml_id range=116954 -> 116957
# Processed 492/16742 new rows | completed batches 123/4186 | last batch size=4 | gml_id range=116971 -> 116974
# Processed 496/16742 new rows | completed batches 124/4186 | last batch size=4 | gml_id range=116975 -> 116978
# Processed 500/16742 new rows | completed batches 125/4186 | last batch size=4 | gml_id range=116963 -> 116966
# Processed 504/16742 new rows | completed batches 126/4186 | last batch size=4 | gml_id range=116967 -> 116970
# Processed 508/16742 new rows | completed batches 127/4186 | last batch size=4 | gml_id range=116958 -> 116962
# Processed 512/16742 new rows | completed batches 128/4186 | last batch size=4 | gml_id range=116998 -> 117001
# Processed 516/16742 new rows | completed batches 129/4186 | last batch size=4 | gml_id range=116979 -> 116984
# Processed 520/16742 new rows | completed batches 130/4186 | last batch size=4 | gml_id range=116989 -> 116993
# Checkpoint saved with 52 new rows
# Processed 524/16742 new rows | completed batches 131/4186 | last batch size=4 | gml_id range=116994 -> 116997
# Processed 528/16742 new rows | completed batches 132/4186 | last batch size=4 | gml_id range=116985 -> 116988
# Processed 532/16742 new rows | completed batches 133/4186 | last batch size=4 | gml_id range=117002 -> 117005
# Processed 536/16742 new rows | completed batches 134/4186 | last batch size=4 | gml_id range=117006 -> 117009
# Processed 540/16742 new rows | completed batches 135/4186 | last batch size=4 | gml_id range=117014 -> 117018
# Processed 544/16742 new rows | completed batches 136/4186 | last batch size=4 | gml_id range=117019 -> 117022
# Processed 548/16742 new rows | completed batches 137/4186 | last batch size=4 | gml_id range=117010 -> 117013
# Processed 552/16742 new rows | completed batches 138/4186 | last batch size=4 | gml_id range=117024 -> 117027
# Processed 556/16742 new rows | completed batches 139/4186 | last batch size=4 | gml_id range=117028 -> 117031
# Processed 560/16742 new rows | completed batches 140/4186 | last batch size=4 | gml_id range=117032 -> 117035
# Processed 564/16742 new rows | completed batches 141/4186 | last batch size=4 | gml_id range=117036 -> 117039
# Processed 568/16742 new rows | completed batches 142/4186 | last batch size=4 | gml_id range=117040 -> 117043
# Processed 572/16742 new rows | completed batches 143/4186 | last batch size=4 | gml_id range=117048 -> 117051
# Checkpoint saved with 52 new rows
# Processed 576/16742 new rows | completed batches 144/4186 | last batch size=4 | gml_id range=117044 -> 117047
# Processed 580/16742 new rows | completed batches 145/4186 | last batch size=4 | gml_id range=117052 -> 117055
# Processed 584/16742 new rows | completed batches 146/4186 | last batch size=4 | gml_id range=117056 -> 117060
# Processed 588/16742 new rows | completed batches 147/4186 | last batch size=4 | gml_id range=117061 -> 117065
# Processed 592/16742 new rows | completed batches 148/4186 | last batch size=4 | gml_id range=117078 -> 117082
# Processed 596/16742 new rows | completed batches 149/4186 | last batch size=4 | gml_id range=117070 -> 117073
# Processed 600/16742 new rows | completed batches 150/4186 | last batch size=4 | gml_id range=117083 -> 117086
# Processed 604/16742 new rows | completed batches 151/4186 | last batch size=4 | gml_id range=117074 -> 117077
# Processed 608/16742 new rows | completed batches 152/4186 | last batch size=4 | gml_id range=117092 -> 117095
# Processed 612/16742 new rows | completed batches 153/4186 | last batch size=4 | gml_id range=121846 -> 121849
# Processed 616/16742 new rows | completed batches 154/4186 | last batch size=4 | gml_id range=117120 -> 117124
# Processed 620/16742 new rows | completed batches 155/4186 | last batch size=4 | gml_id range=123289 -> 126436
# Processed 624/16742 new rows | completed batches 156/4186 | last batch size=4 | gml_id range=126437 -> 127778
# Checkpoint saved with 52 new rows
# Processed 628/16742 new rows | completed batches 157/4186 | last batch size=4 | gml_id range=127779 -> 127833
# Processed 632/16742 new rows | completed batches 158/4186 | last batch size=4 | gml_id range=127834 -> 130465
# Processed 636/16742 new rows | completed batches 159/4186 | last batch size=4 | gml_id range=131481 -> 132288
# Processed 640/16742 new rows | completed batches 160/4186 | last batch size=4 | gml_id range=130466 -> 131480
# Processed 644/16742 new rows | completed batches 161/4186 | last batch size=4 | gml_id range=132289 -> 136306
# Processed 648/16742 new rows | completed batches 162/4186 | last batch size=4 | gml_id range=138497 -> 140599
# Processed 652/16742 new rows | completed batches 163/4186 | last batch size=4 | gml_id range=140600 -> 143924
# Processed 656/16742 new rows | completed batches 164/4186 | last batch size=4 | gml_id range=136309 -> 138496
# Processed 660/16742 new rows | completed batches 165/4186 | last batch size=4 | gml_id range=145965 -> 146199
# Processed 664/16742 new rows | completed batches 166/4186 | last batch size=4 | gml_id range=143925 -> 145943
# Processed 668/16742 new rows | completed batches 167/4186 | last batch size=4 | gml_id range=145944 -> 145964
# Processed 672/16742 new rows | completed batches 168/4186 | last batch size=4 | gml_id range=148711 -> 148909
# Processed 676/16742 new rows | completed batches 169/4186 | last batch size=4 | gml_id range=148910 -> 149425
# Checkpoint saved with 52 new rows
# Processed 680/16742 new rows | completed batches 170/4186 | last batch size=4 | gml_id range=146200 -> 148710
# Processed 684/16742 new rows | completed batches 171/4186 | last batch size=4 | gml_id range=152134 -> 156052
# Processed 688/16742 new rows | completed batches 172/4186 | last batch size=4 | gml_id range=149426 -> 151134
# Processed 692/16742 new rows | completed batches 173/4186 | last batch size=4 | gml_id range=151135 -> 152133
# Processed 696/16742 new rows | completed batches 174/4186 | last batch size=4 | gml_id range=156053 -> 157944
# Processed 700/16742 new rows | completed batches 175/4186 | last batch size=4 | gml_id range=157945 -> 160094
# Processed 704/16742 new rows | completed batches 176/4186 | last batch size=4 | gml_id range=160414 -> 160439
# Processed 708/16742 new rows | completed batches 177/4186 | last batch size=4 | gml_id range=160095 -> 160413
# Processed 712/16742 new rows | completed batches 178/4186 | last batch size=4 | gml_id range=160554 -> 163411
# Processed 716/16742 new rows | completed batches 179/4186 | last batch size=4 | gml_id range=163412 -> 164051
# Processed 720/16742 new rows | completed batches 180/4186 | last batch size=4 | gml_id range=160440 -> 160553
# Processed 724/16742 new rows | completed batches 181/4186 | last batch size=4 | gml_id range=164052 -> 165710
# Processed 728/16742 new rows | completed batches 182/4186 | last batch size=4 | gml_id range=165711 -> 173952
# Checkpoint saved with 52 new rows
# Processed 732/16742 new rows | completed batches 183/4186 | last batch size=4 | gml_id range=173953 -> 174355
# Processed 736/16742 new rows | completed batches 184/4186 | last batch size=4 | gml_id range=174356 -> 174496
# Processed 740/16742 new rows | completed batches 185/4186 | last batch size=4 | gml_id range=174497 -> 176239
# Processed 744/16742 new rows | completed batches 186/4186 | last batch size=4 | gml_id range=176756 -> 176900
# Processed 748/16742 new rows | completed batches 187/4186 | last batch size=4 | gml_id range=176240 -> 176755
# Processed 752/16742 new rows | completed batches 188/4186 | last batch size=4 | gml_id range=178133 -> 178231
# Processed 756/16742 new rows | completed batches 189/4186 | last batch size=4 | gml_id range=176901 -> 178132
# Processed 760/16742 new rows | completed batches 190/4186 | last batch size=4 | gml_id range=178232 -> 178602
# Processed 764/16742 new rows | completed batches 191/4186 | last batch size=4 | gml_id range=178786 -> 179562
# Processed 768/16742 new rows | completed batches 192/4186 | last batch size=4 | gml_id range=178603 -> 178785
# Processed 772/16742 new rows | completed batches 193/4186 | last batch size=4 | gml_id range=179563 -> 179635
# Processed 776/16742 new rows | completed batches 194/4186 | last batch size=4 | gml_id range=179636 -> 179758
# Processed 780/16742 new rows | completed batches 195/4186 | last batch size=4 | gml_id range=179759 -> 180247
# Checkpoint saved with 52 new rows
# Processed 784/16742 new rows | completed batches 196/4186 | last batch size=4 | gml_id range=180248 -> 180592
# Processed 788/16742 new rows | completed batches 197/4186 | last batch size=4 | gml_id range=185710 -> 187254
# Processed 792/16742 new rows | completed batches 198/4186 | last batch size=4 | gml_id range=180830 -> 185709
# Processed 796/16742 new rows | completed batches 199/4186 | last batch size=4 | gml_id range=180593 -> 180829
# Processed 800/16742 new rows | completed batches 200/4186 | last batch size=4 | gml_id range=187255 -> 188094
# Processed 804/16742 new rows | completed batches 201/4186 | last batch size=4 | gml_id range=190838 -> 191041
# Processed 808/16742 new rows | completed batches 202/4186 | last batch size=4 | gml_id range=188096 -> 190837
# Processed 812/16742 new rows | completed batches 203/4186 | last batch size=4 | gml_id range=191042 -> 191957
# Processed 816/16742 new rows | completed batches 204/4186 | last batch size=4 | gml_id range=191958 -> 193147
# Processed 820/16742 new rows | completed batches 205/4186 | last batch size=4 | gml_id range=193679 -> 195212
# Processed 824/16742 new rows | completed batches 206/4186 | last batch size=4 | gml_id range=195213 -> 195300
# Processed 828/16742 new rows | completed batches 207/4186 | last batch size=4 | gml_id range=193148 -> 193678
# Processed 832/16742 new rows | completed batches 208/4186 | last batch size=4 | gml_id range=195597 -> 196118
# Checkpoint saved with 52 new rows
# Processed 836/16742 new rows | completed batches 209/4186 | last batch size=4 | gml_id range=195301 -> 195596
# Processed 840/16742 new rows | completed batches 210/4186 | last batch size=4 | gml_id range=196119 -> 196397
# Processed 844/16742 new rows | completed batches 211/4186 | last batch size=4 | gml_id range=196398 -> 198781
# Processed 848/16742 new rows | completed batches 212/4186 | last batch size=4 | gml_id range=198782 -> 199774
# Processed 852/16742 new rows | completed batches 213/4186 | last batch size=4 | gml_id range=199775 -> 200798
# Processed 856/16742 new rows | completed batches 214/4186 | last batch size=4 | gml_id range=201083 -> 201209
# Processed 860/16742 new rows | completed batches 215/4186 | last batch size=4 | gml_id range=200799 -> 201082
# Processed 864/16742 new rows | completed batches 216/4186 | last batch size=4 | gml_id range=201746 -> 204110
# Processed 868/16742 new rows | completed batches 217/4186 | last batch size=4 | gml_id range=201210 -> 201745
# Processed 872/16742 new rows | completed batches 218/4186 | last batch size=4 | gml_id range=204232 -> 205357
# Processed 876/16742 new rows | completed batches 219/4186 | last batch size=4 | gml_id range=204111 -> 204231
# Processed 880/16742 new rows | completed batches 220/4186 | last batch size=4 | gml_id range=205418 -> 205479
# Processed 884/16742 new rows | completed batches 221/4186 | last batch size=4 | gml_id range=205358 -> 205417
# Checkpoint saved with 52 new rows
# Processed 888/16742 new rows | completed batches 222/4186 | last batch size=4 | gml_id range=205480 -> 205535
# Processed 892/16742 new rows | completed batches 223/4186 | last batch size=4 | gml_id range=205536 -> 206506
# Processed 896/16742 new rows | completed batches 224/4186 | last batch size=4 | gml_id range=206507 -> 208883
# Processed 900/16742 new rows | completed batches 225/4186 | last batch size=4 | gml_id range=208916 -> 209192
# Processed 904/16742 new rows | completed batches 226/4186 | last batch size=4 | gml_id range=208884 -> 208915
# Processed 908/16742 new rows | completed batches 227/4186 | last batch size=4 | gml_id range=209193 -> 209245
# Processed 912/16742 new rows | completed batches 228/4186 | last batch size=4 | gml_id range=209246 -> 209768
# Processed 916/16742 new rows | completed batches 229/4186 | last batch size=4 | gml_id range=209998 -> 210194
# Processed 920/16742 new rows | completed batches 230/4186 | last batch size=4 | gml_id range=209833 -> 209997
# Processed 924/16742 new rows | completed batches 231/4186 | last batch size=4 | gml_id range=209769 -> 209832
# Processed 928/16742 new rows | completed batches 232/4186 | last batch size=4 | gml_id range=210195 -> 210298
# Processed 932/16742 new rows | completed batches 233/4186 | last batch size=4 | gml_id range=211054 -> 211085
# Processed 936/16742 new rows | completed batches 234/4186 | last batch size=4 | gml_id range=210299 -> 211053
# Checkpoint saved with 52 new rows
# Processed 940/16742 new rows | completed batches 235/4186 | last batch size=4 | gml_id range=211086 -> 211105
# Processed 944/16742 new rows | completed batches 236/4186 | last batch size=4 | gml_id range=211106 -> 211109
# Processed 948/16742 new rows | completed batches 237/4186 | last batch size=4 | gml_id range=211110 -> 211404
# Processed 952/16742 new rows | completed batches 238/4186 | last batch size=4 | gml_id range=211405 -> 211464
# Processed 956/16742 new rows | completed batches 239/4186 | last batch size=4 | gml_id range=212359 -> 212978
# Processed 960/16742 new rows | completed batches 240/4186 | last batch size=4 | gml_id range=211465 -> 211598
# Processed 964/16742 new rows | completed batches 241/4186 | last batch size=4 | gml_id range=211599 -> 212358
# Processed 968/16742 new rows | completed batches 242/4186 | last batch size=4 | gml_id range=214088 -> 214282
# Processed 972/16742 new rows | completed batches 243/4186 | last batch size=4 | gml_id range=212979 -> 214075
# Processed 976/16742 new rows | completed batches 244/4186 | last batch size=4 | gml_id range=214076 -> 214087
# Processed 980/16742 new rows | completed batches 245/4186 | last batch size=4 | gml_id range=214283 -> 214471
# Processed 984/16742 new rows | completed batches 246/4186 | last batch size=4 | gml_id range=214472 -> 215245
# Processed 988/16742 new rows | completed batches 247/4186 | last batch size=4 | gml_id range=215246 -> 216427
# Checkpoint saved with 52 new rows
# Processed 992/16742 new rows | completed batches 248/4186 | last batch size=4 | gml_id range=216420 -> 216394
# Processed 996/16742 new rows | completed batches 249/4186 | last batch size=4 | gml_id range=216428 -> 216419
# Processed 1000/16742 new rows | completed batches 250/4186 | last batch size=4 | gml_id range=216395 -> 216415
# Processed 1004/16742 new rows | completed batches 251/4186 | last batch size=4 | gml_id range=216416 -> 216431
# Processed 1008/16742 new rows | completed batches 252/4186 | last batch size=4 | gml_id range=216440 -> 216443
# Processed 1012/16742 new rows | completed batches 253/4186 | last batch size=4 | gml_id range=216436 -> 216439
# Processed 1016/16742 new rows | completed batches 254/4186 | last batch size=4 | gml_id range=216432 -> 216435
# Processed 1020/16742 new rows | completed batches 255/4186 | last batch size=4 | gml_id range=216444 -> 216447
# Processed 1024/16742 new rows | completed batches 256/4186 | last batch size=4 | gml_id range=216448 -> 216451
# Processed 1028/16742 new rows | completed batches 257/4186 | last batch size=4 | gml_id range=216460 -> 216455
# Processed 1032/16742 new rows | completed batches 258/4186 | last batch size=4 | gml_id range=216452 -> 216459
# Processed 1036/16742 new rows | completed batches 259/4186 | last batch size=4 | gml_id range=216464 -> 216467
# Processed 1040/16742 new rows | completed batches 260/4186 | last batch size=4 | gml_id range=216468 -> 216471
# Checkpoint saved with 52 new rows
# Processed 1044/16742 new rows | completed batches 261/4186 | last batch size=4 | gml_id range=216456 -> 216463
# Processed 1048/16742 new rows | completed batches 262/4186 | last batch size=4 | gml_id range=216472 -> 216475
# Processed 1052/16742 new rows | completed batches 263/4186 | last batch size=4 | gml_id range=216476 -> 216479
# Processed 1056/16742 new rows | completed batches 264/4186 | last batch size=4 | gml_id range=216480 -> 216483
# Processed 1060/16742 new rows | completed batches 265/4186 | last batch size=4 | gml_id range=216484 -> 216487
# Processed 1064/16742 new rows | completed batches 266/4186 | last batch size=4 | gml_id range=216488 -> 216491
# Processed 1068/16742 new rows | completed batches 267/4186 | last batch size=4 | gml_id range=216492 -> 216499
# Processed 1072/16742 new rows | completed batches 268/4186 | last batch size=4 | gml_id range=216500 -> 216495
# Processed 1076/16742 new rows | completed batches 269/4186 | last batch size=4 | gml_id range=216496 -> 216503
# Processed 1080/16742 new rows | completed batches 270/4186 | last batch size=4 | gml_id range=216504 -> 216507
# Processed 1084/16742 new rows | completed batches 271/4186 | last batch size=4 | gml_id range=216508 -> 216511
# Processed 1088/16742 new rows | completed batches 272/4186 | last batch size=4 | gml_id range=216520 -> 216515
# Processed 1092/16742 new rows | completed batches 273/4186 | last batch size=4 | gml_id range=216512 -> 216519
# Checkpoint saved with 52 new rows
# Processed 1096/16742 new rows | completed batches 274/4186 | last batch size=4 | gml_id range=216516 -> 216523
# Processed 1100/16742 new rows | completed batches 275/4186 | last batch size=4 | gml_id range=216528 -> 216532
# Processed 1104/16742 new rows | completed batches 276/4186 | last batch size=4 | gml_id range=216533 -> 216536
# Processed 1108/16742 new rows | completed batches 277/4186 | last batch size=4 | gml_id range=216537 -> 216540
# Processed 1112/16742 new rows | completed batches 278/4186 | last batch size=4 | gml_id range=216541 -> 216544
# Processed 1116/16742 new rows | completed batches 279/4186 | last batch size=4 | gml_id range=216545 -> 216548
# Processed 1120/16742 new rows | completed batches 280/4186 | last batch size=4 | gml_id range=216549 -> 216552
# Processed 1124/16742 new rows | completed batches 281/4186 | last batch size=4 | gml_id range=216553 -> 216556
# Processed 1128/16742 new rows | completed batches 282/4186 | last batch size=4 | gml_id range=216524 -> 216527
# Processed 1132/16742 new rows | completed batches 283/4186 | last batch size=4 | gml_id range=216557 -> 216561
# Processed 1136/16742 new rows | completed batches 284/4186 | last batch size=4 | gml_id range=216562 -> 216566
# Processed 1140/16742 new rows | completed batches 285/4186 | last batch size=4 | gml_id range=216567 -> 216571
# Processed 1144/16742 new rows | completed batches 286/4186 | last batch size=4 | gml_id range=216577 -> 216580
# Checkpoint saved with 52 new rows
# Processed 1148/16742 new rows | completed batches 287/4186 | last batch size=4 | gml_id range=216572 -> 216576
# Processed 1152/16742 new rows | completed batches 288/4186 | last batch size=4 | gml_id range=216589 -> 216592
# Processed 1156/16742 new rows | completed batches 289/4186 | last batch size=4 | gml_id range=216581 -> 216584
# Processed 1160/16742 new rows | completed batches 290/4186 | last batch size=4 | gml_id range=216585 -> 216588
# Processed 1164/16742 new rows | completed batches 291/4186 | last batch size=4 | gml_id range=216593 -> 216596
# Processed 1168/16742 new rows | completed batches 292/4186 | last batch size=4 | gml_id range=216597 -> 216600
# Processed 1172/16742 new rows | completed batches 293/4186 | last batch size=4 | gml_id range=216605 -> 216608
# Processed 1176/16742 new rows | completed batches 294/4186 | last batch size=4 | gml_id range=216601 -> 216604
# Processed 1180/16742 new rows | completed batches 295/4186 | last batch size=4 | gml_id range=216613 -> 216616
# Processed 1184/16742 new rows | completed batches 296/4186 | last batch size=4 | gml_id range=216609 -> 216612
# Processed 1188/16742 new rows | completed batches 297/4186 | last batch size=4 | gml_id range=216617 -> 216620
# Processed 1192/16742 new rows | completed batches 298/4186 | last batch size=4 | gml_id range=216621 -> 216624
# Processed 1196/16742 new rows | completed batches 299/4186 | last batch size=4 | gml_id range=216633 -> 216636
# Checkpoint saved with 52 new rows
# Processed 1200/16742 new rows | completed batches 300/4186 | last batch size=4 | gml_id range=216629 -> 216632
# Processed 1204/16742 new rows | completed batches 301/4186 | last batch size=4 | gml_id range=216625 -> 216628
# Processed 1208/16742 new rows | completed batches 302/4186 | last batch size=4 | gml_id range=216637 -> 216640
# Processed 1212/16742 new rows | completed batches 303/4186 | last batch size=4 | gml_id range=216641 -> 216644
# Processed 1216/16742 new rows | completed batches 304/4186 | last batch size=4 | gml_id range=216645 -> 216648
# Processed 1220/16742 new rows | completed batches 305/4186 | last batch size=4 | gml_id range=216653 -> 216656
# Processed 1224/16742 new rows | completed batches 306/4186 | last batch size=4 | gml_id range=216649 -> 216652
# Processed 1228/16742 new rows | completed batches 307/4186 | last batch size=4 | gml_id range=216657 -> 216660
# Processed 1232/16742 new rows | completed batches 308/4186 | last batch size=4 | gml_id range=216661 -> 216664
# Processed 1236/16742 new rows | completed batches 309/4186 | last batch size=4 | gml_id range=216666 -> 216669
# Processed 1240/16742 new rows | completed batches 310/4186 | last batch size=4 | gml_id range=216670 -> 216673
# Processed 1244/16742 new rows | completed batches 311/4186 | last batch size=4 | gml_id range=216674 -> 216677
# Processed 1248/16742 new rows | completed batches 312/4186 | last batch size=4 | gml_id range=216678 -> 216681
# Checkpoint saved with 52 new rows
# Processed 1252/16742 new rows | completed batches 313/4186 | last batch size=4 | gml_id range=216686 -> 216689
# Processed 1256/16742 new rows | completed batches 314/4186 | last batch size=4 | gml_id range=216682 -> 216685
# Processed 1260/16742 new rows | completed batches 315/4186 | last batch size=4 | gml_id range=216690 -> 216693
# Processed 1264/16742 new rows | completed batches 316/4186 | last batch size=4 | gml_id range=216702 -> 216705
# Processed 1268/16742 new rows | completed batches 317/4186 | last batch size=4 | gml_id range=216698 -> 216701
# Processed 1272/16742 new rows | completed batches 318/4186 | last batch size=4 | gml_id range=216694 -> 216697
# Processed 1276/16742 new rows | completed batches 319/4186 | last batch size=4 | gml_id range=216714 -> 216717
# Processed 1280/16742 new rows | completed batches 320/4186 | last batch size=4 | gml_id range=216710 -> 216713
# Processed 1284/16742 new rows | completed batches 321/4186 | last batch size=4 | gml_id range=216706 -> 216709
# Processed 1288/16742 new rows | completed batches 322/4186 | last batch size=4 | gml_id range=216718 -> 216721
# Processed 1292/16742 new rows | completed batches 323/4186 | last batch size=4 | gml_id range=216722 -> 216725
# Processed 1296/16742 new rows | completed batches 324/4186 | last batch size=4 | gml_id range=216726 -> 216729
# Processed 1300/16742 new rows | completed batches 325/4186 | last batch size=4 | gml_id range=216730 -> 216733
# Checkpoint saved with 52 new rows
# Processed 1304/16742 new rows | completed batches 326/4186 | last batch size=4 | gml_id range=216734 -> 216737
# Processed 1308/16742 new rows | completed batches 327/4186 | last batch size=4 | gml_id range=216739 -> 216742
# Processed 1312/16742 new rows | completed batches 328/4186 | last batch size=4 | gml_id range=216747 -> 216750
# Processed 1316/16742 new rows | completed batches 329/4186 | last batch size=4 | gml_id range=216751 -> 216754
# Processed 1320/16742 new rows | completed batches 330/4186 | last batch size=4 | gml_id range=216743 -> 216746
# Processed 1324/16742 new rows | completed batches 331/4186 | last batch size=4 | gml_id range=216755 -> 216758
# Processed 1328/16742 new rows | completed batches 332/4186 | last batch size=4 | gml_id range=216763 -> 216766
# Processed 1332/16742 new rows | completed batches 333/4186 | last batch size=4 | gml_id range=216759 -> 216762
# Processed 1336/16742 new rows | completed batches 334/4186 | last batch size=4 | gml_id range=216767 -> 216770
# Processed 1340/16742 new rows | completed batches 335/4186 | last batch size=4 | gml_id range=216771 -> 216774
# Processed 1344/16742 new rows | completed batches 336/4186 | last batch size=4 | gml_id range=216779 -> 216782
# Processed 1348/16742 new rows | completed batches 337/4186 | last batch size=4 | gml_id range=216775 -> 216778
# Processed 1352/16742 new rows | completed batches 338/4186 | last batch size=4 | gml_id range=216783 -> 216786
# Checkpoint saved with 52 new rows
# Processed 1356/16742 new rows | completed batches 339/4186 | last batch size=4 | gml_id range=216787 -> 216790
# Processed 1360/16742 new rows | completed batches 340/4186 | last batch size=4 | gml_id range=216791 -> 216794
# Processed 1364/16742 new rows | completed batches 341/4186 | last batch size=4 | gml_id range=216795 -> 216798
# Processed 1368/16742 new rows | completed batches 342/4186 | last batch size=4 | gml_id range=216799 -> 216802
# Processed 1372/16742 new rows | completed batches 343/4186 | last batch size=4 | gml_id range=216803 -> 216806
# Processed 1376/16742 new rows | completed batches 344/4186 | last batch size=4 | gml_id range=216807 -> 216810
# Processed 1380/16742 new rows | completed batches 345/4186 | last batch size=4 | gml_id range=216811 -> 216814
# Processed 1384/16742 new rows | completed batches 346/4186 | last batch size=4 | gml_id range=216819 -> 216822
# Processed 1388/16742 new rows | completed batches 347/4186 | last batch size=4 | gml_id range=216815 -> 216818
# Processed 1392/16742 new rows | completed batches 348/4186 | last batch size=4 | gml_id range=216827 -> 216830
# Processed 1396/16742 new rows | completed batches 349/4186 | last batch size=4 | gml_id range=216831 -> 216834
# Processed 1400/16742 new rows | completed batches 350/4186 | last batch size=4 | gml_id range=216835 -> 216838
# Processed 1404/16742 new rows | completed batches 351/4186 | last batch size=4 | gml_id range=216823 -> 216826
# Checkpoint saved with 52 new rows
# Processed 1408/16742 new rows | completed batches 352/4186 | last batch size=4 | gml_id range=216839 -> 216842
# Processed 1412/16742 new rows | completed batches 353/4186 | last batch size=4 | gml_id range=216843 -> 216846
# Processed 1416/16742 new rows | completed batches 354/4186 | last batch size=4 | gml_id range=216855 -> 216858
# Processed 1420/16742 new rows | completed batches 355/4186 | last batch size=4 | gml_id range=216847 -> 216850
# Processed 1424/16742 new rows | completed batches 356/4186 | last batch size=4 | gml_id range=216851 -> 216854
# Processed 1428/16742 new rows | completed batches 357/4186 | last batch size=4 | gml_id range=216859 -> 216862
# Processed 1432/16742 new rows | completed batches 358/4186 | last batch size=4 | gml_id range=216863 -> 216866
# Processed 1436/16742 new rows | completed batches 359/4186 | last batch size=4 | gml_id range=216871 -> 216874
# Processed 1440/16742 new rows | completed batches 360/4186 | last batch size=4 | gml_id range=216875 -> 216878
# Processed 1444/16742 new rows | completed batches 361/4186 | last batch size=4 | gml_id range=216867 -> 216870
# Processed 1448/16742 new rows | completed batches 362/4186 | last batch size=4 | gml_id range=216887 -> 216890
# Processed 1452/16742 new rows | completed batches 363/4186 | last batch size=4 | gml_id range=216883 -> 216886
# Processed 1456/16742 new rows | completed batches 364/4186 | last batch size=4 | gml_id range=216879 -> 216882
# Checkpoint saved with 52 new rows
# Processed 1460/16742 new rows | completed batches 365/4186 | last batch size=4 | gml_id range=216895 -> 216898
# Processed 1464/16742 new rows | completed batches 366/4186 | last batch size=4 | gml_id range=216899 -> 216902
# Processed 1468/16742 new rows | completed batches 367/4186 | last batch size=4 | gml_id range=216891 -> 216894
# Processed 1472/16742 new rows | completed batches 368/4186 | last batch size=4 | gml_id range=216903 -> 216906
# Processed 1476/16742 new rows | completed batches 369/4186 | last batch size=4 | gml_id range=216911 -> 216914
# Processed 1480/16742 new rows | completed batches 370/4186 | last batch size=4 | gml_id range=216907 -> 216910
# Processed 1484/16742 new rows | completed batches 371/4186 | last batch size=4 | gml_id range=216919 -> 216922
# Processed 1488/16742 new rows | completed batches 372/4186 | last batch size=4 | gml_id range=216915 -> 216918
# Processed 1492/16742 new rows | completed batches 373/4186 | last batch size=4 | gml_id range=216923 -> 216926
# Processed 1496/16742 new rows | completed batches 374/4186 | last batch size=4 | gml_id range=216927 -> 216930
# Processed 1500/16742 new rows | completed batches 375/4186 | last batch size=4 | gml_id range=216931 -> 216934
# Processed 1504/16742 new rows | completed batches 376/4186 | last batch size=4 | gml_id range=216935 -> 216938
# Processed 1508/16742 new rows | completed batches 377/4186 | last batch size=4 | gml_id range=216939 -> 216942
# Checkpoint saved with 52 new rows
# Processed 1512/16742 new rows | completed batches 378/4186 | last batch size=4 | gml_id range=216947 -> 216950
# Processed 1516/16742 new rows | completed batches 379/4186 | last batch size=4 | gml_id range=216951 -> 216954
# Processed 1520/16742 new rows | completed batches 380/4186 | last batch size=4 | gml_id range=216955 -> 216958
# Processed 1524/16742 new rows | completed batches 381/4186 | last batch size=4 | gml_id range=216943 -> 216946
# Processed 1528/16742 new rows | completed batches 382/4186 | last batch size=4 | gml_id range=216963 -> 216966
# Processed 1532/16742 new rows | completed batches 383/4186 | last batch size=4 | gml_id range=216959 -> 216962
# Processed 1536/16742 new rows | completed batches 384/4186 | last batch size=4 | gml_id range=216967 -> 216970
# Processed 1540/16742 new rows | completed batches 385/4186 | last batch size=4 | gml_id range=216975 -> 216978
# Processed 1544/16742 new rows | completed batches 386/4186 | last batch size=4 | gml_id range=216971 -> 216974
# Processed 1548/16742 new rows | completed batches 387/4186 | last batch size=4 | gml_id range=216979 -> 216982
# Processed 1552/16742 new rows | completed batches 388/4186 | last batch size=4 | gml_id range=216987 -> 216990
# Processed 1556/16742 new rows | completed batches 389/4186 | last batch size=4 | gml_id range=216983 -> 216986
# Processed 1560/16742 new rows | completed batches 390/4186 | last batch size=4 | gml_id range=216991 -> 216994
# Checkpoint saved with 52 new rows
# Processed 1564/16742 new rows | completed batches 391/4186 | last batch size=4 | gml_id range=216999 -> 217002
# Processed 1568/16742 new rows | completed batches 392/4186 | last batch size=4 | gml_id range=216995 -> 216998
# Processed 1572/16742 new rows | completed batches 393/4186 | last batch size=4 | gml_id range=217003 -> 217006
# Processed 1576/16742 new rows | completed batches 394/4186 | last batch size=4 | gml_id range=217007 -> 217010
# Processed 1580/16742 new rows | completed batches 395/4186 | last batch size=4 | gml_id range=217011 -> 217014
# Processed 1584/16742 new rows | completed batches 396/4186 | last batch size=4 | gml_id range=217015 -> 217018
# Processed 1588/16742 new rows | completed batches 397/4186 | last batch size=4 | gml_id range=217019 -> 217022
# Processed 1592/16742 new rows | completed batches 398/4186 | last batch size=4 | gml_id range=217028 -> 217031
# Processed 1596/16742 new rows | completed batches 399/4186 | last batch size=4 | gml_id range=217023 -> 217027
# Processed 1600/16742 new rows | completed batches 400/4186 | last batch size=4 | gml_id range=217040 -> 217043
# Processed 1604/16742 new rows | completed batches 401/4186 | last batch size=4 | gml_id range=217036 -> 217039
# Processed 1608/16742 new rows | completed batches 402/4186 | last batch size=4 | gml_id range=217032 -> 217035
# Processed 1612/16742 new rows | completed batches 403/4186 | last batch size=4 | gml_id range=217044 -> 217047
# Checkpoint saved with 52 new rows
# Processed 1616/16742 new rows | completed batches 404/4186 | last batch size=4 | gml_id range=217048 -> 217051
# Processed 1620/16742 new rows | completed batches 405/4186 | last batch size=4 | gml_id range=217052 -> 217055
# Processed 1624/16742 new rows | completed batches 406/4186 | last batch size=4 | gml_id range=217056 -> 217059
# Processed 1628/16742 new rows | completed batches 407/4186 | last batch size=4 | gml_id range=217064 -> 217067
# Processed 1632/16742 new rows | completed batches 408/4186 | last batch size=4 | gml_id range=217068 -> 217071
# Processed 1636/16742 new rows | completed batches 409/4186 | last batch size=4 | gml_id range=217072 -> 217075
# Processed 1640/16742 new rows | completed batches 410/4186 | last batch size=4 | gml_id range=217060 -> 217063
# Processed 1644/16742 new rows | completed batches 411/4186 | last batch size=4 | gml_id range=217076 -> 217079
# Processed 1648/16742 new rows | completed batches 412/4186 | last batch size=4 | gml_id range=217080 -> 217083
# Processed 1652/16742 new rows | completed batches 413/4186 | last batch size=4 | gml_id range=217088 -> 217091
# Processed 1656/16742 new rows | completed batches 414/4186 | last batch size=4 | gml_id range=217084 -> 217087
# Processed 1660/16742 new rows | completed batches 415/4186 | last batch size=4 | gml_id range=217092 -> 217095
# Processed 1664/16742 new rows | completed batches 416/4186 | last batch size=4 | gml_id range=217096 -> 217099
# Checkpoint saved with 52 new rows
# Processed 1668/16742 new rows | completed batches 417/4186 | last batch size=4 | gml_id range=217108 -> 217111
# Processed 1672/16742 new rows | completed batches 418/4186 | last batch size=4 | gml_id range=217104 -> 217107
# Processed 1676/16742 new rows | completed batches 419/4186 | last batch size=4 | gml_id range=217100 -> 217103
# Processed 1680/16742 new rows | completed batches 420/4186 | last batch size=4 | gml_id range=217120 -> 217123
# Processed 1684/16742 new rows | completed batches 421/4186 | last batch size=4 | gml_id range=217112 -> 217115
# Processed 1688/16742 new rows | completed batches 422/4186 | last batch size=4 | gml_id range=217116 -> 217119
# Processed 1692/16742 new rows | completed batches 423/4186 | last batch size=4 | gml_id range=217128 -> 217131
# Processed 1696/16742 new rows | completed batches 424/4186 | last batch size=4 | gml_id range=217124 -> 217127
# Processed 1700/16742 new rows | completed batches 425/4186 | last batch size=4 | gml_id range=217132 -> 217135
# Processed 1704/16742 new rows | completed batches 426/4186 | last batch size=4 | gml_id range=217140 -> 217143
# ...
# Processed 16196/16742 new rows | completed batches 4049/4186 | last batch size=4 | gml_id range=588440 -> 588641
# Processed 16200/16742 new rows | completed batches 4050/4186 | last batch size=4 | gml_id range=588642 -> 588981
# Processed 16204/16742 new rows | completed batches 4051/4186 | last batch size=4 | gml_id range=588982 -> 588989
# Processed 16208/16742 new rows | completed batches 4052/4186 | last batch size=4 | gml_id range=588990 -> 589033
# Processed 16212/16742 new rows | completed batches 4053/4186 | last batch size=4 | gml_id range=589035 -> 589113
# Processed 16216/16742 new rows | completed batches 4054/4186 | last batch size=4 | gml_id range=589118 -> 589290
# Processed 16220/16742 new rows | completed batches 4055/4186 | last batch size=4 | gml_id range=589319 -> 589446
# Processed 16224/16742 new rows | completed batches 4056/4186 | last batch size=4 | gml_id range=589291 -> 589318
# Checkpoint saved with 52 new rows
# Processed 16228/16742 new rows | completed batches 4057/4186 | last batch size=4 | gml_id range=589447 -> 589618
# Processed 16232/16742 new rows | completed batches 4058/4186 | last batch size=4 | gml_id range=589619 -> 589622
# Processed 16236/16742 new rows | completed batches 4059/4186 | last batch size=4 | gml_id range=589623 -> 589800
# Processed 16240/16742 new rows | completed batches 4060/4186 | last batch size=4 | gml_id range=589801 -> 589991
# Processed 16244/16742 new rows | completed batches 4061/4186 | last batch size=4 | gml_id range=589992 -> 590342
# Processed 16248/16742 new rows | completed batches 4062/4186 | last batch size=4 | gml_id range=590343 -> 590585
# Processed 16252/16742 new rows | completed batches 4063/4186 | last batch size=4 | gml_id range=590586 -> 590764
# Processed 16256/16742 new rows | completed batches 4064/4186 | last batch size=4 | gml_id range=590765 -> 591269
# Processed 16260/16742 new rows | completed batches 4065/4186 | last batch size=4 | gml_id range=591340 -> 591438
# Processed 16264/16742 new rows | completed batches 4066/4186 | last batch size=4 | gml_id range=591270 -> 591339
# Processed 16268/16742 new rows | completed batches 4067/4186 | last batch size=4 | gml_id range=591441 -> 591730
# Processed 16272/16742 new rows | completed batches 4068/4186 | last batch size=4 | gml_id range=591731 -> 591816
# Processed 16276/16742 new rows | completed batches 4069/4186 | last batch size=4 | gml_id range=591817 -> 592102
# Checkpoint saved with 52 new rows
# Processed 16280/16742 new rows | completed batches 4070/4186 | last batch size=4 | gml_id range=592103 -> 592160
# Processed 16284/16742 new rows | completed batches 4071/4186 | last batch size=4 | gml_id range=592161 -> 592348
# Processed 16288/16742 new rows | completed batches 4072/4186 | last batch size=4 | gml_id range=592597 -> 592775
# Processed 16292/16742 new rows | completed batches 4073/4186 | last batch size=4 | gml_id range=592349 -> 592596
# Processed 16296/16742 new rows | completed batches 4074/4186 | last batch size=4 | gml_id range=593069 -> 593380
# Processed 16300/16742 new rows | completed batches 4075/4186 | last batch size=4 | gml_id range=593381 -> 593521
# Processed 16304/16742 new rows | completed batches 4076/4186 | last batch size=4 | gml_id range=592776 -> 593068
# Processed 16308/16742 new rows | completed batches 4077/4186 | last batch size=4 | gml_id range=593522 -> 593600
# Processed 16312/16742 new rows | completed batches 4078/4186 | last batch size=4 | gml_id range=593632 -> 593762
# Processed 16316/16742 new rows | completed batches 4079/4186 | last batch size=4 | gml_id range=593602 -> 593631
# Processed 16320/16742 new rows | completed batches 4080/4186 | last batch size=4 | gml_id range=594179 -> 594372
# Processed 16324/16742 new rows | completed batches 4081/4186 | last batch size=4 | gml_id range=593763 -> 594178
# Processed 16328/16742 new rows | completed batches 4082/4186 | last batch size=4 | gml_id range=594373 -> 594456
# Checkpoint saved with 52 new rows
# Processed 16332/16742 new rows | completed batches 4083/4186 | last batch size=4 | gml_id range=594617 -> 595314
# Processed 16336/16742 new rows | completed batches 4084/4186 | last batch size=4 | gml_id range=594457 -> 594616
# Processed 16340/16742 new rows | completed batches 4085/4186 | last batch size=4 | gml_id range=595315 -> 596519
# Processed 16344/16742 new rows | completed batches 4086/4186 | last batch size=4 | gml_id range=596520 -> 596599
# Processed 16348/16742 new rows | completed batches 4087/4186 | last batch size=4 | gml_id range=596600 -> 596935
# Processed 16352/16742 new rows | completed batches 4088/4186 | last batch size=4 | gml_id range=597167 -> 597558
# Processed 16356/16742 new rows | completed batches 4089/4186 | last batch size=4 | gml_id range=596936 -> 597049
# Processed 16360/16742 new rows | completed batches 4090/4186 | last batch size=4 | gml_id range=597050 -> 597166
# Processed 16364/16742 new rows | completed batches 4091/4186 | last batch size=4 | gml_id range=597563 -> 597594
# Processed 16368/16742 new rows | completed batches 4092/4186 | last batch size=4 | gml_id range=597595 -> 597831
# Processed 16372/16742 new rows | completed batches 4093/4186 | last batch size=4 | gml_id range=597559 -> 597562
# Processed 16376/16742 new rows | completed batches 4094/4186 | last batch size=4 | gml_id range=597832 -> 598042
# Processed 16380/16742 new rows | completed batches 4095/4186 | last batch size=4 | gml_id range=598063 -> 598226
# Checkpoint saved with 52 new rows
# Processed 16384/16742 new rows | completed batches 4096/4186 | last batch size=4 | gml_id range=598043 -> 598062
# Processed 16388/16742 new rows | completed batches 4097/4186 | last batch size=4 | gml_id range=598227 -> 598264
# Processed 16392/16742 new rows | completed batches 4098/4186 | last batch size=4 | gml_id range=598388 -> 598657
# Processed 16396/16742 new rows | completed batches 4099/4186 | last batch size=4 | gml_id range=598265 -> 598387
# Processed 16400/16742 new rows | completed batches 4100/4186 | last batch size=4 | gml_id range=598658 -> 599078
# Processed 16404/16742 new rows | completed batches 4101/4186 | last batch size=4 | gml_id range=599217 -> 599543
# Processed 16408/16742 new rows | completed batches 4102/4186 | last batch size=4 | gml_id range=599079 -> 599216
# Processed 16412/16742 new rows | completed batches 4103/4186 | last batch size=4 | gml_id range=599544 -> 599730
# Processed 16416/16742 new rows | completed batches 4104/4186 | last batch size=4 | gml_id range=599731 -> 599953
# Processed 16420/16742 new rows | completed batches 4105/4186 | last batch size=4 | gml_id range=599954 -> 600263
# Processed 16424/16742 new rows | completed batches 4106/4186 | last batch size=4 | gml_id range=600264 -> 600417
# Processed 16428/16742 new rows | completed batches 4107/4186 | last batch size=4 | gml_id range=600418 -> 600498
# Processed 16432/16742 new rows | completed batches 4108/4186 | last batch size=4 | gml_id range=600499 -> 600640
# Checkpoint saved with 52 new rows
# Processed 16436/16742 new rows | completed batches 4109/4186 | last batch size=4 | gml_id range=601060 -> 601282
# Processed 16440/16742 new rows | completed batches 4110/4186 | last batch size=4 | gml_id range=600641 -> 601058
# Processed 16444/16742 new rows | completed batches 4111/4186 | last batch size=4 | gml_id range=601284 -> 601343
# Processed 16448/16742 new rows | completed batches 4112/4186 | last batch size=4 | gml_id range=601344 -> 601671
# Processed 16452/16742 new rows | completed batches 4113/4186 | last batch size=4 | gml_id range=601980 -> 602294
# Processed 16456/16742 new rows | completed batches 4114/4186 | last batch size=4 | gml_id range=601672 -> 601979
# Processed 16460/16742 new rows | completed batches 4115/4186 | last batch size=4 | gml_id range=602295 -> 602396
# Processed 16464/16742 new rows | completed batches 4116/4186 | last batch size=4 | gml_id range=603019 -> 603046
# Processed 16468/16742 new rows | completed batches 4117/4186 | last batch size=4 | gml_id range=602397 -> 602509
# Processed 16472/16742 new rows | completed batches 4118/4186 | last batch size=4 | gml_id range=602510 -> 603018
# Processed 16476/16742 new rows | completed batches 4119/4186 | last batch size=4 | gml_id range=603436 -> 603689
# Processed 16480/16742 new rows | completed batches 4120/4186 | last batch size=4 | gml_id range=603047 -> 603435
# Processed 16484/16742 new rows | completed batches 4121/4186 | last batch size=4 | gml_id range=603690 -> 603746
# Checkpoint saved with 52 new rows
# Processed 16488/16742 new rows | completed batches 4122/4186 | last batch size=4 | gml_id range=603747 -> 603850
# Processed 16492/16742 new rows | completed batches 4123/4186 | last batch size=4 | gml_id range=603998 -> 604281
# Processed 16496/16742 new rows | completed batches 4124/4186 | last batch size=4 | gml_id range=603851 -> 603994
# Processed 16500/16742 new rows | completed batches 4125/4186 | last batch size=4 | gml_id range=604282 -> 604532
# Processed 16504/16742 new rows | completed batches 4126/4186 | last batch size=4 | gml_id range=604667 -> 605024
# Processed 16508/16742 new rows | completed batches 4127/4186 | last batch size=4 | gml_id range=604533 -> 604666
# Processed 16512/16742 new rows | completed batches 4128/4186 | last batch size=4 | gml_id range=605025 -> 605093
# Processed 16516/16742 new rows | completed batches 4129/4186 | last batch size=4 | gml_id range=605094 -> 605514
# Processed 16520/16742 new rows | completed batches 4130/4186 | last batch size=4 | gml_id range=605515 -> 605654
# Processed 16524/16742 new rows | completed batches 4131/4186 | last batch size=4 | gml_id range=605655 -> 606038
# Processed 16528/16742 new rows | completed batches 4132/4186 | last batch size=4 | gml_id range=606039 -> 606067
# Processed 16532/16742 new rows | completed batches 4133/4186 | last batch size=4 | gml_id range=606425 -> 606520
# Processed 16536/16742 new rows | completed batches 4134/4186 | last batch size=4 | gml_id range=606298 -> 606424
# Checkpoint saved with 52 new rows
# Processed 16540/16742 new rows | completed batches 4135/4186 | last batch size=4 | gml_id range=606068 -> 606297
# Processed 16544/16742 new rows | completed batches 4136/4186 | last batch size=4 | gml_id range=606529 -> 606524
# Processed 16548/16742 new rows | completed batches 4137/4186 | last batch size=4 | gml_id range=606525 -> 606512
# Processed 16552/16742 new rows | completed batches 4138/4186 | last batch size=4 | gml_id range=606521 -> 606528
# Processed 16556/16742 new rows | completed batches 4139/4186 | last batch size=4 | gml_id range=606513 -> 606868
# Processed 16560/16742 new rows | completed batches 4140/4186 | last batch size=4 | gml_id range=606941 -> 607129
# Processed 16564/16742 new rows | completed batches 4141/4186 | last batch size=4 | gml_id range=606869 -> 606940
# Processed 16568/16742 new rows | completed batches 4142/4186 | last batch size=4 | gml_id range=607130 -> 607281
# Processed 16572/16742 new rows | completed batches 4143/4186 | last batch size=4 | gml_id range=607628 -> 607690
# Processed 16576/16742 new rows | completed batches 4144/4186 | last batch size=4 | gml_id range=607282 -> 607627
# Processed 16580/16742 new rows | completed batches 4145/4186 | last batch size=4 | gml_id range=607691 -> 607713
# Processed 16584/16742 new rows | completed batches 4146/4186 | last batch size=4 | gml_id range=607714 -> 608014
# Processed 16588/16742 new rows | completed batches 4147/4186 | last batch size=4 | gml_id range=608015 -> 608010
# Checkpoint saved with 52 new rows
# Processed 16592/16742 new rows | completed batches 4148/4186 | last batch size=4 | gml_id range=608060 -> 608086
# Processed 16596/16742 new rows | completed batches 4149/4186 | last batch size=4 | gml_id range=608011 -> 608059
# Processed 16600/16742 new rows | completed batches 4150/4186 | last batch size=4 | gml_id range=608087 -> 608343
# Processed 16604/16742 new rows | completed batches 4151/4186 | last batch size=4 | gml_id range=608368 -> 608838
# Processed 16608/16742 new rows | completed batches 4152/4186 | last batch size=4 | gml_id range=608344 -> 608367
# Processed 16612/16742 new rows | completed batches 4153/4186 | last batch size=4 | gml_id range=608974 -> 609153
# Processed 16616/16742 new rows | completed batches 4154/4186 | last batch size=4 | gml_id range=608839 -> 608969
# Processed 16620/16742 new rows | completed batches 4155/4186 | last batch size=4 | gml_id range=608970 -> 608973
# Processed 16624/16742 new rows | completed batches 4156/4186 | last batch size=4 | gml_id range=609154 -> 609414
# Processed 16628/16742 new rows | completed batches 4157/4186 | last batch size=4 | gml_id range=609415 -> 609791
# Processed 16632/16742 new rows | completed batches 4158/4186 | last batch size=4 | gml_id range=609792 -> 609971
# Processed 16636/16742 new rows | completed batches 4159/4186 | last batch size=4 | gml_id range=609975 -> 610224
# Processed 16640/16742 new rows | completed batches 4160/4186 | last batch size=4 | gml_id range=610232 -> 610408
# Checkpoint saved with 52 new rows
# Processed 16644/16742 new rows | completed batches 4161/4186 | last batch size=4 | gml_id range=610409 -> 610466
# Processed 16648/16742 new rows | completed batches 4162/4186 | last batch size=4 | gml_id range=610467 -> 610533
# Processed 16652/16742 new rows | completed batches 4163/4186 | last batch size=4 | gml_id range=610534 -> 610553
# Processed 16656/16742 new rows | completed batches 4164/4186 | last batch size=4 | gml_id range=610554 -> 610726
# Processed 16660/16742 new rows | completed batches 4165/4186 | last batch size=4 | gml_id range=610763 -> 610786
# Processed 16664/16742 new rows | completed batches 4166/4186 | last batch size=4 | gml_id range=610727 -> 610762
# Processed 16668/16742 new rows | completed batches 4167/4186 | last batch size=4 | gml_id range=610824 -> 610847
# Processed 16672/16742 new rows | completed batches 4168/4186 | last batch size=4 | gml_id range=610787 -> 610823
# Processed 16676/16742 new rows | completed batches 4169/4186 | last batch size=4 | gml_id range=610985 -> 611076
# Processed 16680/16742 new rows | completed batches 4170/4186 | last batch size=4 | gml_id range=610848 -> 610984
# Processed 16684/16742 new rows | completed batches 4171/4186 | last batch size=4 | gml_id range=611077 -> 611236
# Processed 16688/16742 new rows | completed batches 4172/4186 | last batch size=4 | gml_id range=611237 -> 611252
# Processed 16692/16742 new rows | completed batches 4173/4186 | last batch size=4 | gml_id range=611295 -> 611639
# Checkpoint saved with 52 new rows
# Processed 16696/16742 new rows | completed batches 4174/4186 | last batch size=4 | gml_id range=611253 -> 611294
# Processed 16700/16742 new rows | completed batches 4175/4186 | last batch size=4 | gml_id range=611640 -> 611671
# Processed 16704/16742 new rows | completed batches 4176/4186 | last batch size=4 | gml_id range=611672 -> 611880
# Processed 16708/16742 new rows | completed batches 4177/4186 | last batch size=4 | gml_id range=611885 -> 611931
# Processed 16712/16742 new rows | completed batches 4178/4186 | last batch size=4 | gml_id range=612000 -> 612420
# Processed 16716/16742 new rows | completed batches 4179/4186 | last batch size=4 | gml_id range=611932 -> 611999
# Processed 16720/16742 new rows | completed batches 4180/4186 | last batch size=4 | gml_id range=612421 -> 612560
# Processed 16724/16742 new rows | completed batches 4181/4186 | last batch size=4 | gml_id range=612561 -> 612598
# Processed 16728/16742 new rows | completed batches 4182/4186 | last batch size=4 | gml_id range=612599 -> 612594
# Processed 16732/16742 new rows | completed batches 4183/4186 | last batch size=4 | gml_id range=613226 -> 613293
# Processed 16736/16742 new rows | completed batches 4184/4186 | last batch size=4 | gml_id range=612595 -> 613145
# Processed 16740/16742 new rows | completed batches 4185/4186 | last batch size=4 | gml_id range=613146 -> 613225
# Processed 16742/16742 new rows | completed batches 4186/4186 | last batch size=2 | gml_id range=613294 -> 613295
# Checkpoint saved with 50 new rows
