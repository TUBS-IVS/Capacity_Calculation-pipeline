# %%
import geopandas as gpd

pois = r"condensed_buildings_with_pois.gpkg"

# Load the POI layer
pois = gpd.read_file(pois)

print(f"Loaded {len(pois)} POIs")
# Out:
# Loaded 578080 POIs

# %%
pois.head()
# Out:
#    gml_id    volume_m3                            label_en osm_building_type  \
# 0       0   931.423451  Buildings for business or commerce              None
# 1       1  1275.527533  Buildings for business or commerce              None
# 2       2   229.902499  Buildings for business or commerce              None
# 3       3    84.748005  Buildings for business or commerce              None
# 4       4   351.716079  Buildings for business or commerce              None
#
#   osm_landuse_class osm_landuse_name gfk_class ALKIS_Landuse_info osm_names  \
# 0       residential             None   Gebäude         commercial      None
# 1       residential             None   Gebäude         commercial      None
# 2       residential             None   Gebäude          residence      None
# 3       residential             None   Gebäude          residence      None
# 4       residential             None   Gebäude          residence      None
#
#                         alkis_address email amenity building  shop tourism  \
# 0      Ackerweg 2 Braunschweig, Stadt  None    None     None  None    None
# 1  Stieglitzweg 3 Braunschweig, Stadt  None    None     None  None    None
# 2                 Braunschweig, Stadt  None    None     None  None    None
# 3                 Braunschweig, Stadt  None    None     None  None    None
# 4                 Braunschweig, Stadt  None    None     None  None    None
#
#   information tags_search additional_information website  \
# 0        None        None                   None    None
# 1        None        None                   None    None
# 2        None        None                   None    None
# 3        None        None                   None    None
# 4        None        None                   None    None
#
#                                             geometry
# 0  MULTIPOLYGON Z (((609554.181 5797264.172 78.94...
# 1  MULTIPOLYGON Z (((608098.849 5796746.146 83.91...
# 2  MULTIPOLYGON Z (((608926.355 5797165.768 84.6,...
# 3  MULTIPOLYGON Z (((609588.957 5797487.563 77.14...
# 4  MULTIPOLYGON Z (((608902.529 5796965.286 84.84...

# %%
pois.columns
# Out:
# Index(['gml_id', 'volume_m3', 'label_en', 'osm_building_type',
#        'osm_landuse_class', 'osm_landuse_name', 'gfk_class',
#        'ALKIS_Landuse_info', 'osm_names', 'alkis_address', 'email', 'amenity',
#        'building', 'shop', 'tourism', 'information', 'tags_search',
#        'additional_information', 'website', 'geometry'],
#       dtype='object')

# %%
import pandas as pd

def is_missing(x) -> bool:
    if x is None:
        return True
    if isinstance(x, float) and pd.isna(x):
        return True
    if isinstance(x, str) and x.strip().lower() in ["", "none", "nan", "null"]:
        return True
    if isinstance(x, (list, tuple, set, dict)) and len(x) == 0:
        return True
    return False


def format_value(x):
    if is_missing(x):
        return None

    if isinstance(x, (list, tuple, set)):
        vals = [format_value(v) for v in x if not is_missing(v)]
        vals = [v for v in vals if v]
        return "; ".join(vals) if vals else None

    if isinstance(x, dict):
        vals = []
        for k, v in x.items():
            v_clean = format_value(v)
            if v_clean:
                vals.append(f"{k}: {v_clean}")
        return "; ".join(vals) if vals else None

    return str(x).strip()


def collect_fields(row, fields):
    bits = []

    for col, label in fields:
        val = format_value(row.get(col))
        if val:
            bits.append(f"{label}={val}")

    return bits


def row_to_llm_input(row) -> str:
    precise_fields = [
        ("osm_names", "name"),
        ("amenity", "amenity"),
        ("building", "building"),
        ("shop", "shop"),
        ("tourism", "tourism"),
        ("information", "information"),
        ("website", "website"),
        ("email", "email"),
    ]

    general_fields = [
        ("label_en", "building_label"),
        ("osm_building_type", "osm_building_type"),
        ("osm_landuse_class", "osm_landuse_class"),
        ("osm_landuse_name", "osm_landuse_name"),
        ("gfk_class", "gfk_class"),
        ("ALKIS_Landuse_info", "alkis_landuse"),
        ("tags_search", "tags"),
        ("additional_information", "additional_info"),
    ]

    precise_bits = collect_fields(row, precise_fields)
    general_bits = collect_fields(row, general_fields)

    sections = []

    if precise_bits:
        sections.append("precise_known_info: " + " | ".join(precise_bits))

    if general_bits:
        sections.append("general_building_context: " + " | ".join(general_bits))

    return "\n".join(sections)


pois["sentence"] = pois.apply(row_to_llm_input, axis=1)

# %%
pois[["gml_id", "sentence"]].tail()
# Out:
#         gml_id                                           sentence
# 578075  613463  precise_known_info: name=['Kita Steimker Gärte...
# 578076  613464  precise_known_info: name=['DHL'] | amenity=['p...
# 578077  613465  general_building_context: osm_building_type=se...
# 578078  613466  general_building_context: osm_building_type=ca...
# 578079  613468  general_building_context: osm_building_type=se...

# %%
pois.head()
# Out:
#    gml_id    volume_m3                            label_en osm_building_type  \
# 0       0   931.423451  Buildings for business or commerce              None
# 1       1  1275.527533  Buildings for business or commerce              None
# 2       2   229.902499  Buildings for business or commerce              None
# 3       3    84.748005  Buildings for business or commerce              None
# 4       4   351.716079  Buildings for business or commerce              None
#
#   osm_landuse_class osm_landuse_name gfk_class ALKIS_Landuse_info osm_names  \
# 0       residential             None   Gebäude         commercial      None
# 1       residential             None   Gebäude         commercial      None
# 2       residential             None   Gebäude          residence      None
# 3       residential             None   Gebäude          residence      None
# 4       residential             None   Gebäude          residence      None
#
#                         alkis_address  ... amenity building  shop tourism  \
# 0      Ackerweg 2 Braunschweig, Stadt  ...    None     None  None    None
# 1  Stieglitzweg 3 Braunschweig, Stadt  ...    None     None  None    None
# 2                 Braunschweig, Stadt  ...    None     None  None    None
# 3                 Braunschweig, Stadt  ...    None     None  None    None
# 4                 Braunschweig, Stadt  ...    None     None  None    None
#
#   information tags_search additional_information website  \
# 0        None        None                   None    None
# 1        None        None                   None    None
# 2        None        None                   None    None
# 3        None        None                   None    None
# 4        None        None                   None    None
#
#                                             geometry  \
# 0  MULTIPOLYGON Z (((609554.181 5797264.172 78.94...
# 1  MULTIPOLYGON Z (((608098.849 5796746.146 83.91...
# 2  MULTIPOLYGON Z (((608926.355 5797165.768 84.6,...
# 3  MULTIPOLYGON Z (((609588.957 5797487.563 77.14...
# 4  MULTIPOLYGON Z (((608902.529 5796965.286 84.84...
#
#                                             sentence
# 0  general_building_context: building_label=Build...
# 1  general_building_context: building_label=Build...
# 2  general_building_context: building_label=Build...
# 3  general_building_context: building_label=Build...
# 4  general_building_context: building_label=Build...
#
# [5 rows x 21 columns]

# %%
import json
import time
import re
import requests
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

ENV_PATH = Path(".env")
load_dotenv(dotenv_path=ENV_PATH)

TU_TOKEN = os.getenv("TU_KI_TOOLBOX_TOKEN")

if not TU_TOKEN:
    raise RuntimeError(
        "Missing TU_KI_TOOLBOX_TOKEN."
        "Check Areas-of-interest-POIs/.env"
    )

API_URL = "https://ki-toolbox.tu-braunschweig.de/api/v1/chat/send"
# MODEL = "gpt-5.4-2026-03-05" # chatgpt-5.2
MODEL = "gpt-oss-120b" # open source chatgpt-oss-120b

# %%
SYSTEM_PROMPT = """
You are a building activity interpreter and classifier.

Your task is to classify BUILDINGS using structured input divided into TWO PARTS:

1) precise_known_info → high-confidence OSM-derived signals such as names, amenity, shop, office, tourism, healthcare, leisure, etc.
2) general_building_context → broader contextual signals such as ALKIS landuse, OSM building type, OSM landuse, auxiliary tags, and other building-context information.

You must produce TWO outputs:
1) Activity labels (mid_labels) → what activities take place inside the building
2) Bosserhof class → the dominant functional building-use class for capacity / volume estimation

────────────────────────────────────
CRITICAL SCOPE RULE
────────────────────────────────────

Only classify ENTERABLE BUILDINGS or building-like places people actually use as destinations.

If the described place is not a building, not enterable, or only an outdoor / infrastructure / passive object:
- "mid_labels": []
- "bosserhof_class": null

────────────────────────────────────
INPUT STRUCTURE AND EVIDENCE PRIORITY
────────────────────────────────────

precise_known_info:
- Primary source for mid_labels
- Usually contains reliable OSM-derived evidence
- May contain several names, shops, amenities, offices, healthcare uses, leisure uses, tourism uses, or other POI functions
- Treat multiple entries as possible multiple activities inside the same building

general_building_context:
- Primary source for Bosserhof classification
- Broader but less precise
- May include ALKIS building/land-use information, OSM building type, tags (General Information About pois), or auxiliary contextual fields
- Use it as fallback for mid_labels only when precise_known_info is weak, empty, or incomplete

────────────────────────────────────
PART A — ACTIVITY LABELS (VISITOR INTENT)
────────────────────────────────────

ALLOWED ACTIVITY LABELS
- work
- university
- school
- childcare
- retail_daily
- retail_non_daily
- leisure
- sports
- errands
- meetup
- lessons
- business

GOAL:
Identify ALL clearly supported activities taking place INSIDE the building.

MANDATORY PROCEDURE:
1) First extract every distinct function from precise_known_info.
   Each name, amenity, shop, office, healthcare, leisure, tourism, craft, service, or other POI-like entry can represent a separate function.
2) Map each extracted function independently to one or more activity labels.
3) Aggregate labels across all functions.
4) Remove duplicates.
5) Do not stop after the first detected function.

If precise_known_info is missing or very weak, use general_building_context to infer likely building activity, but be more conservative.

MULTI-ACTIVITY RULE (VERY IMPORTANT):
- A building may contain MANY activities (e.g., mall, mixed-use building)
- You MUST extract ALL clearly supported activities
- Do NOT collapse multiple activities into one
- Do NOT stop at the first match

Think of the building as a container of activities:
→ Identify EACH distinct function mentioned
→ Map EACH to a label

────────────────────────────────────
LABEL DEFINITIONS
────────────────────────────────────

- work

Represents on-site labor, operational activity, or institutional functioning carried out by people inside the building.
Assign this label whenever the building’s normal use depends on people being physically present
to carry out tasks, responsibilities, operations, supervision, coordination, production,
maintenance, administration, instruction, care, or service provision.
The focus of this label is not why visitors come, but whether the building functions as a place
where human work is performed as part of its regular purpose.
A building should receive "work" whenever people are not merely present incidentally,
but are there in an active functional role that helps the building fulfill its purpose.
This includes cases where the same building also serves customers, students, patients, clients,
guests, or other visitors. In such cases, "work" must be added in parallel with the visitor-oriented label(s),
because the activity of workers is part of the building’s core function.
Core idea: "People are here not only to use the building, but also to make it function."

- university

Represents tertiary/higher-level education activity.
Covers structured learning, teaching, and research at the higher education level
Involves academic instruction, research, and study environments
Distinct from general learning by its institutional and advanced nature
Core idea: “Advanced academic education and research happen here.”

- school

Represents formal compulsory or pre-tertiary education activity.
Covers structured education for children and adolescents
Includes general and vocational schooling
Defined by curriculum-based learning under institutional supervision
Core idea: “Children or teenagers receive structured education here.”

- childcare

Represents supervision and early development care for young children.
Focuses on care, supervision, and early-stage development
Not primarily academic or curriculum-driven (unlike school)
Strong emphasis on custodial and developmental support
Core idea: “Young children are cared for and supervised here.”

- retail_daily

Represents frequent, necessity-driven consumption activity.
Covers acquisition of essential, regularly needed goods
Characterized by high frequency and routine visits
Typically tied to basic living needs
Core idea: “People come here regularly to fulfill essential daily needs.”

- retail_non_daily

Represents infrequent, discretionary consumption activity.
Covers acquisition of non-essential or durable goods
Visits are planned, occasional, or need-based
Often involves comparison, browsing, or larger purchases
Core idea: “People come here occasionally to buy non-essential or long-term goods.”

- leisure

Represents hedonic, relaxation, or enjoyment-oriented activity.
Focuses on free-time use driven by pleasure, comfort, or experience
Includes passive or active enjoyment, but not primarily goal-oriented tasks
Distinguished by non-obligatory participation. People choose to go here for enjoyment, not out of necessity or obligation.
Core idea: “People come here to relax, enjoy, or spend free time.”

- sports

Represents physical activity, exercise, or bodily training.
Focuses on intentional physical exertion or fitness improvement
Can be recreational or structured, but always movement-centered
Distinguished from leisure by physical intensity and purpose
Core idea: “People come here to be physically active or train their body.”

- errands

Represents task-oriented, functional activities needed for daily life management.
Covers practical obligations or maintenance tasks
Typically short, goal-driven visits with a clear outcome
Often involves services, administration, or personal maintenance
Core idea: “People come here to complete necessary tasks or obligations.”

- meetup

Represents social interaction and gathering activity.
Focuses on interpersonal connection and shared presence
Can be informal or organized, but the primary purpose is social exchange
Not necessarily tied to consumption or formal structure
Core idea: “People come here to meet and interact with others.”

- lessons

Represents structured instruction or skill acquisition activity.
Focuses on learning guided by an instructor
Can occur at any level (formal or informal), but always organized and instructional
Distinguished from general education by activity type (learning session), not institution
Core idea: “People come here to learn something through instruction.”

- business

Represents professional or organizational interaction activity (non-routine workplace).
Covers goal-oriented professional interactions, often external-facing
Includes meetings, consulting, administrative dealings, or formal exchanges
Distinct from "work" because it reflects the visitor’s purpose, not employment
Core idea: “People come here for professional or organizational matters.”

────────────────────────────────────
PART B — BOSSERHOF BUILDING-USE CLASS
────────────────────────────────────

GOAL
Assign EXACTLY ONE Bosserhof label that matches the categories/subcategories.

KEY PRINCIPLE:
Bosserhof is NOT about activities — it is about the BUILDING TYPE.

SOURCE PRIORITY FOR BOSSERHOF:
1) general_building_context is the primary source
2) precise_known_info supports or refines the choice
3) mid_labels can help interpret use, but must not override stronger building-type evidence

DOMINANCE HEURISTIC:
Choose the dominant function using:
1) explicit building type or ALKIS function
2) landuse / area context
3) scale indicators such as mall, shopping centre, school complex, office building, industrial hall, hospital, hotel
4) repeated / majority functions among multiple entries
5) if still unclear, choose the closest headline class rather than null

MULTI-TENANT BUILDINGS:
- Extract ALL activities (mid_labels)
- Assign ONE dominant Bosserhof class

STEP 1 — Subcategory FIRST (preferred)
If you can confidently map the building to ONE of the Bosserhof SUBCATEGORIES listed below,
output that subcategory label (exact string match).

STEP 2 — Headline category fallback (MANDATORY WHEN SUBCATEGORY IS UNCERTAIN)
If the exact subcategory is uncertain but the dominant functional sector is inferable,
you MUST output the corresponding HEADLINE category.
Do not return null when a headline category can reasonably represent the building's dominant use.

STEP 3 — No assignment
If the building does not fit reliably in any headline category OR is not an enterable building,
output bosserhof_class = null.

────────────────────────────────────
ALLOWED BOSSERHOF HEADLINE CATEGORIES AND SUBCATEGORIES
────────────────────────────────────

NEAREST-VALID-CLASS RULE (MANDATORY)

If the building is clearly enterable and supports a recognizable human activity,
you MUST assign the closest Bosserhof class, even if the fit is imperfect.

1) Transport
- no fixed subcategories given; use headline when transport building with staff is clear
Notes: Transport-related buildings with operational staff (depots, terminals)
Exclude: stops/platforms/tracks

2) Yards, depots, storage areas, construction yards
- no fixed subcategories given; use headline when storage/yard with staff is clear
Notes: Storage or operational yards with staff
Exclude: pure storage without staff, open yards without buildings

3) Industrial operations / Production
Subcategories:
- highly productive industries / machine / material or space intensive
- others

4) Crafts and trades
Subcategories:
- craft businesses
- craft courtyards

5) Services
Subcategories:
- normal office
- open-plan office
- business-oriented services
- customer-oriented services
- hotels
- hotels with conference areas
- restaurants / gastronomy
- suppliers for car dealerships
- vehicle / electrical repair
- customer service
- car dealerships

6) Retail
Subcategories:
- wholesale
- retail (small-scale)
- discount stores
- DIY stores
- furniture stores
- hypermarkets / superstores
- shopping centers
- self-service department stores
- department stores
- factory outlet centers

7) Public facilities
Subcategories:
- schools
- universities
- research institutes
- kindergartens
- hospitals
- nursing homes

8) Facilities for culture, leisure and sports
Subcategories:
- entertainment, culture
- large cinemas
- musical theatres
- large discos, fun / leisure pools
- arenas, large events
- theme parks
- fitness / wellness

────────────────────────────────────
OUTPUT FORMAT (STRICT JSON ONLY)
────────────────────────────────────

{
  "interpreted_type": "<plain-English description of what the place most likely is>",
  "mid_labels": ["<zero or more activity labels from the allowed list>"],
  "bosserhof_class": "<one Bosserhof class or null>"}
""".strip()

# %%
# -----------------------------
# MiD labels (STRICT)
# -----------------------------

TARGET_MID_LABELS = {
    "work",
    "university",
    "school",
    "childcare",
    "retail_daily",
    "retail_non_daily",
    "leisure",
    "sports",
    "errands",
    "meetup",
    "lessons",
    "business",
}


# -----------------------------
# JSON extraction
# -----------------------------

def extract_first_json_array(text: str) -> list:
    """
    Extract the first JSON array from model output.
    Used for batch mode.
    """
    text = "" if text is None else str(text).strip()

    # Remove markdown fences if present
    text = re.sub(r"^```(?:json)?", "", text, flags=re.IGNORECASE).strip()
    text = re.sub(r"```$", "", text).strip()

    decoder = json.JSONDecoder()

    for i, ch in enumerate(text):
        if ch == "[":
            try:
                obj, _ = decoder.raw_decode(text[i:])
                if isinstance(obj, list):
                    return obj
            except json.JSONDecodeError:
                continue

    raise ValueError("No valid JSON array found in model response.")


# -----------------------------
# Validation
# -----------------------------

def validate(obj: dict):
    # ---- Required keys ----
    if "interpreted_type" not in obj or not isinstance(obj["interpreted_type"], str):
        raise ValueError("Missing or invalid interpreted_type")

    if "mid_labels" not in obj or not isinstance(obj["mid_labels"], list):
        raise ValueError("mid_labels must be a list")

    if "bosserhof_class" not in obj:
        raise ValueError("Missing bosserhof_class")

    # ---- Validate MiD labels ----
    for lab in obj["mid_labels"]:
        if lab not in TARGET_MID_LABELS:
            raise ValueError(f"Invalid MiD label: {lab}")

    # ---- Validate Bosserhof class ----
    bc = obj["bosserhof_class"]

    if bc is None or bc == []:
        return

    if isinstance(bc, str) and bc.strip():
        return

    raise ValueError("bosserhof_class must be a non-empty string, [] or None")

# %%
def call_tu_llm(
    user_input: str = None,
    batch_inputs: list = None,
    max_retries=3,
    backoff_sec=2.0,
    debug=False,
) -> str:

    headers = {
        "Authorization": f"Bearer {TU_TOKEN}",
        "Accept": "application/json",
        "Content-Type": "application/json",
    }

    # -----------------------------
    # Build prompt
    # -----------------------------
    if batch_inputs is not None:
        items = []
        for i, row in enumerate(batch_inputs, start=1):
            gml_id = str(row["gml_id"])
            sentence = "" if row.get("sentence") is None else str(row.get("sentence"))
            items.append(
                f"ITEM {i}\n"
                f"gml_id: {gml_id}\n"
                f"sentence: {sentence}"
            )

        prompt_text = (
            "Classify each ITEM independently. "
            "Return ONLY one valid JSON array with one object per ITEM, in the same order.\n\n"
            + "\n\n".join(items)
        )
    else:
        prompt_text = "" if user_input is None else str(user_input)

    payload = {
        "thread": None,
        "prompt": prompt_text,
        "model": MODEL,
        "customInstructions": SYSTEM_PROMPT,
        "hideCustomInstructions": True,
    }

    last_err = None

    for attempt in range(1, max_retries + 1):
        try:
            r = requests.post(
                API_URL,
                headers=headers,
                json=payload,
                stream=True,
                timeout=120,
            )

            if debug:
                print("STATUS:", r.status_code)
                try:
                    print("REQUEST PAYLOAD:", json.dumps(payload, indent=2)[:4000])
                except Exception:
                    pass

            r.raise_for_status()

            full_text = ""

            for line in r.iter_lines(decode_unicode=True):
                if not line:
                    continue
                try:
                    event = json.loads(line)
                except json.JSONDecodeError:
                    continue

                if event.get("type") == "chunk":
                    full_text += event.get("content", "")
                elif event.get("type") == "done":
                    if "response" in event:
                        full_text = event["response"]
                    break

            return full_text

        except Exception as e:
            last_err = e
            if debug:
                print(f"Attempt {attempt} failed: {e}")
            time.sleep(backoff_sec * attempt)

    raise RuntimeError(f"TU LLM call failed: {last_err}")

# %%
import json
import re

def extract_first_json_array(text: str):
    text = "" if text is None else str(text).strip()

    # remove markdown fences if model returns ```json ... ```
    text = re.sub(r"^```(?:json)?", "", text.strip(), flags=re.IGNORECASE)
    text = re.sub(r"```$", "", text.strip())

    decoder = json.JSONDecoder()

    for i, ch in enumerate(text):
        if ch == "[":
            try:
                obj, _ = decoder.raw_decode(text[i:])
                if isinstance(obj, list):
                    return obj
            except json.JSONDecodeError:
                continue

    raise ValueError("No valid JSON array found in model response.")

def predict_from_sentence(gml_id=None, sentence=None, batch_rows=None, debug=False):

    # -----------------------------
    # BATCH MODE
    # -----------------------------
    if batch_rows is not None:
        try:
            raw = call_tu_llm(batch_inputs=batch_rows, debug=debug)
            objs = extract_first_json_array(raw)

            if len(objs) != len(batch_rows):
                raise ValueError(
                    f"Batch size mismatch: got {len(objs)} outputs for {len(batch_rows)} inputs."
                )

            results = []
            for row, obj in zip(batch_rows, objs):
                row_gml_id = str(row["gml_id"])

                try:
                    validate(obj)
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": obj["interpreted_type"],
                        "mid_labels": obj["mid_labels"],
                        "bosserhof_class": obj["bosserhof_class"],
                    })
                except Exception as e:
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": "error",
                        "mid_labels": [],
                        "bosserhof_class": None,
                        "error": str(e),
                    })

            return results

        except Exception as e:
            return [
                {
                    "gml_id": str(row["gml_id"]),
                    "interpreted_type": "error",
                    "mid_labels": [],
                    "bosserhof_class": None,
                    "error": str(e),
                }
                for row in batch_rows
            ]

    # -----------------------------
    # SINGLE MODE
    # -----------------------------
    gml_id = gml_id.item() if hasattr(gml_id, "item") else gml_id
    sentence = "" if sentence is None else str(sentence)

    try:
        raw = call_tu_llm(user_input=sentence, debug=debug)
        obj = extract_first_json_object(raw)
        validate(obj)

        return {
            "gml_id": str(gml_id),
            "interpreted_type": obj["interpreted_type"],
            "mid_labels": obj["mid_labels"],
            "bosserhof_class": obj["bosserhof_class"],
        }
    except Exception as e:
        return [
            {
                "gml_id": str(row["gml_id"]),
                "interpreted_type": "error",
                "mid_labels": [],
                "bosserhof_class": None,
                "error": str(e),
            }
            for row in batch_rows
        ]

# %%
import time
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd


# ---------------------------------------------------------
# Helper: split list into chunks
# ---------------------------------------------------------
def chunk_list(items, batch_size):
    for i in range(0, len(items), batch_size):
        yield items[i:i + batch_size]


# ---------------------------------------------------------
# RETRY WRAPPER FOR A WHOLE BATCH
# ---------------------------------------------------------
def predict_batch_with_retry(batch_rows, debug=False, max_retries=3, wait_sec=5):
    last_err = None
    batch_ids = [str(r["gml_id"]) for r in batch_rows]

    for attempt in range(1, max_retries + 1):
        try:
            return predict_batch_from_sentences(
                batch_rows=batch_rows,
                debug=debug,
            )
        except Exception as e:
            last_err = e
            print(f"[batch {batch_ids[:3]}... size={len(batch_rows)}] attempt {attempt}/{max_retries} failed: {e}")
            time.sleep(wait_sec)

    raise last_err


# ---------------------------------------------------------
# THIS IS THE MAIN PLACE TO IMPLEMENT REAL API BATCHING
# ---------------------------------------------------------
def predict_batch_from_sentences(batch_rows, debug=False):
    results = []

    prompts = []
    for row in batch_rows:
        gml_id = str(row["gml_id"])
        sentence = row.get("sentence", "")
        prompts.append({
            "gml_id": gml_id,
            "sentence": sentence,
        })

    res = predict_from_sentence(
        batch_rows=prompts,
        debug=debug,
    )

    if not isinstance(res, list):
        raise ValueError("Batch prediction must return a list.")

    if len(res) != len(batch_rows):
        raise ValueError(
            f"Batch output length mismatch: got {len(res)} results for {len(batch_rows)} rows."
        )

    for item in res:
        if isinstance(item, dict):
            results.append(item)
        else:
            results.append({"prediction": item})

    return results


# ---------------------------------------------------------
# APPEND TO PARQUET
# ---------------------------------------------------------
def append_parquet(path, new_rows, deduplicate_on=None):
    if not new_rows:
        return

    new_df = pd.DataFrame(new_rows)

    if path.exists():
        old_df = pd.read_parquet(path)
        merged = pd.concat([old_df, new_df], ignore_index=True)
    else:
        merged = new_df.copy()

    if deduplicate_on is not None:
        merged = merged.drop_duplicates(subset=[deduplicate_on], keep="last")

    merged.to_parquet(path, index=False)


# ---------------------------------------------------------
# MAIN FUNCTION: PARALLEL + BATCHED
# ---------------------------------------------------------
def classify_resume_parallel_batched(
    pois_df: pd.DataFrame,
    checkpoint_path="predictions_checkpoint.parquet",
    error_path="prediction_errors.parquet",
    save_every=200,
    max_workers=5,
    batch_size=10,
    debug=False,
    max_retries=3,
    retry_wait_sec=5,
):
    checkpoint_path = Path(checkpoint_path)
    error_path = Path(error_path)

    df = pois_df.copy().reset_index(drop=True)

    if "gml_id" not in df.columns:
        raise ValueError("pois_df must contain a 'gml_id' column.")

    if "sentence" not in df.columns:
        raise ValueError("pois_df must contain a 'sentence' column.")

    df["gml_id"] = df["gml_id"].astype(str)

    # do not checkpoint geometry
    cols_to_save = [c for c in df.columns if c != "geometry"]

    # ---------------------------
    # Load checkpoint
    # ---------------------------
    if checkpoint_path.exists():
        checkpoint_df = pd.read_parquet(checkpoint_path)
        checkpoint_df["gml_id"] = checkpoint_df["gml_id"].astype(str)
        done_ids = set(checkpoint_df["gml_id"])
        print(f"Loaded checkpoint with {len(done_ids)} completed rows")
    else:
        done_ids = set()
        print("No checkpoint found. Starting from scratch.")

    remaining_df = df[~df["gml_id"].isin(done_ids)].copy()
    print(f"Remaining rows to process: {len(remaining_df)} / {len(df)}")

    records = remaining_df.to_dict("records")
    batches = list(chunk_list(records, batch_size))

    print(f"Total batches to process: {len(batches)} | batch_size={batch_size} | max_workers={max_workers}")

    def batch_worker(batch_rows):
        batch_results = predict_batch_with_retry(
            batch_rows=batch_rows,
            debug=debug,
            max_retries=max_retries,
            wait_sec=retry_wait_sec,
        )

        if not isinstance(batch_results, list):
            raise ValueError("predict_batch_from_sentences() must return a list.")

        if len(batch_results) != len(batch_rows):
            raise ValueError(
                f"Batch output length mismatch: got {len(batch_results)} results for {len(batch_rows)} rows."
            )

        out_rows = []
        for row_dict, res in zip(batch_rows, batch_results):
            out_row = {k: v for k, v in row_dict.items() if k in cols_to_save}

            if isinstance(res, dict):
                out_row.update(res)
            else:
                out_row["prediction"] = res

            out_rows.append(out_row)

        return out_rows

    buffer = []
    error_buffer = []
    processed_now = 0
    completed_batches = 0

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_batch = {
            executor.submit(batch_worker, batch_rows): batch_rows
            for batch_rows in batches
        }

        for future in as_completed(future_to_batch):
            batch_rows = future_to_batch[future]
            batch_ids = [str(r["gml_id"]) for r in batch_rows]

            try:
                out_rows = future.result()
                buffer.extend(out_rows)

                processed_now += len(out_rows)
                completed_batches += 1

                print(
                    f"Processed {processed_now}/{len(remaining_df)} new rows "
                    f"| completed batches {completed_batches}/{len(batches)} "
                    f"| last batch size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]}"
                )

            except Exception as e:
                for row in batch_rows:
                    error_buffer.append({
                        "gml_id": str(row["gml_id"]),
                        "error": str(e),
                    })

                completed_batches += 1
                print(
                    f"Failed batch {completed_batches}/{len(batches)} "
                    f"| size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]} "
                    f"| error={e}"
                )

            # Save regularly from main thread only
            if len(buffer) >= save_every:
                append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
                print(f"Checkpoint saved with {len(buffer)} new rows")
                buffer = []

            if len(error_buffer) >= save_every:
                append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
                print(f"Error log saved with {len(error_buffer)} rows")
                error_buffer = []

    # final flush
    if buffer:
        append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
        print("Final checkpoint saved.")

    if error_buffer:
        append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
        print("Final error log saved.")

    final_df = pd.read_parquet(checkpoint_path)
    final_df["gml_id"] = final_df["gml_id"].astype(str)

    return final_df

# %%
final_df = classify_resume_parallel_batched(
    pois_df=pois,
    checkpoint_path="predictions_checkpoint.parquet",
    error_path="prediction_errors.parquet",
    save_every=100,
    max_workers=5,
    batch_size=4,
    debug=False,
    max_retries=1,
    retry_wait_sec=3,
)
# Out:
# No checkpoint found. Starting from scratch.
# Remaining rows to process: 578080 / 578080
# Total batches to process: 144520 | batch_size=4 | max_workers=5
# Processed 4/578080 new rows | completed batches 1/144520 | last batch size=4 | gml_id range=17 -> 20
# Processed 8/578080 new rows | completed batches 2/144520 | last batch size=4 | gml_id range=13 -> 16
# Processed 12/578080 new rows | completed batches 3/144520 | last batch size=4 | gml_id range=0 -> 3
# Processed 16/578080 new rows | completed batches 4/144520 | last batch size=4 | gml_id range=9 -> 12
# Processed 20/578080 new rows | completed batches 5/144520 | last batch size=4 | gml_id range=21 -> 24
# Processed 24/578080 new rows | completed batches 6/144520 | last batch size=4 | gml_id range=4 -> 8
# Processed 28/578080 new rows | completed batches 7/144520 | last batch size=4 | gml_id range=25 -> 28
# Processed 32/578080 new rows | completed batches 8/144520 | last batch size=4 | gml_id range=29 -> 32
# Processed 36/578080 new rows | completed batches 9/144520 | last batch size=4 | gml_id range=33 -> 36
# Processed 40/578080 new rows | completed batches 10/144520 | last batch size=4 | gml_id range=37 -> 40
# Processed 44/578080 new rows | completed batches 11/144520 | last batch size=4 | gml_id range=41 -> 44
# Processed 48/578080 new rows | completed batches 12/144520 | last batch size=4 | gml_id range=45 -> 48
# Processed 52/578080 new rows | completed batches 13/144520 | last batch size=4 | gml_id range=49 -> 52
# Processed 56/578080 new rows | completed batches 14/144520 | last batch size=4 | gml_id range=61 -> 64
# Processed 60/578080 new rows | completed batches 15/144520 | last batch size=4 | gml_id range=53 -> 56
# Processed 64/578080 new rows | completed batches 16/144520 | last batch size=4 | gml_id range=65 -> 68
# Processed 68/578080 new rows | completed batches 17/144520 | last batch size=4 | gml_id range=57 -> 60
# Processed 72/578080 new rows | completed batches 18/144520 | last batch size=4 | gml_id range=77 -> 80
# Processed 76/578080 new rows | completed batches 19/144520 | last batch size=4 | gml_id range=69 -> 72
# Processed 80/578080 new rows | completed batches 20/144520 | last batch size=4 | gml_id range=81 -> 84
# Processed 84/578080 new rows | completed batches 21/144520 | last batch size=4 | gml_id range=73 -> 76
# Processed 88/578080 new rows | completed batches 22/144520 | last batch size=4 | gml_id range=94 -> 97
# Processed 92/578080 new rows | completed batches 23/144520 | last batch size=4 | gml_id range=102 -> 105
# Processed 96/578080 new rows | completed batches 24/144520 | last batch size=4 | gml_id range=98 -> 101
# Processed 100/578080 new rows | completed batches 25/144520 | last batch size=4 | gml_id range=85 -> 89
# Checkpoint saved with 100 new rows
# Processed 104/578080 new rows | completed batches 26/144520 | last batch size=4 | gml_id range=90 -> 93
# Processed 108/578080 new rows | completed batches 27/144520 | last batch size=4 | gml_id range=115 -> 118
# Processed 112/578080 new rows | completed batches 28/144520 | last batch size=4 | gml_id range=123 -> 126
# Processed 116/578080 new rows | completed batches 29/144520 | last batch size=4 | gml_id range=106 -> 110
# Processed 120/578080 new rows | completed batches 30/144520 | last batch size=4 | gml_id range=111 -> 114
# Processed 124/578080 new rows | completed batches 31/144520 | last batch size=4 | gml_id range=119 -> 122
# Processed 128/578080 new rows | completed batches 32/144520 | last batch size=4 | gml_id range=127 -> 130
# Processed 132/578080 new rows | completed batches 33/144520 | last batch size=4 | gml_id range=135 -> 139
# Processed 136/578080 new rows | completed batches 34/144520 | last batch size=4 | gml_id range=153 -> 156
# Processed 140/578080 new rows | completed batches 35/144520 | last batch size=4 | gml_id range=131 -> 134
# Processed 144/578080 new rows | completed batches 36/144520 | last batch size=4 | gml_id range=144 -> 147
# Processed 148/578080 new rows | completed batches 37/144520 | last batch size=4 | gml_id range=140 -> 143
# Processed 152/578080 new rows | completed batches 38/144520 | last batch size=4 | gml_id range=149 -> 152
# Processed 156/578080 new rows | completed batches 39/144520 | last batch size=4 | gml_id range=161 -> 164
# Processed 160/578080 new rows | completed batches 40/144520 | last batch size=4 | gml_id range=157 -> 160
# Processed 164/578080 new rows | completed batches 41/144520 | last batch size=4 | gml_id range=165 -> 168
# Processed 168/578080 new rows | completed batches 42/144520 | last batch size=4 | gml_id range=173 -> 176
# Processed 172/578080 new rows | completed batches 43/144520 | last batch size=4 | gml_id range=169 -> 172
# Processed 176/578080 new rows | completed batches 44/144520 | last batch size=4 | gml_id range=181 -> 184
# Processed 180/578080 new rows | completed batches 45/144520 | last batch size=4 | gml_id range=177 -> 180
# Processed 184/578080 new rows | completed batches 46/144520 | last batch size=4 | gml_id range=185 -> 188
# Processed 188/578080 new rows | completed batches 47/144520 | last batch size=4 | gml_id range=189 -> 192
# Processed 192/578080 new rows | completed batches 48/144520 | last batch size=4 | gml_id range=193 -> 196
# Processed 196/578080 new rows | completed batches 49/144520 | last batch size=4 | gml_id range=201 -> 204
# Processed 200/578080 new rows | completed batches 50/144520 | last batch size=4 | gml_id range=197 -> 200
# Checkpoint saved with 100 new rows
# Processed 204/578080 new rows | completed batches 51/144520 | last batch size=4 | gml_id range=213 -> 216
# Processed 208/578080 new rows | completed batches 52/144520 | last batch size=4 | gml_id range=209 -> 212
# Processed 212/578080 new rows | completed batches 53/144520 | last batch size=4 | gml_id range=218 -> 221
# Processed 216/578080 new rows | completed batches 54/144520 | last batch size=4 | gml_id range=205 -> 208
# Processed 220/578080 new rows | completed batches 55/144520 | last batch size=4 | gml_id range=222 -> 225
# Processed 224/578080 new rows | completed batches 56/144520 | last batch size=4 | gml_id range=227 -> 230
# Processed 228/578080 new rows | completed batches 57/144520 | last batch size=4 | gml_id range=235 -> 238
# Processed 232/578080 new rows | completed batches 58/144520 | last batch size=4 | gml_id range=243 -> 246
# Processed 236/578080 new rows | completed batches 59/144520 | last batch size=4 | gml_id range=231 -> 234
# Processed 240/578080 new rows | completed batches 60/144520 | last batch size=4 | gml_id range=247 -> 250
# Processed 244/578080 new rows | completed batches 61/144520 | last batch size=4 | gml_id range=239 -> 242
# Processed 248/578080 new rows | completed batches 62/144520 | last batch size=4 | gml_id range=255 -> 258
# Processed 252/578080 new rows | completed batches 63/144520 | last batch size=4 | gml_id range=251 -> 254
# Processed 256/578080 new rows | completed batches 64/144520 | last batch size=4 | gml_id range=259 -> 262
# Processed 260/578080 new rows | completed batches 65/144520 | last batch size=4 | gml_id range=267 -> 270
# Processed 264/578080 new rows | completed batches 66/144520 | last batch size=4 | gml_id range=263 -> 266
# Processed 268/578080 new rows | completed batches 67/144520 | last batch size=4 | gml_id range=284 -> 287
# Processed 272/578080 new rows | completed batches 68/144520 | last batch size=4 | gml_id range=271 -> 274
# Processed 276/578080 new rows | completed batches 69/144520 | last batch size=4 | gml_id range=279 -> 283
# Processed 280/578080 new rows | completed batches 70/144520 | last batch size=4 | gml_id range=275 -> 278
# Processed 284/578080 new rows | completed batches 71/144520 | last batch size=4 | gml_id range=288 -> 291
# Processed 288/578080 new rows | completed batches 72/144520 | last batch size=4 | gml_id range=296 -> 299
# Processed 292/578080 new rows | completed batches 73/144520 | last batch size=4 | gml_id range=300 -> 303
# Processed 296/578080 new rows | completed batches 74/144520 | last batch size=4 | gml_id range=292 -> 295
# Processed 300/578080 new rows | completed batches 75/144520 | last batch size=4 | gml_id range=313 -> 316
# Checkpoint saved with 100 new rows
# Processed 304/578080 new rows | completed batches 76/144520 | last batch size=4 | gml_id range=309 -> 312
# Processed 308/578080 new rows | completed batches 77/144520 | last batch size=4 | gml_id range=304 -> 308
# Processed 312/578080 new rows | completed batches 78/144520 | last batch size=4 | gml_id range=317 -> 320
# Processed 316/578080 new rows | completed batches 79/144520 | last batch size=4 | gml_id range=329 -> 332
# Processed 320/578080 new rows | completed batches 80/144520 | last batch size=4 | gml_id range=333 -> 336
# Processed 324/578080 new rows | completed batches 81/144520 | last batch size=4 | gml_id range=321 -> 324
# Processed 328/578080 new rows | completed batches 82/144520 | last batch size=4 | gml_id range=325 -> 328
# Processed 332/578080 new rows | completed batches 83/144520 | last batch size=4 | gml_id range=341 -> 344
# Processed 336/578080 new rows | completed batches 84/144520 | last batch size=4 | gml_id range=349 -> 352
# Processed 340/578080 new rows | completed batches 85/144520 | last batch size=4 | gml_id range=337 -> 340
# Processed 344/578080 new rows | completed batches 86/144520 | last batch size=4 | gml_id range=353 -> 356
# Processed 348/578080 new rows | completed batches 87/144520 | last batch size=4 | gml_id range=345 -> 348
# Processed 352/578080 new rows | completed batches 88/144520 | last batch size=4 | gml_id range=357 -> 360
# Processed 356/578080 new rows | completed batches 89/144520 | last batch size=4 | gml_id range=369 -> 372
# Processed 360/578080 new rows | completed batches 90/144520 | last batch size=4 | gml_id range=361 -> 364
# Processed 364/578080 new rows | completed batches 91/144520 | last batch size=4 | gml_id range=365 -> 368
# Processed 368/578080 new rows | completed batches 92/144520 | last batch size=4 | gml_id range=379 -> 382
# Processed 372/578080 new rows | completed batches 93/144520 | last batch size=4 | gml_id range=374 -> 378
# Processed 376/578080 new rows | completed batches 94/144520 | last batch size=4 | gml_id range=387 -> 390
# Processed 380/578080 new rows | completed batches 95/144520 | last batch size=4 | gml_id range=383 -> 386
# Processed 384/578080 new rows | completed batches 96/144520 | last batch size=4 | gml_id range=399 -> 402
# Processed 388/578080 new rows | completed batches 97/144520 | last batch size=4 | gml_id range=403 -> 406
# Processed 392/578080 new rows | completed batches 98/144520 | last batch size=4 | gml_id range=407 -> 410
# Processed 396/578080 new rows | completed batches 99/144520 | last batch size=4 | gml_id range=395 -> 398
# Processed 400/578080 new rows | completed batches 100/144520 | last batch size=4 | gml_id range=391 -> 394
# Checkpoint saved with 100 new rows
# Processed 404/578080 new rows | completed batches 101/144520 | last batch size=4 | gml_id range=412 -> 415
# Processed 408/578080 new rows | completed batches 102/144520 | last batch size=4 | gml_id range=428 -> 431
# Processed 412/578080 new rows | completed batches 103/144520 | last batch size=4 | gml_id range=420 -> 423
# Processed 416/578080 new rows | completed batches 104/144520 | last batch size=4 | gml_id range=416 -> 419
# Processed 420/578080 new rows | completed batches 105/144520 | last batch size=4 | gml_id range=424 -> 427
# Processed 424/578080 new rows | completed batches 106/144520 | last batch size=4 | gml_id range=432 -> 435
# Processed 428/578080 new rows | completed batches 107/144520 | last batch size=4 | gml_id range=440 -> 444
# Processed 432/578080 new rows | completed batches 108/144520 | last batch size=4 | gml_id range=454 -> 458
# Processed 436/578080 new rows | completed batches 109/144520 | last batch size=4 | gml_id range=450 -> 453
# Processed 440/578080 new rows | completed batches 110/144520 | last batch size=4 | gml_id range=445 -> 449
# Processed 444/578080 new rows | completed batches 111/144520 | last batch size=4 | gml_id range=436 -> 439
# Processed 448/578080 new rows | completed batches 112/144520 | last batch size=4 | gml_id range=459 -> 463
# Processed 452/578080 new rows | completed batches 113/144520 | last batch size=4 | gml_id range=464 -> 468
# Processed 456/578080 new rows | completed batches 114/144520 | last batch size=4 | gml_id range=473 -> 476
# Processed 460/578080 new rows | completed batches 115/144520 | last batch size=4 | gml_id range=469 -> 472
# Processed 464/578080 new rows | completed batches 116/144520 | last batch size=4 | gml_id range=485 -> 488
# Processed 468/578080 new rows | completed batches 117/144520 | last batch size=4 | gml_id range=477 -> 480
# Processed 472/578080 new rows | completed batches 118/144520 | last batch size=4 | gml_id range=481 -> 484
# Processed 476/578080 new rows | completed batches 119/144520 | last batch size=4 | gml_id range=493 -> 496
# Processed 480/578080 new rows | completed batches 120/144520 | last batch size=4 | gml_id range=497 -> 500
# Processed 484/578080 new rows | completed batches 121/144520 | last batch size=4 | gml_id range=489 -> 492
# Processed 488/578080 new rows | completed batches 122/144520 | last batch size=4 | gml_id range=501 -> 504
# Processed 492/578080 new rows | completed batches 123/144520 | last batch size=4 | gml_id range=505 -> 508
# Processed 496/578080 new rows | completed batches 124/144520 | last batch size=4 | gml_id range=517 -> 520
# Processed 500/578080 new rows | completed batches 125/144520 | last batch size=4 | gml_id range=509 -> 512
# Checkpoint saved with 100 new rows
# Processed 504/578080 new rows | completed batches 126/144520 | last batch size=4 | gml_id range=521 -> 524
# Processed 508/578080 new rows | completed batches 127/144520 | last batch size=4 | gml_id range=513 -> 516
# Processed 512/578080 new rows | completed batches 128/144520 | last batch size=4 | gml_id range=525 -> 528
# Processed 516/578080 new rows | completed batches 129/144520 | last batch size=4 | gml_id range=534 -> 537
# Processed 520/578080 new rows | completed batches 130/144520 | last batch size=4 | gml_id range=530 -> 533
# Processed 524/578080 new rows | completed batches 131/144520 | last batch size=4 | gml_id range=542 -> 545
# Processed 528/578080 new rows | completed batches 132/144520 | last batch size=4 | gml_id range=538 -> 541
# Processed 532/578080 new rows | completed batches 133/144520 | last batch size=4 | gml_id range=546 -> 549
# Processed 536/578080 new rows | completed batches 134/144520 | last batch size=4 | gml_id range=550 -> 553
# Processed 540/578080 new rows | completed batches 135/144520 | last batch size=4 | gml_id range=554 -> 557
# Processed 544/578080 new rows | completed batches 136/144520 | last batch size=4 | gml_id range=558 -> 561
# Processed 548/578080 new rows | completed batches 137/144520 | last batch size=4 | gml_id range=562 -> 565
# Processed 552/578080 new rows | completed batches 138/144520 | last batch size=4 | gml_id range=566 -> 569
# Processed 556/578080 new rows | completed batches 139/144520 | last batch size=4 | gml_id range=578 -> 581
# Processed 560/578080 new rows | completed batches 140/144520 | last batch size=4 | gml_id range=570 -> 573
# Processed 564/578080 new rows | completed batches 141/144520 | last batch size=4 | gml_id range=574 -> 577
# Processed 568/578080 new rows | completed batches 142/144520 | last batch size=4 | gml_id range=582 -> 586
# Processed 572/578080 new rows | completed batches 143/144520 | last batch size=4 | gml_id range=587 -> 591
# Processed 576/578080 new rows | completed batches 144/144520 | last batch size=4 | gml_id range=596 -> 599
# Processed 580/578080 new rows | completed batches 145/144520 | last batch size=4 | gml_id range=592 -> 595
# Processed 584/578080 new rows | completed batches 146/144520 | last batch size=4 | gml_id range=604 -> 607
# Processed 588/578080 new rows | completed batches 147/144520 | last batch size=4 | gml_id range=600 -> 603
# Processed 592/578080 new rows | completed batches 148/144520 | last batch size=4 | gml_id range=608 -> 611
# Processed 596/578080 new rows | completed batches 149/144520 | last batch size=4 | gml_id range=612 -> 615
# Processed 600/578080 new rows | completed batches 150/144520 | last batch size=4 | gml_id range=616 -> 619
# Checkpoint saved with 100 new rows
# Processed 604/578080 new rows | completed batches 151/144520 | last batch size=4 | gml_id range=620 -> 623
# Processed 608/578080 new rows | completed batches 152/144520 | last batch size=4 | gml_id range=628 -> 631
# Processed 612/578080 new rows | completed batches 153/144520 | last batch size=4 | gml_id range=624 -> 627
# Processed 616/578080 new rows | completed batches 154/144520 | last batch size=4 | gml_id range=636 -> 639
# Processed 620/578080 new rows | completed batches 155/144520 | last batch size=4 | gml_id range=640 -> 646
# Processed 624/578080 new rows | completed batches 156/144520 | last batch size=4 | gml_id range=632 -> 635
# Processed 628/578080 new rows | completed batches 157/144520 | last batch size=4 | gml_id range=647 -> 651
# Processed 632/578080 new rows | completed batches 158/144520 | last batch size=4 | gml_id range=652 -> 655
# Processed 636/578080 new rows | completed batches 159/144520 | last batch size=4 | gml_id range=660 -> 663
# Processed 640/578080 new rows | completed batches 160/144520 | last batch size=4 | gml_id range=656 -> 659
# Processed 644/578080 new rows | completed batches 161/144520 | last batch size=4 | gml_id range=672 -> 675
# Processed 648/578080 new rows | completed batches 162/144520 | last batch size=4 | gml_id range=664 -> 667
# Processed 652/578080 new rows | completed batches 163/144520 | last batch size=4 | gml_id range=668 -> 671
# Processed 656/578080 new rows | completed batches 164/144520 | last batch size=4 | gml_id range=676 -> 679
# Processed 660/578080 new rows | completed batches 165/144520 | last batch size=4 | gml_id range=680 -> 683
# Processed 664/578080 new rows | completed batches 166/144520 | last batch size=4 | gml_id range=688 -> 692
# Processed 668/578080 new rows | completed batches 167/144520 | last batch size=4 | gml_id range=697 -> 700
# Processed 672/578080 new rows | completed batches 168/144520 | last batch size=4 | gml_id range=693 -> 696
# Processed 676/578080 new rows | completed batches 169/144520 | last batch size=4 | gml_id range=684 -> 687
# Processed 680/578080 new rows | completed batches 170/144520 | last batch size=4 | gml_id range=701 -> 704
# Processed 684/578080 new rows | completed batches 171/144520 | last batch size=4 | gml_id range=709 -> 712
# Processed 688/578080 new rows | completed batches 172/144520 | last batch size=4 | gml_id range=717 -> 721
# Processed 692/578080 new rows | completed batches 173/144520 | last batch size=4 | gml_id range=705 -> 708
# Processed 696/578080 new rows | completed batches 174/144520 | last batch size=4 | gml_id range=713 -> 716
# Processed 700/578080 new rows | completed batches 175/144520 | last batch size=4 | gml_id range=726 -> 729
# Checkpoint saved with 100 new rows
# Processed 704/578080 new rows | completed batches 176/144520 | last batch size=4 | gml_id range=722 -> 725
# Processed 708/578080 new rows | completed batches 177/144520 | last batch size=4 | gml_id range=734 -> 737
# Processed 712/578080 new rows | completed batches 178/144520 | last batch size=4 | gml_id range=738 -> 741
# Processed 716/578080 new rows | completed batches 179/144520 | last batch size=4 | gml_id range=730 -> 733
# Processed 720/578080 new rows | completed batches 180/144520 | last batch size=4 | gml_id range=742 -> 746
# Processed 724/578080 new rows | completed batches 181/144520 | last batch size=4 | gml_id range=751 -> 755
# Processed 728/578080 new rows | completed batches 182/144520 | last batch size=4 | gml_id range=747 -> 750
# Processed 732/578080 new rows | completed batches 183/144520 | last batch size=4 | gml_id range=756 -> 759
# Processed 736/578080 new rows | completed batches 184/144520 | last batch size=4 | gml_id range=768 -> 771
# Processed 740/578080 new rows | completed batches 185/144520 | last batch size=4 | gml_id range=782 -> 786
# Processed 744/578080 new rows | completed batches 186/144520 | last batch size=4 | gml_id range=764 -> 767
# Processed 748/578080 new rows | completed batches 187/144520 | last batch size=4 | gml_id range=777 -> 781
# Processed 752/578080 new rows | completed batches 188/144520 | last batch size=4 | gml_id range=773 -> 776
# Processed 756/578080 new rows | completed batches 189/144520 | last batch size=4 | gml_id range=760 -> 763
# Processed 760/578080 new rows | completed batches 190/144520 | last batch size=4 | gml_id range=791 -> 794
# Processed 764/578080 new rows | completed batches 191/144520 | last batch size=4 | gml_id range=795 -> 798
# Processed 768/578080 new rows | completed batches 192/144520 | last batch size=4 | gml_id range=787 -> 790
# Processed 772/578080 new rows | completed batches 193/144520 | last batch size=4 | gml_id range=799 -> 802
# Processed 776/578080 new rows | completed batches 194/144520 | last batch size=4 | gml_id range=803 -> 806
# Processed 780/578080 new rows | completed batches 195/144520 | last batch size=4 | gml_id range=807 -> 810
# Processed 784/578080 new rows | completed batches 196/144520 | last batch size=4 | gml_id range=824 -> 827
# Processed 788/578080 new rows | completed batches 197/144520 | last batch size=4 | gml_id range=811 -> 814
# Processed 792/578080 new rows | completed batches 198/144520 | last batch size=4 | gml_id range=819 -> 823
# Processed 796/578080 new rows | completed batches 199/144520 | last batch size=4 | gml_id range=828 -> 831
# Processed 800/578080 new rows | completed batches 200/144520 | last batch size=4 | gml_id range=815 -> 818
# Checkpoint saved with 100 new rows
# Processed 804/578080 new rows | completed batches 201/144520 | last batch size=4 | gml_id range=832 -> 835
# Processed 808/578080 new rows | completed batches 202/144520 | last batch size=4 | gml_id range=840 -> 843
# Processed 812/578080 new rows | completed batches 203/144520 | last batch size=4 | gml_id range=836 -> 839
# Processed 816/578080 new rows | completed batches 204/144520 | last batch size=4 | gml_id range=848 -> 852
# Processed 820/578080 new rows | completed batches 205/144520 | last batch size=4 | gml_id range=844 -> 847
# Processed 824/578080 new rows | completed batches 206/144520 | last batch size=4 | gml_id range=853 -> 856
# Processed 828/578080 new rows | completed batches 207/144520 | last batch size=4 | gml_id range=857 -> 860
# Processed 832/578080 new rows | completed batches 208/144520 | last batch size=4 | gml_id range=861 -> 864
# Processed 836/578080 new rows | completed batches 209/144520 | last batch size=4 | gml_id range=869 -> 872
# Processed 840/578080 new rows | completed batches 210/144520 | last batch size=4 | gml_id range=865 -> 868
# Processed 844/578080 new rows | completed batches 211/144520 | last batch size=4 | gml_id range=873 -> 876
# Processed 848/578080 new rows | completed batches 212/144520 | last batch size=4 | gml_id range=877 -> 880
# Processed 852/578080 new rows | completed batches 213/144520 | last batch size=4 | gml_id range=889 -> 892
# Processed 856/578080 new rows | completed batches 214/144520 | last batch size=4 | gml_id range=881 -> 884
# Processed 860/578080 new rows | completed batches 215/144520 | last batch size=4 | gml_id range=885 -> 888
# Processed 864/578080 new rows | completed batches 216/144520 | last batch size=4 | gml_id range=899 -> 902
# Processed 868/578080 new rows | completed batches 217/144520 | last batch size=4 | gml_id range=893 -> 896
# Processed 872/578080 new rows | completed batches 218/144520 | last batch size=4 | gml_id range=903 -> 906
# Processed 876/578080 new rows | completed batches 219/144520 | last batch size=4 | gml_id range=907 -> 911
# Processed 880/578080 new rows | completed batches 220/144520 | last batch size=4 | gml_id range=912 -> 915
# Processed 884/578080 new rows | completed batches 221/144520 | last batch size=4 | gml_id range=928 -> 931
# Processed 888/578080 new rows | completed batches 222/144520 | last batch size=4 | gml_id range=920 -> 923
# Processed 892/578080 new rows | completed batches 223/144520 | last batch size=4 | gml_id range=924 -> 927
# Processed 896/578080 new rows | completed batches 224/144520 | last batch size=4 | gml_id range=916 -> 919
# Processed 900/578080 new rows | completed batches 225/144520 | last batch size=4 | gml_id range=932 -> 935
# Checkpoint saved with 100 new rows
# Processed 904/578080 new rows | completed batches 226/144520 | last batch size=4 | gml_id range=944 -> 947
# Processed 908/578080 new rows | completed batches 227/144520 | last batch size=4 | gml_id range=940 -> 943
# Processed 912/578080 new rows | completed batches 228/144520 | last batch size=4 | gml_id range=948 -> 951
# Processed 916/578080 new rows | completed batches 229/144520 | last batch size=4 | gml_id range=936 -> 939
# Processed 920/578080 new rows | completed batches 230/144520 | last batch size=4 | gml_id range=958 -> 961
# Processed 924/578080 new rows | completed batches 231/144520 | last batch size=4 | gml_id range=962 -> 966
# Processed 928/578080 new rows | completed batches 232/144520 | last batch size=4 | gml_id range=967 -> 970
# Processed 932/578080 new rows | completed batches 233/144520 | last batch size=4 | gml_id range=953 -> 956
# Processed 936/578080 new rows | completed batches 234/144520 | last batch size=4 | gml_id range=979 -> 982
# Processed 940/578080 new rows | completed batches 235/144520 | last batch size=4 | gml_id range=983 -> 986
# Processed 944/578080 new rows | completed batches 236/144520 | last batch size=4 | gml_id range=971 -> 974
# Processed 948/578080 new rows | completed batches 237/144520 | last batch size=4 | gml_id range=975 -> 978
# Processed 952/578080 new rows | completed batches 238/144520 | last batch size=4 | gml_id range=992 -> 995
# Processed 956/578080 new rows | completed batches 239/144520 | last batch size=4 | gml_id range=1001 -> 1004
# Processed 960/578080 new rows | completed batches 240/144520 | last batch size=4 | gml_id range=987 -> 991
# Processed 964/578080 new rows | completed batches 241/144520 | last batch size=4 | gml_id range=1005 -> 1008
# Processed 968/578080 new rows | completed batches 242/144520 | last batch size=4 | gml_id range=996 -> 1000
# Processed 972/578080 new rows | completed batches 243/144520 | last batch size=4 | gml_id range=1009 -> 1014
# Processed 976/578080 new rows | completed batches 244/144520 | last batch size=4 | gml_id range=1015 -> 1019
# Processed 980/578080 new rows | completed batches 245/144520 | last batch size=4 | gml_id range=1020 -> 1023
# Processed 984/578080 new rows | completed batches 246/144520 | last batch size=4 | gml_id range=1024 -> 1027
# Processed 988/578080 new rows | completed batches 247/144520 | last batch size=4 | gml_id range=1028 -> 1031
# Processed 992/578080 new rows | completed batches 248/144520 | last batch size=4 | gml_id range=1032 -> 1035
# Processed 996/578080 new rows | completed batches 249/144520 | last batch size=4 | gml_id range=1036 -> 1039
# Processed 1000/578080 new rows | completed batches 250/144520 | last batch size=4 | gml_id range=1044 -> 1048
# Checkpoint saved with 100 new rows
# Processed 1004/578080 new rows | completed batches 251/144520 | last batch size=4 | gml_id range=1049 -> 1054
# Processed 1008/578080 new rows | completed batches 252/144520 | last batch size=4 | gml_id range=1055 -> 1059
# Processed 1012/578080 new rows | completed batches 253/144520 | last batch size=4 | gml_id range=1040 -> 1043
# Processed 1016/578080 new rows | completed batches 254/144520 | last batch size=4 | gml_id range=1068 -> 1071
# Processed 1020/578080 new rows | completed batches 255/144520 | last batch size=4 | gml_id range=1060 -> 1063
# Processed 1024/578080 new rows | completed batches 256/144520 | last batch size=4 | gml_id range=1072 -> 1075
# Processed 1028/578080 new rows | completed batches 257/144520 | last batch size=4 | gml_id range=1064 -> 1067
# Processed 1032/578080 new rows | completed batches 258/144520 | last batch size=4 | gml_id range=1076 -> 1080
# Processed 1036/578080 new rows | completed batches 259/144520 | last batch size=4 | gml_id range=1081 -> 1084
# Processed 1040/578080 new rows | completed batches 260/144520 | last batch size=4 | gml_id range=1085 -> 1088
# Processed 1044/578080 new rows | completed batches 261/144520 | last batch size=4 | gml_id range=1089 -> 1092
# Processed 1048/578080 new rows | completed batches 262/144520 | last batch size=4 | gml_id range=1105 -> 1108
# Processed 1052/578080 new rows | completed batches 263/144520 | last batch size=4 | gml_id range=1097 -> 1100
# Processed 1056/578080 new rows | completed batches 264/144520 | last batch size=4 | gml_id range=1093 -> 1096
# Processed 1060/578080 new rows | completed batches 265/144520 | last batch size=4 | gml_id range=1101 -> 1104
# Processed 1064/578080 new rows | completed batches 266/144520 | last batch size=4 | gml_id range=1113 -> 1116
# Processed 1068/578080 new rows | completed batches 267/144520 | last batch size=4 | gml_id range=1109 -> 1112
# Processed 1072/578080 new rows | completed batches 268/144520 | last batch size=4 | gml_id range=1122 -> 1125
# Processed 1076/578080 new rows | completed batches 269/144520 | last batch size=4 | gml_id range=1117 -> 1121
# Processed 1080/578080 new rows | completed batches 270/144520 | last batch size=4 | gml_id range=1130 -> 1133
# Processed 1084/578080 new rows | completed batches 271/144520 | last batch size=4 | gml_id range=1126 -> 1129
# Processed 1088/578080 new rows | completed batches 272/144520 | last batch size=4 | gml_id range=1134 -> 1137
# Processed 1092/578080 new rows | completed batches 273/144520 | last batch size=4 | gml_id range=1138 -> 1143
# Processed 1096/578080 new rows | completed batches 274/144520 | last batch size=4 | gml_id range=1148 -> 1151
# Processed 1100/578080 new rows | completed batches 275/144520 | last batch size=4 | gml_id range=1156 -> 1160
# Checkpoint saved with 100 new rows
# Processed 1104/578080 new rows | completed batches 276/144520 | last batch size=4 | gml_id range=1144 -> 1147
# Processed 1108/578080 new rows | completed batches 277/144520 | last batch size=4 | gml_id range=1152 -> 1155
# Processed 1112/578080 new rows | completed batches 278/144520 | last batch size=4 | gml_id range=1161 -> 1164
# Processed 1116/578080 new rows | completed batches 279/144520 | last batch size=4 | gml_id range=1165 -> 1168
# Processed 1120/578080 new rows | completed batches 280/144520 | last batch size=4 | gml_id range=1169 -> 1172
# Processed 1124/578080 new rows | completed batches 281/144520 | last batch size=4 | gml_id range=1173 -> 1176
# Processed 1128/578080 new rows | completed batches 282/144520 | last batch size=4 | gml_id range=1177 -> 1180
# Processed 1132/578080 new rows | completed batches 283/144520 | last batch size=4 | gml_id range=1181 -> 1184
# Processed 1136/578080 new rows | completed batches 284/144520 | last batch size=4 | gml_id range=1189 -> 1192
# Processed 1140/578080 new rows | completed batches 285/144520 | last batch size=4 | gml_id range=1185 -> 1188
# Processed 1144/578080 new rows | completed batches 286/144520 | last batch size=4 | gml_id range=1202 -> 1205
# Processed 1148/578080 new rows | completed batches 287/144520 | last batch size=4 | gml_id range=1194 -> 1197
# Processed 1152/578080 new rows | completed batches 288/144520 | last batch size=4 | gml_id range=1210 -> 1213
# Processed 1156/578080 new rows | completed batches 289/144520 | last batch size=4 | gml_id range=1206 -> 1209
# Processed 1160/578080 new rows | completed batches 290/144520 | last batch size=4 | gml_id range=1198 -> 1201
# Processed 1164/578080 new rows | completed batches 291/144520 | last batch size=4 | gml_id range=1227 -> 1230
# Processed 1168/578080 new rows | completed batches 292/144520 | last batch size=4 | gml_id range=1219 -> 1222
# Processed 1172/578080 new rows | completed batches 293/144520 | last batch size=4 | gml_id range=1214 -> 1218
# Processed 1176/578080 new rows | completed batches 294/144520 | last batch size=4 | gml_id range=1223 -> 1226
# Processed 1180/578080 new rows | completed batches 295/144520 | last batch size=4 | gml_id range=1231 -> 1235
# Processed 1184/578080 new rows | completed batches 296/144520 | last batch size=4 | gml_id range=1236 -> 1239
# Processed 1188/578080 new rows | completed batches 297/144520 | last batch size=4 | gml_id range=1240 -> 1243
