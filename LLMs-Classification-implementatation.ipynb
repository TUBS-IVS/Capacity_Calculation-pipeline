# %%
import geopandas as gpd

pois = r"condensed_buildings_with_pois.gpkg"

# Load the POI layer
pois = gpd.read_file(pois)

print(f"Loaded {len(pois)} POIs")
# Out:
# Loaded 601174 POIs

# %%
pois.head()
# Out:
#    gml_id    volume_m3                            label_en osm_building_type  \
# 0       0   931.423451  Buildings for business or commerce              None
# 1       1  1275.527533  Buildings for business or commerce              None
# 2       2   229.902499  Buildings for business or commerce              None
# 3       3    84.748005  Buildings for business or commerce              None
# 4       4   351.716079  Buildings for business or commerce              None
#
#   osm_landuse_class osm_landuse_name gfk_class ALKIS_Landuse_info osm_names  \
# 0       residential             None   Gebäude         commercial      None
# 1       residential             None   Gebäude         commercial      None
# 2       residential             None   Gebäude          residence      None
# 3       residential             None   Gebäude          residence      None
# 4       residential             None   Gebäude          residence      None
#
#                         alkis_address email amenity building  shop tourism  \
# 0      Ackerweg 2 Braunschweig, Stadt  None    None     None  None    None
# 1  Stieglitzweg 3 Braunschweig, Stadt  None    None     None  None    None
# 2                 Braunschweig, Stadt  None    None     None  None    None
# 3                 Braunschweig, Stadt  None    None     None  None    None
# 4                 Braunschweig, Stadt  None    None     None  None    None
#
#   information tags_search additional_information website  \
# 0        None        None                   None    None
# 1        None        None                   None    None
# 2        None        None                   None    None
# 3        None        None                   None    None
# 4        None        None                   None    None
#
#                                             geometry
# 0  MULTIPOLYGON Z (((609554.181 5797264.172 78.94...
# 1  MULTIPOLYGON Z (((608098.849 5796746.146 83.91...
# 2  MULTIPOLYGON Z (((608926.355 5797165.768 84.6,...
# 3  MULTIPOLYGON Z (((609588.957 5797487.563 77.14...
# 4  MULTIPOLYGON Z (((608902.529 5796965.286 84.84...

# %%
pois.columns
# Out:
# Index(['gml_id', 'volume_m3', 'label_en', 'osm_building_type',
#        'osm_landuse_class', 'osm_landuse_name', 'gfk_class',
#        'ALKIS_Landuse_info', 'osm_names', 'alkis_address', 'email', 'amenity',
#        'building', 'shop', 'tourism', 'information', 'tags_search',
#        'additional_information', 'website', 'geometry'],
#       dtype='object')

# %%
# pois = pois[pois['osm_landuse_class'] == 'allotments']
# pois.head()

# %%
import pandas as pd

def is_missing(x) -> bool:
    if x is None:
        return True
    if isinstance(x, float) and pd.isna(x):
        return True
    if isinstance(x, str) and x.strip() == "":
        return True
    if isinstance(x, (list, tuple, set, dict)) and len(x) == 0:
        return True
    return False


def format_value(x):
    if is_missing(x):
        return None

    if isinstance(x, (list, tuple, set)):
        vals = [str(v).strip() for v in x if not is_missing(v)]
        vals = [v for v in vals if v != ""]
        return "; ".join(vals) if vals else None

    if isinstance(x, dict):
        vals = []
        for k, v in x.items():
            if not is_missing(v):
                vals.append(f"{k}: {v}")
        return "; ".join(vals) if vals else None

    return str(x).strip()


def row_to_sentence(row) -> str:
    parts = []
    parts.append("This row describes one building.")

    # Name / identity
    identity_bits = []
    if format_value(row.get("osm_names")):
        identity_bits.append(f"Known OSM name(s): {format_value(row.get('osm_names'))}")
    if format_value(row.get("label_en")):
        identity_bits.append(f"Building label: {format_value(row.get('label_en'))}")
    if format_value(row.get("gfk_class")):
        identity_bits.append(f"GFK class: {format_value(row.get('gfk_class'))}")

    if identity_bits:
        parts.append("Building identity: " + ". ".join(identity_bits) + ".")

    # Address
    if format_value(row.get("alkis_address")):
        parts.append(f"Address from ALKIS: {format_value(row.get('alkis_address'))}.")

    # OSM typed attributes
    osm_attr_bits = []
    for col, label in [
        ("amenity", "amenity"),
        ("building", "building"),
        ("shop", "shop"),
        ("tourism", "tourism"),
        ("information", "information"),
        ("osm_building_type", "OSM building type"),
        ("osm_landuse_class", "OSM land-use class"),
        ("osm_landuse_name", "OSM land-use name"),
    ]:
        val = format_value(row.get(col))
        if val:
            osm_attr_bits.append(f"{label}: {val}")

    if osm_attr_bits:
        parts.append("OSM-derived attributes: " + "; ".join(osm_attr_bits) + ".")

    # Other official / building-purpose clues
    official_bits = []
    if format_value(row.get("ALKIS_Landuse_info")):
        official_bits.append(f"ALKIS land-use information: {format_value(row.get('ALKIS_Landuse_info'))}")

    if official_bits:
        parts.append("Official land-use clues: " + "; ".join(official_bits) + ".")

    # Contact / online presence
    contact_bits = []
    if format_value(row.get("email")):
        contact_bits.append(f"email: {format_value(row.get('email'))}")
    if format_value(row.get("website")):
        contact_bits.append(f"website: {format_value(row.get('website'))}")

    if contact_bits:
        parts.append("Contact or web clues: " + "; ".join(contact_bits) + ".")

    # Free text
    if format_value(row.get("additional_information")):
        parts.append(f"Additional descriptive information: {format_value(row.get('additional_information'))}.")
    if format_value(row.get("tags_search")):
        parts.append(f"Search tags or keywords: {format_value(row.get('tags_search'))}.")

    # Geometry / size clue
    if not is_missing(row.get("volume_m3")):
        parts.append(f"Estimated building volume: {row.get('volume_m3')} cubic meters.")

    return " ".join(parts).strip()


pois["sentence"] = pois.apply(row_to_sentence, axis=1)

# %%
pois.head()
# Out:
#    gml_id    volume_m3                            label_en osm_building_type  \
# 0       0   931.423451  Buildings for business or commerce              None
# 1       1  1275.527533  Buildings for business or commerce              None
# 2       2   229.902499  Buildings for business or commerce              None
# 3       3    84.748005  Buildings for business or commerce              None
# 4       4   351.716079  Buildings for business or commerce              None
#
#   osm_landuse_class osm_landuse_name gfk_class ALKIS_Landuse_info osm_names  \
# 0       residential             None   Gebäude         commercial      None
# 1       residential             None   Gebäude         commercial      None
# 2       residential             None   Gebäude          residence      None
# 3       residential             None   Gebäude          residence      None
# 4       residential             None   Gebäude          residence      None
#
#                         alkis_address  ... amenity building  shop tourism  \
# 0      Ackerweg 2 Braunschweig, Stadt  ...    None     None  None    None
# 1  Stieglitzweg 3 Braunschweig, Stadt  ...    None     None  None    None
# 2                 Braunschweig, Stadt  ...    None     None  None    None
# 3                 Braunschweig, Stadt  ...    None     None  None    None
# 4                 Braunschweig, Stadt  ...    None     None  None    None
#
#   information tags_search additional_information website  \
# 0        None        None                   None    None
# 1        None        None                   None    None
# 2        None        None                   None    None
# 3        None        None                   None    None
# 4        None        None                   None    None
#
#                                             geometry  \
# 0  MULTIPOLYGON Z (((609554.181 5797264.172 78.94...
# 1  MULTIPOLYGON Z (((608098.849 5796746.146 83.91...
# 2  MULTIPOLYGON Z (((608926.355 5797165.768 84.6,...
# 3  MULTIPOLYGON Z (((609588.957 5797487.563 77.14...
# 4  MULTIPOLYGON Z (((608902.529 5796965.286 84.84...
#
#                                             sentence
# 0  This row describes one building. Building iden...
# 1  This row describes one building. Building iden...
# 2  This row describes one building. Building iden...
# 3  This row describes one building. Building iden...
# 4  This row describes one building. Building iden...
#
# [5 rows x 21 columns]

# %%
import json
import time
import re
import requests
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

ENV_PATH = Path(".env")
load_dotenv(dotenv_path=ENV_PATH)

TU_TOKEN = os.getenv("TU_KI_TOOLBOX_TOKEN")

if not TU_TOKEN:
    raise RuntimeError(
        "Missing TU_KI_TOOLBOX_TOKEN."
        "Check Areas-of-interest-POIs/.env"
    )

API_URL = "https://ki-toolbox.tu-braunschweig.de/api/v1/chat/send"
# MODEL = "gpt-5.4-2026-03-05" # chatgpt-5.2
MODEL = "gpt-oss-120b" # open source chatgpt-oss-120b

# %%
SYSTEM_PROMPT = """

Reasoning: high

You are a building activity interpreter and classifier.

Your job is to infer what a place most likely is from a text snippet
and classify it in TWO WAYS:
1) Activity labels (visitor intent / building use based on the label set)
2) A Bosserhof-based building-use class for capacity / volume estimation

IMPORTANT SCOPE RESTRICTION (CRITICAL)
This task is about CLASSIFYING BUILDINGS OR BUILDING-LIKE PLACES ONLY.

- If the described place is NOT a building or not a place people enter/use as a destination,
  you MUST return:
    - "mid_labels": []
    - "bosserhof_class": null
- Do NOT assign any class to pure outdoor objects, infrastructure, or non-living POIs.

INPUT
You will receive ONE text describing a place. It may contain:
- Name, address, city
- OSM tags: amenity=*, shop=*, office=*, leisure=*, tourism=*, building=*, landuse=*
- Free-form keywords (German/English): “Gymnasium”, “Kita”, “Praxis”, “Rathaus”, “Universität”, etc.

────────────────────────────────────
PART A — ACTIVITY LABELS (VISITOR INTENT)
────────────────────────────────────

ALLOWED ACTIVITY LABELS
- work
- university
- school
- childcare
- retail_daily
- retail_non_daily
- leisure
- sports
- errands
- meetup
- lessons
- business

CORE PRINCIPLE
Classify by VISITOR INTENT to a BUILDING:
What do people primarily go there FOR?

MULTI-LABEL RULE (CRITICAL)
A building may support MULTIPLE activities.
Assign ALL labels that clearly apply to the building’s typical use.
Do not force labels that are only weakly implied.

────────────────────────────────────
LABEL DEFINITIONS
────────────────────────────────────

- work

Represents on-site labor, operational activity, or institutional functioning carried out by people inside the building.
Assign this label whenever the building’s normal use depends on people being physically present
to carry out tasks, responsibilities, operations, supervision, coordination, production,
maintenance, administration, instruction, care, or service provision.
The focus of this label is not why visitors come, but whether the building functions as a place
where human work is performed as part of its regular purpose.
A building should receive "work" whenever people are not merely present incidentally,
but are there in an active functional role that helps the building fulfill its purpose.
This includes cases where the same building also serves customers, students, patients, clients,
guests, or other visitors. In such cases, "work" must be added in parallel with the visitor-oriented label(s),
because the activity of workers is part of the building’s core function.
Do not require explicit evidence of employment words or job titles.
Infer "work" from the meaning of the building, the type of activity taking place there,
and the fact that its function normally depends on people performing organized tasks on-site.
Do NOT assign "work" when human presence is only private, incidental, passive, or non-functional,
such as merely being at home, visiting socially, resting, or informally occupying the space
without contributing to the building’s operation or organized purpose.
Core idea: "People are here not only to use the building, but also to make it function."

- university

Represents tertiary/higher-level education activity.
Covers structured learning, teaching, and research at the higher education level
Involves academic instruction, research, and study environments
Distinct from general learning by its institutional and advanced nature
Core idea: “Advanced academic education and research happen here.”

- school

Represents formal compulsory or pre-tertiary education activity.
Covers structured education for children and adolescents
Includes general and vocational schooling
Defined by curriculum-based learning under institutional supervision
Core idea: “Children or teenagers receive structured education here.”

- childcare

Represents supervision and early development care for young children.
Focuses on care, supervision, and early-stage development
Not primarily academic or curriculum-driven (unlike school)
Strong emphasis on custodial and developmental support
Core idea: “Young children are cared for and supervised here.”

- retail_daily

Represents frequent, necessity-driven consumption activity.
Covers acquisition of essential, regularly needed goods
Characterized by high frequency and routine visits
Typically tied to basic living needs
Core idea: “People come here regularly to fulfill essential daily needs.”

- retail_non_daily

Represents infrequent, discretionary consumption activity.
Covers acquisition of non-essential or durable goods
Visits are planned, occasional, or need-based
Often involves comparison, browsing, or larger purchases
Core idea: “People come here occasionally to buy non-essential or long-term goods.”

- leisure

Represents hedonic, relaxation, or enjoyment-oriented activity.
Focuses on free-time use driven by pleasure, comfort, or experience
Includes passive or active enjoyment, but not primarily goal-oriented tasks
Distinguished by non-obligatory participation. People choose to go here for enjoyment, not out of necessity or obligation.
Core idea: “People come here to relax, enjoy, or spend free time.”

- sports

Represents physical activity, exercise, or bodily training.
Focuses on intentional physical exertion or fitness improvement
Can be recreational or structured, but always movement-centered
Distinguished from leisure by physical intensity and purpose
Core idea: “People come here to be physically active or train their body.”

- errands

Represents task-oriented, functional activities needed for daily life management.
Covers practical obligations or maintenance tasks
Typically short, goal-driven visits with a clear outcome
Often involves services, administration, or personal maintenance
Core idea: “People come here to complete necessary tasks or obligations.”

- meetup

Represents social interaction and gathering activity.
Focuses on interpersonal connection and shared presence
Can be informal or organized, but the primary purpose is social exchange
Not necessarily tied to consumption or formal structure
Core idea: “People come here to meet and interact with others.”

- lessons

Represents structured instruction or skill acquisition activity.
Focuses on learning guided by an instructor
Can occur at any level (formal or informal), but always organized and instructional
Distinguished from general education by activity type (learning session), not institution
Core idea: “People come here to learn something through instruction.”

- business

Represents professional or organizational interaction activity (non-routine workplace).
Covers goal-oriented professional interactions, often external-facing
Includes meetings, consulting, administrative dealings, or formal exchanges
Distinct from "work" because it reflects the visitor’s purpose, not employment
Core idea: “People come here for professional or organizational matters.”

IMPORTANT
- Multiple labels are allowed and encouraged when clearly supported
- Prefer precision over over-labeling
- If there is no clear building-related visitor activity, return "mid_labels": []

────────────────────────────────────
PART B — BOSSERHOF BUILDING-USE CLASS
────────────────────────────────────

GOAL
Assign EXACTLY ONE Bosserhof label that matches the categories/subcategories.

This label is for capacity / floor-area / employee-intensity estimation,
so it MUST reflect the dominant FUNCTIONAL USE OF THE BUILDING.

STEP 1 — Subcategory FIRST (preferred)
If you can confidently map the building to ONE of the Bosserhof SUBCATEGORIES listed below,
output that subcategory label (exact string match).

STEP 2 — Headline category fallback (MANDATORY WHEN SUBCATEGORY IS UNCERTAIN)
If the exact subcategory is uncertain but the dominant functional sector is inferable,
you MUST output the corresponding HEADLINE category.
Do not return null when a headline category can reasonably represent the building's dominant use.

STEP 3 — No assignment
If the building does not fit reliably in any headline category OR is not an enterable building,
output bosserhof_class = null.

────────────────────────────────────
ALLOWED BOSSERHOF HEADLINE CATEGORIES AND SUBCATEGORIES
────────────────────────────────────

NEAREST-VALID-CLASS RULE (MANDATORY)

If the building is clearly enterable and supports a recognizable human activity,
you MUST assign the closest Bosserhof class, even if the fit is imperfect.

1) Transport
- no fixed subcategories given; use headline when transport building with staff is clear
Notes: Transport-related buildings with operational staff (depots, terminals)
Exclude: stops/platforms/tracks

2) Yards, depots, storage areas, construction yards
- no fixed subcategories given; use headline when storage/yard with staff is clear
Notes: Storage or operational yards with staff
Exclude: pure storage without staff, open yards without buildings

3) Industrial operations / Production
Subcategories:
- highly productive industries / machine / material or space intensive
- others

4) Crafts and trades
Subcategories:
- craft businesses
- craft courtyards

5) Services
Subcategories:
- normal office
- open-plan office
- business-oriented services
- customer-oriented services
- hotels
- hotels with conference areas
- restaurants / gastronomy
- suppliers for car dealerships
- vehicle / electrical repair
- customer service
- car dealerships

6) Retail
Subcategories:
- wholesale
- retail (small-scale)
- discount stores
- DIY stores
- furniture stores
- hypermarkets / superstores
- shopping centers
- self-service department stores
- department stores
- factory outlet centers

7) Public facilities
Subcategories:
- schools
- universities
- research institutes
- kindergartens
- hospitals
- nursing homes

8) Facilities for culture, leisure and sports
Subcategories:
- entertainment, culture
- large cinemas
- musical theatres
- large discos, fun / leisure pools
- arenas, large events
- theme parks
- fitness / wellness

────────────────────────────────────
OUTPUT FORMAT (STRICT JSON ONLY)
────────────────────────────────────

{
  "interpreted_type": "<plain-English description of what the place most likely is>",
  "mid_labels": ["<zero or more activity labels from the allowed list>"],
  "bosserhof_class": "<one Bosserhof class or null>",
  "reason": "<max 200 words. Explain both classifications, referencing OSM tags, keywords, and any verification used. Explicitly justify the Bosserhof choice or why it is null.>"
}
""".strip()

# %%
# -----------------------------
# MiD labels (STRICT)
# -----------------------------

TARGET_MID_LABELS = {
    "work",
    "university",
    "school",
    "childcare",
    "retail_daily",
    "retail_non_daily",
    "leisure",
    "sports",
    "errands",
    "meetup",
    "lessons",
    "business"
}
# Felix proposed an extended set of MiD labels for more granularity and better coverage of activities. The original MiD labels are a subset of these, so the model can still assign the original ones when appropriate.

#     "work",
#     "university",
#     "school",
#     "childcare",
#     "errands",
#     "retail_non_daily",
#     "retail_daily",
#     "leisure",
# } Lasse proposed classes for Mid Labels!

# -----------------------------
# JSON extraction
# -----------------------------
def extract_first_json_object(text: str) -> dict:
    """
    Extract the first JSON object from model output.
    """
    m = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found in output.")
    return json.loads(m.group(0))


# -----------------------------
# Validation (PROMPT-ALIGNED)
# -----------------------------
def validate(obj: dict):
    # ---- Required keys ----
    if "interpreted_type" not in obj or not isinstance(obj["interpreted_type"], str):
        raise ValueError("Missing or invalid interpreted_type")

    if "mid_labels" not in obj or not isinstance(obj["mid_labels"], list):
        raise ValueError("mid_labels must be a list")

    if "bosserhof_class" not in obj:
        raise ValueError("Missing bosserhof_class")

    if "reason" not in obj or not isinstance(obj["reason"], str):
        raise ValueError("Missing or invalid reason")

    # ---- Validate MiD labels ----
    for lab in obj["mid_labels"]:
        if lab not in TARGET_MID_LABELS:
            raise ValueError(f"Invalid MiD label: {lab}")

    # ---- Validate Bosserhof class ----
    bc = obj["bosserhof_class"]

    # Allowed: no assignment
    if bc is None or bc == []:
        pass

    # Allowed: any non-empty string (granular OR fallback)
    elif isinstance(bc, str) and bc.strip():
        pass

    else:
        raise ValueError("bosserhof_class must be a non-empty string, [] or None")

    # ---- Consistency rule ----
    # If there is no building-related visitor activity,
    # there must not be a Bosserhof assignment
    if len(obj["mid_labels"]) == 0 and bc not in (None, []):
        raise ValueError(
            "bosserhof_class assigned but mid_labels is empty — inconsistent"
        )

# %%
def call_tu_llm(
    user_input: str = None,
    batch_inputs: list = None,
    max_retries=3,
    backoff_sec=2.0,
    debug=False,
) -> str:

    headers = {
        "Authorization": f"Bearer {TU_TOKEN}",
        "Accept": "application/json",
        "Content-Type": "application/json",
    }

    # -----------------------------
    # Build prompt
    # -----------------------------
    if batch_inputs is not None:
        items = []
        for i, row in enumerate(batch_inputs, start=1):
            gml_id = str(row["gml_id"])
            sentence = "" if row.get("sentence") is None else str(row.get("sentence"))
            items.append(
                f"ITEM {i}\n"
                f"gml_id: {gml_id}\n"
                f"sentence: {sentence}"
            )
        prompt_text = "\n\n".join(items)
    else:
        prompt_text = "" if user_input is None else str(user_input)

    payload = {
        "thread": None,
        "prompt": prompt_text,
        "model": MODEL,
        "customInstructions": SYSTEM_PROMPT,
        "hideCustomInstructions": True,
    }

    last_err = None

    for attempt in range(1, max_retries + 1):
        try:
            r = requests.post(
                API_URL,
                headers=headers,
                json=payload,
                stream=True,
                timeout=120,
            )

            if debug:
                print("STATUS:", r.status_code)
                try:
                    print("REQUEST PAYLOAD:", json.dumps(payload, indent=2)[:4000])
                except Exception:
                    pass

            r.raise_for_status()

            full_text = ""

            for line in r.iter_lines(decode_unicode=True):
                if not line:
                    continue
                try:
                    event = json.loads(line)
                except json.JSONDecodeError:
                    continue

                if event.get("type") == "chunk":
                    full_text += event.get("content", "")
                elif event.get("type") == "done":
                    if "response" in event:
                        full_text = event["response"]
                    break

            return full_text

        except Exception as e:
            last_err = e
            if debug:
                print(f"Attempt {attempt} failed: {e}")
            time.sleep(backoff_sec * attempt)

    raise RuntimeError(f"TU LLM call failed: {last_err}")

# %%
def predict_from_sentence(gml_id=None, sentence=None, batch_rows=None, debug=False):
    # -------------------------------------------------
    # BATCH MODE
    # -------------------------------------------------
    if batch_rows is not None:
        try:
            raw = call_tu_llm(batch_inputs=batch_rows, debug=debug)
            objs = extract_first_json_array(raw)

            if not isinstance(objs, list):
                raise ValueError("Batch output is not a list.")

            if len(objs) != len(batch_rows):
                raise ValueError(
                    f"Batch size mismatch: got {len(objs)} outputs for {len(batch_rows)} inputs."
                )

            results = []
            for row, obj in zip(batch_rows, objs):
                row_gml_id = row["gml_id"]

                try:
                    validate(obj)
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": obj["interpreted_type"],
                        "mid_labels": obj["mid_labels"],
                        "bosserhof_class": obj["bosserhof_class"],
                    })
                except Exception:
                    results.append({
                        "gml_id": row_gml_id,
                        "interpreted_type": "error",
                        "mid_labels": [],
                        "bosserhof_class": None,
                    })

            return results

        except Exception:
            return [
                {
                    "gml_id": row["gml_id"],
                    "interpreted_type": "error",
                    "mid_labels": [],
                    "bosserhof_class": None,
                }
                for row in batch_rows
            ]

    # -------------------------------------------------
    # SINGLE MODE
    # -------------------------------------------------
    gml_id = gml_id.item() if hasattr(gml_id, "item") else gml_id
    sentence = "" if sentence is None else str(sentence)

    try:
        raw = call_tu_llm(user_input=sentence, debug=debug)
        obj = extract_first_json_object(raw)
        validate(obj)

        return {
            "gml_id": gml_id,
            "interpreted_type": obj["interpreted_type"],
            "mid_labels": obj["mid_labels"],
            "bosserhof_class": obj["bosserhof_class"],
        }

    except Exception:
        return {
            "gml_id": gml_id,
            "interpreted_type": "error",
            "mid_labels": [],
            "bosserhof_class": None,
        }
    
def extract_first_json_array(text: str):
    import json
    import re

    match = re.search(r"\[\s*{.*}\s*\]", text, flags=re.DOTALL)
    if not match:
        raise ValueError("No JSON array found in model response.")
    return json.loads(match.group(0))

# %%
# def classify_first_n(pois_df: pd.DataFrame, n=5, debug=False) -> pd.DataFrame:
#     df = pois_df.head(n).copy()
#     results = []

#     for i, row in df.iterrows():
#         gml_id = row.get("gml_id", row.get("id", i))
#         sentence = row.get("sentence", "")

#         res = predict_from_sentence(
#             gml_id=gml_id,
#             sentence=sentence,
#             debug=debug,
#         )

#         results.append(res)
#         print(f"Done {len(results)}/{len(df)}")

#     return df.reset_index(drop=True).join(
#         pd.DataFrame(results), rsuffix="_pred"
#     )

# %%
# # pick 30 random rows (different each run)
# sample_df = pois.sample(n=5)

# # classify them once
# out5 = classify_first_n(sample_df, debug=False)

# %%
import time
import math
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd


# ---------------------------------------------------------
# Helper: split list into chunks
# ---------------------------------------------------------
def chunk_list(items, batch_size):
    for i in range(0, len(items), batch_size):
        yield items[i:i + batch_size]


# ---------------------------------------------------------
# RETRY WRAPPER FOR A WHOLE BATCH
# ---------------------------------------------------------
def predict_batch_with_retry(batch_rows, debug=False, max_retries=3, wait_sec=5):
    last_err = None
    batch_ids = [str(r["gml_id"]) for r in batch_rows]

    for attempt in range(1, max_retries + 1):
        try:
            return predict_batch_from_sentences(
                batch_rows=batch_rows,
                debug=debug,
            )
        except Exception as e:
            last_err = e
            print(f"[batch {batch_ids[:3]}... size={len(batch_rows)}] attempt {attempt}/{max_retries} failed: {e}")
            time.sleep(wait_sec)

    raise last_err


# ---------------------------------------------------------
# THIS IS THE MAIN PLACE TO IMPLEMENT REAL API BATCHING
# ---------------------------------------------------------
def predict_batch_from_sentences(batch_rows, debug=False):
    results = []

    prompts = []
    for row in batch_rows:
        gml_id = str(row["gml_id"])
        sentence = row.get("sentence", "")
        prompts.append({
            "gml_id": gml_id,
            "sentence": sentence,
        })

    res = predict_from_sentence(
        batch_rows=prompts,
        debug=debug,
    )

    if not isinstance(res, list):
        raise ValueError("Batch prediction must return a list.")

    if len(res) != len(batch_rows):
        raise ValueError(
            f"Batch output length mismatch: got {len(res)} results for {len(batch_rows)} rows."
        )

    for item in res:
        if isinstance(item, dict):
            results.append(item)
        else:
            results.append({"prediction": item})

    return results


# ---------------------------------------------------------
# APPEND TO PARQUET
# ---------------------------------------------------------
def append_parquet(path, new_rows, deduplicate_on=None):
    if not new_rows:
        return

    new_df = pd.DataFrame(new_rows)

    if path.exists():
        old_df = pd.read_parquet(path)
        merged = pd.concat([old_df, new_df], ignore_index=True)
    else:
        merged = new_df.copy()

    if deduplicate_on is not None:
        merged = merged.drop_duplicates(subset=[deduplicate_on], keep="last")

    merged.to_parquet(path, index=False)


# ---------------------------------------------------------
# MAIN FUNCTION: PARALLEL + BATCHED
# ---------------------------------------------------------
def classify_resume_parallel_batched(
    pois_df: pd.DataFrame,
    checkpoint_path="predictions_checkpoint.parquet",
    error_path="prediction_errors.parquet",
    save_every=200,
    max_workers=5,
    batch_size=10,
    debug=False,
    max_retries=3,
    retry_wait_sec=5,
):
    checkpoint_path = Path(checkpoint_path)
    error_path = Path(error_path)

    df = pois_df.copy().reset_index(drop=True)

    if "gml_id" not in df.columns:
        raise ValueError("pois_df must contain a 'gml_id' column.")

    if "sentence" not in df.columns:
        raise ValueError("pois_df must contain a 'sentence' column.")

    df["gml_id"] = df["gml_id"].astype(str)

    # do not checkpoint geometry
    cols_to_save = [c for c in df.columns if c != "geometry"]

    # ---------------------------
    # Load checkpoint
    # ---------------------------
    if checkpoint_path.exists():
        checkpoint_df = pd.read_parquet(checkpoint_path)
        checkpoint_df["gml_id"] = checkpoint_df["gml_id"].astype(str)
        done_ids = set(checkpoint_df["gml_id"])
        print(f"Loaded checkpoint with {len(done_ids)} completed rows")
    else:
        done_ids = set()
        print("No checkpoint found. Starting from scratch.")

    remaining_df = df[~df["gml_id"].isin(done_ids)].copy()
    print(f"Remaining rows to process: {len(remaining_df)} / {len(df)}")

    records = remaining_df.to_dict("records")
    batches = list(chunk_list(records, batch_size))

    print(f"Total batches to process: {len(batches)} | batch_size={batch_size} | max_workers={max_workers}")

    def batch_worker(batch_rows):
        batch_results = predict_batch_with_retry(
            batch_rows=batch_rows,
            debug=debug,
            max_retries=max_retries,
            wait_sec=retry_wait_sec,
        )

        if not isinstance(batch_results, list):
            raise ValueError("predict_batch_from_sentences() must return a list.")

        if len(batch_results) != len(batch_rows):
            raise ValueError(
                f"Batch output length mismatch: got {len(batch_results)} results for {len(batch_rows)} rows."
            )

        out_rows = []
        for row_dict, res in zip(batch_rows, batch_results):
            out_row = {k: v for k, v in row_dict.items() if k in cols_to_save}

            if isinstance(res, dict):
                out_row.update(res)
            else:
                out_row["prediction"] = res

            out_rows.append(out_row)

        return out_rows

    buffer = []
    error_buffer = []
    processed_now = 0
    completed_batches = 0

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_batch = {
            executor.submit(batch_worker, batch_rows): batch_rows
            for batch_rows in batches
        }

        for future in as_completed(future_to_batch):
            batch_rows = future_to_batch[future]
            batch_ids = [str(r["gml_id"]) for r in batch_rows]

            try:
                out_rows = future.result()
                buffer.extend(out_rows)

                processed_now += len(out_rows)
                completed_batches += 1

                print(
                    f"Processed {processed_now}/{len(remaining_df)} new rows "
                    f"| completed batches {completed_batches}/{len(batches)} "
                    f"| last batch size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]}"
                )

            except Exception as e:
                for row in batch_rows:
                    error_buffer.append({
                        "gml_id": str(row["gml_id"]),
                        "error": str(e),
                    })

                completed_batches += 1
                print(
                    f"Failed batch {completed_batches}/{len(batches)} "
                    f"| size={len(batch_rows)} "
                    f"| gml_id range={batch_ids[0]} -> {batch_ids[-1]} "
                    f"| error={e}"
                )

            # Save regularly from main thread only
            if len(buffer) >= save_every:
                append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
                print(f"Checkpoint saved with {len(buffer)} new rows")
                buffer = []

            if len(error_buffer) >= save_every:
                append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
                print(f"Error log saved with {len(error_buffer)} rows")
                error_buffer = []

    # final flush
    if buffer:
        append_parquet(checkpoint_path, buffer, deduplicate_on="gml_id")
        print("Final checkpoint saved.")

    if error_buffer:
        append_parquet(error_path, error_buffer, deduplicate_on="gml_id")
        print("Final error log saved.")

    final_df = pd.read_parquet(checkpoint_path)
    final_df["gml_id"] = final_df["gml_id"].astype(str)

    return final_df

# %%
final_df = classify_resume_parallel_batched(
    pois_df=pois,
    checkpoint_path="predictions_checkpoint.parquet",
    error_path="prediction_errors.parquet",
    save_every=100,
    max_workers=4,
    batch_size=4,
    debug=False,
    max_retries=2,
    retry_wait_sec=3,
)
# Out:
# Loaded checkpoint with 516200 completed rows
# Remaining rows to process: 84974 / 601174
# Total batches to process: 21244 | batch_size=4 | max_workers=4
# Processed 4/84974 new rows | completed batches 1/21244 | last batch size=4 | gml_id range=516212 -> 516215
# Processed 8/84974 new rows | completed batches 2/21244 | last batch size=4 | gml_id range=516204 -> 516207
# Processed 12/84974 new rows | completed batches 3/21244 | last batch size=4 | gml_id range=516200 -> 516203
# Processed 16/84974 new rows | completed batches 4/21244 | last batch size=4 | gml_id range=516208 -> 516211
# Processed 20/84974 new rows | completed batches 5/21244 | last batch size=4 | gml_id range=516216 -> 516219
# Processed 24/84974 new rows | completed batches 6/21244 | last batch size=4 | gml_id range=516228 -> 516231
# Processed 28/84974 new rows | completed batches 7/21244 | last batch size=4 | gml_id range=516220 -> 516223
# Processed 32/84974 new rows | completed batches 8/21244 | last batch size=4 | gml_id range=516224 -> 516227
# Processed 36/84974 new rows | completed batches 9/21244 | last batch size=4 | gml_id range=516232 -> 516235
# Processed 40/84974 new rows | completed batches 10/21244 | last batch size=4 | gml_id range=516244 -> 516247
# Processed 44/84974 new rows | completed batches 11/21244 | last batch size=4 | gml_id range=516236 -> 516239
# Processed 48/84974 new rows | completed batches 12/21244 | last batch size=4 | gml_id range=516240 -> 516243
# Processed 52/84974 new rows | completed batches 13/21244 | last batch size=4 | gml_id range=516260 -> 516263
# Processed 56/84974 new rows | completed batches 14/21244 | last batch size=4 | gml_id range=516248 -> 516251
# Processed 60/84974 new rows | completed batches 15/21244 | last batch size=4 | gml_id range=516256 -> 516259
# Processed 64/84974 new rows | completed batches 16/21244 | last batch size=4 | gml_id range=516252 -> 516255
# Processed 68/84974 new rows | completed batches 17/21244 | last batch size=4 | gml_id range=516264 -> 516267
# Processed 72/84974 new rows | completed batches 18/21244 | last batch size=4 | gml_id range=516272 -> 516275
# Processed 76/84974 new rows | completed batches 19/21244 | last batch size=4 | gml_id range=516268 -> 516271
# Processed 80/84974 new rows | completed batches 20/21244 | last batch size=4 | gml_id range=516276 -> 516279
# Processed 84/84974 new rows | completed batches 21/21244 | last batch size=4 | gml_id range=516280 -> 516283
# Processed 88/84974 new rows | completed batches 22/21244 | last batch size=4 | gml_id range=516284 -> 516287
# Processed 92/84974 new rows | completed batches 23/21244 | last batch size=4 | gml_id range=516292 -> 516295
# Processed 96/84974 new rows | completed batches 24/21244 | last batch size=4 | gml_id range=516300 -> 516303
# Processed 100/84974 new rows | completed batches 25/21244 | last batch size=4 | gml_id range=516288 -> 516291
# Checkpoint saved with 100 new rows
# Processed 104/84974 new rows | completed batches 26/21244 | last batch size=4 | gml_id range=516304 -> 516307
# Processed 108/84974 new rows | completed batches 27/21244 | last batch size=4 | gml_id range=516296 -> 516299
# Processed 112/84974 new rows | completed batches 28/21244 | last batch size=4 | gml_id range=516312 -> 516315
# Processed 116/84974 new rows | completed batches 29/21244 | last batch size=4 | gml_id range=516308 -> 516311
# Processed 120/84974 new rows | completed batches 30/21244 | last batch size=4 | gml_id range=516320 -> 516323
# Processed 124/84974 new rows | completed batches 31/21244 | last batch size=4 | gml_id range=516316 -> 516319
# Processed 128/84974 new rows | completed batches 32/21244 | last batch size=4 | gml_id range=516324 -> 516327
# Processed 132/84974 new rows | completed batches 33/21244 | last batch size=4 | gml_id range=516332 -> 516335
# Processed 136/84974 new rows | completed batches 34/21244 | last batch size=4 | gml_id range=516328 -> 516331
# Processed 140/84974 new rows | completed batches 35/21244 | last batch size=4 | gml_id range=516340 -> 516343
# Processed 144/84974 new rows | completed batches 36/21244 | last batch size=4 | gml_id range=516336 -> 516339
# Processed 148/84974 new rows | completed batches 37/21244 | last batch size=4 | gml_id range=516348 -> 516351
# Processed 152/84974 new rows | completed batches 38/21244 | last batch size=4 | gml_id range=516352 -> 516355
# Processed 156/84974 new rows | completed batches 39/21244 | last batch size=4 | gml_id range=516356 -> 516359
# Processed 160/84974 new rows | completed batches 40/21244 | last batch size=4 | gml_id range=516360 -> 516363
# Processed 164/84974 new rows | completed batches 41/21244 | last batch size=4 | gml_id range=516364 -> 516367
# Processed 168/84974 new rows | completed batches 42/21244 | last batch size=4 | gml_id range=516368 -> 516371
# Processed 172/84974 new rows | completed batches 43/21244 | last batch size=4 | gml_id range=516344 -> 516347
# Processed 176/84974 new rows | completed batches 44/21244 | last batch size=4 | gml_id range=516380 -> 516383
# Processed 180/84974 new rows | completed batches 45/21244 | last batch size=4 | gml_id range=516372 -> 516375
# Processed 184/84974 new rows | completed batches 46/21244 | last batch size=4 | gml_id range=516376 -> 516379
# Processed 188/84974 new rows | completed batches 47/21244 | last batch size=4 | gml_id range=516384 -> 516387
# Processed 192/84974 new rows | completed batches 48/21244 | last batch size=4 | gml_id range=516388 -> 516391
# Processed 196/84974 new rows | completed batches 49/21244 | last batch size=4 | gml_id range=516392 -> 516395
# Processed 200/84974 new rows | completed batches 50/21244 | last batch size=4 | gml_id range=516396 -> 516399
# Checkpoint saved with 100 new rows
# Processed 204/84974 new rows | completed batches 51/21244 | last batch size=4 | gml_id range=516400 -> 516403
# Processed 208/84974 new rows | completed batches 52/21244 | last batch size=4 | gml_id range=516404 -> 516407
# Processed 212/84974 new rows | completed batches 53/21244 | last batch size=4 | gml_id range=516412 -> 516415
# Processed 216/84974 new rows | completed batches 54/21244 | last batch size=4 | gml_id range=516408 -> 516411
# Processed 220/84974 new rows | completed batches 55/21244 | last batch size=4 | gml_id range=516416 -> 516419
# Processed 224/84974 new rows | completed batches 56/21244 | last batch size=4 | gml_id range=516420 -> 516423
# Processed 228/84974 new rows | completed batches 57/21244 | last batch size=4 | gml_id range=516424 -> 516427
# Processed 232/84974 new rows | completed batches 58/21244 | last batch size=4 | gml_id range=516432 -> 516435
# Processed 236/84974 new rows | completed batches 59/21244 | last batch size=4 | gml_id range=516428 -> 516431
# Processed 240/84974 new rows | completed batches 60/21244 | last batch size=4 | gml_id range=516436 -> 516439
# Processed 244/84974 new rows | completed batches 61/21244 | last batch size=4 | gml_id range=516440 -> 516443
# Processed 248/84974 new rows | completed batches 62/21244 | last batch size=4 | gml_id range=516444 -> 516447
# Processed 252/84974 new rows | completed batches 63/21244 | last batch size=4 | gml_id range=516456 -> 516459
# Processed 256/84974 new rows | completed batches 64/21244 | last batch size=4 | gml_id range=516452 -> 516455
# Processed 260/84974 new rows | completed batches 65/21244 | last batch size=4 | gml_id range=516448 -> 516451
# Processed 264/84974 new rows | completed batches 66/21244 | last batch size=4 | gml_id range=516460 -> 516463
# Processed 268/84974 new rows | completed batches 67/21244 | last batch size=4 | gml_id range=516472 -> 516475
# Processed 272/84974 new rows | completed batches 68/21244 | last batch size=4 | gml_id range=516468 -> 516471
# Processed 276/84974 new rows | completed batches 69/21244 | last batch size=4 | gml_id range=516464 -> 516467
# Processed 280/84974 new rows | completed batches 70/21244 | last batch size=4 | gml_id range=516476 -> 516479
# Processed 284/84974 new rows | completed batches 71/21244 | last batch size=4 | gml_id range=516480 -> 516483
# Processed 288/84974 new rows | completed batches 72/21244 | last batch size=4 | gml_id range=516484 -> 516487
# Processed 292/84974 new rows | completed batches 73/21244 | last batch size=4 | gml_id range=516492 -> 516495
# Processed 296/84974 new rows | completed batches 74/21244 | last batch size=4 | gml_id range=516488 -> 516491
# Processed 300/84974 new rows | completed batches 75/21244 | last batch size=4 | gml_id range=516500 -> 516503
# Checkpoint saved with 100 new rows
# Processed 304/84974 new rows | completed batches 76/21244 | last batch size=4 | gml_id range=516496 -> 516499
# Processed 308/84974 new rows | completed batches 77/21244 | last batch size=4 | gml_id range=516504 -> 516507
# Processed 312/84974 new rows | completed batches 78/21244 | last batch size=4 | gml_id range=516508 -> 516511
# Processed 316/84974 new rows | completed batches 79/21244 | last batch size=4 | gml_id range=516512 -> 516515
# Processed 320/84974 new rows | completed batches 80/21244 | last batch size=4 | gml_id range=516520 -> 516523
# Processed 324/84974 new rows | completed batches 81/21244 | last batch size=4 | gml_id range=516516 -> 516519
# Processed 328/84974 new rows | completed batches 82/21244 | last batch size=4 | gml_id range=516524 -> 516527
# Processed 332/84974 new rows | completed batches 83/21244 | last batch size=4 | gml_id range=516532 -> 516535
# Processed 336/84974 new rows | completed batches 84/21244 | last batch size=4 | gml_id range=516536 -> 516539
# Processed 340/84974 new rows | completed batches 85/21244 | last batch size=4 | gml_id range=516528 -> 516531
# Processed 344/84974 new rows | completed batches 86/21244 | last batch size=4 | gml_id range=516540 -> 516543
# Processed 348/84974 new rows | completed batches 87/21244 | last batch size=4 | gml_id range=516548 -> 516551
# Processed 352/84974 new rows | completed batches 88/21244 | last batch size=4 | gml_id range=516544 -> 516547
# Processed 356/84974 new rows | completed batches 89/21244 | last batch size=4 | gml_id range=516556 -> 516559
# Processed 360/84974 new rows | completed batches 90/21244 | last batch size=4 | gml_id range=516552 -> 516555
# Processed 364/84974 new rows | completed batches 91/21244 | last batch size=4 | gml_id range=516560 -> 516563
# Processed 368/84974 new rows | completed batches 92/21244 | last batch size=4 | gml_id range=516564 -> 516567
# Processed 372/84974 new rows | completed batches 93/21244 | last batch size=4 | gml_id range=516576 -> 516579
# Processed 376/84974 new rows | completed batches 94/21244 | last batch size=4 | gml_id range=516572 -> 516575
# Processed 380/84974 new rows | completed batches 95/21244 | last batch size=4 | gml_id range=516580 -> 516583
# Processed 384/84974 new rows | completed batches 96/21244 | last batch size=4 | gml_id range=516568 -> 516571
# Processed 388/84974 new rows | completed batches 97/21244 | last batch size=4 | gml_id range=516584 -> 516587
# Processed 392/84974 new rows | completed batches 98/21244 | last batch size=4 | gml_id range=516592 -> 516595
# Processed 396/84974 new rows | completed batches 99/21244 | last batch size=4 | gml_id range=516588 -> 516591
# Processed 400/84974 new rows | completed batches 100/21244 | last batch size=4 | gml_id range=516596 -> 516599
# Checkpoint saved with 100 new rows
# Processed 404/84974 new rows | completed batches 101/21244 | last batch size=4 | gml_id range=516604 -> 516607
# Processed 408/84974 new rows | completed batches 102/21244 | last batch size=4 | gml_id range=516600 -> 516603
# Processed 412/84974 new rows | completed batches 103/21244 | last batch size=4 | gml_id range=516608 -> 516611
# Processed 416/84974 new rows | completed batches 104/21244 | last batch size=4 | gml_id range=516612 -> 516615
# Processed 420/84974 new rows | completed batches 105/21244 | last batch size=4 | gml_id range=516620 -> 516623
# Processed 424/84974 new rows | completed batches 106/21244 | last batch size=4 | gml_id range=516616 -> 516619
# Processed 428/84974 new rows | completed batches 107/21244 | last batch size=4 | gml_id range=516624 -> 516627
# Processed 432/84974 new rows | completed batches 108/21244 | last batch size=4 | gml_id range=516628 -> 516631
# Processed 436/84974 new rows | completed batches 109/21244 | last batch size=4 | gml_id range=516636 -> 516639
# Processed 440/84974 new rows | completed batches 110/21244 | last batch size=4 | gml_id range=516640 -> 516643
# Processed 444/84974 new rows | completed batches 111/21244 | last batch size=4 | gml_id range=516644 -> 516647
# Processed 448/84974 new rows | completed batches 112/21244 | last batch size=4 | gml_id range=516632 -> 516635
# Processed 452/84974 new rows | completed batches 113/21244 | last batch size=4 | gml_id range=516656 -> 516659
# Processed 456/84974 new rows | completed batches 114/21244 | last batch size=4 | gml_id range=516648 -> 516651
# Processed 460/84974 new rows | completed batches 115/21244 | last batch size=4 | gml_id range=516660 -> 516663
# Processed 464/84974 new rows | completed batches 116/21244 | last batch size=4 | gml_id range=516652 -> 516655
# Processed 468/84974 new rows | completed batches 117/21244 | last batch size=4 | gml_id range=516664 -> 516667
# Processed 472/84974 new rows | completed batches 118/21244 | last batch size=4 | gml_id range=516672 -> 516675
# Processed 476/84974 new rows | completed batches 119/21244 | last batch size=4 | gml_id range=516668 -> 516671
# Processed 480/84974 new rows | completed batches 120/21244 | last batch size=4 | gml_id range=516684 -> 516687
# Processed 484/84974 new rows | completed batches 121/21244 | last batch size=4 | gml_id range=516680 -> 516683
# Processed 488/84974 new rows | completed batches 122/21244 | last batch size=4 | gml_id range=516676 -> 516679
# Processed 492/84974 new rows | completed batches 123/21244 | last batch size=4 | gml_id range=516688 -> 516691
# Processed 496/84974 new rows | completed batches 124/21244 | last batch size=4 | gml_id range=516696 -> 516699
# Processed 500/84974 new rows | completed batches 125/21244 | last batch size=4 | gml_id range=516692 -> 516695
# Checkpoint saved with 100 new rows
# Processed 504/84974 new rows | completed batches 126/21244 | last batch size=4 | gml_id range=516700 -> 516703
# Processed 508/84974 new rows | completed batches 127/21244 | last batch size=4 | gml_id range=516708 -> 516711
# Processed 512/84974 new rows | completed batches 128/21244 | last batch size=4 | gml_id range=516712 -> 516715
# Processed 516/84974 new rows | completed batches 129/21244 | last batch size=4 | gml_id range=516704 -> 516707
# Processed 520/84974 new rows | completed batches 130/21244 | last batch size=4 | gml_id range=516728 -> 516731
# Processed 524/84974 new rows | completed batches 131/21244 | last batch size=4 | gml_id range=516720 -> 516723
# Processed 528/84974 new rows | completed batches 132/21244 | last batch size=4 | gml_id range=516716 -> 516719
# Processed 532/84974 new rows | completed batches 133/21244 | last batch size=4 | gml_id range=516724 -> 516727
# Processed 536/84974 new rows | completed batches 134/21244 | last batch size=4 | gml_id range=516732 -> 516735
# Processed 540/84974 new rows | completed batches 135/21244 | last batch size=4 | gml_id range=516736 -> 516739
# Processed 544/84974 new rows | completed batches 136/21244 | last batch size=4 | gml_id range=516740 -> 516743
# Processed 548/84974 new rows | completed batches 137/21244 | last batch size=4 | gml_id range=516744 -> 516747
# Processed 552/84974 new rows | completed batches 138/21244 | last batch size=4 | gml_id range=516748 -> 516751
# Processed 556/84974 new rows | completed batches 139/21244 | last batch size=4 | gml_id range=516752 -> 516755
# Processed 560/84974 new rows | completed batches 140/21244 | last batch size=4 | gml_id range=516760 -> 516763
# Processed 564/84974 new rows | completed batches 141/21244 | last batch size=4 | gml_id range=516756 -> 516759
# Processed 568/84974 new rows | completed batches 142/21244 | last batch size=4 | gml_id range=516764 -> 516767
# Processed 572/84974 new rows | completed batches 143/21244 | last batch size=4 | gml_id range=516768 -> 516771
# Processed 576/84974 new rows | completed batches 144/21244 | last batch size=4 | gml_id range=516772 -> 516775
# Processed 580/84974 new rows | completed batches 145/21244 | last batch size=4 | gml_id range=516776 -> 516779
# Processed 584/84974 new rows | completed batches 146/21244 | last batch size=4 | gml_id range=516780 -> 516783
# Processed 588/84974 new rows | completed batches 147/21244 | last batch size=4 | gml_id range=516788 -> 516791
# Processed 592/84974 new rows | completed batches 148/21244 | last batch size=4 | gml_id range=516796 -> 516799
# Processed 596/84974 new rows | completed batches 149/21244 | last batch size=4 | gml_id range=516784 -> 516787
# Processed 600/84974 new rows | completed batches 150/21244 | last batch size=4 | gml_id range=516800 -> 516803
# Checkpoint saved with 100 new rows
# Processed 604/84974 new rows | completed batches 151/21244 | last batch size=4 | gml_id range=516792 -> 516795
# Processed 608/84974 new rows | completed batches 152/21244 | last batch size=4 | gml_id range=516804 -> 516807
# Processed 612/84974 new rows | completed batches 153/21244 | last batch size=4 | gml_id range=516808 -> 516811
# Processed 616/84974 new rows | completed batches 154/21244 | last batch size=4 | gml_id range=516812 -> 516815
# Processed 620/84974 new rows | completed batches 155/21244 | last batch size=4 | gml_id range=516820 -> 516823
# Processed 624/84974 new rows | completed batches 156/21244 | last batch size=4 | gml_id range=516816 -> 516819
# Processed 628/84974 new rows | completed batches 157/21244 | last batch size=4 | gml_id range=516824 -> 516827
# Processed 632/84974 new rows | completed batches 158/21244 | last batch size=4 | gml_id range=516828 -> 516831
# Processed 636/84974 new rows | completed batches 159/21244 | last batch size=4 | gml_id range=516832 -> 516835
# Processed 640/84974 new rows | completed batches 160/21244 | last batch size=4 | gml_id range=516836 -> 516839
# Processed 644/84974 new rows | completed batches 161/21244 | last batch size=4 | gml_id range=516840 -> 516843
# Processed 648/84974 new rows | completed batches 162/21244 | last batch size=4 | gml_id range=516844 -> 516847
# Processed 652/84974 new rows | completed batches 163/21244 | last batch size=4 | gml_id range=516848 -> 516851
# Processed 656/84974 new rows | completed batches 164/21244 | last batch size=4 | gml_id range=516856 -> 516859
# Processed 660/84974 new rows | completed batches 165/21244 | last batch size=4 | gml_id range=516852 -> 516855
# Processed 664/84974 new rows | completed batches 166/21244 | last batch size=4 | gml_id range=516860 -> 516863
# Processed 668/84974 new rows | completed batches 167/21244 | last batch size=4 | gml_id range=516864 -> 516867
# Processed 672/84974 new rows | completed batches 168/21244 | last batch size=4 | gml_id range=516868 -> 516871
# Processed 676/84974 new rows | completed batches 169/21244 | last batch size=4 | gml_id range=516872 -> 516875
# Processed 680/84974 new rows | completed batches 170/21244 | last batch size=4 | gml_id range=516876 -> 516879
# Processed 684/84974 new rows | completed batches 171/21244 | last batch size=4 | gml_id range=516880 -> 516883
# Processed 688/84974 new rows | completed batches 172/21244 | last batch size=4 | gml_id range=516884 -> 516887
# Processed 692/84974 new rows | completed batches 173/21244 | last batch size=4 | gml_id range=516888 -> 516891
# Processed 696/84974 new rows | completed batches 174/21244 | last batch size=4 | gml_id range=516892 -> 516895
# Processed 700/84974 new rows | completed batches 175/21244 | last batch size=4 | gml_id range=516900 -> 516903
# Checkpoint saved with 100 new rows
# Processed 704/84974 new rows | completed batches 176/21244 | last batch size=4 | gml_id range=516904 -> 516907
# Processed 708/84974 new rows | completed batches 177/21244 | last batch size=4 | gml_id range=516896 -> 516899
# Processed 712/84974 new rows | completed batches 178/21244 | last batch size=4 | gml_id range=516912 -> 516915
# Processed 716/84974 new rows | completed batches 179/21244 | last batch size=4 | gml_id range=516908 -> 516911
# Processed 720/84974 new rows | completed batches 180/21244 | last batch size=4 | gml_id range=516916 -> 516919
# Processed 724/84974 new rows | completed batches 181/21244 | last batch size=4 | gml_id range=516920 -> 516923
# Processed 728/84974 new rows | completed batches 182/21244 | last batch size=4 | gml_id range=516928 -> 516931
# Processed 732/84974 new rows | completed batches 183/21244 | last batch size=4 | gml_id range=516924 -> 516927
# Processed 736/84974 new rows | completed batches 184/21244 | last batch size=4 | gml_id range=516932 -> 516935
# Processed 740/84974 new rows | completed batches 185/21244 | last batch size=4 | gml_id range=516936 -> 516939
# Processed 744/84974 new rows | completed batches 186/21244 | last batch size=4 | gml_id range=516940 -> 516943
# Processed 748/84974 new rows | completed batches 187/21244 | last batch size=4 | gml_id range=516948 -> 516951
# Processed 752/84974 new rows | completed batches 188/21244 | last batch size=4 | gml_id range=516944 -> 516947
# Processed 756/84974 new rows | completed batches 189/21244 | last batch size=4 | gml_id range=516952 -> 516955
# Processed 760/84974 new rows | completed batches 190/21244 | last batch size=4 | gml_id range=516956 -> 516959
# Processed 764/84974 new rows | completed batches 191/21244 | last batch size=4 | gml_id range=516964 -> 516967
# Processed 768/84974 new rows | completed batches 192/21244 | last batch size=4 | gml_id range=516960 -> 516963
# Processed 772/84974 new rows | completed batches 193/21244 | last batch size=4 | gml_id range=516968 -> 516971
# Processed 776/84974 new rows | completed batches 194/21244 | last batch size=4 | gml_id range=516972 -> 516975
# Processed 780/84974 new rows | completed batches 195/21244 | last batch size=4 | gml_id range=516976 -> 516979
# Processed 784/84974 new rows | completed batches 196/21244 | last batch size=4 | gml_id range=516988 -> 516991
# Processed 788/84974 new rows | completed batches 197/21244 | last batch size=4 | gml_id range=516980 -> 516983
# Processed 792/84974 new rows | completed batches 198/21244 | last batch size=4 | gml_id range=516992 -> 516995
# Processed 796/84974 new rows | completed batches 199/21244 | last batch size=4 | gml_id range=516984 -> 516987
# Processed 800/84974 new rows | completed batches 200/21244 | last batch size=4 | gml_id range=516996 -> 516999
# Checkpoint saved with 100 new rows
# Processed 804/84974 new rows | completed batches 201/21244 | last batch size=4 | gml_id range=517000 -> 517003
# Processed 808/84974 new rows | completed batches 202/21244 | last batch size=4 | gml_id range=517004 -> 517007
# Processed 812/84974 new rows | completed batches 203/21244 | last batch size=4 | gml_id range=517008 -> 517011
# Processed 816/84974 new rows | completed batches 204/21244 | last batch size=4 | gml_id range=517012 -> 517015
# Processed 820/84974 new rows | completed batches 205/21244 | last batch size=4 | gml_id range=517016 -> 517019
# Processed 824/84974 new rows | completed batches 206/21244 | last batch size=4 | gml_id range=517020 -> 517023
# Processed 828/84974 new rows | completed batches 207/21244 | last batch size=4 | gml_id range=517028 -> 517031
# Processed 832/84974 new rows | completed batches 208/21244 | last batch size=4 | gml_id range=517032 -> 517035
# Processed 836/84974 new rows | completed batches 209/21244 | last batch size=4 | gml_id range=517024 -> 517027
# Processed 840/84974 new rows | completed batches 210/21244 | last batch size=4 | gml_id range=517036 -> 517039
# Processed 844/84974 new rows | completed batches 211/21244 | last batch size=4 | gml_id range=517044 -> 517047
# Processed 848/84974 new rows | completed batches 212/21244 | last batch size=4 | gml_id range=517048 -> 517051
# Processed 852/84974 new rows | completed batches 213/21244 | last batch size=4 | gml_id range=517040 -> 517043
# Processed 856/84974 new rows | completed batches 214/21244 | last batch size=4 | gml_id range=517052 -> 517055
# Processed 860/84974 new rows | completed batches 215/21244 | last batch size=4 | gml_id range=517056 -> 517059
# Processed 864/84974 new rows | completed batches 216/21244 | last batch size=4 | gml_id range=517060 -> 517063
# Processed 868/84974 new rows | completed batches 217/21244 | last batch size=4 | gml_id range=517064 -> 517067
# Processed 872/84974 new rows | completed batches 218/21244 | last batch size=4 | gml_id range=517072 -> 517075
# Processed 876/84974 new rows | completed batches 219/21244 | last batch size=4 | gml_id range=517068 -> 517071
# Processed 880/84974 new rows | completed batches 220/21244 | last batch size=4 | gml_id range=517076 -> 517079
# Processed 884/84974 new rows | completed batches 221/21244 | last batch size=4 | gml_id range=517080 -> 517083
# Processed 888/84974 new rows | completed batches 222/21244 | last batch size=4 | gml_id range=517084 -> 517087
# Processed 892/84974 new rows | completed batches 223/21244 | last batch size=4 | gml_id range=517096 -> 517099
# Processed 896/84974 new rows | completed batches 224/21244 | last batch size=4 | gml_id range=517088 -> 517091
# Processed 900/84974 new rows | completed batches 225/21244 | last batch size=4 | gml_id range=517092 -> 517095
# Checkpoint saved with 100 new rows
# Processed 904/84974 new rows | completed batches 226/21244 | last batch size=4 | gml_id range=517100 -> 517103
# Processed 908/84974 new rows | completed batches 227/21244 | last batch size=4 | gml_id range=517104 -> 517107
# Processed 912/84974 new rows | completed batches 228/21244 | last batch size=4 | gml_id range=517108 -> 517111
# Processed 916/84974 new rows | completed batches 229/21244 | last batch size=4 | gml_id range=517112 -> 517115
# Processed 920/84974 new rows | completed batches 230/21244 | last batch size=4 | gml_id range=517124 -> 517127
# Processed 924/84974 new rows | completed batches 231/21244 | last batch size=4 | gml_id range=517116 -> 517119
# Processed 928/84974 new rows | completed batches 232/21244 | last batch size=4 | gml_id range=517120 -> 517123
# Processed 932/84974 new rows | completed batches 233/21244 | last batch size=4 | gml_id range=517128 -> 517131
# Processed 936/84974 new rows | completed batches 234/21244 | last batch size=4 | gml_id range=517132 -> 517135
# Processed 940/84974 new rows | completed batches 235/21244 | last batch size=4 | gml_id range=517140 -> 517143
# Processed 944/84974 new rows | completed batches 236/21244 | last batch size=4 | gml_id range=517136 -> 517139
# Processed 948/84974 new rows | completed batches 237/21244 | last batch size=4 | gml_id range=517148 -> 517151
# Processed 952/84974 new rows | completed batches 238/21244 | last batch size=4 | gml_id range=517144 -> 517147
# Processed 956/84974 new rows | completed batches 239/21244 | last batch size=4 | gml_id range=517152 -> 517155
# Processed 960/84974 new rows | completed batches 240/21244 | last batch size=4 | gml_id range=517156 -> 517159
# Processed 964/84974 new rows | completed batches 241/21244 | last batch size=4 | gml_id range=517160 -> 517163
# Processed 968/84974 new rows | completed batches 242/21244 | last batch size=4 | gml_id range=517164 -> 517167
# Processed 972/84974 new rows | completed batches 243/21244 | last batch size=4 | gml_id range=517168 -> 517171
# Processed 976/84974 new rows | completed batches 244/21244 | last batch size=4 | gml_id range=517172 -> 517175
# Processed 980/84974 new rows | completed batches 245/21244 | last batch size=4 | gml_id range=517176 -> 517179
# Processed 984/84974 new rows | completed batches 246/21244 | last batch size=4 | gml_id range=517192 -> 517195
# Processed 988/84974 new rows | completed batches 247/21244 | last batch size=4 | gml_id range=517180 -> 517183
# Processed 992/84974 new rows | completed batches 248/21244 | last batch size=4 | gml_id range=517184 -> 517187
# Processed 996/84974 new rows | completed batches 249/21244 | last batch size=4 | gml_id range=517188 -> 517191
# Processed 1000/84974 new rows | completed batches 250/21244 | last batch size=4 | gml_id range=517200 -> 517203
# Checkpoint saved with 100 new rows
# Processed 1004/84974 new rows | completed batches 251/21244 | last batch size=4 | gml_id range=517196 -> 517199
# Processed 1008/84974 new rows | completed batches 252/21244 | last batch size=4 | gml_id range=517204 -> 517207
# Processed 1012/84974 new rows | completed batches 253/21244 | last batch size=4 | gml_id range=517208 -> 517211
# Processed 1016/84974 new rows | completed batches 254/21244 | last batch size=4 | gml_id range=517216 -> 517219
# Processed 1020/84974 new rows | completed batches 255/21244 | last batch size=4 | gml_id range=517212 -> 517215
# Processed 1024/84974 new rows | completed batches 256/21244 | last batch size=4 | gml_id range=517220 -> 517223
# Processed 1028/84974 new rows | completed batches 257/21244 | last batch size=4 | gml_id range=517224 -> 517227
# Processed 1032/84974 new rows | completed batches 258/21244 | last batch size=4 | gml_id range=517228 -> 517231
# Processed 1036/84974 new rows | completed batches 259/21244 | last batch size=4 | gml_id range=517232 -> 517235
# Processed 1040/84974 new rows | completed batches 260/21244 | last batch size=4 | gml_id range=517236 -> 517239
# Processed 1044/84974 new rows | completed batches 261/21244 | last batch size=4 | gml_id range=517240 -> 517243
# Processed 1048/84974 new rows | completed batches 262/21244 | last batch size=4 | gml_id range=517248 -> 517251
# Processed 1052/84974 new rows | completed batches 263/21244 | last batch size=4 | gml_id range=517244 -> 517247
# Processed 1056/84974 new rows | completed batches 264/21244 | last batch size=4 | gml_id range=517252 -> 517255
# Processed 1060/84974 new rows | completed batches 265/21244 | last batch size=4 | gml_id range=517256 -> 517259
# Processed 1064/84974 new rows | completed batches 266/21244 | last batch size=4 | gml_id range=517260 -> 517263
# Processed 1068/84974 new rows | completed batches 267/21244 | last batch size=4 | gml_id range=517268 -> 517271
# Processed 1072/84974 new rows | completed batches 268/21244 | last batch size=4 | gml_id range=517272 -> 517275
# Processed 1076/84974 new rows | completed batches 269/21244 | last batch size=4 | gml_id range=517276 -> 517279
# Processed 1080/84974 new rows | completed batches 270/21244 | last batch size=4 | gml_id range=517264 -> 517267
# Processed 1084/84974 new rows | completed batches 271/21244 | last batch size=4 | gml_id range=517280 -> 517283
# Processed 1088/84974 new rows | completed batches 272/21244 | last batch size=4 | gml_id range=517284 -> 517287
# Processed 1092/84974 new rows | completed batches 273/21244 | last batch size=4 | gml_id range=517288 -> 517291
# Processed 1096/84974 new rows | completed batches 274/21244 | last batch size=4 | gml_id range=517292 -> 517295
# Processed 1100/84974 new rows | completed batches 275/21244 | last batch size=4 | gml_id range=517300 -> 517303
# Checkpoint saved with 100 new rows
# Processed 1104/84974 new rows | completed batches 276/21244 | last batch size=4 | gml_id range=517304 -> 517307
# Processed 1108/84974 new rows | completed batches 277/21244 | last batch size=4 | gml_id range=517308 -> 517311
# Processed 1112/84974 new rows | completed batches 278/21244 | last batch size=4 | gml_id range=517296 -> 517299
# Processed 1116/84974 new rows | completed batches 279/21244 | last batch size=4 | gml_id range=517312 -> 517315
# Processed 1120/84974 new rows | completed batches 280/21244 | last batch size=4 | gml_id range=517320 -> 517323
# Processed 1124/84974 new rows | completed batches 281/21244 | last batch size=4 | gml_id range=517316 -> 517319
# Processed 1128/84974 new rows | completed batches 282/21244 | last batch size=4 | gml_id range=517324 -> 517327
# Processed 1132/84974 new rows | completed batches 283/21244 | last batch size=4 | gml_id range=517332 -> 517335
# Processed 1136/84974 new rows | completed batches 284/21244 | last batch size=4 | gml_id range=517328 -> 517331
# Processed 1140/84974 new rows | completed batches 285/21244 | last batch size=4 | gml_id range=517340 -> 517343
# Processed 1144/84974 new rows | completed batches 286/21244 | last batch size=4 | gml_id range=517336 -> 517339
# Processed 1148/84974 new rows | completed batches 287/21244 | last batch size=4 | gml_id range=517348 -> 517351
# Processed 1152/84974 new rows | completed batches 288/21244 | last batch size=4 | gml_id range=517344 -> 517347
# Processed 1156/84974 new rows | completed batches 289/21244 | last batch size=4 | gml_id range=517352 -> 517355
# Processed 1160/84974 new rows | completed batches 290/21244 | last batch size=4 | gml_id range=517356 -> 517359
# Processed 1164/84974 new rows | completed batches 291/21244 | last batch size=4 | gml_id range=517364 -> 517367
# Processed 1168/84974 new rows | completed batches 292/21244 | last batch size=4 | gml_id range=517360 -> 517363
# Processed 1172/84974 new rows | completed batches 293/21244 | last batch size=4 | gml_id range=517368 -> 517371
# Processed 1176/84974 new rows | completed batches 294/21244 | last batch size=4 | gml_id range=517372 -> 517375
# Processed 1180/84974 new rows | completed batches 295/21244 | last batch size=4 | gml_id range=517376 -> 517379
# Processed 1184/84974 new rows | completed batches 296/21244 | last batch size=4 | gml_id range=517384 -> 517387
# Processed 1188/84974 new rows | completed batches 297/21244 | last batch size=4 | gml_id range=517380 -> 517383
# Processed 1192/84974 new rows | completed batches 298/21244 | last batch size=4 | gml_id range=517392 -> 517395
# Processed 1196/84974 new rows | completed batches 299/21244 | last batch size=4 | gml_id range=517388 -> 517391
# Processed 1200/84974 new rows | completed batches 300/21244 | last batch size=4 | gml_id range=517400 -> 517403
# Checkpoint saved with 100 new rows
# Processed 1204/84974 new rows | completed batches 301/21244 | last batch size=4 | gml_id range=517396 -> 517399
# Processed 1208/84974 new rows | completed batches 302/21244 | last batch size=4 | gml_id range=517404 -> 517407
# Processed 1212/84974 new rows | completed batches 303/21244 | last batch size=4 | gml_id range=517408 -> 517411
# Processed 1216/84974 new rows | completed batches 304/21244 | last batch size=4 | gml_id range=517412 -> 517415
# Processed 1220/84974 new rows | completed batches 305/21244 | last batch size=4 | gml_id range=517420 -> 517423
# Processed 1224/84974 new rows | completed batches 306/21244 | last batch size=4 | gml_id range=517416 -> 517419
# Processed 1228/84974 new rows | completed batches 307/21244 | last batch size=4 | gml_id range=517428 -> 517431
# Processed 1232/84974 new rows | completed batches 308/21244 | last batch size=4 | gml_id range=517424 -> 517427
# Processed 1236/84974 new rows | completed batches 309/21244 | last batch size=4 | gml_id range=517432 -> 517435
# Processed 1240/84974 new rows | completed batches 310/21244 | last batch size=4 | gml_id range=517436 -> 517439
# Processed 1244/84974 new rows | completed batches 311/21244 | last batch size=4 | gml_id range=517440 -> 517443
# Processed 1248/84974 new rows | completed batches 312/21244 | last batch size=4 | gml_id range=517444 -> 517447
# Processed 1252/84974 new rows | completed batches 313/21244 | last batch size=4 | gml_id range=517448 -> 517451
# Processed 1256/84974 new rows | completed batches 314/21244 | last batch size=4 | gml_id range=517456 -> 517459
# Processed 1260/84974 new rows | completed batches 315/21244 | last batch size=4 | gml_id range=517452 -> 517455
# Processed 1264/84974 new rows | completed batches 316/21244 | last batch size=4 | gml_id range=517460 -> 517463
# Processed 1268/84974 new rows | completed batches 317/21244 | last batch size=4 | gml_id range=517464 -> 517467
# Processed 1272/84974 new rows | completed batches 318/21244 | last batch size=4 | gml_id range=517468 -> 517471
# Processed 1276/84974 new rows | completed batches 319/21244 | last batch size=4 | gml_id range=517472 -> 517475
# Processed 1280/84974 new rows | completed batches 320/21244 | last batch size=4 | gml_id range=517476 -> 517479
# Processed 1284/84974 new rows | completed batches 321/21244 | last batch size=4 | gml_id range=517480 -> 517483
# Processed 1288/84974 new rows | completed batches 322/21244 | last batch size=4 | gml_id range=517484 -> 517487
# Processed 1292/84974 new rows | completed batches 323/21244 | last batch size=4 | gml_id range=517492 -> 517495
# Processed 1296/84974 new rows | completed batches 324/21244 | last batch size=4 | gml_id range=517488 -> 517491
# Processed 1300/84974 new rows | completed batches 325/21244 | last batch size=4 | gml_id range=517500 -> 517503
# Checkpoint saved with 100 new rows
# Processed 1304/84974 new rows | completed batches 326/21244 | last batch size=4 | gml_id range=517496 -> 517499
# Processed 1308/84974 new rows | completed batches 327/21244 | last batch size=4 | gml_id range=517504 -> 517507
# Processed 1312/84974 new rows | completed batches 328/21244 | last batch size=4 | gml_id range=517512 -> 517515
# Processed 1316/84974 new rows | completed batches 329/21244 | last batch size=4 | gml_id range=517508 -> 517511
# Processed 1320/84974 new rows | completed batches 330/21244 | last batch size=4 | gml_id range=517516 -> 517519
# Processed 1324/84974 new rows | completed batches 331/21244 | last batch size=4 | gml_id range=517524 -> 517527
# Processed 1328/84974 new rows | completed batches 332/21244 | last batch size=4 | gml_id range=517528 -> 517531
# Processed 1332/84974 new rows | completed batches 333/21244 | last batch size=4 | gml_id range=517520 -> 517523
# Processed 1336/84974 new rows | completed batches 334/21244 | last batch size=4 | gml_id range=517532 -> 517535
# Processed 1340/84974 new rows | completed batches 335/21244 | last batch size=4 | gml_id range=517540 -> 517543
# Processed 1344/84974 new rows | completed batches 336/21244 | last batch size=4 | gml_id range=517536 -> 517539
# Processed 1348/84974 new rows | completed batches 337/21244 | last batch size=4 | gml_id range=517544 -> 517547
# Processed 1352/84974 new rows | completed batches 338/21244 | last batch size=4 | gml_id range=517552 -> 517555
# Processed 1356/84974 new rows | completed batches 339/21244 | last batch size=4 | gml_id range=517548 -> 517551
# Processed 1360/84974 new rows | completed batches 340/21244 | last batch size=4 | gml_id range=517556 -> 517559
# Processed 1364/84974 new rows | completed batches 341/21244 | last batch size=4 | gml_id range=517560 -> 517563
# Processed 1368/84974 new rows | completed batches 342/21244 | last batch size=4 | gml_id range=517564 -> 517567
# Processed 1372/84974 new rows | completed batches 343/21244 | last batch size=4 | gml_id range=517568 -> 517571
# Processed 1376/84974 new rows | completed batches 344/21244 | last batch size=4 | gml_id range=517576 -> 517579
# Processed 1380/84974 new rows | completed batches 345/21244 | last batch size=4 | gml_id range=517572 -> 517575
# Processed 1384/84974 new rows | completed batches 346/21244 | last batch size=4 | gml_id range=517584 -> 517587
# Processed 1388/84974 new rows | completed batches 347/21244 | last batch size=4 | gml_id range=517580 -> 517583
# Processed 1392/84974 new rows | completed batches 348/21244 | last batch size=4 | gml_id range=517588 -> 517591
# Processed 1396/84974 new rows | completed batches 349/21244 | last batch size=4 | gml_id range=517596 -> 517599
# Processed 1400/84974 new rows | completed batches 350/21244 | last batch size=4 | gml_id range=517600 -> 517603
# Checkpoint saved with 100 new rows
# Processed 1404/84974 new rows | completed batches 351/21244 | last batch size=4 | gml_id range=517592 -> 517595
# Processed 1408/84974 new rows | completed batches 352/21244 | last batch size=4 | gml_id range=517612 -> 517615
# Processed 1412/84974 new rows | completed batches 353/21244 | last batch size=4 | gml_id range=517604 -> 517607
# Processed 1416/84974 new rows | completed batches 354/21244 | last batch size=4 | gml_id range=517616 -> 517619
# Processed 1420/84974 new rows | completed batches 355/21244 | last batch size=4 | gml_id range=517608 -> 517611
# Processed 1424/84974 new rows | completed batches 356/21244 | last batch size=4 | gml_id range=517632 -> 517635
# Processed 1428/84974 new rows | completed batches 357/21244 | last batch size=4 | gml_id range=517620 -> 517623
# Processed 1432/84974 new rows | completed batches 358/21244 | last batch size=4 | gml_id range=517624 -> 517627
# Processed 1436/84974 new rows | completed batches 359/21244 | last batch size=4 | gml_id range=517628 -> 517631
# Processed 1440/84974 new rows | completed batches 360/21244 | last batch size=4 | gml_id range=517636 -> 517639
# Processed 1444/84974 new rows | completed batches 361/21244 | last batch size=4 | gml_id range=517644 -> 517647
# Processed 1448/84974 new rows | completed batches 362/21244 | last batch size=4 | gml_id range=517652 -> 517655
# Processed 1452/84974 new rows | completed batches 363/21244 | last batch size=4 | gml_id range=517648 -> 517651
# Processed 1456/84974 new rows | completed batches 364/21244 | last batch size=4 | gml_id range=517640 -> 517643
# Processed 1460/84974 new rows | completed batches 365/21244 | last batch size=4 | gml_id range=517660 -> 517663
# Processed 1464/84974 new rows | completed batches 366/21244 | last batch size=4 | gml_id range=517668 -> 517671
# Processed 1468/84974 new rows | completed batches 367/21244 | last batch size=4 | gml_id range=517656 -> 517659
# Processed 1472/84974 new rows | completed batches 368/21244 | last batch size=4 | gml_id range=517664 -> 517667
# Processed 1476/84974 new rows | completed batches 369/21244 | last batch size=4 | gml_id range=517672 -> 517675
# Processed 1480/84974 new rows | completed batches 370/21244 | last batch size=4 | gml_id range=517680 -> 517683
# Processed 1484/84974 new rows | completed batches 371/21244 | last batch size=4 | gml_id range=517676 -> 517679
# Processed 1488/84974 new rows | completed batches 372/21244 | last batch size=4 | gml_id range=517688 -> 517691
# Processed 1492/84974 new rows | completed batches 373/21244 | last batch size=4 | gml_id range=517684 -> 517687
# Processed 1496/84974 new rows | completed batches 374/21244 | last batch size=4 | gml_id range=517692 -> 517695
# Processed 1500/84974 new rows | completed batches 375/21244 | last batch size=4 | gml_id range=517704 -> 517707
# Checkpoint saved with 100 new rows
# Processed 1504/84974 new rows | completed batches 376/21244 | last batch size=4 | gml_id range=517696 -> 517699
# Processed 1508/84974 new rows | completed batches 377/21244 | last batch size=4 | gml_id range=517708 -> 517711
# Processed 1512/84974 new rows | completed batches 378/21244 | last batch size=4 | gml_id range=517700 -> 517703
# Processed 1516/84974 new rows | completed batches 379/21244 | last batch size=4 | gml_id range=517712 -> 517715
# Processed 1520/84974 new rows | completed batches 380/21244 | last batch size=4 | gml_id range=517716 -> 517719
# Processed 1524/84974 new rows | completed batches 381/21244 | last batch size=4 | gml_id range=517724 -> 517727
# Processed 1528/84974 new rows | completed batches 382/21244 | last batch size=4 | gml_id range=517720 -> 517723
# Processed 1532/84974 new rows | completed batches 383/21244 | last batch size=4 | gml_id range=517728 -> 517731
# Processed 1536/84974 new rows | completed batches 384/21244 | last batch size=4 | gml_id range=517732 -> 517735
# Processed 1540/84974 new rows | completed batches 385/21244 | last batch size=4 | gml_id range=517740 -> 517743
# Processed 1544/84974 new rows | completed batches 386/21244 | last batch size=4 | gml_id range=517736 -> 517739
# Processed 1548/84974 new rows | completed batches 387/21244 | last batch size=4 | gml_id range=517744 -> 517747
# Processed 1552/84974 new rows | completed batches 388/21244 | last batch size=4 | gml_id range=517752 -> 517755
# Processed 1556/84974 new rows | completed batches 389/21244 | last batch size=4 | gml_id range=517748 -> 517751
# Processed 1560/84974 new rows | completed batches 390/21244 | last batch size=4 | gml_id range=517756 -> 517759
# Processed 1564/84974 new rows | completed batches 391/21244 | last batch size=4 | gml_id range=517760 -> 517763
# Processed 1568/84974 new rows | completed batches 392/21244 | last batch size=4 | gml_id range=517764 -> 517767
# Processed 1572/84974 new rows | completed batches 393/21244 | last batch size=4 | gml_id range=517768 -> 517771
# Processed 1576/84974 new rows | completed batches 394/21244 | last batch size=4 | gml_id range=517772 -> 517775
# Processed 1580/84974 new rows | completed batches 395/21244 | last batch size=4 | gml_id range=517780 -> 517783
# Processed 1584/84974 new rows | completed batches 396/21244 | last batch size=4 | gml_id range=517776 -> 517779
# Processed 1588/84974 new rows | completed batches 397/21244 | last batch size=4 | gml_id range=517784 -> 517787
# Processed 1592/84974 new rows | completed batches 398/21244 | last batch size=4 | gml_id range=517792 -> 517795
# Processed 1596/84974 new rows | completed batches 399/21244 | last batch size=4 | gml_id range=517788 -> 517791
# Processed 1600/84974 new rows | completed batches 400/21244 | last batch size=4 | gml_id range=517800 -> 517803
# Checkpoint saved with 100 new rows
# Processed 1604/84974 new rows | completed batches 401/21244 | last batch size=4 | gml_id range=517796 -> 517799
# Processed 1608/84974 new rows | completed batches 402/21244 | last batch size=4 | gml_id range=517808 -> 517811
# Processed 1612/84974 new rows | completed batches 403/21244 | last batch size=4 | gml_id range=517804 -> 517807
# Processed 1616/84974 new rows | completed batches 404/21244 | last batch size=4 | gml_id range=517812 -> 517815
# Processed 1620/84974 new rows | completed batches 405/21244 | last batch size=4 | gml_id range=517820 -> 517823
# Processed 1624/84974 new rows | completed batches 406/21244 | last batch size=4 | gml_id range=517824 -> 517827
# Processed 1628/84974 new rows | completed batches 407/21244 | last batch size=4 | gml_id range=517816 -> 517819
# Processed 1632/84974 new rows | completed batches 408/21244 | last batch size=4 | gml_id range=517828 -> 517831
# Processed 1636/84974 new rows | completed batches 409/21244 | last batch size=4 | gml_id range=517836 -> 517839
# Processed 1640/84974 new rows | completed batches 410/21244 | last batch size=4 | gml_id range=517832 -> 517835
# Processed 1644/84974 new rows | completed batches 411/21244 | last batch size=4 | gml_id range=517840 -> 517843
# Processed 1648/84974 new rows | completed batches 412/21244 | last batch size=4 | gml_id range=517844 -> 517847
# Processed 1652/84974 new rows | completed batches 413/21244 | last batch size=4 | gml_id range=517848 -> 517851
# Processed 1656/84974 new rows | completed batches 414/21244 | last batch size=4 | gml_id range=517856 -> 517859
# Processed 1660/84974 new rows | completed batches 415/21244 | last batch size=4 | gml_id range=517852 -> 517855
# Processed 1664/84974 new rows | completed batches 416/21244 | last batch size=4 | gml_id range=517860 -> 517863
# Processed 1668/84974 new rows | completed batches 417/21244 | last batch size=4 | gml_id range=517864 -> 517867
# Processed 1672/84974 new rows | completed batches 418/21244 | last batch size=4 | gml_id range=517872 -> 517875
# Processed 1676/84974 new rows | completed batches 419/21244 | last batch size=4 | gml_id range=517876 -> 517879
# Processed 1680/84974 new rows | completed batches 420/21244 | last batch size=4 | gml_id range=517868 -> 517871
# Processed 1684/84974 new rows | completed batches 421/21244 | last batch size=4 | gml_id range=517884 -> 517887
# Processed 1688/84974 new rows | completed batches 422/21244 | last batch size=4 | gml_id range=517888 -> 517891
# Processed 1692/84974 new rows | completed batches 423/21244 | last batch size=4 | gml_id range=517892 -> 517895
# Processed 1696/84974 new rows | completed batches 424/21244 | last batch size=4 | gml_id range=517880 -> 517883
# Processed 1700/84974 new rows | completed batches 425/21244 | last batch size=4 | gml_id range=517900 -> 517903
# Checkpoint saved with 100 new rows
# ...
# Processed 84432/84974 new rows | completed batches 21108/21244 | last batch size=4 | gml_id range=600628 -> 600631
# Processed 84436/84974 new rows | completed batches 21109/21244 | last batch size=4 | gml_id range=600632 -> 600635
# Processed 84440/84974 new rows | completed batches 21110/21244 | last batch size=4 | gml_id range=600636 -> 600639
# Processed 84444/84974 new rows | completed batches 21111/21244 | last batch size=4 | gml_id range=600640 -> 600643
# Processed 84448/84974 new rows | completed batches 21112/21244 | last batch size=4 | gml_id range=600644 -> 600647
# Processed 84452/84974 new rows | completed batches 21113/21244 | last batch size=4 | gml_id range=600648 -> 600651
# Processed 84456/84974 new rows | completed batches 21114/21244 | last batch size=4 | gml_id range=600660 -> 600663
# Processed 84460/84974 new rows | completed batches 21115/21244 | last batch size=4 | gml_id range=600664 -> 600667
# Processed 84464/84974 new rows | completed batches 21116/21244 | last batch size=4 | gml_id range=600652 -> 600655
# Processed 84468/84974 new rows | completed batches 21117/21244 | last batch size=4 | gml_id range=600656 -> 600659
# Processed 84472/84974 new rows | completed batches 21118/21244 | last batch size=4 | gml_id range=600672 -> 600675
# Processed 84476/84974 new rows | completed batches 21119/21244 | last batch size=4 | gml_id range=600668 -> 600671
# Processed 84480/84974 new rows | completed batches 21120/21244 | last batch size=4 | gml_id range=600680 -> 600683
# Processed 84484/84974 new rows | completed batches 21121/21244 | last batch size=4 | gml_id range=600676 -> 600679
# Processed 84488/84974 new rows | completed batches 21122/21244 | last batch size=4 | gml_id range=600684 -> 600687
# Processed 84492/84974 new rows | completed batches 21123/21244 | last batch size=4 | gml_id range=600688 -> 600691
# Processed 84496/84974 new rows | completed batches 21124/21244 | last batch size=4 | gml_id range=600692 -> 600695
# Processed 84500/84974 new rows | completed batches 21125/21244 | last batch size=4 | gml_id range=600696 -> 600699
# Checkpoint saved with 100 new rows
# Processed 84504/84974 new rows | completed batches 21126/21244 | last batch size=4 | gml_id range=600700 -> 600703
# Processed 84508/84974 new rows | completed batches 21127/21244 | last batch size=4 | gml_id range=600704 -> 600707
# Processed 84512/84974 new rows | completed batches 21128/21244 | last batch size=4 | gml_id range=600708 -> 600711
# Processed 84516/84974 new rows | completed batches 21129/21244 | last batch size=4 | gml_id range=600712 -> 600715
# Processed 84520/84974 new rows | completed batches 21130/21244 | last batch size=4 | gml_id range=600716 -> 600719
# Processed 84524/84974 new rows | completed batches 21131/21244 | last batch size=4 | gml_id range=600720 -> 600723
# Processed 84528/84974 new rows | completed batches 21132/21244 | last batch size=4 | gml_id range=600724 -> 600727
# Processed 84532/84974 new rows | completed batches 21133/21244 | last batch size=4 | gml_id range=600728 -> 600731
# Processed 84536/84974 new rows | completed batches 21134/21244 | last batch size=4 | gml_id range=600732 -> 600735
# Processed 84540/84974 new rows | completed batches 21135/21244 | last batch size=4 | gml_id range=600740 -> 600743
# Processed 84544/84974 new rows | completed batches 21136/21244 | last batch size=4 | gml_id range=600736 -> 600739
# Processed 84548/84974 new rows | completed batches 21137/21244 | last batch size=4 | gml_id range=600744 -> 600747
# Processed 84552/84974 new rows | completed batches 21138/21244 | last batch size=4 | gml_id range=600752 -> 600755
# Processed 84556/84974 new rows | completed batches 21139/21244 | last batch size=4 | gml_id range=600748 -> 600751
# Processed 84560/84974 new rows | completed batches 21140/21244 | last batch size=4 | gml_id range=600760 -> 600763
# Processed 84564/84974 new rows | completed batches 21141/21244 | last batch size=4 | gml_id range=600764 -> 600767
# Processed 84568/84974 new rows | completed batches 21142/21244 | last batch size=4 | gml_id range=600768 -> 600771
# Processed 84572/84974 new rows | completed batches 21143/21244 | last batch size=4 | gml_id range=600756 -> 600759
# Processed 84576/84974 new rows | completed batches 21144/21244 | last batch size=4 | gml_id range=600772 -> 600775
# Processed 84580/84974 new rows | completed batches 21145/21244 | last batch size=4 | gml_id range=600776 -> 600779
# Processed 84584/84974 new rows | completed batches 21146/21244 | last batch size=4 | gml_id range=600784 -> 600787
# Processed 84588/84974 new rows | completed batches 21147/21244 | last batch size=4 | gml_id range=600780 -> 600783
# Processed 84592/84974 new rows | completed batches 21148/21244 | last batch size=4 | gml_id range=600788 -> 600791
# Processed 84596/84974 new rows | completed batches 21149/21244 | last batch size=4 | gml_id range=600796 -> 600799
# Processed 84600/84974 new rows | completed batches 21150/21244 | last batch size=4 | gml_id range=600792 -> 600795
# Checkpoint saved with 100 new rows
# Processed 84604/84974 new rows | completed batches 21151/21244 | last batch size=4 | gml_id range=600800 -> 600803
# Processed 84608/84974 new rows | completed batches 21152/21244 | last batch size=4 | gml_id range=600804 -> 600807
# Processed 84612/84974 new rows | completed batches 21153/21244 | last batch size=4 | gml_id range=600808 -> 600811
# Processed 84616/84974 new rows | completed batches 21154/21244 | last batch size=4 | gml_id range=600812 -> 600815
# Processed 84620/84974 new rows | completed batches 21155/21244 | last batch size=4 | gml_id range=600820 -> 600823
# Processed 84624/84974 new rows | completed batches 21156/21244 | last batch size=4 | gml_id range=600816 -> 600819
# Processed 84628/84974 new rows | completed batches 21157/21244 | last batch size=4 | gml_id range=600824 -> 600827
# Processed 84632/84974 new rows | completed batches 21158/21244 | last batch size=4 | gml_id range=600828 -> 600831
# Processed 84636/84974 new rows | completed batches 21159/21244 | last batch size=4 | gml_id range=600832 -> 600835
# Processed 84640/84974 new rows | completed batches 21160/21244 | last batch size=4 | gml_id range=600836 -> 600839
# Processed 84644/84974 new rows | completed batches 21161/21244 | last batch size=4 | gml_id range=600840 -> 600843
# Processed 84648/84974 new rows | completed batches 21162/21244 | last batch size=4 | gml_id range=600844 -> 600847
# Processed 84652/84974 new rows | completed batches 21163/21244 | last batch size=4 | gml_id range=600852 -> 600855
# Processed 84656/84974 new rows | completed batches 21164/21244 | last batch size=4 | gml_id range=600848 -> 600851
# Processed 84660/84974 new rows | completed batches 21165/21244 | last batch size=4 | gml_id range=600856 -> 600859
# Processed 84664/84974 new rows | completed batches 21166/21244 | last batch size=4 | gml_id range=600860 -> 600863
# Processed 84668/84974 new rows | completed batches 21167/21244 | last batch size=4 | gml_id range=600864 -> 600867
# Processed 84672/84974 new rows | completed batches 21168/21244 | last batch size=4 | gml_id range=600868 -> 600871
# Processed 84676/84974 new rows | completed batches 21169/21244 | last batch size=4 | gml_id range=600872 -> 600875
# Processed 84680/84974 new rows | completed batches 21170/21244 | last batch size=4 | gml_id range=600884 -> 600887
# Processed 84684/84974 new rows | completed batches 21171/21244 | last batch size=4 | gml_id range=600880 -> 600883
# Processed 84688/84974 new rows | completed batches 21172/21244 | last batch size=4 | gml_id range=600876 -> 600879
# Processed 84692/84974 new rows | completed batches 21173/21244 | last batch size=4 | gml_id range=600888 -> 600891
# Processed 84696/84974 new rows | completed batches 21174/21244 | last batch size=4 | gml_id range=600896 -> 600899
# Processed 84700/84974 new rows | completed batches 21175/21244 | last batch size=4 | gml_id range=600892 -> 600895
# Checkpoint saved with 100 new rows
# Processed 84704/84974 new rows | completed batches 21176/21244 | last batch size=4 | gml_id range=600900 -> 600903
# Processed 84708/84974 new rows | completed batches 21177/21244 | last batch size=4 | gml_id range=600908 -> 600911
# Processed 84712/84974 new rows | completed batches 21178/21244 | last batch size=4 | gml_id range=600904 -> 600907
# Processed 84716/84974 new rows | completed batches 21179/21244 | last batch size=4 | gml_id range=600912 -> 600915
# Processed 84720/84974 new rows | completed batches 21180/21244 | last batch size=4 | gml_id range=600916 -> 600919
# Processed 84724/84974 new rows | completed batches 21181/21244 | last batch size=4 | gml_id range=600924 -> 600927
# Processed 84728/84974 new rows | completed batches 21182/21244 | last batch size=4 | gml_id range=600920 -> 600923
# Processed 84732/84974 new rows | completed batches 21183/21244 | last batch size=4 | gml_id range=600928 -> 600931
# Processed 84736/84974 new rows | completed batches 21184/21244 | last batch size=4 | gml_id range=600932 -> 600935
# Processed 84740/84974 new rows | completed batches 21185/21244 | last batch size=4 | gml_id range=600936 -> 600939
# Processed 84744/84974 new rows | completed batches 21186/21244 | last batch size=4 | gml_id range=600940 -> 600943
# Processed 84748/84974 new rows | completed batches 21187/21244 | last batch size=4 | gml_id range=600944 -> 600947
# Processed 84752/84974 new rows | completed batches 21188/21244 | last batch size=4 | gml_id range=600948 -> 600951
# Processed 84756/84974 new rows | completed batches 21189/21244 | last batch size=4 | gml_id range=600952 -> 600955
# Processed 84760/84974 new rows | completed batches 21190/21244 | last batch size=4 | gml_id range=600960 -> 600963
# Processed 84764/84974 new rows | completed batches 21191/21244 | last batch size=4 | gml_id range=600964 -> 600967
# Processed 84768/84974 new rows | completed batches 21192/21244 | last batch size=4 | gml_id range=600956 -> 600959
# Processed 84772/84974 new rows | completed batches 21193/21244 | last batch size=4 | gml_id range=600968 -> 600971
# Processed 84776/84974 new rows | completed batches 21194/21244 | last batch size=4 | gml_id range=600972 -> 600975
# Processed 84780/84974 new rows | completed batches 21195/21244 | last batch size=4 | gml_id range=600980 -> 600983
# Processed 84784/84974 new rows | completed batches 21196/21244 | last batch size=4 | gml_id range=600976 -> 600979
# Processed 84788/84974 new rows | completed batches 21197/21244 | last batch size=4 | gml_id range=600984 -> 600987
# Processed 84792/84974 new rows | completed batches 21198/21244 | last batch size=4 | gml_id range=600988 -> 600991
# Processed 84796/84974 new rows | completed batches 21199/21244 | last batch size=4 | gml_id range=600992 -> 600995
# Processed 84800/84974 new rows | completed batches 21200/21244 | last batch size=4 | gml_id range=600996 -> 600999
# Checkpoint saved with 100 new rows
# Processed 84804/84974 new rows | completed batches 21201/21244 | last batch size=4 | gml_id range=601000 -> 601003
# Processed 84808/84974 new rows | completed batches 21202/21244 | last batch size=4 | gml_id range=601004 -> 601007
# Processed 84812/84974 new rows | completed batches 21203/21244 | last batch size=4 | gml_id range=601012 -> 601015
# Processed 84816/84974 new rows | completed batches 21204/21244 | last batch size=4 | gml_id range=601008 -> 601011
# Processed 84820/84974 new rows | completed batches 21205/21244 | last batch size=4 | gml_id range=601016 -> 601019
# Processed 84824/84974 new rows | completed batches 21206/21244 | last batch size=4 | gml_id range=601020 -> 601023
# Processed 84828/84974 new rows | completed batches 21207/21244 | last batch size=4 | gml_id range=601024 -> 601027
# Processed 84832/84974 new rows | completed batches 21208/21244 | last batch size=4 | gml_id range=601028 -> 601031
# Processed 84836/84974 new rows | completed batches 21209/21244 | last batch size=4 | gml_id range=601032 -> 601035
# Processed 84840/84974 new rows | completed batches 21210/21244 | last batch size=4 | gml_id range=601036 -> 601039
# Processed 84844/84974 new rows | completed batches 21211/21244 | last batch size=4 | gml_id range=601040 -> 601043
# Processed 84848/84974 new rows | completed batches 21212/21244 | last batch size=4 | gml_id range=601044 -> 601047
# Processed 84852/84974 new rows | completed batches 21213/21244 | last batch size=4 | gml_id range=601048 -> 601051
# Processed 84856/84974 new rows | completed batches 21214/21244 | last batch size=4 | gml_id range=601056 -> 601059
# Processed 84860/84974 new rows | completed batches 21215/21244 | last batch size=4 | gml_id range=601052 -> 601055
# Processed 84864/84974 new rows | completed batches 21216/21244 | last batch size=4 | gml_id range=601060 -> 601063
# Processed 84868/84974 new rows | completed batches 21217/21244 | last batch size=4 | gml_id range=601064 -> 601067
# Processed 84872/84974 new rows | completed batches 21218/21244 | last batch size=4 | gml_id range=601068 -> 601071
# Processed 84876/84974 new rows | completed batches 21219/21244 | last batch size=4 | gml_id range=601072 -> 601075
# Processed 84880/84974 new rows | completed batches 21220/21244 | last batch size=4 | gml_id range=601076 -> 601079
# Processed 84884/84974 new rows | completed batches 21221/21244 | last batch size=4 | gml_id range=601080 -> 601083
# Processed 84888/84974 new rows | completed batches 21222/21244 | last batch size=4 | gml_id range=601092 -> 601095
# Processed 84892/84974 new rows | completed batches 21223/21244 | last batch size=4 | gml_id range=601096 -> 601099
# Processed 84896/84974 new rows | completed batches 21224/21244 | last batch size=4 | gml_id range=601084 -> 601087
# Processed 84900/84974 new rows | completed batches 21225/21244 | last batch size=4 | gml_id range=601088 -> 601091
# Checkpoint saved with 100 new rows
# Processed 84904/84974 new rows | completed batches 21226/21244 | last batch size=4 | gml_id range=601100 -> 601103
# Processed 84908/84974 new rows | completed batches 21227/21244 | last batch size=4 | gml_id range=601112 -> 601115
# Processed 84912/84974 new rows | completed batches 21228/21244 | last batch size=4 | gml_id range=601108 -> 601111
# Processed 84916/84974 new rows | completed batches 21229/21244 | last batch size=4 | gml_id range=601104 -> 601107
# Processed 84920/84974 new rows | completed batches 21230/21244 | last batch size=4 | gml_id range=601116 -> 601119
# Processed 84924/84974 new rows | completed batches 21231/21244 | last batch size=4 | gml_id range=601120 -> 601123
# Processed 84928/84974 new rows | completed batches 21232/21244 | last batch size=4 | gml_id range=601128 -> 601131
# Processed 84932/84974 new rows | completed batches 21233/21244 | last batch size=4 | gml_id range=601124 -> 601127
# Processed 84936/84974 new rows | completed batches 21234/21244 | last batch size=4 | gml_id range=601136 -> 601139
# Processed 84940/84974 new rows | completed batches 21235/21244 | last batch size=4 | gml_id range=601132 -> 601135
# Processed 84944/84974 new rows | completed batches 21236/21244 | last batch size=4 | gml_id range=601144 -> 601147
# Processed 84948/84974 new rows | completed batches 21237/21244 | last batch size=4 | gml_id range=601148 -> 601151
# Processed 84952/84974 new rows | completed batches 21238/21244 | last batch size=4 | gml_id range=601152 -> 601155
# Processed 84956/84974 new rows | completed batches 21239/21244 | last batch size=4 | gml_id range=601140 -> 601143
# Processed 84960/84974 new rows | completed batches 21240/21244 | last batch size=4 | gml_id range=601156 -> 601159
# Processed 84964/84974 new rows | completed batches 21241/21244 | last batch size=4 | gml_id range=601160 -> 601163
# Processed 84966/84974 new rows | completed batches 21242/21244 | last batch size=2 | gml_id range=601172 -> 601173
# Processed 84970/84974 new rows | completed batches 21243/21244 | last batch size=4 | gml_id range=601164 -> 601167
# Processed 84974/84974 new rows | completed batches 21244/21244 | last batch size=4 | gml_id range=601168 -> 601171
# Final checkpoint saved.
