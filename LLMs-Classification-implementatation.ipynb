# %%
import geopandas as gpd

pois = r"Areas-of-interest-POIs\OSM-POIs-modified.gpkg"

# Load the POI layer
pois = gpd.read_file(pois)

print(f"Loaded {len(pois)} POIs")
# Out:
# Loaded 86542 POIs

# %%
pois.head()
# Out:
#          id                             email  \
# 0  23654979                              None
# 1  23657656          goslar@jugendherberge.de
# 2  23657903  hankensbuettel@jugendherberge.de
# 3  29683760                              None
# 4  29683806                              None
#
#                                name                            website  \
# 0          Jugendhotel "Drei Bären"                               None
# 1         DJH Jugendherberge Goslar  https://goslar.jugendherberge.de/
# 2  DJH Jugendherberge Hankensbüttel  https://www.jugendherberge.de/299
# 3                              None                               None
# 4                              None                               None
#
#   amenity building  shop      tourism information  \
# 0    None     None  None       hostel        None
# 1    None     None  None       hostel        None
# 2    None     None  None       hostel        None
# 3    None     None  None  information   guidepost
# 4    None     None  None  information   guidepost
#
#                                        addr:full  \
# 0  Auf der Rose, 11, Clausthal-Zellerfeld, 38707
# 1        Rammelsberger Straße, 25, Goslar, 38644
# 2         Helmrichsweg, 24, Hankensbüttel, 29386
# 3                                           None
# 4                                           None
#
#                                          tags_search  \
# 0  addr suburb altenau schulenberg im oberharz ch...
# 1  beds 163 business conference rooms capacity be...
# 2  beds 156 business conference rooms capacity be...
# 3                                               None
# 4                                 ele 837 hiking yes
#
#                        additional_information                   geometry
# 0                                        None  POINT (10.44708 51.79586)
# 1              internet_access: wlan;terminal  POINT (10.41911 51.89897)
# 2  internet_access: wlan; guest_house: hostel  POINT (10.60845 52.72488)
# 3                                        None   POINT (10.57783 51.7821)
# 4                                        None   POINT (10.57268 51.7765)

# %%
pois.columns
# Out:
# Index(['id', 'email', 'name', 'website', 'amenity', 'building', 'shop',
#        'tourism', 'information', 'addr:full', 'tags_search',
#        'additional_information', 'geometry'],
#       dtype='object')

# %%
import pandas as pd

def is_missing(x) -> bool:
    return (
        x is None
        or pd.isna(x)
        or (isinstance(x, str) and x.strip() == "")
    )

def row_to_sentence(row) -> str:
    parts = []

    # Name
    if not is_missing(row.get("name")):
        parts.append(f"{row['name']}.")

    # Contact / web
    contact_bits = []
    if not is_missing(row.get("website")):
        contact_bits.append(f"Website: {row['website']}")
    if not is_missing(row.get("email")):
        contact_bits.append(f"Email: {row['email']}")
    if contact_bits:
        parts.append("; ".join(contact_bits) + ".")

    # Place type / function
    type_bits = []
    for col, label in [
        ("amenity", "Amenity"),
        ("building", "Building"),
        ("shop", "Shop"),
        ("tourism", "Tourism"),
        ("information", "Information"),
    ]:
        v = row.get(col)
        if not is_missing(v):
            type_bits.append(f"{label}: {v}")

    if type_bits:
        parts.append("; ".join(type_bits) + ".")

    # Address
    if not is_missing(row.get("addr:full")):
        parts.append(f"Address: {row['addr:full']}.")

    # Additional free-text info (column typo preserved)
    if not is_missing(row.get("additional_informatio")):
        parts.append(f"Additional information: {row['additional_informatio']}.")

    # Tags / search text
    if not is_missing(row.get("tags_search")):
        parts.append(f"Additional tags: {row['tags_search']}.")

    return " ".join(parts)

# usage for pois_sample
pois["sentence"] = pois.apply(row_to_sentence, axis=1)

# %%
pois.head()
# Out:
#          id                             email  \
# 0  23654979                              None
# 1  23657656          goslar@jugendherberge.de
# 2  23657903  hankensbuettel@jugendherberge.de
# 3  29683760                              None
# 4  29683806                              None
#
#                                name                            website  \
# 0          Jugendhotel "Drei Bären"                               None
# 1         DJH Jugendherberge Goslar  https://goslar.jugendherberge.de/
# 2  DJH Jugendherberge Hankensbüttel  https://www.jugendherberge.de/299
# 3                              None                               None
# 4                              None                               None
#
#   amenity building  shop      tourism information  \
# 0    None     None  None       hostel        None
# 1    None     None  None       hostel        None
# 2    None     None  None       hostel        None
# 3    None     None  None  information   guidepost
# 4    None     None  None  information   guidepost
#
#                                        addr:full  \
# 0  Auf der Rose, 11, Clausthal-Zellerfeld, 38707
# 1        Rammelsberger Straße, 25, Goslar, 38644
# 2         Helmrichsweg, 24, Hankensbüttel, 29386
# 3                                           None
# 4                                           None
#
#                                          tags_search  \
# 0  addr suburb altenau schulenberg im oberharz ch...
# 1  beds 163 business conference rooms capacity be...
# 2  beds 156 business conference rooms capacity be...
# 3                                               None
# 4                                 ele 837 hiking yes
#
#                        additional_information                   geometry  \
# 0                                        None  POINT (10.44708 51.79586)
# 1              internet_access: wlan;terminal  POINT (10.41911 51.89897)
# 2  internet_access: wlan; guest_house: hostel  POINT (10.60845 52.72488)
# 3                                        None   POINT (10.57783 51.7821)
# 4                                        None   POINT (10.57268 51.7765)
#
#                                             sentence
# 0  Jugendhotel "Drei Bären". Tourism: hostel. Add...
# 1  DJH Jugendherberge Goslar. Website: https://go...
# 2  DJH Jugendherberge Hankensbüttel. Website: htt...
# 3      Tourism: information; Information: guidepost.
# 4  Tourism: information; Information: guidepost. ...

# %%
import json
import time
import re
import requests
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

ENV_PATH = Path("Areas-of-interest-POIs") / ".env"
load_dotenv(dotenv_path=ENV_PATH)

TU_TOKEN = os.getenv("TU_KI_TOOLBOX_TOKEN")

if not TU_TOKEN:
    raise RuntimeError(
        "Missing TU_KI_TOOLBOX_TOKEN. "
        "Check Areas-of-interest-POIs/.env"
    )

API_URL = "https://ki-toolbox.tu-braunschweig.de/api/v1/chat/send"
MODEL = "gpt-5.2-2025-12-11"

# %%
TARGET_LABELS = [
    "work",
    "education_university",
    "education_school",
    "education_childcare",
    "errands_essential",
    "retail_non_daily",
    "leisure",
]

SYSTEM_PROMPT = """
ROLE
You are a POI (place/building) interpreter and classifier.

Your job is to infer what a place most likely is from a short OSM-derived text snippet
and classify it in TWO WAYS:
1) MiD 2023 trip-purpose–based activity labels (visitor intent)
2) A Bosserhof-based building-use class for capacity / volume redistribution

The Bosserhof class is used to estimate intensity (employees / floor area)
and MUST therefore reflect the dominant functional use of the BUILDING.

IMPORTANT SCOPE RESTRICTION (CRITICAL)
This task is about CLASSIFYING BUILDINGS OR BUILDING-LIKE PLACES ONLY.

- If the described place is NOT a building or not a place people enter/use as a destination,
  you MUST return:
    - "mid_labels": []
    - "bosserhof_class": []
- Do NOT assign any class to pure outdoor objects, infrastructure, or non-living POIs.

INTERNET & VERIFICATION (ALLOWED AND ENCOURAGED)
You MAY use internet resources (web search, maps, official websites) to:
- Verify what the place actually is
- Resolve ambiguous names or tags
- Confirm whether the POI represents an enterable building
- Identify the dominant functional use of the building
Use verification especially when assigning a SPECIFIC Bosserhof class.

INPUT
You will receive ONE short text describing a place. It may contain:
- Name, address, city
- OSM tags: amenity=*, shop=*, office=*, leisure=*, tourism=*, building=*, landuse=*
- Free-form keywords (German/English): “Gymnasium”, “Kita”, “Praxis”, “Rathaus”, “Universität”, etc.

────────────────────────────────────
PART A — MiD 2023 VISITOR-PURPOSE LABELS
────────────────────────────────────

ALLOWED MiD LABELS
- work
- education_university
- education_school
- education_childcare
- errands_essential
- retail_non_daily
- leisure

CORE MiD PRINCIPLE
Classify by VISITOR INTENT to a BUILDING:
What do people primarily go there FOR?

IMPORTANT EXTENSION — WORK IS UBIQUITOUS
Paid work happens in most building-based activities.

Therefore:
- Assign "work" whenever the building clearly employs people on-site
- "work" is NOT exclusive to offices or industry
- "work" is a parallel activity layer

Examples:
- Supermarket → errands_essential + work
- Restaurant → leisure + work
- School → education_school + work

If there is NO clear building-related visitor activity, return mid_labels = [].

────────────────────────────────────
PART B — BOSSERHOF BUILDING-USE CLASS
────────────────────────────────────

Assign EXACTLY ONE Bosserhof class that best represents
the DOMINANT FUNCTION of the BUILDING for capacity estimation.

If no Bosserhof class clearly applies, return:
- "bosserhof_class": []

ALLOWED BOSSERHOF CLASSES

Transport
- Transport-related buildings with operational staff (depots, logistics terminals)
Exclude: stops, platforms, tracks

Industrie_Produktion
- Industrial production facilities
- Highly machine-/material-intensive plants
- Warehouses, logistics halls, large storage (Ballen, Lager, Bauhof)

Handwerk_Gewerbe
- Handwerksbetriebe
- Small-scale production and repair workshops
- Handwerkerhöfe

Dienstleistung_Buero
- Normal offices
- Large open-plan offices (Großraumbüro)
- Company administration buildings

Dienstleistung_Unternehmensbezogen
- Legal, tax, consulting, advertising
- Publishing, IT services, engineering offices
- Steueramt, Verwaltung mit primär interner Nutzung

Dienstleistung_Publikumsorientiert
- Arztpraxen, medizinische centers
- Beratungsstellen, customer service centers
- Copy shops, service counters

Hotel
- Hotels, hostels, guesthouses
Exclude: campsites

Hotel_Konferenz
- Hotels with significant conference / seminar facilities

Gastronomie
- Restaurants, cafes, bars, canteens

Kfz_Handel_Service
- Car dealerships
- Automotive and electrotechnical repair
- Customer service workshops
- Zulieferbetriebe für Autohäuser

Handel_Grosshandel
- Wholesale trade buildings

Handel_Einzelhandel_Klein
- Small-scale retail
- Discount markets, neighborhood shops

Handel_Einzelhandel_Gross
- Large-scale retail:
  - Baumarkt
  - Möbelmarkt
  - Verbrauchermarkt
  - Einkaufszentrum
  - SB-Warenhaus
  - Waren-/Kaufhaus
  - Factory Outlet Center

Gemeinbedarf
- Schools
- Universities
- Research institutes
- Kindergartens
- Hospitals
- Elderly care homes (Altenheime)

Kultur_Freizeit_Sport
- Cinemas (including Großkino)
- Theaters, music halls
- Discotheques, spas, Erlebnisbäder
- Arenas, large event venues
- Fitness, wellness centers
Exclude: parks, outdoor attractions without buildings

────────────────────────────────────
CRITICAL EXCLUSIONS (FOR BOTH PARTS)
────────────────────────────────────

If the place is primarily any of the following, DO NOT ASSIGN ANY CLASS:

- Outdoor or object-like POIs:
  * bench, viewpoint, artwork, memorial
- Transport infrastructure:
  * bus_stop, tram_stop, railway_platform
- Land-use only:
  * campsite, picnic_site, park, forest, meadow
- Tourism objects without an enterable building

Return:
- mid_labels: []
- bosserhof_class: []

────────────────────────────────────
UNCERTAINTY RULE
────────────────────────────────────

If, even after verification, the building function remains unclear
or does not match any Bosserhof class reliably:
- Assign MiD labels if possible
- Set "bosserhof_class": []

────────────────────────────────────
OUTPUT FORMAT (STRICT JSON ONLY)
────────────────────────────────────

{
  "interpreted_type": "<plain-English description of what the place most likely is>",
  "mid_labels": ["<zero or more MiD labels>"],
  "bosserhof_class": "<one Bosserhof class or null>",
  "reason": "<max 200 words. Explain both classifications, referencing OSM tags, keywords, and any verification used. Explicitly justify the Bosserhof choice or why it is null.>"
}
""".strip()

# %%
# -----------------------------
# MiD labels (STRICT)
# -----------------------------
TARGET_MID_LABELS = {
    "work",
    "education_university",
    "education_school",
    "education_childcare",
    "errands_essential",
    "retail_non_daily",
    "leisure",
}

# -----------------------------
# JSON extraction
# -----------------------------
def extract_first_json_object(text: str) -> dict:
    """
    Extract the first JSON object from model output.
    """
    m = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found in output.")
    return json.loads(m.group(0))


# -----------------------------
# Validation (PROMPT-ALIGNED)
# -----------------------------
def validate(obj: dict):
    # ---- Required keys ----
    if "interpreted_type" not in obj or not isinstance(obj["interpreted_type"], str):
        raise ValueError("Missing or invalid interpreted_type")

    if "mid_labels" not in obj or not isinstance(obj["mid_labels"], list):
        raise ValueError("mid_labels must be a list")

    if "bosserhof_class" not in obj:
        raise ValueError("Missing bosserhof_class")

    if "reason" not in obj or not isinstance(obj["reason"], str):
        raise ValueError("Missing or invalid reason")

    # ---- Validate MiD labels ----
    for lab in obj["mid_labels"]:
        if lab not in TARGET_MID_LABELS:
            raise ValueError(f"Invalid MiD label: {lab}")

    # ---- Validate Bosserhof class ----
    bc = obj["bosserhof_class"]

    # Allowed: no assignment
    if bc is None or bc == []:
        pass

    # Allowed: any non-empty string (granular OR fallback)
    elif isinstance(bc, str) and bc.strip():
        pass

    else:
        raise ValueError("bosserhof_class must be a non-empty string, [] or None")

    # ---- Consistency rule ----
    # If there is no building-related visitor activity,
    # there must not be a Bosserhof assignment
    if len(obj["mid_labels"]) == 0 and bc not in (None, []):
        raise ValueError(
            "bosserhof_class assigned but mid_labels is empty — inconsistent"
        )

# %%
def call_tu_llm(
    user_input: str,
    max_retries=3,
    backoff_sec=2.0,
    debug=False,
) -> str:

    headers = {
        "Authorization": f"Bearer {TU_TOKEN}",
        "Accept": "application/json",
        "Content-Type": "application/json",
    }

    payload = {
        "thread": None,
        "prompt": user_input,              # <-- ONLY the sentence goes here
        "model": MODEL,
        "customInstructions": SYSTEM_PROMPT,  # <-- full prompt lives here
        "hideCustomInstructions": True,
    }

    last_err = None

    for attempt in range(1, max_retries + 1):
        try:
            r = requests.post(
                API_URL,
                headers=headers,
                json=payload,
                stream=True,
                timeout=60,
            )
            r.raise_for_status()

            full_text = ""

            for line in r.iter_lines(decode_unicode=True):
                if not line:
                    continue
                try:
                    event = json.loads(line)
                except json.JSONDecodeError:
                    continue

                if event.get("type") == "chunk":
                    full_text += event.get("content", "")
                elif event.get("type") == "done":
                    if "response" in event:
                        full_text = event["response"]
                    break

            return full_text

        except Exception as e:
            last_err = e
            if debug:
                print(f"Attempt {attempt} failed: {e}")
            time.sleep(backoff_sec * attempt)

    raise RuntimeError(f"TU LLM call failed: {last_err}")

# %%
def predict_from_sentence(gml_id, sentence, debug=False):
    gml_id = gml_id.item() if hasattr(gml_id, "item") else gml_id
    sentence = "" if sentence is None else str(sentence)

    try:
        raw = call_tu_llm(sentence, debug=debug)
        obj = extract_first_json_object(raw)
        validate(obj)

        return {
            "gml_id": gml_id,
            "interpreted_type": obj["interpreted_type"],
            "mid_labels": obj["mid_labels"],
            "bosserhof_class": obj["bosserhof_class"],
            "short_reason": obj["reason"][:100],
        }

    except Exception as e:
        return {
            "gml_id": gml_id,
            "interpreted_type": "error",
            "mid_labels": [],
            "bosserhof_class": None,
            "short_reason": f"Failed: {e}",
        }

# %%
def classify_first_n(pois_df: pd.DataFrame, n=50, debug=False) -> pd.DataFrame:
    df = pois_df.head(n).copy()
    results = []

    for i, row in df.iterrows():
        gml_id = row.get("gml_id", row.get("id", i))
        sentence = row.get("sentence", "")

        res = predict_from_sentence(
            gml_id=gml_id,
            sentence=sentence,
            debug=debug,
        )

        results.append(res)
        print(f"Done {len(results)}/{len(df)}")

    return df.reset_index(drop=True).join(
        pd.DataFrame(results), rsuffix="_pred"
    )

# %%
# pick 30 random rows (different each run)
sample_df = pois.sample(n=50)

# classify them once
out5 = classify_first_n(sample_df, debug=False)
# Out:
# Done 1/50
# Done 2/50
# Done 3/50
# Done 4/50
# Done 5/50
# Done 6/50
# Done 7/50
# Done 8/50
# Done 9/50
# Done 10/50
# Done 11/50
# Done 12/50
# Done 13/50
# Done 14/50
# Done 15/50
# Done 16/50
# Done 17/50
# Done 18/50
# Done 19/50
# Done 20/50
# Done 21/50
# Done 22/50
# Done 23/50
# Done 24/50
# Done 25/50
# Done 26/50
# Done 27/50
# Done 28/50
# Done 29/50
# Done 30/50
# Done 31/50
# Done 32/50
# Done 33/50
# Done 34/50
# Done 35/50
# Done 36/50
# Done 37/50
# Done 38/50
# Done 39/50
# Done 40/50
# Done 41/50
# Done 42/50
# Done 43/50
# Done 44/50
# Done 45/50
# Done 46/50
# Done 47/50
# Done 48/50
# Done 49/50
# Done 50/50

# %%
out5.columns
# Out:
# Index(['id', 'email', 'name', 'website', 'amenity', 'building', 'shop',
#        'tourism', 'information', 'addr:full', 'tags_search',
#        'additional_information', 'geometry', 'sentence', 'gml_id',
#        'interpreted_type', 'mid_labels', 'bosserhof_class', 'short_reason'],
#       dtype='object')

# %%
# out5[['name','labels']][:50]
out5.head(50)
# Out:
#              id                      email  \
# 0    6795190362                       None
# 1      38433269                       None
# 2    1608496446                       None
# 3    1861373076                       None
# 4     549913217  aph-landhaus-ahlum@gmx.de
# 5     905951996                       None
# 6    3252489872                       None
# 7     889490721                       None
# 8    6253461000                       None
# 9      37791838                       None
# 10    210804948                       None
# 11   3496451378                       None
# 12   1917404780                       None
# 13    414232234                       None
# 14    390408398                       None
# 15    469261990                       None
# 16   6918250866                       None
# 17    945315407                       None
# 18  11898306546                       None
# 19   1002099408                       None
# 20  10914388075                       None
# 21   7603114205                       None
# 22    211287153                       None
# 23  12094757231                       None
# 24   2701506755                       None
# 25  12351147707                       None
# 26    413550869                       None
# 27    276289022                       None
# 28    292401552                       None
# 29   2828731805                       None
# 30   1348006030                       None
# 31  11181448789                       None
# 32   1346762242                       None
# 33   1450830251                       None
# 34   1017440028                       None
# 35   1027539268                       None
# 36    411061592                       None
# 37    191221788                       None
# 38   1666349346                       None
# 39    272476514                       None
# 40    403464483                       None
# 41  12223014685                       None
# 42   4940067975                       None
# 43   1060293328                       None
# 44   4737938722                       None
# 45   1448316538                       None
# 46    201905322                       None
# 47    234071811                       None
# 48  55809623421                       None
# 49   7203508728                       None
#
#                                             name  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4   Altenpflegeheim Landhaus Ahlum Hübscher GmbH
# 5                                           None
# 6                                      Wegweiser
# 7                                   Farbe & Mehr
# 8                                           None
# 9                      Hauptschule Sophienstraße
# 10                                          None
# 11                         Südheide Gifhorn GmbH
# 12                                          None
# 13                              Nerina Bellinato
# 14                            Kunsthandwerkerhof
# 15                              Buchenberg-Hütte
# 16                                          None
# 17                                          None
# 18                                          None
# 19                                          None
# 20                           Döner & Pizza Treff
# 21                                          None
# 22                                        Masala
# 23                                          None
# 24                                          None
# 25                          Lotto-Toto Truebacco
# 26                              Zur Mönchsklause
# 27                                 Deutsche Post
# 28                                          None
# 29                                          None
# 30                                          None
# 31                                          None
# 32                                          None
# 33                                          None
# 34                                          None
# 35                                          None
# 36                                          None
# 37                                          None
# 38                           Eicklinger Apotheke
# 39                                          None
# 40                                          None
# 41                           Amazon Abholstation
# 42                                          None
# 43                                          None
# 44                                          None
# 45                                          None
# 46                                          None
# 47                                           IAC
# 48                      Campingplatz Paradiessee
# 49                             Nationalpark Harz
#
#                                       website          amenity    building  \
# 0                                        None             None        None
# 1                                        None       grave_yard        None
# 2                                        None  bicycle_parking        None
# 3                                        None     waste_basket        None
# 4          https://www.aph-landhaus-ahlum.de/  social_facility         yes
# 5                                        None          parking        None
# 6                                        None             None        None
# 7                                        None             None        None
# 8                                        None     waste_basket        None
# 9                                        None           school         yes
# 10                                       None          parking        None
# 11                                       None             None        None
# 12                                       None             None        None
# 13          http://www.tierarzt-wesendorf.de/       veterinary        None
# 14                                       None             None        None
# 15                                       None          shelter        None
# 16                                       None  bicycle_parking        None
# 17                                       None        recycling        None
# 18                                       None            bench        None
# 19                                       None          parking        None
# 20             https://doener-pizza-treff.de/        fast_food        None
# 21                                       None            bench        None
# 22                                       None       restaurant  apartments
# 23                                       None            bench        None
# 24                                       None    hunting_stand        None
# 25                                       None             None        None
# 26  http://www.moenchs-klause-badenhausen.de/       restaurant        None
# 27                                       None         post_box        None
# 28                                       None  bicycle_parking        None
# 29                                       None            bench        None
# 30                                       None          parking        None
# 31                                       None     waste_basket        None
# 32                                       None    parking_space        None
# 33                                       None    parking_space        None
# 34                                       None          parking        None
# 35                                       None          parking        None
# 36                                       None             None        None
# 37                                       None    parking_space        None
# 38                                       None         pharmacy        None
# 39                                       None          parking        None
# 40                                       None    parking_space        None
# 41                                       None             None        None
# 42                                       None  bicycle_parking        None
# 43                                       None          parking        None
# 44                                       None  bicycle_parking        None
# 45                                       None  bicycle_parking         yes
# 46                                       None    parking_space        None
# 47                                       None          parking        None
# 48              http://camping-paradiessee.de             None        None
# 49                                       None             None        None
#
#                    shop      tourism information  \
# 0                  None  information   guidepost
# 1                  None         None        None
# 2                  None         None        None
# 3                  None         None        None
# 4                  None         None        None
# 5                  None         None        None
# 6                  None  information         map
# 7   interior_decoration         None        None
# 8                  None         None        None
# 9                  None         None        None
# 10                 None         None        None
# 11                 None  information   guidepost
# 12                 None  information         map
# 13                 None         None        None
# 14                 None      artwork        None
# 15                 None         None        None
# 16                 None         None        None
# 17                 None         None        None
# 18                 None         None        None
# 19                 None         None        None
# 20                 None         None        None
# 21                 None         None        None
# 22                 None         None        None
# 23                 None         None        None
# 24                 None         None        None
# 25                kiosk         None        None
# 26                 None         None        None
# 27                 None         None        None
# 28                 None         None        None
# 29                 None         None        None
# 30                 None         None        None
# 31                 None         None        None
# 32                 None         None        None
# 33                 None         None        None
# 34                 None         None        None
# 35                 None         None        None
# 36                 None  information   guidepost
# 37                 None         None        None
# 38                 None         None        None
# 39                 None         None        None
# 40                 None         None        None
# 41              outpost         None        None
# 42                 None         None        None
# 43                 None         None        None
# 44                 None         None        None
# 45                 None         None        None
# 46                 None         None        None
# 47                 None         None        None
# 48                 None    camp_site        None
# 49                 None  information   guidepost
#
#                                        addr:full  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4          Adenemer Weg, 25, Wolfenbüttel, 38302
# 5                                           None
# 6                                           None
# 7   Fallersleber Straße, 41, Braunschweig, 38100
# 8                                           None
# 9                                           None
# 10                                          None
# 11                                          None
# 12                                          None
# 13            Celler Straße, 1, Wesendorf, 29392
# 14                                          None
# 15                                          None
# 16                                          None
# 17                                          None
# 18                                          None
# 19                                          None
# 20         Hauptstraße, 13, Müden (Aller), 38539
# 21                                          None
# 22     Braunschweiger Straße, 93, Gifhorn, 38518
# 23                                          None
# 24                                          None
# 25         Am Wasserwerk, 3, Wolfenbüttel, 38304
# 26       Thüringer Straße, 295, Bad Grund, 37539
# 27                                          None
# 28                                          None
# 29                                          None
# 30                                          None
# 31                                          None
# 32                                          None
# 33                                          None
# 34                                          None
# 35                                          None
# 36                                          None
# 37                                          None
# 38                                          None
# 39                                          None
# 40                                          None
# 41         An der Bundesstr., 3, Burgdorf, 31303
# 42                                          None
# 43                                          None
# 44                                          None
# 45                                          None
# 46                                          None
# 47                                          None
# 48                        Kieswerk, 1, Wendeburg
# 49                                          None
#
#                                           tags_search  \
# 0                                                None
# 1                                                None
# 2             access yes capacity 7 covered no fee no
# 3                                                None
# 4        addr suburb ahlum social facility for senior
# 5                                          capacity 8
# 6            hiking yes map size site map type scheme
# 7                                                None
# 8                                         waste trash
# 9                               check date 2024 04 11
# 10                                               None
# 11  description radwanderregion südheide gifhorn n...
# 12                      map size city map type street
# 13                                               None
# 14  building colour yellow building material wood ...
# 15                               shelter type lean to
# 16  capacity 2 capacity note 2 stands per capacity...
# 17  location overground recycling clothes yes recy...
# 18                                       backrest yes
# 19                                               None
# 20           cuisine kebab pizza turkish takeaway yes
# 21                         backrest yes material wood
# 22  cuisine indian diet vegetarian yes drive throu...
# 23                                       backrest yes
# 24                                               None
# 25  payment cards yes payment cash yes tickets pub...
# 26  addr suburb badenhausen cuisine regional note ...
# 27  check date 2025 05 29 collection times mo sa 0...
# 28               covered no created by potlatch 0 10b
# 29  backrest yes check date 2021 01 01 colour brow...
# 30                          orientation perpendicular
# 31                                        waste trash
# 32                                               None
# 33                                               None
# 34               capacity 6 orientation perpendicular
# 35                              surface paving stones
# 36                                               None
# 37  capacity 1 covered no lit limited supervised n...
# 38             healthcare pharmacy wheelchair limited
# 39                                               None
# 40                                               None
# 41                                               None
# 42                             capacity 13 covered no
# 43                                     access private
# 44                                               None
# 45                                          access no
# 46                                            level 3
# 47                                          access no
# 48  barrier fence fence type chain link type multi...
# 49  description kaiserweg 5 5km oderbrück 35e 2 7k...
#
#            additional_information  \
# 0                            None
# 1             religion: christian
# 2         bicycle_parking: stands
# 3                            None
# 4   social_facility: nursing_home
# 5                            None
# 6                            None
# 7                            None
# 8                            None
# 9                            None
# 10                           None
# 11                   bicycle: yes
# 12                           None
# 13                           None
# 14                           None
# 15                  fireplace: no
# 16        bicycle_parking: stands
# 17                           None
# 18                           None
# 19                           None
# 20                           None
# 21                           None
# 22                           None
# 23                           None
# 24                           None
# 25                           None
# 26                           None
# 27                           None
# 28        bicycle_parking: stands
# 29                           None
# 30           parking: street_side
# 31                           None
# 32                           None
# 33                           None
# 34               parking: surface
# 35               parking: surface
# 36                           None
# 37               parking: surface
# 38                           None
# 39                           None
# 40                           None
# 41                           None
# 42        bicycle_parking: stands
# 43               parking: surface
# 44                           None
# 45          bicycle_parking: shed
# 46                           None
# 47               parking: surface
# 48                           None
# 49                           None
#
#                                              geometry  \
# 0                           POINT (10.65482 51.66263)
# 1   POLYGON ((10.90959 52.5475, 10.91003 52.54759,...
# 2                           POINT (10.56895 52.30134)
# 3                           POINT (10.53609 52.38544)
# 4   POLYGON ((10.59988 52.17098, 10.59993 52.17109...
# 5   POLYGON ((10.26787 52.4571, 10.26814 52.45738,...
# 6                           POINT (10.61941 52.73268)
# 7                           POINT (10.52862 52.26875)
# 8                           POINT (10.63193 52.51087)
# 9   POLYGON ((10.50751 52.25731, 10.50754 52.25727...
# 10  POLYGON ((10.12549 51.89264, 10.12544 51.8927,...
# 11                          POINT (10.75565 52.75603)
# 12                            POINT (10.535 52.62122)
# 13                          POINT (10.53386 52.59297)
# 14  POLYGON ((10.33251 51.81766, 10.33243 51.81769...
# 15                          POINT (10.34615 52.30157)
# 16                          POINT (10.00034 51.70768)
# 17                          POINT (10.43505 51.92313)
# 18                          POINT (10.13362 52.01349)
# 19  POLYGON ((10.7216 52.36216, 10.7225 52.36222, ...
# 20                          POINT (10.35797 52.52652)
# 21                           POINT (10.3702 51.97175)
# 22  POLYGON ((10.54349 52.47166, 10.54351 52.47166...
# 23                          POINT (10.37676 52.32565)
# 24                          POINT (10.34583 51.84024)
# 25                          POINT (10.54366 52.15033)
# 26                          POINT (10.21194 51.76461)
# 27                          POINT (10.00941 52.45556)
# 28                          POINT (10.34612 52.47652)
# 29                          POINT (10.54993 52.48733)
# 30  POLYGON ((10.50754 52.29376, 10.50754 52.29377...
# 31                          POINT (10.75742 52.41448)
# 32  POLYGON ((10.3427 51.65697, 10.34272 51.65693,...
# 33  POLYGON ((10.00041 51.69935, 10.00044 51.69937...
# 34  POLYGON ((9.99612 51.69761, 9.99592 51.69763, ...
# 35  POLYGON ((9.99794 51.6938, 9.99799 51.69385, 9...
# 36                          POINT (10.32177 51.84781)
# 37  POLYGON ((10.53501 52.48676, 10.53502 52.48672...
# 38                          POINT (10.18546 52.55268)
# 39  POLYGON ((10.76801 52.14836, 10.76841 52.14832...
# 40  POLYGON ((10.53902 52.46167, 10.53898 52.46166...
# 41                          POINT (10.02485 52.51878)
# 42                          POINT (10.71641 52.42399)
# 43  POLYGON ((10.57231 52.16597, 10.5724 52.16563,...
# 44                           POINT (10.5582 52.31607)
# 45  POLYGON ((10.49843 52.28887, 10.49849 52.28889...
# 46  POLYGON ((10.78892 52.42262, 10.78888 52.42262...
# 47  POLYGON ((10.05767 52.56029, 10.05717 52.55863...
# 48  MULTILINESTRING ((10.32602 52.33728, 10.32614 ...
# 49                          POINT (10.55966 51.81636)
#
#                                              sentence       gml_id  \
# 0       Tourism: information; Information: guidepost.   6795190362
# 1                                Amenity: grave_yard.     38433269
# 2   Amenity: bicycle_parking. Additional tags: acc...   1608496446
# 3                              Amenity: waste_basket.   1861373076
# 4   Altenpflegeheim Landhaus Ahlum Hübscher GmbH. ...    549913217
# 5      Amenity: parking. Additional tags: capacity 8.    905951996
# 6   Wegweiser. Tourism: information; Information: ...   3252489872
# 7   Farbe & Mehr. Shop: interior_decoration. Addre...    889490721
# 8   Amenity: waste_basket. Additional tags: waste ...   6253461000
# 9   Hauptschule Sophienstraße. Amenity: school; Bu...     37791838
# 10                                  Amenity: parking.    210804948
# 11  Südheide Gifhorn GmbH. Tourism: information; I...   3496451378
# 12  Tourism: information; Information: map. Additi...   1917404780
# 13  Nerina Bellinato. Website: http://www.tierarzt...    414232234
# 14  Kunsthandwerkerhof. Tourism: artwork. Addition...    390408398
# 15  Buchenberg-Hütte. Amenity: shelter. Additional...    469261990
# 16  Amenity: bicycle_parking. Additional tags: cap...   6918250866
# 17  Amenity: recycling. Additional tags: location ...    945315407
# 18     Amenity: bench. Additional tags: backrest yes.  11898306546
# 19                                  Amenity: parking.   1002099408
# 20  Döner & Pizza Treff. Website: https://doener-p...  10914388075
# 21  Amenity: bench. Additional tags: backrest yes ...   7603114205
# 22  Masala. Amenity: restaurant; Building: apartme...    211287153
# 23     Amenity: bench. Additional tags: backrest yes.  12094757231
# 24                            Amenity: hunting_stand.   2701506755
# 25  Lotto-Toto Truebacco. Shop: kiosk. Address: Am...  12351147707
# 26  Zur Mönchsklause. Website: http://www.moenchs-...    413550869
# 27  Deutsche Post. Amenity: post_box. Additional t...    276289022
# 28  Amenity: bicycle_parking. Additional tags: cov...    292401552
# 29  Amenity: bench. Additional tags: backrest yes ...   2828731805
# 30  Amenity: parking. Additional tags: orientation...   1348006030
# 31  Amenity: waste_basket. Additional tags: waste ...  11181448789
# 32                            Amenity: parking_space.   1346762242
# 33                            Amenity: parking_space.   1450830251
# 34  Amenity: parking. Additional tags: capacity 6 ...   1017440028
# 35  Amenity: parking. Additional tags: surface pav...   1027539268
# 36      Tourism: information; Information: guidepost.    411061592
# 37  Amenity: parking_space. Additional tags: capac...    191221788
# 38  Eicklinger Apotheke. Amenity: pharmacy. Additi...   1666349346
# 39                                  Amenity: parking.    272476514
# 40                            Amenity: parking_space.    403464483
# 41  Amazon Abholstation. Shop: outpost. Address: A...  12223014685
# 42  Amenity: bicycle_parking. Additional tags: cap...   4940067975
# 43  Amenity: parking. Additional tags: access priv...   1060293328
# 44                          Amenity: bicycle_parking.   4737938722
# 45  Amenity: bicycle_parking; Building: yes. Addit...   1448316538
# 46  Amenity: parking_space. Additional tags: level 3.    201905322
# 47  IAC. Amenity: parking. Additional tags: access...    234071811
# 48  Campingplatz Paradiessee. Website: http://camp...  55809623421
# 49  Nationalpark Harz. Tourism: information; Infor...   7203508728
#
#                                      interpreted_type  \
# 0                       Tourism information guidepost
# 1                                Graveyard (cemetery)
# 2                           Bicycle parking rack/area
# 3                                        Waste basket
# 4          Altenpflegeheim (nursing home for seniors)
# 5                                         parking lot
# 6               Tourist information signpost with map
# 7                            Interior decoration shop
# 8                                        Waste basket
# 9   Hauptschule Sophienstraße (secondary school bu...
# 10                                        parking lot
# 11                      tourist information guidepost
# 12                    tourist information map display
# 13                                  Veterinary clinic
# 14           Tourism artwork (sculpture/installation)
# 15              lean-to shelter (open hiking shelter)
# 16                         bicycle parking stand/rack
# 17                        Outdoor recycling container
# 18                                              bench
# 19                                            parking
# 20    Fast food restaurant (döner and pizza takeaway)
# 21                                      outdoor bench
# 22                         Indian restaurant (Masala)
# 23                                              bench
# 24                                      hunting stand
# 25                Kiosk (Lotto-Toto and tobacco shop)
# 26  Restaurant (Zur Mönchsklause) – geschlossen fü...
# 27                                           Post box
# 28                       bicycle parking (rack/stand)
# 29                         Wooden bench with backrest
# 30                                        parking lot
# 31                           waste basket (trash bin)
# 32                                      Parking space
# 33                                      Parking space
# 34                                        Parking lot
# 35                                        parking lot
# 36                      Tourism information guidepost
# 37                                      Parking space
# 38                                           Pharmacy
# 39                                        parking lot
# 40                              Outdoor parking space
# 41  Amazon Abholstation (Amazon Outpost Paketabhol...
# 42                          uncovered bicycle parking
# 43                                private parking lot
# 44                                    bicycle parking
# 45                           Bicycle parking facility
# 46                            Parking space (level 3)
# 47          Parking area (amenity=parking, access=no)
# 48                campsite (Campingplatz Paradiessee)
# 49             Tourist guidepost in Nationalpark Harz
#
#                    mid_labels                     bosserhof_class  \
# 0                          []                                None
# 1                          []                                None
# 2                          []                                None
# 3                          []                                None
# 4                      [work]                        Gemeinbedarf
# 5                          []                                None
# 6                          []                                None
# 7    [retail_non_daily, work]           Handel_Einzelhandel_Klein
# 8                          []                                None
# 9    [education_school, work]                        Gemeinbedarf
# 10                         []                                None
# 11                         []                                None
# 12                         []                                None
# 13  [errands_essential, work]  Dienstleistung_Publikumsorientiert
# 14                         []                                None
# 15                         []                                  []
# 16                         []                                None
# 17                         []                                None
# 18                         []                                None
# 19                         []                                None
# 20            [leisure, work]                         Gastronomie
# 21                         []                                None
# 22            [leisure, work]                         Gastronomie
# 23                         []                                  []
# 24                         []                                None
# 25  [errands_essential, work]           Handel_Einzelhandel_Klein
# 26                     [work]                         Gastronomie
# 27                         []                                None
# 28                         []                                None
# 29                         []                                None
# 30                         []                                None
# 31                         []                                None
# 32                         []                                None
# 33                         []                                None
# 34                         []                                None
# 35                         []                                None
# 36                         []                                None
# 37                         []                                None
# 38  [errands_essential, work]           Handel_Einzelhandel_Klein
# 39                         []                                None
# 40                         []                                  []
# 41        [errands_essential]  Dienstleistung_Publikumsorientiert
# 42                         []                                  []
# 43                         []                                None
# 44                         []                                None
# 45                         []                                None
# 46                         []                                None
# 47                         []                                None
# 48                         []                                None
# 49                         []                                None
#
#                                          short_reason
# 0   This POI is tagged tourism=information and inf...
# 1   A grave_yard is an outdoor burial ground witho...
# 2   This is an outdoor bicycle parking facility (a...
# 3   This is a standalone waste basket (amenity=was...
# 4   The OSM tags (amenity=social_facility; buildin...
# 5   The OSM tag amenity=parking describes an outdo...
# 6   The OSM tags indicate an information point (‘t...
# 7   The OSM tag shop=interior_decoration and the n...
# 8   The POI is an outdoor waste basket (amenity=wa...
# 9   The OSM tag amenity=school and building=yes id...
# 10  The OSM tag amenity=parking indicates a surfac...
# 11  The OSM tags tourism=information and informati...
# 12  This feature is an outdoor tourism information...
# 13  The OSM tag amenity=veterinary and the website...
# 14  This POI is tagged tourism=artwork and buildin...
# 15  The OSM tags amenity=shelter and shelter_type=...
# 16  This POI is an outdoor bicycle parking facilit...
# 17  This POI is an outdoor recycling container (am...
# 18  The OSM tags (amenity=bench, backrest=yes) des...
# 19  The OSM tag amenity=parking indicates a parkin...
# 20  The OSM tag amenity=fast_food and cuisine=keba...
# 21  The OSM tag amenity=bench indicates a simple o...
# 22  The OSM tags (amenity=restaurant, cuisine=indi...
# 23  The OSM tag amenity=bench (with backrest=yes) ...
# 24  The OSM tag amenity=hunting_stand refers to a ...
# 25  The OSM tag shop=kiosk and the name “Lotto-Tot...
# 26  The OSM tag amenity=restaurant and the officia...
# 27  The OSM tag amenity=post_box indicates a stree...
# 28  This amenity=bicycle_parking tag denotes an ou...
# 29  The OSM tags describe a bench (amenity=bench) ...
# 30  This OSM snippet describes an outdoor parking ...
# 31  The OSM tags indicate an amenity=waste_basket,...
# 32  The OSM tag amenity=parking_space denotes an o...
# 33  The OSM tag amenity=parking_space indicates an...
# 34  The OSM tag amenity=parking with capacity and ...
# 35  The OSM tags (amenity=parking, surface=paving_...
# 36  The OSM tags tourism=information and informati...
# 37  The OSM tag amenity=parking_space indicates a ...
# 38  Eicklinger Apotheke is tagged amenity=pharmacy...
# 39  The OSM tag amenity=parking refers to an outdo...
# 40  The OSM tag amenity=parking_space indicates an...
# 41  The POI is an Amazon parcel pickup station (sh...
# 42  This POI is tagged amenity=bicycle_parking wit...
# 43  The feature is tagged amenity=parking with acc...
# 44  The POI is tagged amenity=bicycle_parking, ind...
# 45  The OSM tags (amenity=bicycle_parking; buildin...
# 46  The feature is tagged amenity=parking_space, i...
# 47  The OSM tags indicate an amenity=parking with ...
# 48  The POI is tagged tourism=camp_site and repres...
# 49  The OSM tags ‘tourism=information’ and ‘inform...

# %%
# optional: save
out5.to_csv("output-sample.csv", index=False)

# %%
# import requests

# HF_TOKEN = "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"

# r = requests.get(
#     "https://router.huggingface.co/v1/models",
#     headers={"Authorization": f"Bearer {HF_TOKEN}"},
#     timeout=30,
# )

# print("STATUS:", r.status_code)
# print(r.text[:500])
# r.raise_for_status()

# data = r.json()
# print("Models returned:", len(data.get("data", [])))
# for m in data.get("data", [])[:30]:
#     print(m.get("id"))

# %%
# import json, time, re, requests
# import pandas as pd

# HF_TOKEN = str(HF_TOKEN).strip()

# MODEL = "deepseek-ai/DeepSeek-R1"
# URL = "https://router.huggingface.co/v1/chat/completions"

# HEADERS = {
#     "Authorization": f"Bearer {HF_TOKEN}",
#     "Content-Type": "application/json",
# }

# # MiD 2023–aligned activity labels
# TARGET_LABELS = [
#     "work",
#     "education_university",
#     "education_school",
#     "education_childcare",
#     "errands_essential",
#     "retail_non_daily",
#     "leisure",
# ]

# SYSTEM_PROMPT = f"""
# You are a POI (place/building) interpreter and classifier.

# Infer what a place most likely is from a short OSM-derived text snippet
# and assign visitor-purpose activity classes aligned with MiD 2023
# (Hauptwegezwecke).

# Input fields:
# - gml_id
# - sentence: short place description (name, tags, keywords)

# Allowed labels:
# {TARGET_LABELS}

# Core principle:
# Classify by dominant visitor intent.

# Class definitions:
# - work: paid work destinations (offices, factories, admin, authorities)
# - education_university: university / Hochschule / campus buildings
# - education_school: primary or secondary schools
# - education_childcare: Kita / Kindergarten / daycare
# - errands_essential: necessary errands & essential supply
#   (pharmacy, doctors, bank, post, supermarket, fuel, bakery)
# - retail_non_daily: non-essential discretionary shopping
#   (clothes, electronics, furniture, malls)
# - leisure: recreation, gastronomy, culture, sports, entertainment

# Multi-label rule:
# Assign multiple labels only if clearly supported by evidence.

# Uncertainty rule:
# If function is unclear, return labels [] and interpreted_type "unknown".

# Output STRICT JSON only:
# {{
#   "gml_id": "<string or number>",
#   "interpreted_type": "<plain English description>",
#   "labels": ["<zero or more allowed labels>"],
#   "short_reason": "<max 20 words; strongest evidence from sentence>"
# }}

# Rules:
# - labels must be a JSON array
# - labels must match allowed list exactly
# - no markdown
# - no extra text
# """.strip()


# def extract_json_object(text: str) -> str:
#     text = text.strip()
#     if text.startswith("{") and text.endswith("}"):
#         return text
#     m = re.search(r"\{.*\}", text, flags=re.DOTALL)
#     if not m:
#         raise ValueError("No JSON object found in model output.")
#     return m.group(0)


# def validate(obj: dict):
#     for k in ["gml_id", "interpreted_type", "labels", "short_reason"]:
#         if k not in obj:
#             raise ValueError(f"Missing key: {k}")
#     if not isinstance(obj["labels"], list):
#         raise ValueError('"labels" must be a list.')
#     for lab in obj["labels"]:
#         if lab not in TARGET_LABELS:
#             raise ValueError(f"Invalid label: {lab}")


# def predict_from_sentence(
#     gml_id,
#     sentence,
#     max_retries=3,
#     backoff_sec=2.0,
#     debug=False,
# ):
#     gml_id = gml_id.item() if hasattr(gml_id, "item") else gml_id
#     sentence = "" if sentence is None else str(sentence)

#     messages = [
#         {"role": "system", "content": SYSTEM_PROMPT},
#         {
#             "role": "user",
#             "content": json.dumps(
#                 {
#                     "gml_id": gml_id,
#                     "sentence": sentence,
#                 },
#                 ensure_ascii=False,
#             ),
#         },
#     ]

#     payload = {
#         "model": MODEL,
#         "messages": messages,
#         "temperature": 0.2,
#         "max_tokens": 300,
#     }

#     last_err = None
#     for attempt in range(1, max_retries + 1):
#         try:
#             r = requests.post(URL, headers=HEADERS, json=payload, timeout=60)
#             r.raise_for_status()

#             content = r.json()["choices"][0]["message"]["content"]
#             obj = json.loads(extract_json_object(content))
#             validate(obj)
#             return obj

#         except Exception as e:
#             last_err = e
#             if debug:
#                 print(f"Attempt {attempt} failed: {e}")
#             time.sleep(backoff_sec * attempt)

#     return {
#         "gml_id": gml_id,
#         "interpreted_type": "error",
#         "labels": [],
#         "short_reason": f"LLM call failed: {last_err}",
#     }


# def classify_first_n(pois_sample: pd.DataFrame, n=5, debug=False) -> pd.DataFrame:
#     df = pois_sample.head(n).copy()

#     results = []
#     for idx, row in df.iterrows():
#         gml_id = row.get("gml_id", row.get("id", idx))
#         sentence = row["sentence"] if "sentence" in row else ""

#         res = predict_from_sentence(
#             gml_id=gml_id,
#             sentence=sentence,
#             debug=debug,
#         )
#         results.append(res)
#         print(f"Done {len(results)}/{len(df)}")

#     return df.reset_index(drop=True).join(
#         pd.DataFrame(results), rsuffix="_pred"
#     )

# %%
# out5 = classify_first_n(pois, n=5, debug=False)

# %%
# out5.head()
