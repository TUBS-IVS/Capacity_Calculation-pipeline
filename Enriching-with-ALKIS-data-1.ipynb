# %%
import geopandas as gpd

gdf = gpd.read_file(r"Areas-of-interest-POIs\merged_building_volumes_filtered.gpkg")

print(gdf.crs)
# Out:
# EPSG:25832

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 668291 entries, 0 to 668290
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   gml_id      668291 non-null  object
#  1   measHeight  668291 non-null  float64
#  2   function    668291 non-null  object
#  3   Stadt       668291 non-null  object
#  4   Strasse     252239 non-null  object
#  5   HausNr      252239 non-null  object
#  6   Name        6851 non-null    object
#  7   area_m2     668291 non-null  float64
#  8   volume_m3   668291 non-null  float64
#  9   has_poi     668291 non-null  bool
#  10  _cluster    668291 non-null  int64
#  11  geometry    668291 non-null  geometry
# dtypes: bool(1), float64(3), geometry(1), int64(1), object(6)
# memory usage: 56.7+ MB

# %%
import xml.etree.ElementTree as ET

tree = ET.parse(r"Areas-of-interest-POIs\BuildingFunctionTypeAdV.xml")
root = tree.getroot()

# %%
import xml.etree.ElementTree as ET
import pandas as pd

def read_adv_codelist(xml_path):
    ns = {"gml": "http://www.opengis.net/gml"}
    root = ET.parse(xml_path).getroot()

    rows = []
    for d in root.findall(".//gml:Definition", ns):
        code = None
        label_de = None
        for n in d.findall("gml:name", ns):
            if "codeSpace" in n.attrib:
                code = (n.text or "").strip()
            else:
                label_de = (n.text or "").strip()
        if code and label_de:
            rows.append((code, label_de))

    return (pd.DataFrame(rows, columns=["function", "label_de"])
              .drop_duplicates("function")
              .sort_values("function")
              .reset_index(drop=True))

df_codes = read_adv_codelist(r"Areas-of-interest-POIs\BuildingFunctionTypeAdV.xml")
df_codes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   function  301 non-null    object
#  1   label_de  301 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB

# %%
len(df_codes['label_de'].unique())
# Out:
# 293

# %%
df_codes['label_de'].value_counts()
# Out:
# label_de
# Sonstiges                                  6
# Schöpfwerk                                 2
# Umformer                                   2
# Nach Quellenlage nicht zu spezifizieren    2
# Wohngebäude                                1
#                                           ..
# Betriebsgebäude zur Seilbahn               1
# Bootshaus                                  1
# Betriebsgebäude zur Schleuse               1
# Dock (Halle)                               1
# Sperrwerk                                  1
# Name: count, Length: 293, dtype: int64

# %%
df_codes.head()
# Out:
#      function      label_de
# 0  31001_1000   Wohngebäude
# 1  31001_1010      Wohnhaus
# 2  31001_1020      Wohnheim
# 3  31001_1021    Kinderheim
# 4  31001_1022  Seniorenheim

# %%
df_codes.to_csv(
    r"Areas-of-interest-POIs\building_function_codelist.csv",
    index=False,
    encoding="utf-8"
)

# %%
# from googletrans import Translator

# df = pd.read_csv(
#     r"Areas-of-interest-POIs\building_function_codelist.csv",
#     encoding="utf-8-sig"
# )

# translator = Translator()

# def translate(text):
#     if pd.isna(text):
#         return text
#     return translator.translate(text, src="de", dest="en").text

# df["label_en"] = df["label_de"].apply(translate)

# df.to_csv(
#     r"Areas-of-interest-POIs\building_function_codelist_de_en.csv",
#     index=False,
#     encoding="utf-8-sig"
# )

# df.head(10)

# %%
df = pd.read_csv(r"Areas-of-interest-POIs\building_function_codelist_de_en.csv")

gdf = gdf.merge(
    df[["function", "label_de", "label_en"]],
    on="function",
    how="left"
)

# %%
gdf.tail()
# Out:
#                                            gml_id  measHeight    function  \
# 668286  UUID_ffd2aeee-9565-4056-a11b-f1ca0383a4a4       6.446  31001_2010
# 668287  UUID_ffde2e68-2cfb-4bd7-9286-15fe43ac31d6       2.519  31001_2000
# 668288  UUID_fff0d051-6f00-47f5-9b68-1f1ac8acdb2f       2.668  31001_2000
# 668289  UUID_fff161eb-9dbe-4910-a18c-92f37ff908a5       3.744  31001_3000
# 668290  UUID_fff34825-8b9c-467c-9d42-486069a7ffbe       8.089  31001_1000
#
#                     Stadt     Strasse HausNr            Name     area_m2  \
# 668286      Goslar, Stadt  Okerstraße     18            None  998.355737
# 668287      Goslar, Stadt        None   None            None   40.276721
# 668288          Wasbüttel        None   None            None   68.497208
# 668289       Peine, Stadt    Bruchweg      4  Kinderparadies  282.841400
# 668290  Salzgitter, Stadt   Im Winkel     10            None  104.378961
#
#           volume_m3  has_poi  _cluster  \
# 668286  6435.401081     True    754723
# 668287   101.457059    False    754724
# 668288   182.750552    False    754734
# 668289  1058.958202     True    754735
# 668290   844.321416    False    754736
#
#                                                  geometry  \
# 668286  MULTIPOLYGON Z (((599398.064 5752424.514 236.4...
# 668287  MULTIPOLYGON Z (((598386.446 5753239.569 262.5...
# 668288  MULTIPOLYGON Z (((608175.333 5808227.048 70.29...
# 668289  MULTIPOLYGON Z (((586364.995 5794470.718 73.74...
# 668290  MULTIPOLYGON Z (((596284.494 5784414.372 95.36...
#
#                                        label_de  \
# 668286  Gebäude für Handel und Dienstleistungen
# 668287      Gebäude für Wirtschaft oder Gewerbe
# 668288      Gebäude für Wirtschaft oder Gewerbe
# 668289           Gebäude für öffentliche Zwecke
# 668290                              Wohngebäude
#
#                                   label_en
# 668286    Buildings for trade and services
# 668287  Buildings for business or commerce
# 668288  Buildings for business or commerce
# 668289       Buildings for public purposes
# 668290               residential buildings

# %%
osm_building_data = gpd.read_file(r"Areas-of-interest-POIs\Buildings-Area-of-study.gpkg")

osm_building_data.head()
# Out:
#      osm_id  code    fclass             name        type  \
# 0  17248750  1500  building  VW Parkhaus FE1     parking
# 1  23621807  1500  building   VW Parkpalette        None
# 2  24030702  1500  building         Halle 73  industrial
# 3  24030779  1500  building             None  industrial
# 4  24030795  1500  building         Halle 74  industrial
#
#                                             geometry
# 0  MULTIPOLYGON (((10.74321 52.43561, 10.74727 52...
# 1  MULTIPOLYGON (((10.74755 52.43733, 10.74825 52...
# 2  MULTIPOLYGON (((10.74496 52.44097, 10.74531 52...
# 3  MULTIPOLYGON (((10.74662 52.43858, 10.74673 52...
# 4  MULTIPOLYGON (((10.74864 52.44009, 10.75003 52...

# %%
osm_building_data.to_crs(gdf.crs, inplace=True)
print(osm_building_data.crs)
# Out:
# EPSG:25832

# %%
import numpy as np

name_col = "name"
type_col = "type"

# keep only features that actually have a name
osm_named = osm_building_data[
    osm_building_data[name_col].notna()
    & (osm_building_data[name_col].astype(str).str.strip() != "")
].copy()

# spatial join: which OSM buildings intersect each gdf polygon
j = gpd.sjoin(
    gdf[["geometry"]].reset_index(names="gdf_idx"),
    osm_named[[name_col, type_col, "geometry"]],
    how="left",
    predicate="intersects"
)

# aggregate names → semicolon-separated string
names = (
    j.groupby("gdf_idx")[name_col]
     .apply(lambda s: ";".join(
         sorted(set(str(x).strip() for x in s.dropna() if str(x).strip()))
     ))
     .replace("", np.nan)
     .rename("osm_names")
)

# aggregate types → semicolon-separated string
types = (
    j.groupby("gdf_idx")[type_col]
     .apply(lambda s: ";".join(
         sorted(set(str(x).strip() for x in s.dropna() if str(x).strip()))
     ))
     .replace("", np.nan)
     .rename("osm_building_type")
)

# attach back to gdf
gdf["osm_names"] = gdf.index.to_series().map(names)
gdf["osm_building_type"] = gdf.index.to_series().map(types)

# %%
gdf[gdf["osm_names"].notna() & gdf["osm_names"].str.contains(";")].head()
# Out:
#                 gml_id  measHeight    function                Stadt  \
# 2268  DENILD0100000SWu       6.150  31001_3024  Braunschweig, Stadt
# 2984  DENILD0100000TK1       4.390  31001_2000  Braunschweig, Stadt
# 3018  DENILD0100000TLc       4.009  31001_1000  Braunschweig, Stadt
# 3071  DENILD0100000TNp       3.838  31001_3000  Braunschweig, Stadt
# 6537  DENILD0100000zD0       7.556  31001_1000  Braunschweig, Stadt
#
#          Strasse HausNr         Name      area_m2     volume_m3  has_poi  \
# 2268        None   None         None  2863.790831  17612.313614    False
# 2984        None   None         None   195.809084    859.601879    False
# 3018        None   None         None    42.367404    169.850923    False
# 3071        None   None  Flugleitung    63.724994    244.576529    False
# 6537  Wendebrück     20         None  7308.626285  55223.980211    False
#
#       _cluster                                           geometry  \
# 2268      2376  MULTIPOLYGON Z (((606380.787 5797190.672 84.26...
# 2984      3168  MULTIPOLYGON Z (((606671.871 5797085.842 84.94...
# 3018      3207  MULTIPOLYGON Z (((606490.993 5794471.601 76.36...
# 3071      3265  MULTIPOLYGON Z (((606314.007 5797390.318 86.06...
# 6537      7006  MULTIPOLYGON Z (((603859.978 5798557.671 68.97...
#
#                                  label_de                            label_en  \
# 2268                   Forschungsinstitut                  Research institute
# 2984  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 3018                          Wohngebäude               residential buildings
# 3071       Gebäude für öffentliche Zwecke       Buildings for public purposes
# 6537                          Wohngebäude               residential buildings
#
#                                               osm_names osm_building_type
# 2268  118 - Institut für Faserverbundleichtbau und A...               NaN
# 2984  122 - Institut für Softwaretechnologie;Institu...            office
# 3018    Ambulante Pflege Wilhelminum;Tagespflege Querum               NaN
# 3071  Flughafen Braunschweig-Wolfsburg;Terminal Gate...               NaN
# 6537                                  Kartcity;You Jump               NaN

# %%
osm_landuse_data = gpd.read_file(r"Areas-of-interest-POIs\Land-use_Area-of-study.gpkg")

osm_landuse_data.head()
# Out:
#      osm_id  code       fclass  name  \
# 0  15036412  7201       forest  None
# 1  24031436  7207   allotments  None
# 2  24975881  7218        grass  None
# 3  24975929  7218        grass  None
# 4  25021140  7203  residential  None
#
#                                             geometry
# 0  MULTIPOLYGON (((10.77893 52.45542, 10.77913 52...
# 1  MULTIPOLYGON (((10.73406 52.42662, 10.73491 52...
# 2  MULTIPOLYGON (((10.79298 52.43343, 10.79513 52...
# 3  MULTIPOLYGON (((10.79383 52.43305, 10.79451 52...
# 4  MULTIPOLYGON (((10.74657 52.42885, 10.74674 52...

# %%
osm_landuse_data['fclass'].value_counts()
# Out:
# fclass
# farmland             13779
# meadow               13014
# forest               10067
# scrub                 8387
# grass                 4723
# residential           3106
# farmyard              1092
# industrial             927
# park                   739
# commercial             716
# allotments             656
# cemetery               473
# retail                 203
# heath                  199
# quarry                 197
# recreation_ground      147
# orchard                133
# nature_reserve         109
# vineyard                 9
# military                 4
# Name: count, dtype: int64

# %%
osm_landuse_data['name'].value_counts()
# Out:
# name
# Friedhof                            21
# Pfingstanger                        15
# Pferdekoppel                        15
# Festplatz                           11
# Steinkamp                           10
#                                     ..
# Rinderwiese                          1
# Haferbergwiesen                      1
# PHÖNIX-Seniorenzentrum Eichenhof     1
# Gewerbegebiet Rohrwiesen             1
# Seeliger Park                        1
# Name: count, Length: 3388, dtype: int64

# %%
landuse = osm_landuse_data.to_crs(gdf.crs)

# spatial join
j = gpd.sjoin(
    gdf[["geometry"]].reset_index(names="gdf_idx"),
    landuse[["fclass", "name", "geometry"]],
    how="left",
    predicate="intersects"
)

# aggregate landuse class → semicolon-separated string
class_lu = (
    j.groupby("gdf_idx")["fclass"]
     .apply(lambda s: ";".join(
         sorted(set(x for x in s.dropna()))
     ))
     .replace("", np.nan)
)

# aggregate landuse name → semicolon-separated string
name_lu = (
    j.groupby("gdf_idx")["name"]
     .apply(lambda s: ";".join(
         sorted(set(str(x).strip() for x in s.dropna() if str(x).strip()))
     ))
     .replace("", np.nan)
)

# attach to gdf (NaN means no landuse intersected)
gdf["osm_landuse_class"] = gdf.index.to_series().map(class_lu)
gdf["osm_landuse_name"]  = gdf.index.to_series().map(name_lu)

# %%
gdf[gdf["osm_landuse_class"].notna() & gdf["osm_landuse_name"].str.contains(";")].head()
# Out:
#                 gml_id  measHeight    function                Stadt Strasse  \
# 8486  DENILD0100001T9S       2.724  31001_2000  Braunschweig, Stadt    None
# 8647  DENILD0100001TEn       2.847  31001_2000  Braunschweig, Stadt    None
# 8776  DENILD0100001TJD       2.582  31001_2500  Braunschweig, Stadt    None
# 9236  DENILD0100001TZe       3.108  31001_2000  Braunschweig, Stadt    None
# 9367  DENILD0100001TeN       2.754  31001_2000  Braunschweig, Stadt    None
#
#      HausNr  Name    area_m2   volume_m3  has_poi  _cluster  \
# 8486   None  None  46.105128  125.590369    False      9067
# 8647   None  None  28.204322   80.297706    False      9228
# 8776   None  None  22.348812   57.704633    False      9360
# 9236   None  None  39.320126  122.206952    False      9835
# 9367   None  None  34.492380   94.992015    False      9974
#
#                                                geometry  \
# 8486  MULTIPOLYGON Z (((598300.795 5794266.086 83.56...
# 8647  MULTIPOLYGON Z (((597944.746 5794187.166 83.45...
# 8776  MULTIPOLYGON Z (((597486.217 5795395.603 80.86...
# 9236  MULTIPOLYGON Z (((597282.718 5794724.883 78.31...
# 9367  MULTIPOLYGON Z (((597378.85 5795392.655 81.11,...
#
#                                  label_de                            label_en  \
# 8486  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 8647  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 8776               Gebäude zur Versorgung                Buildings for supply
# 9236  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 9367  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
#
#      osm_names osm_building_type  osm_landuse_class  \
# 8486       NaN               NaN  commercial;forest
# 8647       NaN               NaN  commercial;forest
# 8776       NaN               NaN  commercial;forest
# 9236       NaN               NaN  commercial;forest
# 9367       NaN               NaN  commercial;forest
#
#                                        osm_landuse_name
# 8486  Johann Heinrich von Thünen-Institut, Julius Kü...
# 8647  Johann Heinrich von Thünen-Institut, Julius Kü...
# 8776  Johann Heinrich von Thünen-Institut, Julius Kü...
# 9236  Johann Heinrich von Thünen-Institut, Julius Kü...
# 9367  Johann Heinrich von Thünen-Institut, Julius Kü...

# %%
df_map = pd.read_excel(
    r"Areas-of-interest-POIs\alkis_building_activity_map.xlsx"
)

gdf = gdf.merge(
    df_map,
    left_on="function",
    right_on="gfk_code",
    how="left"
).drop(columns=["gfk_code"])

# %%
gdf.head()
# Out:
#              gml_id  measHeight    function                Stadt  \
# 0  DENILD01000000Fg       3.500  51002_1250  Braunschweig, Stadt
# 1  DENILD01000000Fh       3.500  51002_1250  Braunschweig, Stadt
# 2  DENILD01000002A1       4.377  31001_2000  Braunschweig, Stadt
# 3  DENILD01000002A3       5.155  31001_2000  Braunschweig, Stadt
# 4  DENILD01000002A4       2.746  31001_2000  Braunschweig, Stadt
#
#         Strasse HausNr  Name     area_m2    volume_m3  has_poi  ...  \
# 0          None   None  None    3.997289    13.990511    False  ...
# 1          None   None  None    3.997593    13.991576    False  ...
# 2      Ackerweg      2  None  212.799509   931.423451    False  ...
# 3  Stieglitzweg      3  None  247.435021  1275.527533    False  ...
# 4          None   None  None   83.722687   229.902499    False  ...
#
#                                             geometry  \
# 0  MULTIPOLYGON Z (((608736.257 5799617.417 95.25...
# 1  MULTIPOLYGON Z (((608534.443 5799829.37 94.225...
# 2  MULTIPOLYGON Z (((609554.181 5797264.172 78.94...
# 3  MULTIPOLYGON Z (((608098.849 5796746.146 83.91...
# 4  MULTIPOLYGON Z (((608926.355 5797165.768 84.6,...
#
#                               label_de                            label_en  \
# 0                                 Mast                                mast
# 1                                 Mast                                mast
# 2  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 3  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 4  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
#
#   osm_names osm_building_type osm_landuse_class osm_landuse_name  \
# 0       NaN               NaN          farmland              NaN
# 1       NaN               NaN          farmland              NaN
# 2       NaN               NaN       residential              NaN
# 3       NaN               NaN       residential              NaN
# 4       NaN               NaN       residential              NaN
#
#                                        gfk_class  \
# 0  Bauwerk oder Anlage für Industrie und Gewerbe
# 1  Bauwerk oder Anlage für Industrie und Gewerbe
# 2                                        Gebäude
# 3                                        Gebäude
# 4                                        Gebäude
#
#                               gfk_name     activities
# 0                                 Mast           work
# 1                                 Mast           work
# 2  Gebäude für Wirtschaft oder Gewerbe  work;business
# 3  Gebäude für Wirtschaft oder Gewerbe  work;business
# 4  Gebäude für Wirtschaft oder Gewerbe  work;business
#
# [5 rows x 21 columns]

# %%
residencial_ALKIS = gpd.read_file('Areas-of-interest-POIs/Residencial-Landuse_ALKIS.gpkg')
print(residencial_ALKIS.crs)
residencial_ALKIS.head()
# Out:
# EPSG:25832
#                uuid               beginnt  \
# 0  DENIN00100003YDF  2023-08-30T08:41:55Z
# 1  DENIN00100003YDG  2021-05-10T10:19:25Z
# 2  DENIN00100003YDH  2011-03-17T18:07:36Z
# 3  DENIN00100004a5f  2011-03-17T18:16:07Z
# 4  DENIN0010000d82P  2023-08-21T12:10:40Z
#
#                                               anlass  name zeitlichkeit  \
# 0  https://registry.gdi-de.org/codelist/de.adv-on...  None         1000
# 1  https://registry.gdi-de.org/codelist/de.adv-on...  None         1000
# 2  https://registry.gdi-de.org/codelist/de.adv-on...  None         1000
# 3  https://registry.gdi-de.org/codelist/de.adv-on...  None         1000
# 4  https://registry.gdi-de.org/codelist/de.adv-on...  None         1000
#
#   zustand datumderletztenueberpruefung istweiterenutzung  \
# 0    None         2023-11-16T08:25:16Z              None
# 1    None         2023-11-16T08:25:16Z              None
# 2    None         2023-11-16T08:25:16Z              None
# 3    None         2023-11-16T08:25:16Z              None
# 4    None         2023-11-16T08:25:16Z              None
#
#   ergebnisderueberpruefung  mappingannahme     quellobjektid  \
# 0                     2000             1.0  DENIAL0100003YDF
# 1                     2000             1.0  DENIAL0100003YDG
# 2                     2000             1.0  DENIAL0100003YDH
# 3                     2000             1.0  DENIAL0100004a5f
# 4                     2000             1.0  DENIAL010000d82P
#
#                                             geometry
# 0  MULTIPOLYGON (((602885.02 5784212.258, 602886....
# 1  MULTIPOLYGON (((602954.327 5784791.11, 602956....
# 2  MULTIPOLYGON (((603169.893 5784970.22, 603170....
# 3  MULTIPOLYGON (((604680.913 5784691.206, 604681...
# 4  MULTIPOLYGON (((603700.035 5784780.643, 603701...

# %%
residencial_ALKIS.columns
# Out:
# Index(['uuid', 'beginnt', 'anlass', 'name', 'zeitlichkeit', 'zustand',
#        'datumderletztenueberpruefung', 'istweiterenutzung',
#        'ergebnisderueberpruefung', 'mappingannahme', 'quellobjektid',
#        'geometry'],
#       dtype='object')

# %%
residential = residencial_ALKIS[["geometry"]].to_crs(gdf.crs)

j = gpd.sjoin(
    gdf[["geometry"]].reset_index(names="gdf_idx"),
    residential,
    how="inner",          # only matched buildings appear here
    predicate="intersects"  # or "within"
)

# Matched building indices
res_idx = j["gdf_idx"].unique()

# Create/ensure column is string-capable (object dtype) with NaN default
if "ALKIS_Landuse_info" not in gdf.columns:
    gdf["ALKIS_Landuse_info"] = pd.Series(index=gdf.index, dtype="object")
else:
    gdf["ALKIS_Landuse_info"] = gdf["ALKIS_Landuse_info"].astype("object")

# Assign only matching buildings
gdf.loc[res_idx, "ALKIS_Landuse_info"] = "residence"

# %%
gdf.head()
# Out:
#              gml_id  measHeight    function                Stadt  \
# 0  DENILD01000000Fg       3.500  51002_1250  Braunschweig, Stadt
# 1  DENILD01000000Fh       3.500  51002_1250  Braunschweig, Stadt
# 2  DENILD01000002A1       4.377  31001_2000  Braunschweig, Stadt
# 3  DENILD01000002A3       5.155  31001_2000  Braunschweig, Stadt
# 4  DENILD01000002A4       2.746  31001_2000  Braunschweig, Stadt
#
#         Strasse HausNr  Name     area_m2    volume_m3  has_poi  ...  \
# 0          None   None  None    3.997289    13.990511    False  ...
# 1          None   None  None    3.997593    13.991576    False  ...
# 2      Ackerweg      2  None  212.799509   931.423451    False  ...
# 3  Stieglitzweg      3  None  247.435021  1275.527533    False  ...
# 4          None   None  None   83.722687   229.902499    False  ...
#
#                               label_de                            label_en  \
# 0                                 Mast                                mast
# 1                                 Mast                                mast
# 2  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 3  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 4  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
#
#   osm_names osm_building_type osm_landuse_class osm_landuse_name  \
# 0       NaN               NaN          farmland              NaN
# 1       NaN               NaN          farmland              NaN
# 2       NaN               NaN       residential              NaN
# 3       NaN               NaN       residential              NaN
# 4       NaN               NaN       residential              NaN
#
#                                        gfk_class  \
# 0  Bauwerk oder Anlage für Industrie und Gewerbe
# 1  Bauwerk oder Anlage für Industrie und Gewerbe
# 2                                        Gebäude
# 3                                        Gebäude
# 4                                        Gebäude
#
#                               gfk_name     activities ALKIS_Landuse_info
# 0                                 Mast           work                NaN
# 1                                 Mast           work                NaN
# 2  Gebäude für Wirtschaft oder Gewerbe  work;business                NaN
# 3  Gebäude für Wirtschaft oder Gewerbe  work;business                NaN
# 4  Gebäude für Wirtschaft oder Gewerbe  work;business          residence
#
# [5 rows x 22 columns]

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 668291 entries, 0 to 668290
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   gml_id              668291 non-null  object
#  1   measHeight          668291 non-null  float64
#  2   function            668291 non-null  object
#  3   Stadt               668291 non-null  object
#  4   Strasse             252239 non-null  object
#  5   HausNr              252239 non-null  object
#  6   Name                6851 non-null    object
#  7   area_m2             668291 non-null  float64
#  8   volume_m3           668291 non-null  float64
#  9   has_poi             668291 non-null  bool
#  10  _cluster            668291 non-null  int64
#  11  geometry            668291 non-null  geometry
#  12  label_de            668291 non-null  object
#  13  label_en            668291 non-null  object
#  14  osm_names           19909 non-null   object
#  15  osm_building_type   9602 non-null    object
#  16  osm_landuse_class   648853 non-null  object
#  17  osm_landuse_name    58429 non-null   object
#  18  gfk_class           668291 non-null  object
#  19  gfk_name            668291 non-null  object
#  20  activities          668291 non-null  object
#  21  ALKIS_Landuse_info  569714 non-null  object
# dtypes: bool(1), float64(3), geometry(1), int64(1), object(16)
# memory usage: 107.7+ MB

# %%
gdf['ALKIS_Landuse_info'].value_counts(dropna=False)
# Out:
# ALKIS_Landuse_info
# residence    569714
# NaN           98577
# Name: count, dtype: int64

# %%
commercial_ALKIS = gpd.read_file('Areas-of-interest-POIs/Commercial_Landuse_ALKIS.gpkg')
print(commercial_ALKIS.crs)
commercial_ALKIS.head()
# Out:
# EPSG:25832
#                uuid               beginnt  \
# 0  DENIN00100003XZK  2021-05-10T10:19:25Z
# 1  DENIN00100003XZM  2019-10-01T10:24:48Z
# 2  DENIN00100003XZO  2017-04-24T12:53:16Z
# 3  DENIN00100003XZR  2011-03-17T18:07:36Z
# 4  DENIN00100003XZS  2022-12-16T11:41:10Z
#
#                                               anlass  name   art zustand  \
# 0  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
# 1  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
# 2  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
# 3  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
# 4  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
#
#   datumderletztenueberpruefung istweiterenutzung ergebnisderueberpruefung  \
# 0         2023-11-16T08:25:16Z              None                     2000
# 1         2023-11-16T08:25:16Z              None                     2000
# 2         2023-11-16T08:25:16Z              None                     2000
# 3         2023-11-16T08:25:16Z              None                     2000
# 4         2023-11-16T08:25:16Z              None                     2000
#
#    mappingannahme     quellobjektid  \
# 0             NaN  DENIAL0100003XZK
# 1             NaN  DENIAL0100003XZM
# 2             NaN  DENIAL0100003XZO
# 3             NaN  DENIAL0100003XZR
# 4             NaN  DENIAL0100003XZS
#
#                                             geometry
# 0  MULTIPOLYGON (((602948.607 5784530.281, 602949...
# 1  MULTIPOLYGON (((603075.842 5784864.969, 603076...
# 2  MULTIPOLYGON (((603019.189 5784870.042, 603019...
# 3  MULTIPOLYGON (((602877.899 5784936.868, 602893...
# 4  MULTIPOLYGON (((601930.05 5784504.429, 601944....

# %%
import pandas as pd
import geopandas as gpd

commercial = commercial_ALKIS[["geometry"]].to_crs(gdf.crs)

j_com = gpd.sjoin(
    gdf[["geometry"]].reset_index(names="gdf_idx"),
    commercial,
    how="inner",
    predicate="intersects"   # or "within"
)

com_idx = j_com["gdf_idx"].unique()

# ensure string-capable dtype (prevents pandas dtype warnings)
gdf["ALKIS_Landuse_info"] = gdf["ALKIS_Landuse_info"].astype("object")

# rows that are commercial
m = gdf.index.isin(com_idx)

# helper: add tag to a ';' separated string (no duplicates)
def add_tag(existing, tag="commercial"):
    if pd.isna(existing):
        return tag
    tags = [t.strip() for t in str(existing).split(";") if t.strip()]
    if tag not in tags:
        tags.append(tag)
    return ";".join(tags)

# apply ONLY to commercial buildings
gdf.loc[m, "ALKIS_Landuse_info"] = gdf.loc[m, "ALKIS_Landuse_info"].apply(add_tag)

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 668291 entries, 0 to 668290
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   gml_id              668291 non-null  object
#  1   measHeight          668291 non-null  float64
#  2   function            668291 non-null  object
#  3   Stadt               668291 non-null  object
#  4   Strasse             252239 non-null  object
#  5   HausNr              252239 non-null  object
#  6   Name                6851 non-null    object
#  7   area_m2             668291 non-null  float64
#  8   volume_m3           668291 non-null  float64
#  9   has_poi             668291 non-null  bool
#  10  _cluster            668291 non-null  int64
#  11  geometry            668291 non-null  geometry
#  12  label_de            668291 non-null  object
#  13  label_en            668291 non-null  object
#  14  osm_names           19909 non-null   object
#  15  osm_building_type   9602 non-null    object
#  16  osm_landuse_class   648853 non-null  object
#  17  osm_landuse_name    58429 non-null   object
#  18  gfk_class           668291 non-null  object
#  19  gfk_name            668291 non-null  object
#  20  activities          668291 non-null  object
#  21  ALKIS_Landuse_info  598544 non-null  object
# dtypes: bool(1), float64(3), geometry(1), int64(1), object(16)
# memory usage: 107.7+ MB

# %%
gdf['ALKIS_Landuse_info'].value_counts(dropna=False)
# Out:
# ALKIS_Landuse_info
# residence               559453
# NaN                      69747
# commercial               28830
# residence;commercial     10261
# Name: count, dtype: int64

# %%
industries_ALKIS = gpd.read_file('Areas-of-interest-POIs/Industries_Landuse_ALKIS.gpkg')
print(industries_ALKIS.crs)
industries_ALKIS.head()
# Out:
# EPSG:25832
#                uuid               beginnt  \
# 0  DENIN001000032GL  2011-03-17T17:27:38Z
# 1  DENIN0010000b7Br  2013-01-30T10:01:47Z
# 2  DENIN00100002bNR  2015-10-29T13:32:52Z
# 3  DENIN00100002bO3  2011-03-17T16:54:43Z
# 4  DENIN00100002bOm  2011-03-17T16:54:43Z
#
#                                               anlass  name   art zustand  \
# 0  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
# 1  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
# 2  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
# 3  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
# 4  https://registry.gdi-de.org/codelist/de.adv-on...  None  None    None
#
#   datumderletztenueberpruefung istweiterenutzung ergebnisderueberpruefung  \
# 0         2023-11-16T08:25:16Z              None                     2000
# 1         2023-11-16T08:25:16Z              None                     2000
# 2         2023-11-16T08:25:16Z              None                     2000
# 3         2023-11-16T08:25:16Z              None                     2000
# 4         2023-11-16T08:25:16Z              None                     2000
#
#    mappingannahme     quellobjektid  \
# 0             NaN  DENIAL01000032GL
# 1             NaN  DENIAL010000b7Br
# 2             NaN  DENIAL0100002bNR
# 3             NaN  DENIAL0100002bO3
# 4             NaN  DENIAL0100002bOm
#
#                                             geometry
# 0  MULTIPOLYGON (((599196.486 5788350.533, 599198...
# 1  MULTIPOLYGON (((599324.138 5788529.055, 599333...
# 2  MULTIPOLYGON (((598573.553 5791958.433, 598591...
# 3  MULTIPOLYGON (((598178.35 5791936.246, 598197....
# 4  MULTIPOLYGON (((598476.522 5791959.534, 598478...

# %%
industries = industries_ALKIS[["geometry"]].to_crs(gdf.crs)

j_ind = gpd.sjoin(
    gdf[["geometry"]].reset_index(names="gdf_idx"),
    industries,
    how="inner",
    predicate="intersects"   # or "within"
)

ind_idx = j_ind["gdf_idx"].unique()

# ensure string-capable dtype
gdf["ALKIS_Landuse_info"] = gdf["ALKIS_Landuse_info"].astype("object")

# rows that are industrial
m = gdf.index.isin(ind_idx)

# helper: add tag to a ';' separated string (no duplicates)
def add_tag(existing, tag="industrial"):
    if pd.isna(existing):
        return tag
    tags = [t.strip() for t in str(existing).split(";") if t.strip()]
    if tag not in tags:
        tags.append(tag)
    return ";".join(tags)

# apply ONLY to industrial buildings
gdf.loc[m, "ALKIS_Landuse_info"] = gdf.loc[m, "ALKIS_Landuse_info"].apply(add_tag)

# %%
gdf['ALKIS_Landuse_info'].value_counts(dropna=False)
# Out:
# ALKIS_Landuse_info
# residence                          556214
# NaN                                 50874
# commercial                          28182
# industrial                          18873
# residence;commercial                 9983
# residence;industrial                 3239
# commercial;industrial                 648
# residence;commercial;industrial       278
# Name: count, dtype: int64

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 668291 entries, 0 to 668290
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   gml_id              668291 non-null  object
#  1   measHeight          668291 non-null  float64
#  2   function            668291 non-null  object
#  3   Stadt               668291 non-null  object
#  4   Strasse             252239 non-null  object
#  5   HausNr              252239 non-null  object
#  6   Name                6851 non-null    object
#  7   area_m2             668291 non-null  float64
#  8   volume_m3           668291 non-null  float64
#  9   has_poi             668291 non-null  bool
#  10  _cluster            668291 non-null  int64
#  11  geometry            668291 non-null  geometry
#  12  label_de            668291 non-null  object
#  13  label_en            668291 non-null  object
#  14  osm_names           19909 non-null   object
#  15  osm_building_type   9602 non-null    object
#  16  osm_landuse_class   648853 non-null  object
#  17  osm_landuse_name    58429 non-null   object
#  18  gfk_class           668291 non-null  object
#  19  gfk_name            668291 non-null  object
#  20  activities          668291 non-null  object
#  21  ALKIS_Landuse_info  617417 non-null  object
# dtypes: bool(1), float64(3), geometry(1), int64(1), object(16)
# memory usage: 107.7+ MB

# %%
public_office_ALKIS = gpd.read_file('Areas-of-interest-POIs/Public-office_Landuse_ALKIS.gpkg')
print(public_office_ALKIS.crs)
public_office_ALKIS.head()
# Out:
# EPSG:25832
#                uuid               beginnt  \
# 0  DENIN00100003XPH  2015-10-12T13:27:25Z
# 1  DENIN0010000e64Z  2016-06-30T07:16:09Z
# 2  DENIN0010000hVIV  2021-05-10T11:50:38Z
# 3  DENIN0010000hVIW  2021-05-10T10:19:25Z
# 4  DENIN0010000hVnk  2020-03-05T11:26:10Z
#
#                                               anlass  name funktion zustand  \
# 0  https://registry.gdi-de.org/codelist/de.adv-on...  None     1140    None
# 1  https://registry.gdi-de.org/codelist/de.adv-on...  None     1170    None
# 2  https://registry.gdi-de.org/codelist/de.adv-on...  None     1120    None
# 3  https://registry.gdi-de.org/codelist/de.adv-on...  None     1160    None
# 4  https://registry.gdi-de.org/codelist/de.adv-on...  None     1170    None
#
#   datumderletztenueberpruefung istweiterenutzung ergebnisderueberpruefung  \
# 0         2023-11-16T08:25:16Z              None                     2000
# 1         2023-11-16T08:25:16Z              None                     2000
# 2         2023-11-16T08:25:16Z              None                     2000
# 3         2023-11-16T08:25:16Z              None                     2000
# 4         2023-11-16T08:25:16Z              None                     2000
#
#    mappingannahme     quellobjektid  \
# 0             NaN  DENIAL0100003XPH
# 1             NaN  DENIAL010000e64Z
# 2             NaN  DENIAL010000hVIV
# 3             NaN  DENIAL010000hVIW
# 4             NaN  DENIAL010000hVnk
#
#                                             geometry
# 0  MULTIPOLYGON (((603103.462 5784859.466, 603103...
# 1  MULTIPOLYGON (((602986.954 5784872.434, 602988...
# 2  MULTIPOLYGON (((602847.447 5784759.944, 602847...
# 3  MULTIPOLYGON (((602783.376 5784755.872, 602786...
# 4  MULTIPOLYGON (((603100.846 5784933.422, 603102...

# %%
public_office = public_office_ALKIS[["geometry"]].to_crs(gdf.crs)

j_pub = gpd.sjoin(
    gdf[["geometry"]].reset_index(names="gdf_idx"),
    public_office,
    how="inner",
    predicate="intersects"   # or "within"
)

pub_idx = j_pub["gdf_idx"].unique()

# ensure string-capable dtype
gdf["ALKIS_Landuse_info"] = gdf["ALKIS_Landuse_info"].astype("object")

# rows that intersect public office polygons
m = gdf.index.isin(pub_idx)

# helper: add tag safely to ';'-separated string
def add_tag(existing, tag="public_office"):
    if pd.isna(existing):
        return tag
    tags = [t.strip() for t in str(existing).split(";") if t.strip()]
    if tag not in tags:
        tags.append(tag)
    return ";".join(tags)

# apply ONLY to public-office buildings
gdf.loc[m, "ALKIS_Landuse_info"] = gdf.loc[m, "ALKIS_Landuse_info"].apply(add_tag)

# %%
gdf['ALKIS_Landuse_info'].value_counts(dropna=False)
# Out:
# ALKIS_Landuse_info
# residence                                        554187
# NaN                                               36709
# commercial                                        27759
# industrial                                        18784
# public_office                                     14165
# residence;commercial                               9802
# residence;industrial                               3212
# residence;public_office                            2027
# commercial;industrial                               639
# commercial;public_office                            423
# residence;commercial;industrial                     273
# residence;commercial;public_office                  181
# industrial;public_office                             89
# residence;industrial;public_office                   27
# commercial;industrial;public_office                   9
# residence;commercial;industrial;public_office         5
# Name: count, dtype: int64

# %%
sport_ALKIS = gpd.read_file('Areas-of-interest-POIs/Sports-area_Landuse_ALKIS.gpkg')
print(sport_ALKIS.crs)
sport_ALKIS.head()
# Out:
# EPSG:25832
#                uuid               beginnt  \
# 0  DENIN1030000p0H0  2023-07-10T10:25:54Z
# 1  DENIN1030000nId9  2018-07-23T14:00:32Z
# 2  DENIN1030000pPkI  2017-06-15T14:13:49Z
# 3  DENIN1030000mSCG  2014-09-26T06:54:07Z
# 4  DENIN1030000lKHF  2014-01-16T09:09:51Z
#
#                                               anlass                name  \
# 0  https://registry.gdi-de.org/codelist/de.adv-on...  Bogen-Schießanlage
# 1  https://registry.gdi-de.org/codelist/de.adv-on...                None
# 2  https://registry.gdi-de.org/codelist/de.adv-on...                None
# 3  https://registry.gdi-de.org/codelist/de.adv-on...            Biathlon
# 4  https://registry.gdi-de.org/codelist/de.adv-on...                None
#
#   sportart datumderletztenueberpruefung istweiterenutzung  \
# 0     1130                         None              1000
# 1     1130                         None              1000
# 2     1130                         None              1000
# 3     1130                         None              1000
# 4     1130                         None              1000
#
#   ergebnisderueberpruefung  mappingannahme     quellobjektid  \
# 0                     2000             NaN  DENIAL030000p0H0
# 1                     2000             NaN  DENIAL030000nId9
# 2                     2000             NaN  DENIAL030000pPkI
# 3                     2000             NaN  DENIAL030000mSCG
# 4                     2000             NaN  DENIAL030000lKHF
#
#                                             geometry
# 0  MULTIPOLYGON (((615036.216 5726440.935, 615100...
# 1  MULTIPOLYGON (((614767.233 5725379.495, 614771...
# 2  MULTIPOLYGON (((604703.136 5730351.154, 604705...
# 3  MULTIPOLYGON (((604080.892 5735481.424, 604111...
# 4  MULTIPOLYGON (((611086.773 5730754.505, 611095...

# %%
sport = sport_ALKIS[["geometry"]].to_crs(gdf.crs)

j_sport = gpd.sjoin(
    gdf[["geometry"]].reset_index(names="gdf_idx"),
    sport,
    how="inner",
    predicate="intersects"   # or "within"
)

sport_idx = j_sport["gdf_idx"].unique()

# ensure string-capable dtype
gdf["ALKIS_Landuse_info"] = gdf["ALKIS_Landuse_info"].astype("object")

# rows that intersect sport polygons
m = gdf.index.isin(sport_idx)

# helper: add tag safely to ';'-separated string
def add_tag(existing, tag="sport"):
    if pd.isna(existing):
        return tag
    tags = [t.strip() for t in str(existing).split(";") if t.strip()]
    if tag not in tags:
        tags.append(tag)
    return ";".join(tags)

# apply ONLY to sport buildings
gdf.loc[m, "ALKIS_Landuse_info"] = gdf.loc[m, "ALKIS_Landuse_info"].apply(add_tag)

# %%
gdf['ALKIS_Landuse_info'].value_counts(dropna=False)
# Out:
# ALKIS_Landuse_info
# residence                                        554045
# NaN                                               35459
# commercial                                        27730
# industrial                                        18777
# public_office                                     14116
# residence;commercial                               9796
# residence;industrial                               3211
# residence;public_office                            2021
# sport                                              1250
# commercial;industrial                               639
# commercial;public_office                            423
# residence;commercial;industrial                     273
# residence;commercial;public_office                  181
# residence;sport                                     142
# industrial;public_office                             89
# public_office;sport                                  49
# commercial;sport                                     29
# residence;industrial;public_office                   27
# commercial;industrial;public_office                   9
# industrial;sport                                      7
# residence;public_office;sport                         6
# residence;commercial;sport                            6
# residence;commercial;industrial;public_office         5
# residence;industrial;sport                            1
# Name: count, dtype: int64

# %%
gdf[gdf['ALKIS_Landuse_info'].isna()].head()
# Out:
#               gml_id  measHeight    function                Stadt Strasse  \
# 0   DENILD01000000Fg       3.500  51002_1250  Braunschweig, Stadt    None
# 1   DENILD01000000Fh       3.500  51002_1250  Braunschweig, Stadt    None
# 14  DENILD01000002AI       2.567  31001_1000  Braunschweig, Stadt    None
# 63  DENILD01000002BX       2.330  31001_1000  Braunschweig, Stadt    None
# 75  DENILD01000002Bt       2.175  31001_1000  Braunschweig, Stadt    None
#
#    HausNr  Name    area_m2  volume_m3  has_poi  ...     label_de  \
# 0    None  None   3.997289  13.990511    False  ...         Mast
# 1    None  None   3.997593  13.991576    False  ...         Mast
# 14   None  None  20.005565  51.354285    False  ...  Wohngebäude
# 63   None  None  15.681107  36.536978    False  ...  Wohngebäude
# 75   None  None  20.867027  45.385784    False  ...  Wohngebäude
#
#                  label_en osm_names osm_building_type osm_landuse_class  \
# 0                    mast       NaN               NaN          farmland
# 1                    mast       NaN               NaN          farmland
# 14  residential buildings       NaN               NaN        allotments
# 63  residential buildings       NaN               NaN        allotments
# 75  residential buildings       NaN               NaN        allotments
#
#     osm_landuse_name                                      gfk_class  \
# 0                NaN  Bauwerk oder Anlage für Industrie und Gewerbe
# 1                NaN  Bauwerk oder Anlage für Industrie und Gewerbe
# 14  KGV Auf dem Klei                                        Gebäude
# 63  KGV Auf dem Klei                                        Gebäude
# 75  KGV Auf dem Klei                                        Gebäude
#
#        gfk_name   activities ALKIS_Landuse_info
# 0          Mast         work                NaN
# 1          Mast         work                NaN
# 14  Wohngebäude  home;meetup                NaN
# 63  Wohngebäude  home;meetup                NaN
# 75  Wohngebäude  home;meetup                NaN
#
# [5 rows x 22 columns]

# %%
# gdf[gdf['ALKIS_Landuse_info'].isna()].to_file('Buildings-with-no-ALKIS-tags-intersect.gpkg')

# %%
gdf = gdf.drop(['_cluster'],axis=1)
gdf.columns
# Out:
# Index(['gml_id', 'measHeight', 'function', 'Stadt', 'Strasse', 'HausNr',
#        'Name', 'area_m2', 'volume_m3', 'has_poi', 'geometry', 'label_de',
#        'label_en', 'osm_names', 'osm_building_type', 'osm_landuse_class',
#        'osm_landuse_name', 'gfk_class', 'gfk_name', 'activities',
#        'ALKIS_Landuse_info'],
#       dtype='object')

# %%
gdf.head()
# Out:
#              gml_id  measHeight    function                Stadt  \
# 0  DENILD01000000Fg       3.500  51002_1250  Braunschweig, Stadt
# 1  DENILD01000000Fh       3.500  51002_1250  Braunschweig, Stadt
# 2  DENILD01000002A1       4.377  31001_2000  Braunschweig, Stadt
# 3  DENILD01000002A3       5.155  31001_2000  Braunschweig, Stadt
# 4  DENILD01000002A4       2.746  31001_2000  Braunschweig, Stadt
#
#         Strasse HausNr  Name     area_m2    volume_m3  has_poi  ...  \
# 0          None   None  None    3.997289    13.990511    False  ...
# 1          None   None  None    3.997593    13.991576    False  ...
# 2      Ackerweg      2  None  212.799509   931.423451    False  ...
# 3  Stieglitzweg      3  None  247.435021  1275.527533    False  ...
# 4          None   None  None   83.722687   229.902499    False  ...
#
#                               label_de                            label_en  \
# 0                                 Mast                                mast
# 1                                 Mast                                mast
# 2  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 3  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
# 4  Gebäude für Wirtschaft oder Gewerbe  Buildings for business or commerce
#
#   osm_names osm_building_type osm_landuse_class osm_landuse_name  \
# 0       NaN               NaN          farmland              NaN
# 1       NaN               NaN          farmland              NaN
# 2       NaN               NaN       residential              NaN
# 3       NaN               NaN       residential              NaN
# 4       NaN               NaN       residential              NaN
#
#                                        gfk_class  \
# 0  Bauwerk oder Anlage für Industrie und Gewerbe
# 1  Bauwerk oder Anlage für Industrie und Gewerbe
# 2                                        Gebäude
# 3                                        Gebäude
# 4                                        Gebäude
#
#                               gfk_name     activities ALKIS_Landuse_info
# 0                                 Mast           work                NaN
# 1                                 Mast           work                NaN
# 2  Gebäude für Wirtschaft oder Gewerbe  work;business         commercial
# 3  Gebäude für Wirtschaft oder Gewerbe  work;business         commercial
# 4  Gebäude für Wirtschaft oder Gewerbe  work;business          residence
#
# [5 rows x 21 columns]

# %%
gdf.to_file('Areas-of-interest-POIs/Enriched-building-volume-data.gpkg')
